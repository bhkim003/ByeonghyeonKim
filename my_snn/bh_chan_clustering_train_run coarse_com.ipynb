# %% [markdown]
# # ssp.train.py

# %%
import torch   
import torch.nn as nn 
import torch.nn.functional as F   
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle
import json
import time

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    coarse_com_mode = True,
    coarse_com_config = (2.0, -2.0), # (max, min)

    sae_l2_norm_bridge = True,
    sae_lif_bridge = False,
    ):
    seed_assign(my_seed)
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    # JSON으로 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'w') as f:
        json.dump(hyperparameters, f, indent=4)
    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset2", summary="max")


    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])


    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'


    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    if coarse_com_mode == True:
        level_num = TIME
        TIME = spike_length
        spike_length = level_num
        level_interval = (coarse_com_config[0] - coarse_com_config[1]) / (level_num-1)  # max - min
        levels = [coarse_com_config[1] + level_interval * i for i in range(level_num)]
        levels = torch.tensor(levels).to(torch.float).to(device)
        levels = levels.repeat(TIME,1) 
        # print('levels', levels, levels.shape) # TIME, level_num

    n_sample = spike_length

    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            net = Autoencoder_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, 4], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            net = SAE_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge)
            net = torch.nn.DataParallel(net)
        else:
            net = SAE_fc_only(encoder_ch=[96, 64, 32, 4], 
                                decoder_ch=[32,64,96,n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마




    wandb.watch(net, log="all", log_freq = 10)





    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__



    net = net.to(device)
    print(net)
    print('Device:',device)

    criterion = nn.MSELoss()
    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0

    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__
    
    for epoch in range(max_epoch):

        ae_train_start_time = time.time()
        running_loss = 0.0
        iter = 0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike = data
            spike = spike.to(device) # batch, time
            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                spike = (spike > levels).to(torch.float) 
                # spike: batch, time, level_num
                # levels: time, level_num
                assert spike.shape[0] == batch_size and spike.shape[1] == TIME and spike.shape[2] == spike_length
            elif 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
            
            spike_class = net(spike)

            # if 'SAE' in net.module.__class__.__name__:
            #     spike = spike.mean(dim=1)# Time 방향으로 평균
            #     spike_class = spike_class.mean(dim=1)# Time 방향으로 평균

            if 'SAE' in net.module.__class__.__name__:
                loss1 = criterion(spike_class[:, :, 5:25], spike[:, :, 5:25])
                loss2 = criterion(spike_class[:, :, 0:5], spike[:, :, 0:5])
                loss3 = criterion(spike_class[:, :, 25:spike_length], spike[:, :, 25:spike_length])
            else:
                loss1 = criterion(spike_class[:, 5:25], spike[:, 5:25])
                loss2 = criterion(spike_class[:, 0:5], spike[:, 0:5])
                loss3 = criterion(spike_class[:, 25:spike_length], spike[:, 25:spike_length])

            loss = loss1 * 2.125 + (loss2 + loss3)/4
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            print(f'\nepoch-{epoch}, running_loss : {running_loss:.5f}, iter percent {iter/len(train_loader)*100:.2f}%')
            iter += 1
        avg_loss = running_loss / len(train_loader)
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')
        print(f"ae train 실행 시간: {time.time()-ae_train_start_time:.3f}초")





        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    

        if(epoch %5 ==0 or epoch == 1 or epoch == max_epoch-1): 
            accuracy_check_start_time = time.time()
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = 4*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else 4

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    spike_torch = torch.from_numpy(spike_template)
                    spike_torch = spike_torch.float().to(device)
                    if coarse_com_mode == True:
                        spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                    elif 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                    inner_inf = net.module.encoder(spike_torch)
                    # if 'SAE' in net.module.__class__.__name__:
                    #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                    #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                    #     print(all_equal, inner_inf)

                    if 'SAE' in net.module.__class__.__name__:
                        if SAE_hidden_nomean == True:
                            inner_inf = inner_inf.reshape(spike_template.shape[0],-1)# time*feature 펼치기
                        else:
                            inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                    Cluster = inner_inf.cpu().detach().numpy()

                encoder_batch = 128
                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    now_index = 0
                    while (1):
                        now_end_index = now_index+encoder_batch if now_index+encoder_batch < len(spike) else len(spike)
                        spike_batch = spike[now_index:now_end_index] 
                        spike_torch = torch.from_numpy(spike_batch)
                        spike_torch = spike_torch.float().to(device)
                        if coarse_com_mode == True:
                            spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        elif 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.reshape(spike_batch.shape[0],-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[now_index:now_end_index] = inner_inf.cpu().detach().numpy()
                        now_index += encoder_batch
                        if (now_index >= len(spike)):
                            break
                    
                spike_id = np.zeros(len(spike))
                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                            tau[q] = tau[q] / denominator

                    # for i in range(num_cluster): # l2 distance
                    #     distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))
                    distance_sm = np.sum(np.power(np.abs(Cluster - spike_hidden[spike_index, :]), 2), axis=1)

                    m = np.argmin(distance_sm)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16
                
                # print('Cluster',Cluster)
                # print('spike_id', spike_id)

                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                perm_start_time = time.time()
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1
                # print(f"perm 실행 시간: {time.time()-perm_start_time:.3f}초")
                
                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                # print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
            print(f"accuracy_check 실행 시간: {time.time()-accuracy_check_start_time:.3f}초")

        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset2": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


        # 저장
        with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
            pickle.dump({
                "loss_history": loss_history,
                "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
            }, f)

# %%
gpu = 5
Conv_net = True
SAE_net = True

# hyperparameter
dataset_num = 16
spike_length = 50
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 1400 #1400 2400 # 그 초기 몇개까지만 cluster update할지


batch_size = 16
max_epoch = 7000
learning_rate = 0.001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 50 # SAE일 때만 유효
v_decay = 0.5 # -cor
v_threshold = 0.25 # -cor
v_reset = 0.0 # -cor # 10000이상 일 시 hard reset
BPTT_on = True # +cor

SAE_hidden_nomean = False # False가 나았다 이상하게.

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'Adam' #'Adam', 'SGD' # 둘다 준수함. loss 줄이는 거는 adam이 좋긴한데, cluster accuracy는 비슷함.

coarse_com_mode = True
coarse_com_config = (2.0, -2.0) # (max, min)

sae_l2_norm_bridge = True
sae_lif_bridge = False

wandb.init(project= f'spike_sorting just run',save_code=False)

cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    current_time = current_time,
    optimizer = optimizer, #'Adam', 'SGD'

    coarse_com_mode = coarse_com_mode,
    coarse_com_config = coarse_com_config, # (max, min)

    
    sae_l2_norm_bridge = sae_l2_norm_bridge,
    sae_lif_bridge = sae_lif_bridge,
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250103_184039-hp1zgiid</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/hp1zgiid' target="_blank">ethereal-lion-158</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/hp1zgiid' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/hp1zgiid</a>
# {'gpu': 5, 'Conv_net': True, 'SAE_net': True, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 1400, 'batch_size': 16, 'max_epoch': 7000, 'learning_rate': 0.001, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 50, 'v_decay': 0.5, 'v_threshold': 0.25, 'v_reset': 0.0, 'BPTT_on': True, 'SAE_hidden_nomean': False, 'current_time': '20250103_184037_826', 'optimizer': 'Adam', 'coarse_com_mode': True, 'coarse_com_config': (2.0, -2.0)}
# DataParallel(
#   (module): SAE_conv1(
#     (encoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_unsuqeeze()
#       (2): SSBH_DimChanger_for_one_two_coupling()
#       (3): Conv1d(1, 32, kernel_size=(3,), stride=(2,), bias=False)
#       (4): SSBH_DimChanger_for_one_two_decoupling()
#       (5): LIF_layer()
#       (6): SSBH_DimChanger_for_one_two_coupling()
#       (7): Conv1d(32, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (8): SSBH_DimChanger_for_one_two_decoupling()
#       (9): LIF_layer()
#       (10): SSBH_DimChanger_for_one_two_coupling()
#       (11): Conv1d(64, 96, kernel_size=(3,), stride=(2,), bias=False)
#       (12): SSBH_DimChanger_for_one_two_decoupling()
#       (13): LIF_layer()
#       (14): SSBH_DimChanger_for_one_two_coupling()
#       (15): SSBH_DimChanger_for_fc()
#       (16): Linear(in_features=480, out_features=4, bias=False)
#       (17): SSBH_L2NormLayer()
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_one_two()
#     )
#     (decoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_one_two_coupling()
#       (2): Linear(in_features=4, out_features=480, bias=False)
#       (3): SSBH_DimChanger_for_one_two_decoupling()
#       (4): LIF_layer()
#       (5): SSBH_DimChanger_for_one_two_coupling()
#       (6): SSBH_DimChanger_for_conv1()
#       (7): SSBH_DimChanger_for_one_two_decoupling()
#       (8): SSBH_DimChanger_for_one_two_coupling()
#       (9): ConvTranspose1d(96, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (10): SSBH_DimChanger_for_one_two_decoupling()
#       (11): LIF_layer()
#       (12): SSBH_DimChanger_for_one_two_coupling()
#       (13): ConvTranspose1d(64, 32, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (14): SSBH_DimChanger_for_one_two_decoupling()
#       (15): LIF_layer()
#       (16): SSBH_DimChanger_for_one_two_coupling()
#       (17): ConvTranspose1d(32, 1, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_for_suqeeze()
#       (20): SSBH_DimChanger_one_two()
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250103_184037_826
#
# epoch-0, running_loss : 5.27263, iter percent 0.00%
#
# epoch-0, running_loss : 8.11388, iter percent 0.04%
#
# epoch-0, running_loss : 10.17617, iter percent 0.08%
#
# epoch-0, running_loss : 12.03779, iter percent 0.12%
#
# epoch-0, running_loss : 14.08612, iter percent 0.17%
#
# epoch-0, running_loss : 15.99246, iter percent 0.21%
#
# epoch-0, running_loss : 17.64063, iter percent 0.25%
#
# epoch-0, running_loss : 19.19853, iter percent 0.29%
#
# epoch-0, running_loss : 20.66084, iter percent 0.33%
#
# epoch-0, running_loss : 22.09196, iter percent 0.38%
#
# epoch-0, running_loss : 23.48945, iter percent 0.42%
#
# epoch-0, running_loss : 24.82694, iter percent 0.46%
#
# epoch-0, running_loss : 26.14925, iter percent 0.50%
#
# epoch-0, running_loss : 27.40027, iter percent 0.54%
#
# epoch-0, running_loss : 28.64892, iter percent 0.58%
#
# epoch-0, running_loss : 29.83934, iter percent 0.62%
#
# epoch-0, running_loss : 30.97486, iter percent 0.67%
#
# epoch-0, running_loss : 32.06961, iter percent 0.71%
#
# epoch-0, running_loss : 33.08083, iter percent 0.75%
#
# epoch-0, running_loss : 34.11422, iter percent 0.79%
#
# epoch-0, running_loss : 35.08614, iter percent 0.83%
#
# epoch-0, running_loss : 36.04653, iter percent 0.88%
#
# epoch-0, running_loss : 36.99796, iter percent 0.92%
#
# epoch-0, running_loss : 37.93916, iter percent 0.96%
#
# epoch-0, running_loss : 38.92774, iter percent 1.00%
#
# epoch-0, running_loss : 39.89204, iter percent 1.04%
#
# epoch-0, running_loss : 40.82741, iter percent 1.08%
#
# epoch-0, running_loss : 41.72845, iter percent 1.12%
#
# epoch-0, running_loss : 42.61967, iter percent 1.17%
#
# epoch-0, running_loss : 43.54377, iter percent 1.21%
#
# epoch-0, running_loss : 44.44442, iter percent 1.25%
#
# epoch-0, running_loss : 45.31727, iter percent 1.29%
#
# epoch-0, running_loss : 46.18926, iter percent 1.33%
#
# epoch-0, running_loss : 47.07171, iter percent 1.38%
#
# epoch-0, running_loss : 47.88894, iter percent 1.42%
#
# epoch-0, running_loss : 48.74964, iter percent 1.46%
#
# epoch-0, running_loss : 49.57973, iter percent 1.50%
#
# epoch-0, running_loss : 50.40045, iter percent 1.54%
#
# epoch-0, running_loss : 51.17709, iter percent 1.58%
#
# epoch-0, running_loss : 51.96565, iter percent 1.62%
#
# epoch-0, running_loss : 52.75537, iter percent 1.67%
#
# epoch-0, running_loss : 53.55819, iter percent 1.71%
#
# epoch-0, running_loss : 54.33419, iter percent 1.75%
#
# epoch-0, running_loss : 55.09546, iter percent 1.79%
#
# epoch-0, running_loss : 55.88352, iter percent 1.83%
#
# epoch-0, running_loss : 56.67134, iter percent 1.88%
#
# epoch-0, running_loss : 57.43399, iter percent 1.92%
#
# epoch-0, running_loss : 58.16192, iter percent 1.96%
#
# epoch-0, running_loss : 58.87292, iter percent 2.00%
#
# epoch-0, running_loss : 59.58022, iter percent 2.04%
#
# epoch-0, running_loss : 60.27937, iter percent 2.08%
#
# epoch-0, running_loss : 60.99246, iter percent 2.12%
#
# epoch-0, running_loss : 61.68733, iter percent 2.17%
#
# epoch-0, running_loss : 62.37855, iter percent 2.21%
#
# epoch-0, running_loss : 63.07334, iter percent 2.25%
#
# epoch-0, running_loss : 63.73774, iter percent 2.29%
#
# epoch-0, running_loss : 64.40999, iter percent 2.33%
#
# epoch-0, running_loss : 65.09041, iter percent 2.38%
#
# epoch-0, running_loss : 65.75664, iter percent 2.42%
#
# epoch-0, running_loss : 66.42736, iter percent 2.46%
#
# epoch-0, running_loss : 67.09502, iter percent 2.50%
#
# epoch-0, running_loss : 67.76572, iter percent 2.54%
#
# epoch-0, running_loss : 68.44831, iter percent 2.58%
#
# epoch-0, running_loss : 69.11419, iter percent 2.62%
#
# epoch-0, running_loss : 69.77454, iter percent 2.67%
#
# epoch-0, running_loss : 70.42093, iter percent 2.71%
#
# epoch-0, running_loss : 71.07320, iter percent 2.75%
#
# epoch-0, running_loss : 71.71157, iter percent 2.79%
#
# epoch-0, running_loss : 72.35840, iter percent 2.83%
#
# epoch-0, running_loss : 73.01541, iter percent 2.88%
#
# epoch-0, running_loss : 73.66753, iter percent 2.92%
#
# epoch-0, running_loss : 74.30098, iter percent 2.96%
#
# epoch-0, running_loss : 74.99069, iter percent 3.00%
#
# epoch-0, running_loss : 75.61814, iter percent 3.04%
#
# epoch-0, running_loss : 76.24212, iter percent 3.08%
#
# epoch-0, running_loss : 76.85657, iter percent 3.12%
#
# epoch-0, running_loss : 77.47926, iter percent 3.17%
#
# epoch-0, running_loss : 78.09658, iter percent 3.21%
#
# epoch-0, running_loss : 78.71404, iter percent 3.25%
#
# epoch-0, running_loss : 79.33883, iter percent 3.29%
#
# epoch-0, running_loss : 79.96775, iter percent 3.33%
#
# epoch-0, running_loss : 80.60465, iter percent 3.38%
#
# epoch-0, running_loss : 81.24066, iter percent 3.42%
#
# epoch-0, running_loss : 81.86635, iter percent 3.46%
#
# epoch-0, running_loss : 82.47869, iter percent 3.50%
#
# epoch-0, running_loss : 83.07960, iter percent 3.54%
#
# epoch-0, running_loss : 83.70495, iter percent 3.58%
#
# epoch-0, running_loss : 84.31247, iter percent 3.62%
#
# epoch-0, running_loss : 84.92485, iter percent 3.67%
#
# epoch-0, running_loss : 85.53562, iter percent 3.71%
#
# epoch-0, running_loss : 86.14960, iter percent 3.75%
#
# epoch-0, running_loss : 86.74755, iter percent 3.79%
#
# epoch-0, running_loss : 87.37686, iter percent 3.83%
#
# epoch-0, running_loss : 87.98953, iter percent 3.88%
#
# epoch-0, running_loss : 88.60732, iter percent 3.92%
#
# epoch-0, running_loss : 89.21601, iter percent 3.96%
#
# epoch-0, running_loss : 89.81847, iter percent 4.00%
#
# epoch-0, running_loss : 90.42345, iter percent 4.04%
#
# epoch-0, running_loss : 91.03144, iter percent 4.08%
#
# epoch-0, running_loss : 91.64644, iter percent 4.12%
#
# epoch-0, running_loss : 92.25051, iter percent 4.17%
#
# epoch-0, running_loss : 92.87467, iter percent 4.21%
#
# epoch-0, running_loss : 93.48798, iter percent 4.25%
#
# epoch-0, running_loss : 94.11503, iter percent 4.29%
#
# epoch-0, running_loss : 94.70213, iter percent 4.33%
#
# epoch-0, running_loss : 95.29992, iter percent 4.38%
#
# epoch-0, running_loss : 95.90665, iter percent 4.42%
#
# epoch-0, running_loss : 96.49374, iter percent 4.46%
#
# epoch-0, running_loss : 97.11122, iter percent 4.50%
#
# epoch-0, running_loss : 97.69510, iter percent 4.54%
#
# epoch-0, running_loss : 98.28501, iter percent 4.58%
#
# epoch-0, running_loss : 98.89145, iter percent 4.62%
#
# epoch-0, running_loss : 99.46932, iter percent 4.67%
#
# epoch-0, running_loss : 100.05079, iter percent 4.71%
#
# epoch-0, running_loss : 100.63862, iter percent 4.75%
#
# epoch-0, running_loss : 101.21926, iter percent 4.79%
#
# epoch-0, running_loss : 101.80799, iter percent 4.83%
#
# epoch-0, running_loss : 102.40504, iter percent 4.88%
#
# epoch-0, running_loss : 103.00037, iter percent 4.92%
#
# epoch-0, running_loss : 103.58443, iter percent 4.96%
#
# epoch-0, running_loss : 104.17179, iter percent 5.00%
#
# epoch-0, running_loss : 104.76149, iter percent 5.04%
#
# epoch-0, running_loss : 105.34521, iter percent 5.08%
#
# epoch-0, running_loss : 105.92017, iter percent 5.12%
#
# epoch-0, running_loss : 106.49308, iter percent 5.17%
#
# epoch-0, running_loss : 107.06484, iter percent 5.21%
#
# epoch-0, running_loss : 107.64039, iter percent 5.25%
#
# epoch-0, running_loss : 108.20676, iter percent 5.29%
#
# epoch-0, running_loss : 108.79701, iter percent 5.33%
#
# epoch-0, running_loss : 109.37548, iter percent 5.38%
#
# epoch-0, running_loss : 109.96443, iter percent 5.42%
#
# epoch-0, running_loss : 110.54481, iter percent 5.46%
#
# epoch-0, running_loss : 111.12216, iter percent 5.50%
#
# epoch-0, running_loss : 111.70653, iter percent 5.54%
#
# epoch-0, running_loss : 112.28581, iter percent 5.58%
#
# epoch-0, running_loss : 112.87118, iter percent 5.62%
#
# epoch-0, running_loss : 113.46414, iter percent 5.67%
#
# epoch-0, running_loss : 114.03948, iter percent 5.71%
#
# epoch-0, running_loss : 114.63479, iter percent 5.75%
#
# epoch-0, running_loss : 115.21947, iter percent 5.79%
#
# epoch-0, running_loss : 115.79558, iter percent 5.83%
#
# epoch-0, running_loss : 116.37145, iter percent 5.88%
#
# epoch-0, running_loss : 116.94562, iter percent 5.92%
#
# epoch-0, running_loss : 117.51830, iter percent 5.96%
#
# epoch-0, running_loss : 118.07713, iter percent 6.00%
#
# epoch-0, running_loss : 118.63843, iter percent 6.04%
#
# epoch-0, running_loss : 119.20587, iter percent 6.08%
#
# epoch-0, running_loss : 119.76706, iter percent 6.12%
#
# epoch-0, running_loss : 120.32735, iter percent 6.17%
#
# epoch-0, running_loss : 120.88996, iter percent 6.21%
#
# epoch-0, running_loss : 121.46087, iter percent 6.25%
#
# epoch-0, running_loss : 122.02344, iter percent 6.29%
#
# epoch-0, running_loss : 122.59352, iter percent 6.33%
#
# epoch-0, running_loss : 123.15503, iter percent 6.38%
#
# epoch-0, running_loss : 123.70370, iter percent 6.42%
#
# epoch-0, running_loss : 124.26893, iter percent 6.46%
#
# epoch-0, running_loss : 124.79630, iter percent 6.50%
#
# epoch-0, running_loss : 125.35331, iter percent 6.54%
#
# epoch-0, running_loss : 125.90293, iter percent 6.58%
#
# epoch-0, running_loss : 126.45219, iter percent 6.62%
#
# epoch-0, running_loss : 127.00248, iter percent 6.67%
#
# epoch-0, running_loss : 127.54685, iter percent 6.71%
#
# epoch-0, running_loss : 128.10194, iter percent 6.75%
#
# epoch-0, running_loss : 128.63476, iter percent 6.79%
#
# epoch-0, running_loss : 129.18661, iter percent 6.83%
#
# epoch-0, running_loss : 129.72806, iter percent 6.88%
#
# epoch-0, running_loss : 130.28263, iter percent 6.92%
#
# epoch-0, running_loss : 130.82173, iter percent 6.96%
#
# epoch-0, running_loss : 131.38065, iter percent 7.00%
#
# epoch-0, running_loss : 131.92496, iter percent 7.04%
#
# epoch-0, running_loss : 132.46417, iter percent 7.08%
#
# epoch-0, running_loss : 133.00991, iter percent 7.12%
#
# epoch-0, running_loss : 133.54485, iter percent 7.17%
#
# epoch-0, running_loss : 134.07216, iter percent 7.21%
#
# epoch-0, running_loss : 134.61810, iter percent 7.25%
#
# epoch-0, running_loss : 135.15913, iter percent 7.29%
#
# epoch-0, running_loss : 135.69332, iter percent 7.33%
#
# epoch-0, running_loss : 136.25228, iter percent 7.38%
#
# epoch-0, running_loss : 136.80771, iter percent 7.42%
#
# epoch-0, running_loss : 137.35736, iter percent 7.46%
#
# epoch-0, running_loss : 137.91976, iter percent 7.50%
#
# epoch-0, running_loss : 138.45943, iter percent 7.54%
#
# epoch-0, running_loss : 139.00988, iter percent 7.58%
#
# epoch-0, running_loss : 139.53635, iter percent 7.62%
#
# epoch-0, running_loss : 140.07104, iter percent 7.67%
#
# epoch-0, running_loss : 140.59991, iter percent 7.71%
#
# epoch-0, running_loss : 141.15038, iter percent 7.75%
#
# epoch-0, running_loss : 141.70633, iter percent 7.79%
#
# epoch-0, running_loss : 142.24372, iter percent 7.83%
#
# epoch-0, running_loss : 142.78052, iter percent 7.88%
#
# epoch-0, running_loss : 143.34254, iter percent 7.92%
#
# epoch-0, running_loss : 143.87989, iter percent 7.96%
#
# epoch-0, running_loss : 144.43297, iter percent 8.00%
#
# epoch-0, running_loss : 144.97123, iter percent 8.04%
#
# epoch-0, running_loss : 145.50377, iter percent 8.08%
#
# epoch-0, running_loss : 146.04130, iter percent 8.12%
#
# epoch-0, running_loss : 146.57911, iter percent 8.17%
#
# epoch-0, running_loss : 147.12073, iter percent 8.21%
#
# epoch-0, running_loss : 147.66503, iter percent 8.25%
#
# epoch-0, running_loss : 148.18978, iter percent 8.29%
#
# epoch-0, running_loss : 148.70892, iter percent 8.33%
#
# epoch-0, running_loss : 149.22516, iter percent 8.38%
#
# epoch-0, running_loss : 149.75504, iter percent 8.42%
#
# epoch-0, running_loss : 150.29250, iter percent 8.46%
#
# epoch-0, running_loss : 150.82966, iter percent 8.50%
#
# epoch-0, running_loss : 151.34388, iter percent 8.54%
#
# epoch-0, running_loss : 151.87261, iter percent 8.58%
#
# epoch-0, running_loss : 152.41670, iter percent 8.62%
#
# epoch-0, running_loss : 152.94849, iter percent 8.67%
#
# epoch-0, running_loss : 153.46909, iter percent 8.71%
#
# epoch-0, running_loss : 153.99811, iter percent 8.75%
#
# epoch-0, running_loss : 154.51702, iter percent 8.79%
#
# epoch-0, running_loss : 155.04778, iter percent 8.83%
#
# epoch-0, running_loss : 155.58387, iter percent 8.88%
#
# epoch-0, running_loss : 156.10490, iter percent 8.92%
#
# epoch-0, running_loss : 156.61394, iter percent 8.96%
#
# epoch-0, running_loss : 157.14879, iter percent 9.00%
#
# epoch-0, running_loss : 157.66033, iter percent 9.04%
#
# epoch-0, running_loss : 158.18343, iter percent 9.08%
#
# epoch-0, running_loss : 158.69307, iter percent 9.12%
#
# epoch-0, running_loss : 159.23102, iter percent 9.17%
#
# epoch-0, running_loss : 159.74415, iter percent 9.21%
#
# epoch-0, running_loss : 160.27016, iter percent 9.25%
#
# epoch-0, running_loss : 160.79046, iter percent 9.29%
#
# epoch-0, running_loss : 161.32333, iter percent 9.33%
#
# epoch-0, running_loss : 161.84537, iter percent 9.38%
#
# epoch-0, running_loss : 162.37417, iter percent 9.42%
#
# epoch-0, running_loss : 162.88877, iter percent 9.46%
#
# epoch-0, running_loss : 163.41260, iter percent 9.50%
#
# epoch-0, running_loss : 163.92711, iter percent 9.54%
#
# epoch-0, running_loss : 164.45034, iter percent 9.58%
#
# epoch-0, running_loss : 164.96925, iter percent 9.62%
#
# epoch-0, running_loss : 165.48240, iter percent 9.67%
#
# epoch-0, running_loss : 165.98598, iter percent 9.71%
#
# epoch-0, running_loss : 166.49268, iter percent 9.75%
#
# epoch-0, running_loss : 166.99389, iter percent 9.79%
#
# epoch-0, running_loss : 167.50455, iter percent 9.83%
#
# epoch-0, running_loss : 168.01832, iter percent 9.88%
#
# epoch-0, running_loss : 168.52545, iter percent 9.92%
#
# epoch-0, running_loss : 169.02870, iter percent 9.96%
#
# epoch-0, running_loss : 169.53204, iter percent 10.00%
#
# epoch-0, running_loss : 170.03874, iter percent 10.04%
#
# epoch-0, running_loss : 170.53766, iter percent 10.08%
#
# epoch-0, running_loss : 171.06094, iter percent 10.12%
#
# epoch-0, running_loss : 171.56692, iter percent 10.17%
#
# epoch-0, running_loss : 172.07136, iter percent 10.21%
#
# epoch-0, running_loss : 172.57523, iter percent 10.25%
#
# epoch-0, running_loss : 173.07625, iter percent 10.29%
#
# epoch-0, running_loss : 173.55815, iter percent 10.33%
#
# epoch-0, running_loss : 174.07408, iter percent 10.38%
#
# epoch-0, running_loss : 174.57647, iter percent 10.42%
#
# epoch-0, running_loss : 175.06581, iter percent 10.46%
#
# epoch-0, running_loss : 175.55317, iter percent 10.50%
#
# epoch-0, running_loss : 176.04295, iter percent 10.54%
#
# epoch-0, running_loss : 176.52164, iter percent 10.58%
#
# epoch-0, running_loss : 177.01053, iter percent 10.62%
#
# epoch-0, running_loss : 177.50698, iter percent 10.67%
#
# epoch-0, running_loss : 178.01504, iter percent 10.71%
#
# epoch-0, running_loss : 178.49797, iter percent 10.75%
#
# epoch-0, running_loss : 179.00198, iter percent 10.79%
#
# epoch-0, running_loss : 179.48430, iter percent 10.83%
#
# epoch-0, running_loss : 179.97760, iter percent 10.88%
#
# epoch-0, running_loss : 180.47477, iter percent 10.92%
#
# epoch-0, running_loss : 180.95761, iter percent 10.96%
#
# epoch-0, running_loss : 181.44558, iter percent 11.00%
#
# epoch-0, running_loss : 181.91340, iter percent 11.04%
#
# epoch-0, running_loss : 182.39583, iter percent 11.08%
#
# epoch-0, running_loss : 182.87256, iter percent 11.12%
#
# epoch-0, running_loss : 183.35550, iter percent 11.17%
#
# epoch-0, running_loss : 183.82458, iter percent 11.21%
#
# epoch-0, running_loss : 184.29324, iter percent 11.25%
#
# epoch-0, running_loss : 184.75727, iter percent 11.29%
#
# epoch-0, running_loss : 185.23322, iter percent 11.33%
#
# epoch-0, running_loss : 185.71998, iter percent 11.38%
#
# epoch-0, running_loss : 186.19109, iter percent 11.42%
#
# epoch-0, running_loss : 186.65882, iter percent 11.46%
#
# epoch-0, running_loss : 187.12351, iter percent 11.50%
#
# epoch-0, running_loss : 187.58167, iter percent 11.54%
#
# epoch-0, running_loss : 188.04259, iter percent 11.58%
#
# epoch-0, running_loss : 188.51548, iter percent 11.62%
#
# epoch-0, running_loss : 188.98104, iter percent 11.67%
#
# epoch-0, running_loss : 189.44548, iter percent 11.71%
#
# epoch-0, running_loss : 189.90643, iter percent 11.75%
#
# epoch-0, running_loss : 190.35941, iter percent 11.79%
#
# epoch-0, running_loss : 190.80474, iter percent 11.83%
#
# epoch-0, running_loss : 191.25045, iter percent 11.88%
#
# epoch-0, running_loss : 191.69452, iter percent 11.92%
#
# epoch-0, running_loss : 192.14465, iter percent 11.96%
#
# epoch-0, running_loss : 192.60931, iter percent 12.00%
#
# epoch-0, running_loss : 193.06515, iter percent 12.04%
#
# epoch-0, running_loss : 193.51839, iter percent 12.08%
#
# epoch-0, running_loss : 193.95622, iter percent 12.12%
#
# epoch-0, running_loss : 194.41499, iter percent 12.17%
#
# epoch-0, running_loss : 194.83794, iter percent 12.21%
#
# epoch-0, running_loss : 195.28197, iter percent 12.25%
#
# epoch-0, running_loss : 195.72742, iter percent 12.29%
#
# epoch-0, running_loss : 196.17898, iter percent 12.33%
#
# epoch-0, running_loss : 196.62692, iter percent 12.38%
#
# epoch-0, running_loss : 197.07483, iter percent 12.42%
#
# epoch-0, running_loss : 197.50398, iter percent 12.46%
#
# epoch-0, running_loss : 197.93876, iter percent 12.50%
#
# epoch-0, running_loss : 198.37145, iter percent 12.54%
#
# epoch-0, running_loss : 198.80194, iter percent 12.58%
#
# epoch-0, running_loss : 199.24176, iter percent 12.62%
#
# epoch-0, running_loss : 199.68378, iter percent 12.67%
#
# epoch-0, running_loss : 200.12266, iter percent 12.71%
#
# epoch-0, running_loss : 200.55265, iter percent 12.75%
#
# epoch-0, running_loss : 200.98615, iter percent 12.79%
#
# epoch-0, running_loss : 201.42093, iter percent 12.83%
#
# epoch-0, running_loss : 201.84151, iter percent 12.88%
#
# epoch-0, running_loss : 202.27996, iter percent 12.92%
#
# epoch-0, running_loss : 202.70310, iter percent 12.96%
#
# epoch-0, running_loss : 203.14304, iter percent 13.00%
#
# epoch-0, running_loss : 203.56257, iter percent 13.04%
#
# epoch-0, running_loss : 203.97797, iter percent 13.08%
#
# epoch-0, running_loss : 204.41173, iter percent 13.12%
#
# epoch-0, running_loss : 204.82484, iter percent 13.17%
#
# epoch-0, running_loss : 205.24898, iter percent 13.21%
#
# epoch-0, running_loss : 205.66291, iter percent 13.25%
#
# epoch-0, running_loss : 206.07444, iter percent 13.29%
#
# epoch-0, running_loss : 206.48911, iter percent 13.33%
#
# epoch-0, running_loss : 206.89331, iter percent 13.38%
#
# epoch-0, running_loss : 207.30190, iter percent 13.42%
#
# epoch-0, running_loss : 207.70847, iter percent 13.46%
#
# epoch-0, running_loss : 208.10619, iter percent 13.50%
#
# epoch-0, running_loss : 208.52213, iter percent 13.54%
#
# epoch-0, running_loss : 208.93217, iter percent 13.58%
#
# epoch-0, running_loss : 209.34373, iter percent 13.63%
#
# epoch-0, running_loss : 209.75349, iter percent 13.67%
#
# epoch-0, running_loss : 210.15841, iter percent 13.71%
#
# epoch-0, running_loss : 210.56107, iter percent 13.75%
#
# epoch-0, running_loss : 210.95518, iter percent 13.79%
#
# epoch-0, running_loss : 211.33958, iter percent 13.83%
#
# epoch-0, running_loss : 211.73380, iter percent 13.88%
#
# epoch-0, running_loss : 212.14627, iter percent 13.92%
#
# epoch-0, running_loss : 212.53813, iter percent 13.96%
#
# epoch-0, running_loss : 212.94286, iter percent 14.00%
#
# epoch-0, running_loss : 213.35365, iter percent 14.04%
#
# epoch-0, running_loss : 213.76198, iter percent 14.08%
#
# epoch-0, running_loss : 214.15434, iter percent 14.12%
#
# epoch-0, running_loss : 214.54740, iter percent 14.17%
#
# epoch-0, running_loss : 214.93613, iter percent 14.21%
#
# epoch-0, running_loss : 215.32109, iter percent 14.25%
#
# epoch-0, running_loss : 215.70854, iter percent 14.29%
#
# epoch-0, running_loss : 216.10591, iter percent 14.33%
#
# epoch-0, running_loss : 216.49514, iter percent 14.37%
#
# epoch-0, running_loss : 216.89380, iter percent 14.42%
#
# epoch-0, running_loss : 217.27503, iter percent 14.46%
#
# epoch-0, running_loss : 217.65459, iter percent 14.50%
#
# epoch-0, running_loss : 218.02611, iter percent 14.54%
#
# epoch-0, running_loss : 218.40449, iter percent 14.58%
#
# epoch-0, running_loss : 218.77621, iter percent 14.62%
#
# epoch-0, running_loss : 219.14314, iter percent 14.67%
#
# epoch-0, running_loss : 219.52574, iter percent 14.71%
#
# epoch-0, running_loss : 219.89383, iter percent 14.75%
#
# epoch-0, running_loss : 220.25779, iter percent 14.79%
#
# epoch-0, running_loss : 220.61837, iter percent 14.83%
#
# epoch-0, running_loss : 220.98516, iter percent 14.88%
#
# epoch-0, running_loss : 221.35586, iter percent 14.92%
#
# epoch-0, running_loss : 221.75223, iter percent 14.96%
#
# epoch-0, running_loss : 222.13104, iter percent 15.00%
#
# epoch-0, running_loss : 222.50096, iter percent 15.04%
#
# epoch-0, running_loss : 222.87106, iter percent 15.08%
#
# epoch-0, running_loss : 223.22410, iter percent 15.12%
#
# epoch-0, running_loss : 223.58622, iter percent 15.17%
#
# epoch-0, running_loss : 223.94756, iter percent 15.21%
#
# epoch-0, running_loss : 224.30664, iter percent 15.25%
#
# epoch-0, running_loss : 224.66728, iter percent 15.29%
#
# epoch-0, running_loss : 225.02818, iter percent 15.33%
#
# epoch-0, running_loss : 225.37388, iter percent 15.38%
#
# epoch-0, running_loss : 225.72116, iter percent 15.42%
#
# epoch-0, running_loss : 226.06440, iter percent 15.46%
#
# epoch-0, running_loss : 226.40628, iter percent 15.50%
#
# epoch-0, running_loss : 226.75953, iter percent 15.54%
#
# epoch-0, running_loss : 227.11429, iter percent 15.58%
#
# epoch-0, running_loss : 227.47241, iter percent 15.62%
#
# epoch-0, running_loss : 227.82713, iter percent 15.67%
#
# epoch-0, running_loss : 228.17098, iter percent 15.71%
#
# epoch-0, running_loss : 228.51219, iter percent 15.75%
#
# epoch-0, running_loss : 228.86381, iter percent 15.79%
#
# epoch-0, running_loss : 229.19491, iter percent 15.83%
#
# epoch-0, running_loss : 229.52816, iter percent 15.88%
#
# epoch-0, running_loss : 229.87697, iter percent 15.92%
#
# epoch-0, running_loss : 230.22763, iter percent 15.96%
#
# epoch-0, running_loss : 230.57583, iter percent 16.00%
#
# epoch-0, running_loss : 230.92568, iter percent 16.04%
#
# epoch-0, running_loss : 231.26348, iter percent 16.08%
#
# epoch-0, running_loss : 231.59718, iter percent 16.12%
#
# epoch-0, running_loss : 231.92363, iter percent 16.17%
#
# epoch-0, running_loss : 232.25022, iter percent 16.21%
#
# epoch-0, running_loss : 232.58062, iter percent 16.25%
#
# epoch-0, running_loss : 232.92326, iter percent 16.29%
#
# epoch-0, running_loss : 233.25023, iter percent 16.33%
#
# epoch-0, running_loss : 233.56849, iter percent 16.38%
#
# epoch-0, running_loss : 233.88531, iter percent 16.42%
#
# epoch-0, running_loss : 234.20319, iter percent 16.46%
#
# epoch-0, running_loss : 234.52257, iter percent 16.50%
#
# epoch-0, running_loss : 234.84066, iter percent 16.54%
#
# epoch-0, running_loss : 235.17067, iter percent 16.58%
#
# epoch-0, running_loss : 235.49957, iter percent 16.62%
#
# epoch-0, running_loss : 235.82470, iter percent 16.67%
#
# epoch-0, running_loss : 236.13972, iter percent 16.71%
#
# epoch-0, running_loss : 236.45553, iter percent 16.75%
#
# epoch-0, running_loss : 236.77155, iter percent 16.79%
#
# epoch-0, running_loss : 237.07958, iter percent 16.83%
#
# epoch-0, running_loss : 237.40186, iter percent 16.88%
#
# epoch-0, running_loss : 237.71979, iter percent 16.92%
#
# epoch-0, running_loss : 238.03598, iter percent 16.96%
#
# epoch-0, running_loss : 238.34877, iter percent 17.00%
#
# epoch-0, running_loss : 238.66363, iter percent 17.04%
#
# epoch-0, running_loss : 238.96779, iter percent 17.08%
#
# epoch-0, running_loss : 239.26526, iter percent 17.12%
#
# epoch-0, running_loss : 239.57109, iter percent 17.17%
#
# epoch-0, running_loss : 239.87952, iter percent 17.21%
#
# epoch-0, running_loss : 240.17675, iter percent 17.25%
#
# epoch-0, running_loss : 240.47907, iter percent 17.29%
#
# epoch-0, running_loss : 240.78811, iter percent 17.33%
#
# epoch-0, running_loss : 241.08945, iter percent 17.38%
#
# epoch-0, running_loss : 241.38911, iter percent 17.42%
#
# epoch-0, running_loss : 241.68733, iter percent 17.46%
#
# epoch-0, running_loss : 242.00458, iter percent 17.50%
#
# epoch-0, running_loss : 242.29776, iter percent 17.54%
#
# epoch-0, running_loss : 242.58852, iter percent 17.58%
#
# epoch-0, running_loss : 242.89542, iter percent 17.62%
#
# epoch-0, running_loss : 243.19053, iter percent 17.67%
#
# epoch-0, running_loss : 243.48604, iter percent 17.71%
#
# epoch-0, running_loss : 243.78977, iter percent 17.75%
#
# epoch-0, running_loss : 244.07821, iter percent 17.79%
#
# epoch-0, running_loss : 244.36275, iter percent 17.83%
#
# epoch-0, running_loss : 244.65237, iter percent 17.88%
#
# epoch-0, running_loss : 244.94647, iter percent 17.92%
#
# epoch-0, running_loss : 245.23568, iter percent 17.96%
#
# epoch-0, running_loss : 245.53552, iter percent 18.00%
#
# epoch-0, running_loss : 245.82924, iter percent 18.04%
#
# epoch-0, running_loss : 246.11525, iter percent 18.08%
#
# epoch-0, running_loss : 246.40747, iter percent 18.12%
#
# epoch-0, running_loss : 246.69734, iter percent 18.17%
#
# epoch-0, running_loss : 246.98555, iter percent 18.21%
#
# epoch-0, running_loss : 247.26521, iter percent 18.25%
#
# epoch-0, running_loss : 247.54425, iter percent 18.29%
#
# epoch-0, running_loss : 247.83537, iter percent 18.33%
#
# epoch-0, running_loss : 248.11757, iter percent 18.38%
#
# epoch-0, running_loss : 248.39008, iter percent 18.42%
#
# epoch-0, running_loss : 248.67116, iter percent 18.46%
#
# epoch-0, running_loss : 248.94214, iter percent 18.50%
#
# epoch-0, running_loss : 249.20835, iter percent 18.54%
#
# epoch-0, running_loss : 249.47635, iter percent 18.58%
#
# epoch-0, running_loss : 249.74875, iter percent 18.62%
#
# epoch-0, running_loss : 250.01835, iter percent 18.67%
#
# epoch-0, running_loss : 250.29093, iter percent 18.71%
#
# epoch-0, running_loss : 250.55980, iter percent 18.75%
#
# epoch-0, running_loss : 250.81830, iter percent 18.79%
#
# epoch-0, running_loss : 251.07891, iter percent 18.83%
#
# epoch-0, running_loss : 251.33468, iter percent 18.88%
#
# epoch-0, running_loss : 251.60028, iter percent 18.92%
#
# epoch-0, running_loss : 251.86265, iter percent 18.96%
#
# epoch-0, running_loss : 252.12839, iter percent 19.00%
#
# epoch-0, running_loss : 252.38414, iter percent 19.04%
#
# epoch-0, running_loss : 252.64462, iter percent 19.08%
#
# epoch-0, running_loss : 252.90788, iter percent 19.12%
#
# epoch-0, running_loss : 253.16388, iter percent 19.17%
#
# epoch-0, running_loss : 253.41939, iter percent 19.21%
#
# epoch-0, running_loss : 253.67596, iter percent 19.25%
#
# epoch-0, running_loss : 253.92891, iter percent 19.29%
#
# epoch-0, running_loss : 254.17942, iter percent 19.33%
#
# epoch-0, running_loss : 254.43709, iter percent 19.38%
#
# epoch-0, running_loss : 254.68904, iter percent 19.42%
#
# epoch-0, running_loss : 254.94073, iter percent 19.46%
#
# epoch-0, running_loss : 255.18268, iter percent 19.50%
#
# epoch-0, running_loss : 255.43626, iter percent 19.54%
#
# epoch-0, running_loss : 255.67897, iter percent 19.58%
#
# epoch-0, running_loss : 255.93726, iter percent 19.62%
#
# epoch-0, running_loss : 256.18567, iter percent 19.67%
#
# epoch-0, running_loss : 256.43147, iter percent 19.71%
#
# epoch-0, running_loss : 256.67320, iter percent 19.75%
#
# epoch-0, running_loss : 256.91657, iter percent 19.79%
#
# epoch-0, running_loss : 257.15420, iter percent 19.83%
#
# epoch-0, running_loss : 257.40357, iter percent 19.88%
#
# epoch-0, running_loss : 257.65544, iter percent 19.92%
#
# epoch-0, running_loss : 257.89339, iter percent 19.96%
#
# epoch-0, running_loss : 258.13131, iter percent 20.00%
#
# epoch-0, running_loss : 258.36219, iter percent 20.04%
#
# epoch-0, running_loss : 258.59977, iter percent 20.08%
#
# epoch-0, running_loss : 258.82943, iter percent 20.12%
#
# epoch-0, running_loss : 259.06206, iter percent 20.17%
#
# epoch-0, running_loss : 259.29528, iter percent 20.21%
#
# epoch-0, running_loss : 259.52918, iter percent 20.25%
#
# epoch-0, running_loss : 259.76310, iter percent 20.29%
#
# epoch-0, running_loss : 259.98147, iter percent 20.33%
#
# epoch-0, running_loss : 260.20733, iter percent 20.38%
#
# epoch-0, running_loss : 260.44306, iter percent 20.42%
#
# epoch-0, running_loss : 260.68048, iter percent 20.46%
#
# epoch-0, running_loss : 260.91025, iter percent 20.50%
#
# epoch-0, running_loss : 261.13566, iter percent 20.54%
#
# epoch-0, running_loss : 261.37260, iter percent 20.58%
#
# epoch-0, running_loss : 261.60289, iter percent 20.62%
#
# epoch-0, running_loss : 261.82632, iter percent 20.67%
#
# epoch-0, running_loss : 262.04628, iter percent 20.71%
#
# epoch-0, running_loss : 262.27228, iter percent 20.75%
#
# epoch-0, running_loss : 262.48984, iter percent 20.79%
#
# epoch-0, running_loss : 262.70462, iter percent 20.83%
#
# epoch-0, running_loss : 262.92146, iter percent 20.88%
#
# epoch-0, running_loss : 263.14205, iter percent 20.92%
#
# epoch-0, running_loss : 263.35828, iter percent 20.96%
#
# epoch-0, running_loss : 263.57643, iter percent 21.00%
#
# epoch-0, running_loss : 263.79168, iter percent 21.04%
#
# epoch-0, running_loss : 264.00312, iter percent 21.08%
#
# epoch-0, running_loss : 264.22214, iter percent 21.12%
#
# epoch-0, running_loss : 264.44144, iter percent 21.17%
#
# epoch-0, running_loss : 264.65517, iter percent 21.21%
#
# epoch-0, running_loss : 264.85658, iter percent 21.25%
#
# epoch-0, running_loss : 265.06213, iter percent 21.29%
#
# epoch-0, running_loss : 265.26975, iter percent 21.33%
#
# epoch-0, running_loss : 265.48204, iter percent 21.38%
#
# epoch-0, running_loss : 265.68926, iter percent 21.42%
#
# epoch-0, running_loss : 265.89079, iter percent 21.46%
#
# epoch-0, running_loss : 266.09690, iter percent 21.50%
#
# epoch-0, running_loss : 266.29973, iter percent 21.54%
#
# epoch-0, running_loss : 266.50698, iter percent 21.58%
#
# epoch-0, running_loss : 266.71188, iter percent 21.62%
#
# epoch-0, running_loss : 266.91583, iter percent 21.67%
#
# epoch-0, running_loss : 267.12720, iter percent 21.71%
#
# epoch-0, running_loss : 267.32964, iter percent 21.75%
#
# epoch-0, running_loss : 267.52611, iter percent 21.79%
#
# epoch-0, running_loss : 267.72586, iter percent 21.83%
#
# epoch-0, running_loss : 267.92590, iter percent 21.88%
#
# epoch-0, running_loss : 268.12826, iter percent 21.92%
#
# epoch-0, running_loss : 268.33321, iter percent 21.96%
#
# epoch-0, running_loss : 268.53086, iter percent 22.00%
#
# epoch-0, running_loss : 268.72943, iter percent 22.04%
#
# epoch-0, running_loss : 268.92844, iter percent 22.08%
#
# epoch-0, running_loss : 269.11727, iter percent 22.12%
#
# epoch-0, running_loss : 269.31288, iter percent 22.17%
#
# epoch-0, running_loss : 269.50910, iter percent 22.21%
#
# epoch-0, running_loss : 269.70272, iter percent 22.25%
#
# epoch-0, running_loss : 269.89014, iter percent 22.29%
#
# epoch-0, running_loss : 270.07215, iter percent 22.33%
#
# epoch-0, running_loss : 270.25735, iter percent 22.38%
#
# epoch-0, running_loss : 270.43840, iter percent 22.42%
#
# epoch-0, running_loss : 270.62841, iter percent 22.46%
#
# epoch-0, running_loss : 270.81775, iter percent 22.50%
#
# epoch-0, running_loss : 271.00481, iter percent 22.54%
#
# epoch-0, running_loss : 271.18782, iter percent 22.58%
#
# epoch-0, running_loss : 271.37999, iter percent 22.62%
#
# epoch-0, running_loss : 271.56700, iter percent 22.67%
#
# epoch-0, running_loss : 271.74528, iter percent 22.71%
#
# epoch-0, running_loss : 271.93909, iter percent 22.75%
#
# epoch-0, running_loss : 272.11489, iter percent 22.79%
#
# epoch-0, running_loss : 272.29303, iter percent 22.83%
#
# epoch-0, running_loss : 272.47553, iter percent 22.88%
#
# epoch-0, running_loss : 272.64962, iter percent 22.92%
#
# epoch-0, running_loss : 272.83406, iter percent 22.96%
#
# epoch-0, running_loss : 273.00557, iter percent 23.00%
#
# epoch-0, running_loss : 273.18168, iter percent 23.04%
#
# epoch-0, running_loss : 273.35482, iter percent 23.08%
#
# epoch-0, running_loss : 273.52917, iter percent 23.12%
#
# epoch-0, running_loss : 273.69908, iter percent 23.17%
#
# epoch-0, running_loss : 273.86407, iter percent 23.21%
#
# epoch-0, running_loss : 274.04267, iter percent 23.25%
#
# epoch-0, running_loss : 274.21197, iter percent 23.29%
#
# epoch-0, running_loss : 274.38347, iter percent 23.33%
#
# epoch-0, running_loss : 274.55603, iter percent 23.38%
#
# epoch-0, running_loss : 274.72399, iter percent 23.42%
#
# epoch-0, running_loss : 274.89236, iter percent 23.46%
#
# epoch-0, running_loss : 275.06343, iter percent 23.50%
#
# epoch-0, running_loss : 275.23163, iter percent 23.54%
#
# epoch-0, running_loss : 275.39979, iter percent 23.58%
#
# epoch-0, running_loss : 275.56230, iter percent 23.62%
#
# epoch-0, running_loss : 275.71939, iter percent 23.67%
#
# epoch-0, running_loss : 275.88172, iter percent 23.71%
#
# epoch-0, running_loss : 276.04013, iter percent 23.75%
#
# epoch-0, running_loss : 276.19091, iter percent 23.79%
#
# epoch-0, running_loss : 276.35099, iter percent 23.83%
#
# epoch-0, running_loss : 276.51391, iter percent 23.88%
#
# epoch-0, running_loss : 276.67879, iter percent 23.92%
#
# epoch-0, running_loss : 276.83979, iter percent 23.96%
#
# epoch-0, running_loss : 276.99996, iter percent 24.00%
#
# epoch-0, running_loss : 277.16028, iter percent 24.04%
#
# epoch-0, running_loss : 277.31481, iter percent 24.08%
#
# epoch-0, running_loss : 277.47094, iter percent 24.12%
#
# epoch-0, running_loss : 277.63362, iter percent 24.17%
#
# epoch-0, running_loss : 277.78908, iter percent 24.21%
#
# epoch-0, running_loss : 277.94207, iter percent 24.25%
#
# epoch-0, running_loss : 278.09242, iter percent 24.29%
#
# epoch-0, running_loss : 278.24518, iter percent 24.33%
#
# epoch-0, running_loss : 278.39645, iter percent 24.38%
#
# epoch-0, running_loss : 278.54778, iter percent 24.42%
#
# epoch-0, running_loss : 278.70434, iter percent 24.46%
#
# epoch-0, running_loss : 278.86018, iter percent 24.50%
#
# epoch-0, running_loss : 279.01237, iter percent 24.54%
#
# epoch-0, running_loss : 279.15664, iter percent 24.58%
#
# epoch-0, running_loss : 279.30390, iter percent 24.62%
#
# epoch-0, running_loss : 279.44822, iter percent 24.67%
#
# epoch-0, running_loss : 279.60350, iter percent 24.71%
#
# epoch-0, running_loss : 279.75238, iter percent 24.75%
#
# epoch-0, running_loss : 279.89539, iter percent 24.79%
#
# epoch-0, running_loss : 280.03816, iter percent 24.83%
#
# epoch-0, running_loss : 280.18148, iter percent 24.88%
#
# epoch-0, running_loss : 280.33111, iter percent 24.92%
#
# epoch-0, running_loss : 280.47774, iter percent 24.96%
#
# epoch-0, running_loss : 280.62579, iter percent 25.00%
#
# epoch-0, running_loss : 280.78223, iter percent 25.04%
#
# epoch-0, running_loss : 280.93046, iter percent 25.08%
#
# epoch-0, running_loss : 281.06868, iter percent 25.12%
#
# epoch-0, running_loss : 281.20233, iter percent 25.17%
#
# epoch-0, running_loss : 281.34311, iter percent 25.21%
#
# epoch-0, running_loss : 281.48523, iter percent 25.25%
#
# epoch-0, running_loss : 281.62687, iter percent 25.29%
#
# epoch-0, running_loss : 281.77242, iter percent 25.33%
#
# epoch-0, running_loss : 281.91202, iter percent 25.37%
#
# epoch-0, running_loss : 282.04730, iter percent 25.42%
#
# epoch-0, running_loss : 282.18838, iter percent 25.46%
#
# epoch-0, running_loss : 282.32900, iter percent 25.50%
#
# epoch-0, running_loss : 282.46420, iter percent 25.54%
#
# epoch-0, running_loss : 282.59995, iter percent 25.58%
#
# epoch-0, running_loss : 282.74075, iter percent 25.62%
#
# epoch-0, running_loss : 282.87533, iter percent 25.67%
#
# epoch-0, running_loss : 283.01309, iter percent 25.71%
#
# epoch-0, running_loss : 283.14673, iter percent 25.75%
#
# epoch-0, running_loss : 283.28162, iter percent 25.79%
#
# epoch-0, running_loss : 283.41213, iter percent 25.83%
#
# epoch-0, running_loss : 283.54288, iter percent 25.87%
#
# epoch-0, running_loss : 283.66880, iter percent 25.92%
#
# epoch-0, running_loss : 283.79764, iter percent 25.96%
#
# epoch-0, running_loss : 283.93022, iter percent 26.00%
#
# epoch-0, running_loss : 284.06380, iter percent 26.04%
#
# epoch-0, running_loss : 284.19028, iter percent 26.08%
#
# epoch-0, running_loss : 284.31534, iter percent 26.12%
#
# epoch-0, running_loss : 284.44256, iter percent 26.17%
#
# epoch-0, running_loss : 284.57202, iter percent 26.21%
#
# epoch-0, running_loss : 284.69963, iter percent 26.25%
#
# epoch-0, running_loss : 284.82822, iter percent 26.29%
#
# epoch-0, running_loss : 284.95555, iter percent 26.33%
#
# epoch-0, running_loss : 285.09542, iter percent 26.38%
#
# epoch-0, running_loss : 285.22210, iter percent 26.42%
#
# epoch-0, running_loss : 285.34619, iter percent 26.46%
#
# epoch-0, running_loss : 285.46783, iter percent 26.50%
#
# epoch-0, running_loss : 285.59373, iter percent 26.54%
#
# epoch-0, running_loss : 285.71827, iter percent 26.58%
#
# epoch-0, running_loss : 285.83747, iter percent 26.62%
#
# epoch-0, running_loss : 285.96198, iter percent 26.67%
#
# epoch-0, running_loss : 286.08383, iter percent 26.71%
#
# epoch-0, running_loss : 286.19974, iter percent 26.75%
#
# epoch-0, running_loss : 286.32017, iter percent 26.79%
#
# epoch-0, running_loss : 286.43616, iter percent 26.83%
#
# epoch-0, running_loss : 286.55846, iter percent 26.88%
#
# epoch-0, running_loss : 286.67210, iter percent 26.92%
#
# epoch-0, running_loss : 286.78565, iter percent 26.96%
#
# epoch-0, running_loss : 286.90198, iter percent 27.00%
#
# epoch-0, running_loss : 287.01845, iter percent 27.04%
#
# epoch-0, running_loss : 287.13781, iter percent 27.08%
#
# epoch-0, running_loss : 287.25952, iter percent 27.12%
#
# epoch-0, running_loss : 287.37686, iter percent 27.17%
#
# epoch-0, running_loss : 287.49447, iter percent 27.21%
#
# epoch-0, running_loss : 287.60948, iter percent 27.25%
#
# epoch-0, running_loss : 287.72842, iter percent 27.29%
#
# epoch-0, running_loss : 287.83937, iter percent 27.33%
#
# epoch-0, running_loss : 287.95328, iter percent 27.38%
#
# epoch-0, running_loss : 288.07202, iter percent 27.42%
#
# epoch-0, running_loss : 288.19210, iter percent 27.46%
#
# epoch-0, running_loss : 288.30107, iter percent 27.50%
#
# epoch-0, running_loss : 288.42063, iter percent 27.54%
#
# epoch-0, running_loss : 288.53580, iter percent 27.58%
#
# epoch-0, running_loss : 288.65143, iter percent 27.62%
#
# epoch-0, running_loss : 288.76975, iter percent 27.67%
#
# epoch-0, running_loss : 288.89040, iter percent 27.71%
#
# epoch-0, running_loss : 289.00187, iter percent 27.75%
#
# epoch-0, running_loss : 289.11221, iter percent 27.79%
#
# epoch-0, running_loss : 289.21870, iter percent 27.83%
#
# epoch-0, running_loss : 289.33980, iter percent 27.88%
#
# epoch-0, running_loss : 289.44476, iter percent 27.92%
#
# epoch-0, running_loss : 289.55562, iter percent 27.96%
#
# epoch-0, running_loss : 289.66807, iter percent 28.00%
#
# epoch-0, running_loss : 289.77602, iter percent 28.04%
#
# epoch-0, running_loss : 289.88632, iter percent 28.08%
#
# epoch-0, running_loss : 289.99189, iter percent 28.12%
#
# epoch-0, running_loss : 290.10237, iter percent 28.17%
#
# epoch-0, running_loss : 290.21161, iter percent 28.21%
#
# epoch-0, running_loss : 290.31788, iter percent 28.25%
#
# epoch-0, running_loss : 290.41566, iter percent 28.29%
#
# epoch-0, running_loss : 290.52560, iter percent 28.33%
#
# epoch-0, running_loss : 290.63355, iter percent 28.38%
#
# epoch-0, running_loss : 290.74302, iter percent 28.42%
#
# epoch-0, running_loss : 290.85282, iter percent 28.46%
#
# epoch-0, running_loss : 290.96527, iter percent 28.50%
#
# epoch-0, running_loss : 291.07853, iter percent 28.54%
#
# epoch-0, running_loss : 291.18881, iter percent 28.58%
#
# epoch-0, running_loss : 291.29403, iter percent 28.62%
#
# epoch-0, running_loss : 291.38775, iter percent 28.67%
#
# epoch-0, running_loss : 291.49871, iter percent 28.71%
#
# epoch-0, running_loss : 291.60094, iter percent 28.75%
#
# epoch-0, running_loss : 291.70275, iter percent 28.79%
#
# epoch-0, running_loss : 291.80675, iter percent 28.83%
#
# epoch-0, running_loss : 291.91331, iter percent 28.88%
#
# epoch-0, running_loss : 292.01270, iter percent 28.92%
#
# epoch-0, running_loss : 292.11491, iter percent 28.96%
#
# epoch-0, running_loss : 292.21640, iter percent 29.00%
#
# epoch-0, running_loss : 292.31391, iter percent 29.04%
#
# epoch-0, running_loss : 292.42459, iter percent 29.08%
#
# epoch-0, running_loss : 292.52997, iter percent 29.12%
#
# epoch-0, running_loss : 292.62699, iter percent 29.17%
#
# epoch-0, running_loss : 292.72963, iter percent 29.21%
#
# epoch-0, running_loss : 292.83092, iter percent 29.25%
#
# epoch-0, running_loss : 292.92694, iter percent 29.29%
#
# epoch-0, running_loss : 293.02411, iter percent 29.33%
#
# epoch-0, running_loss : 293.11216, iter percent 29.38%
#
# epoch-0, running_loss : 293.21100, iter percent 29.42%
#
# epoch-0, running_loss : 293.30331, iter percent 29.46%
#
# epoch-0, running_loss : 293.39976, iter percent 29.50%
#
# epoch-0, running_loss : 293.49547, iter percent 29.54%
#
# epoch-0, running_loss : 293.59069, iter percent 29.58%
#
# epoch-0, running_loss : 293.68613, iter percent 29.62%
#
# epoch-0, running_loss : 293.78124, iter percent 29.67%
#
# epoch-0, running_loss : 293.87545, iter percent 29.71%
#
# epoch-0, running_loss : 293.96704, iter percent 29.75%
#
# epoch-0, running_loss : 294.06709, iter percent 29.79%
#
# epoch-0, running_loss : 294.16174, iter percent 29.83%
#
# epoch-0, running_loss : 294.25880, iter percent 29.88%
#
# epoch-0, running_loss : 294.35191, iter percent 29.92%
#
# epoch-0, running_loss : 294.44596, iter percent 29.96%
#
# epoch-0, running_loss : 294.53218, iter percent 30.00%
#
# epoch-0, running_loss : 294.61902, iter percent 30.04%
#
# epoch-0, running_loss : 294.71323, iter percent 30.08%
#
# epoch-0, running_loss : 294.80112, iter percent 30.12%
#
# epoch-0, running_loss : 294.88334, iter percent 30.17%
#
# epoch-0, running_loss : 294.97376, iter percent 30.21%
#
# epoch-0, running_loss : 295.06053, iter percent 30.25%
#
# epoch-0, running_loss : 295.14771, iter percent 30.29%
#
# epoch-0, running_loss : 295.23353, iter percent 30.33%
#
# epoch-0, running_loss : 295.32104, iter percent 30.38%
#
# epoch-0, running_loss : 295.41502, iter percent 30.42%
#
# epoch-0, running_loss : 295.50467, iter percent 30.46%
#
# epoch-0, running_loss : 295.59326, iter percent 30.50%
#
# epoch-0, running_loss : 295.68167, iter percent 30.54%
#
# epoch-0, running_loss : 295.76544, iter percent 30.58%
#
# epoch-0, running_loss : 295.85339, iter percent 30.63%
#
# epoch-0, running_loss : 295.94165, iter percent 30.67%
#
# epoch-0, running_loss : 296.02763, iter percent 30.71%
#
# epoch-0, running_loss : 296.11385, iter percent 30.75%
#
# epoch-0, running_loss : 296.20081, iter percent 30.79%
#
# epoch-0, running_loss : 296.28085, iter percent 30.83%
#
# epoch-0, running_loss : 296.36844, iter percent 30.88%
#
# epoch-0, running_loss : 296.45498, iter percent 30.92%
#
# epoch-0, running_loss : 296.54197, iter percent 30.96%
#
# epoch-0, running_loss : 296.62504, iter percent 31.00%
#
# epoch-0, running_loss : 296.71219, iter percent 31.04%
#
# epoch-0, running_loss : 296.79574, iter percent 31.08%
#
# epoch-0, running_loss : 296.87419, iter percent 31.13%
#
# epoch-0, running_loss : 296.95486, iter percent 31.17%
#
# epoch-0, running_loss : 297.03319, iter percent 31.21%
#
# epoch-0, running_loss : 297.11719, iter percent 31.25%
#
# epoch-0, running_loss : 297.19999, iter percent 31.29%
#
# epoch-0, running_loss : 297.27887, iter percent 31.33%
#
# epoch-0, running_loss : 297.36625, iter percent 31.37%
#
# epoch-0, running_loss : 297.44784, iter percent 31.42%
#
# epoch-0, running_loss : 297.52939, iter percent 31.46%
#
# epoch-0, running_loss : 297.61080, iter percent 31.50%
#
# epoch-0, running_loss : 297.68809, iter percent 31.54%
#
# epoch-0, running_loss : 297.76487, iter percent 31.58%
#
# epoch-0, running_loss : 297.84839, iter percent 31.62%
#
# epoch-0, running_loss : 297.92521, iter percent 31.67%
#
# epoch-0, running_loss : 298.00987, iter percent 31.71%
#
# epoch-0, running_loss : 298.08898, iter percent 31.75%
#
# epoch-0, running_loss : 298.16479, iter percent 31.79%
#
# epoch-0, running_loss : 298.23833, iter percent 31.83%
#
# epoch-0, running_loss : 298.31439, iter percent 31.87%
#
# epoch-0, running_loss : 298.39344, iter percent 31.92%
#
# epoch-0, running_loss : 298.47509, iter percent 31.96%
#
# epoch-0, running_loss : 298.55491, iter percent 32.00%
#
# epoch-0, running_loss : 298.63232, iter percent 32.04%
#
# epoch-0, running_loss : 298.70692, iter percent 32.08%
#
# epoch-0, running_loss : 298.78312, iter percent 32.12%
#
# epoch-0, running_loss : 298.86001, iter percent 32.17%
#
# epoch-0, running_loss : 298.94879, iter percent 32.21%
#
# epoch-0, running_loss : 299.02602, iter percent 32.25%
#
# epoch-0, running_loss : 299.10489, iter percent 32.29%
#
# epoch-0, running_loss : 299.17422, iter percent 32.33%
#
# epoch-0, running_loss : 299.24509, iter percent 32.38%
#
# epoch-0, running_loss : 299.32053, iter percent 32.42%
#
# epoch-0, running_loss : 299.39654, iter percent 32.46%
#
# epoch-0, running_loss : 299.47727, iter percent 32.50%
#
# epoch-0, running_loss : 299.56158, iter percent 32.54%
#
# epoch-0, running_loss : 299.63475, iter percent 32.58%
#
# epoch-0, running_loss : 299.71384, iter percent 32.62%
#
# epoch-0, running_loss : 299.78570, iter percent 32.67%
#
# epoch-0, running_loss : 299.86653, iter percent 32.71%
#
# epoch-0, running_loss : 299.93778, iter percent 32.75%
#
# epoch-0, running_loss : 300.01540, iter percent 32.79%
#
# epoch-0, running_loss : 300.08784, iter percent 32.83%
#
# epoch-0, running_loss : 300.16513, iter percent 32.88%
#
# epoch-0, running_loss : 300.23283, iter percent 32.92%
#
# ...
#
# epoch-1, running_loss : 28.09910, iter percent 190.46%
#
# epoch-1, running_loss : 28.10880, iter percent 190.50%
#
# epoch-1, running_loss : 28.12322, iter percent 190.54%
#
# epoch-1, running_loss : 28.13406, iter percent 190.58%
#
# epoch-1, running_loss : 28.14301, iter percent 190.62%
#
# epoch-1, running_loss : 28.15396, iter percent 190.67%
#
# epoch-1, running_loss : 28.16441, iter percent 190.71%
#
# epoch-1, running_loss : 28.17783, iter percent 190.75%
#
# epoch-1, running_loss : 28.18763, iter percent 190.79%
#
# epoch-1, running_loss : 28.19928, iter percent 190.83%
#
# epoch-1, running_loss : 28.20883, iter percent 190.88%
#
# epoch-1, running_loss : 28.22039, iter percent 190.92%
#
# epoch-1, running_loss : 28.23150, iter percent 190.96%
#
# epoch-1, running_loss : 28.24126, iter percent 191.00%
#
# epoch-1, running_loss : 28.25027, iter percent 191.04%
#
# epoch-1, running_loss : 28.25910, iter percent 191.08%
#
# epoch-1, running_loss : 28.26794, iter percent 191.12%
#
# epoch-1, running_loss : 28.27677, iter percent 191.17%
#
# epoch-1, running_loss : 28.28858, iter percent 191.21%
#
# epoch-1, running_loss : 28.29788, iter percent 191.25%
#
# epoch-1, running_loss : 28.30602, iter percent 191.29%
#
# epoch-1, running_loss : 28.31792, iter percent 191.33%
#
# epoch-1, running_loss : 28.32796, iter percent 191.38%
#
# epoch-1, running_loss : 28.33790, iter percent 191.42%
#
# epoch-1, running_loss : 28.34847, iter percent 191.46%
#
# epoch-1, running_loss : 28.36124, iter percent 191.50%
#
# epoch-1, running_loss : 28.37131, iter percent 191.54%
#
# epoch-1, running_loss : 28.38152, iter percent 191.58%
#
# epoch-1, running_loss : 28.39175, iter percent 191.62%
#
# epoch-1, running_loss : 28.40088, iter percent 191.67%
#
# epoch-1, running_loss : 28.41069, iter percent 191.71%
#
# epoch-1, running_loss : 28.42266, iter percent 191.75%
#
# epoch-1, running_loss : 28.43470, iter percent 191.79%
#
# epoch-1, running_loss : 28.44434, iter percent 191.83%
#
# epoch-1, running_loss : 28.45573, iter percent 191.88%
#
# epoch-1, running_loss : 28.46804, iter percent 191.92%
#
# epoch-1, running_loss : 28.47950, iter percent 191.96%
#
# epoch-1, running_loss : 28.48962, iter percent 192.00%
#
# epoch-1, running_loss : 28.49773, iter percent 192.04%
#
# epoch-1, running_loss : 28.51040, iter percent 192.08%
#
# epoch-1, running_loss : 28.52031, iter percent 192.12%
#
# epoch-1, running_loss : 28.53350, iter percent 192.17%
#
# epoch-1, running_loss : 28.54653, iter percent 192.21%
#
# epoch-1, running_loss : 28.55584, iter percent 192.25%
#
# epoch-1, running_loss : 28.56416, iter percent 192.29%
#
# epoch-1, running_loss : 28.57332, iter percent 192.33%
#
# epoch-1, running_loss : 28.58432, iter percent 192.38%
#
# epoch-1, running_loss : 28.59602, iter percent 192.42%
#
# epoch-1, running_loss : 28.60552, iter percent 192.46%
#
# epoch-1, running_loss : 28.61836, iter percent 192.50%
#
# epoch-1, running_loss : 28.62872, iter percent 192.54%
#
# epoch-1, running_loss : 28.63710, iter percent 192.58%
#
# epoch-1, running_loss : 28.64743, iter percent 192.62%
#
# epoch-1, running_loss : 28.65818, iter percent 192.67%
#
# epoch-1, running_loss : 28.66986, iter percent 192.71%
#
# epoch-1, running_loss : 28.68057, iter percent 192.75%
#
# epoch-1, running_loss : 28.68990, iter percent 192.79%
#
# epoch-1, running_loss : 28.70025, iter percent 192.83%
#
# epoch-1, running_loss : 28.71220, iter percent 192.88%
#
# epoch-1, running_loss : 28.72175, iter percent 192.92%
#
# epoch-1, running_loss : 28.73353, iter percent 192.96%
#
# epoch-1, running_loss : 28.74506, iter percent 193.00%
#
# epoch-1, running_loss : 28.75445, iter percent 193.04%
#
# epoch-1, running_loss : 28.76456, iter percent 193.08%
#
# epoch-1, running_loss : 28.77404, iter percent 193.12%
#
# epoch-1, running_loss : 28.78395, iter percent 193.17%
#
# epoch-1, running_loss : 28.79273, iter percent 193.21%
#
# epoch-1, running_loss : 28.80097, iter percent 193.25%
#
# epoch-1, running_loss : 28.81058, iter percent 193.29%
#
# epoch-1, running_loss : 28.82208, iter percent 193.33%
#
# epoch-1, running_loss : 28.83367, iter percent 193.38%
#
# epoch-1, running_loss : 28.84256, iter percent 193.42%
#
# epoch-1, running_loss : 28.85084, iter percent 193.46%
#
# epoch-1, running_loss : 28.85941, iter percent 193.50%
#
# epoch-1, running_loss : 28.86935, iter percent 193.54%
#
# epoch-1, running_loss : 28.88027, iter percent 193.58%
#
# epoch-1, running_loss : 28.89107, iter percent 193.62%
#
# epoch-1, running_loss : 28.90129, iter percent 193.67%
#
# epoch-1, running_loss : 28.91147, iter percent 193.71%
#
# epoch-1, running_loss : 28.92356, iter percent 193.75%
#
# epoch-1, running_loss : 28.93492, iter percent 193.79%
#
# epoch-1, running_loss : 28.94411, iter percent 193.83%
#
# epoch-1, running_loss : 28.95269, iter percent 193.88%
#
# epoch-1, running_loss : 28.96283, iter percent 193.92%
#
# epoch-1, running_loss : 28.97313, iter percent 193.96%
#
# epoch-1, running_loss : 28.98468, iter percent 194.00%
#
# epoch-1, running_loss : 28.99460, iter percent 194.04%
#
# epoch-1, running_loss : 29.00487, iter percent 194.08%
#
# epoch-1, running_loss : 29.01415, iter percent 194.12%
#
# epoch-1, running_loss : 29.02251, iter percent 194.17%
#
# epoch-1, running_loss : 29.03379, iter percent 194.21%
#
# epoch-1, running_loss : 29.04689, iter percent 194.25%
#
# epoch-1, running_loss : 29.05696, iter percent 194.29%
#
# epoch-1, running_loss : 29.06681, iter percent 194.33%
#
# epoch-1, running_loss : 29.07913, iter percent 194.38%
#
# epoch-1, running_loss : 29.08936, iter percent 194.42%
#
# epoch-1, running_loss : 29.09883, iter percent 194.46%
#
# epoch-1, running_loss : 29.10755, iter percent 194.50%
#
# epoch-1, running_loss : 29.11808, iter percent 194.54%
#
# epoch-1, running_loss : 29.12942, iter percent 194.58%
#
# epoch-1, running_loss : 29.13827, iter percent 194.62%
#
# epoch-1, running_loss : 29.14789, iter percent 194.67%
#
# epoch-1, running_loss : 29.15912, iter percent 194.71%
#
# epoch-1, running_loss : 29.16772, iter percent 194.75%
#
# epoch-1, running_loss : 29.17973, iter percent 194.79%
#
# epoch-1, running_loss : 29.19047, iter percent 194.83%
#
# epoch-1, running_loss : 29.20213, iter percent 194.88%
#
# epoch-1, running_loss : 29.21245, iter percent 194.92%
#
# epoch-1, running_loss : 29.22328, iter percent 194.96%
#
# epoch-1, running_loss : 29.23392, iter percent 195.00%
#
# epoch-1, running_loss : 29.24337, iter percent 195.04%
#
# epoch-1, running_loss : 29.25364, iter percent 195.08%
#
# epoch-1, running_loss : 29.26509, iter percent 195.12%
#
# epoch-1, running_loss : 29.27450, iter percent 195.17%
#
# epoch-1, running_loss : 29.28545, iter percent 195.21%
#
# epoch-1, running_loss : 29.29564, iter percent 195.25%
#
# epoch-1, running_loss : 29.30711, iter percent 195.29%
#
# epoch-1, running_loss : 29.31842, iter percent 195.33%
#
# epoch-1, running_loss : 29.32779, iter percent 195.38%
#
# epoch-1, running_loss : 29.33505, iter percent 195.42%
#
# epoch-1, running_loss : 29.34619, iter percent 195.46%
#
# epoch-1, running_loss : 29.35713, iter percent 195.50%
#
# epoch-1, running_loss : 29.36692, iter percent 195.54%
#
# epoch-1, running_loss : 29.37674, iter percent 195.58%
#
# epoch-1, running_loss : 29.38583, iter percent 195.62%
#
# epoch-1, running_loss : 29.39444, iter percent 195.67%
#
# epoch-1, running_loss : 29.40388, iter percent 195.71%
#
# epoch-1, running_loss : 29.41379, iter percent 195.75%
#
# epoch-1, running_loss : 29.42316, iter percent 195.79%
#
# epoch-1, running_loss : 29.43183, iter percent 195.83%
#
# epoch-1, running_loss : 29.44196, iter percent 195.88%
#
# epoch-1, running_loss : 29.45284, iter percent 195.92%
#
# epoch-1, running_loss : 29.46286, iter percent 195.96%
#
# epoch-1, running_loss : 29.47172, iter percent 196.00%
#
# epoch-1, running_loss : 29.48114, iter percent 196.04%
#
# epoch-1, running_loss : 29.48965, iter percent 196.08%
#
# epoch-1, running_loss : 29.49892, iter percent 196.12%
#
# epoch-1, running_loss : 29.50722, iter percent 196.17%
#
# epoch-1, running_loss : 29.51533, iter percent 196.21%
#
# epoch-1, running_loss : 29.52274, iter percent 196.25%
#
# epoch-1, running_loss : 29.53109, iter percent 196.29%
#
# epoch-1, running_loss : 29.54075, iter percent 196.33%
#
# epoch-1, running_loss : 29.55072, iter percent 196.38%
#
# epoch-1, running_loss : 29.56040, iter percent 196.42%
#
# epoch-1, running_loss : 29.56967, iter percent 196.46%
#
# epoch-1, running_loss : 29.57802, iter percent 196.50%
#
# epoch-1, running_loss : 29.58673, iter percent 196.54%
#
# epoch-1, running_loss : 29.59592, iter percent 196.58%
#
# epoch-1, running_loss : 29.60699, iter percent 196.62%
#
# epoch-1, running_loss : 29.61670, iter percent 196.67%
#
# epoch-1, running_loss : 29.62936, iter percent 196.71%
#
# epoch-1, running_loss : 29.63900, iter percent 196.75%
#
# epoch-1, running_loss : 29.64915, iter percent 196.79%
#
# epoch-1, running_loss : 29.65956, iter percent 196.83%
#
# epoch-1, running_loss : 29.66998, iter percent 196.88%
#
# epoch-1, running_loss : 29.68246, iter percent 196.92%
#
# epoch-1, running_loss : 29.69368, iter percent 196.96%
#
# epoch-1, running_loss : 29.70526, iter percent 197.00%
#
# epoch-1, running_loss : 29.71324, iter percent 197.04%
#
# epoch-1, running_loss : 29.72376, iter percent 197.08%
#
# epoch-1, running_loss : 29.73317, iter percent 197.12%
#
# epoch-1, running_loss : 29.74127, iter percent 197.17%
#
# epoch-1, running_loss : 29.75090, iter percent 197.21%
#
# epoch-1, running_loss : 29.76001, iter percent 197.25%
#
# epoch-1, running_loss : 29.77021, iter percent 197.29%
#
# epoch-1, running_loss : 29.78278, iter percent 197.33%
#
# epoch-1, running_loss : 29.79263, iter percent 197.38%
#
# epoch-1, running_loss : 29.80409, iter percent 197.42%
#
# epoch-1, running_loss : 29.81354, iter percent 197.46%
#
# epoch-1, running_loss : 29.82351, iter percent 197.50%
#
# epoch-1, running_loss : 29.83388, iter percent 197.54%
#
# epoch-1, running_loss : 29.84389, iter percent 197.58%
#
# epoch-1, running_loss : 29.85402, iter percent 197.62%
#
# epoch-1, running_loss : 29.86548, iter percent 197.67%
#
# epoch-1, running_loss : 29.87462, iter percent 197.71%
#
# epoch-1, running_loss : 29.88703, iter percent 197.75%
#
# epoch-1, running_loss : 29.89808, iter percent 197.79%
#
# epoch-1, running_loss : 29.91002, iter percent 197.83%
#
# epoch-1, running_loss : 29.92109, iter percent 197.88%
#
# epoch-1, running_loss : 29.92911, iter percent 197.92%
#
# epoch-1, running_loss : 29.93950, iter percent 197.96%
#
# epoch-1, running_loss : 29.94984, iter percent 198.00%
#
# epoch-1, running_loss : 29.95808, iter percent 198.04%
#
# epoch-1, running_loss : 29.96572, iter percent 198.08%
#
# epoch-1, running_loss : 29.97505, iter percent 198.12%
#
# epoch-1, running_loss : 29.98444, iter percent 198.17%
#
# epoch-1, running_loss : 29.99593, iter percent 198.21%
#
# epoch-1, running_loss : 30.00776, iter percent 198.25%
#
# epoch-1, running_loss : 30.01768, iter percent 198.29%
#
# epoch-1, running_loss : 30.02737, iter percent 198.33%
#
# epoch-1, running_loss : 30.03971, iter percent 198.38%
#
# epoch-1, running_loss : 30.05117, iter percent 198.42%
#
# epoch-1, running_loss : 30.06071, iter percent 198.46%
#
# epoch-1, running_loss : 30.06729, iter percent 198.50%
#
# epoch-1, running_loss : 30.07656, iter percent 198.54%
#
# epoch-1, running_loss : 30.08739, iter percent 198.58%
#
# epoch-1, running_loss : 30.10120, iter percent 198.62%
#
# epoch-1, running_loss : 30.10920, iter percent 198.67%
#
# epoch-1, running_loss : 30.11997, iter percent 198.71%
#
# epoch-1, running_loss : 30.13059, iter percent 198.75%
#
# epoch-1, running_loss : 30.14155, iter percent 198.79%
#
# epoch-1, running_loss : 30.15225, iter percent 198.83%
#
# epoch-1, running_loss : 30.16168, iter percent 198.88%
#
# epoch-1, running_loss : 30.17033, iter percent 198.92%
#
# epoch-1, running_loss : 30.18027, iter percent 198.96%
#
# epoch-1, running_loss : 30.18907, iter percent 199.00%
#
# epoch-1, running_loss : 30.19864, iter percent 199.04%
#
# epoch-1, running_loss : 30.20915, iter percent 199.08%
#
# epoch-1, running_loss : 30.21869, iter percent 199.12%
#
# epoch-1, running_loss : 30.22778, iter percent 199.17%
#
# epoch-1, running_loss : 30.23710, iter percent 199.21%
#
# epoch-1, running_loss : 30.24861, iter percent 199.25%
#
# epoch-1, running_loss : 30.25843, iter percent 199.29%
#
# epoch-1, running_loss : 30.26684, iter percent 199.33%
#
# epoch-1, running_loss : 30.27726, iter percent 199.38%
#
# epoch-1, running_loss : 30.28874, iter percent 199.42%
#
# epoch-1, running_loss : 30.30042, iter percent 199.46%
#
# epoch-1, running_loss : 30.30960, iter percent 199.50%
#
# epoch-1, running_loss : 30.32040, iter percent 199.54%
#
# epoch-1, running_loss : 30.32943, iter percent 199.58%
#
# epoch-1, running_loss : 30.33874, iter percent 199.62%
#
# epoch-1, running_loss : 30.34787, iter percent 199.67%
#
# epoch-1, running_loss : 30.35832, iter percent 199.71%
#
# epoch-1, running_loss : 30.37102, iter percent 199.75%
#
# epoch-1, running_loss : 30.38195, iter percent 199.79%
#
# epoch-1, running_loss : 30.39043, iter percent 199.83%
#
# epoch-1, running_loss : 30.39961, iter percent 199.88%
#
# epoch-1, running_loss : 30.40899, iter percent 199.92%
#
# epoch-1, running_loss : 30.41962, iter percent 199.96%
#
# epoch-1 loss : 0.01267
# ae train 실행 시간: 326.345초
#
# epoch-1 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.74787133 0.69509896 0.60905152 0.58486017 0.59054726 0.44622642
#  0.38488314 0.39275635 0.77962683 0.57910156 0.5226834  0.49900695
#  0.54276986 0.42967992 0.39754902 0.33540373]
# mean_cluster_accuracy_during_training_cycle : 53.75%, post_traincycle_acc : 53.36%, total_acc : 53.52%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 55.44%
# accuracy_check 실행 시간: 14.780초
#
# epoch-2, running_loss : 0.01091, iter percent 200.00%
#
# epoch-2, running_loss : 0.02048, iter percent 200.04%
#
# epoch-2, running_loss : 0.03352, iter percent 200.08%
#
# epoch-2, running_loss : 0.04350, iter percent 200.13%
#
# epoch-2, running_loss : 0.05414, iter percent 200.17%
#
# epoch-2, running_loss : 0.06315, iter percent 200.21%
#
# epoch-2, running_loss : 0.07385, iter percent 200.25%
#
# epoch-2, running_loss : 0.08360, iter percent 200.29%
#
# epoch-2, running_loss : 0.09678, iter percent 200.33%
#
# epoch-2, running_loss : 0.10646, iter percent 200.38%
#
# epoch-2, running_loss : 0.11802, iter percent 200.42%
#
# epoch-2, running_loss : 0.12930, iter percent 200.46%
#
# epoch-2, running_loss : 0.14316, iter percent 200.50%
#
# epoch-2, running_loss : 0.15389, iter percent 200.54%
#
# epoch-2, running_loss : 0.16354, iter percent 200.58%
#
# epoch-2, running_loss : 0.17355, iter percent 200.62%
#
# epoch-2, running_loss : 0.18491, iter percent 200.67%
#
# epoch-2, running_loss : 0.19429, iter percent 200.71%
#
# epoch-2, running_loss : 0.20572, iter percent 200.75%
#
# epoch-2, running_loss : 0.21663, iter percent 200.79%
#
# epoch-2, running_loss : 0.22580, iter percent 200.83%
#
# epoch-2, running_loss : 0.23704, iter percent 200.88%
#
# epoch-2, running_loss : 0.24530, iter percent 200.92%
#
# epoch-2, running_loss : 0.25571, iter percent 200.96%
#
# epoch-2, running_loss : 0.26420, iter percent 201.00%
#
# epoch-2, running_loss : 0.27248, iter percent 201.04%
#
# epoch-2, running_loss : 0.28116, iter percent 201.08%
#
# epoch-2, running_loss : 0.29020, iter percent 201.12%
#
# epoch-2, running_loss : 0.30223, iter percent 201.17%
#
# epoch-2, running_loss : 0.31172, iter percent 201.21%
#
# epoch-2, running_loss : 0.32081, iter percent 201.25%
#
# epoch-2, running_loss : 0.32816, iter percent 201.29%
#
# epoch-2, running_loss : 0.33825, iter percent 201.33%
#
# epoch-2, running_loss : 0.35246, iter percent 201.38%
#
# epoch-2, running_loss : 0.36230, iter percent 201.42%
#
# epoch-2, running_loss : 0.37628, iter percent 201.46%
#
# epoch-2, running_loss : 0.38754, iter percent 201.50%
#
# epoch-2, running_loss : 0.39624, iter percent 201.54%
#
# epoch-2, running_loss : 0.40541, iter percent 201.58%
#
# epoch-2, running_loss : 0.41644, iter percent 201.62%
#
# epoch-2, running_loss : 0.42791, iter percent 201.67%
#
# epoch-2, running_loss : 0.43846, iter percent 201.71%
#
# epoch-2, running_loss : 0.44796, iter percent 201.75%
#
# epoch-2, running_loss : 0.45880, iter percent 201.79%
#
# epoch-2, running_loss : 0.46895, iter percent 201.83%
#
# epoch-2, running_loss : 0.47796, iter percent 201.87%
#
# epoch-2, running_loss : 0.49029, iter percent 201.92%
#
# epoch-2, running_loss : 0.50130, iter percent 201.96%

# %%
# # Sweep code


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [True]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400, 2400]}, # [1400, 2400]

#         "batch_size": {"values": [32]}, 
#         "max_epoch": {"values": [10]}, 
#         "learning_rate": {"values": [0.001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [False]}, 

#         "lif_add_at_first": {"values": [True, False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [4,6,8,10]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True, False]}, # [True, False]

#         # "current_time": {"values": [current_time]}, 

#         "coarse_com_mode": {"values": [True, False]}, # ['Adam', 'SGD']
#         "coarse_com_config": {"values": [(-2.0, 2.0)]}, # ['Adam', 'SGD']
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  1
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer

#     coarse_com_mode = wandb.config.coarse_com_mode,
#     coarse_com_config = wandb.config.coarse_com_config, # (max, min)

#     sae_l2_norm_bridge = wandb.config.sae_l2_norm_bridge,
#     sae_lif_bridge = wandb.config.sae_lif_bridge, 


#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'

#         coarse_com_mode = coarse_com_mode,
#         coarse_com_config = coarse_com_config, # (max, min)
        
#         sae_l2_norm_bridge = sae_l2_norm_bridge,
#         sae_lif_bridge = sae_lif_bridge,
#         )
    
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
wandb.finish()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle
import json

# current_time = '20250102_225243_972'

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)


# JSON으로 저장
with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'r') as f:
    loaded_hyperparameters = json.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']
print(data)
max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {loaded_hyperparameters['dataset_num']}, Conv {loaded_hyperparameters['Conv_net']}, SAE {loaded_hyperparameters['SAE_net']}, Current time {loaded_hyperparameters['current_time']}, Spike Length: {loaded_hyperparameters['spike_length']}, Num Cluster: {loaded_hyperparameters['num_cluster']}, "
    f"Training Cycle: {loaded_hyperparameters['training_cycle']}, Batch Size: {loaded_hyperparameters['batch_size']}, Max Epoch: {loaded_hyperparameters['max_epoch']}, \n"
    f"Learning Rate: {loaded_hyperparameters['learning_rate']}, Input Normalize: {loaded_hyperparameters['normalize_on']}, Need Bias: {loaded_hyperparameters['need_bias']}, "
    f"LIF Add at First: {loaded_hyperparameters['lif_add_at_first']}, TIME: {loaded_hyperparameters['TIME']}, Seed: {loaded_hyperparameters['my_seed']}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
