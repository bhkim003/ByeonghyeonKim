# %% [markdown]
# # ssp.train.py

# %%
import torch   
import torch.nn as nn 
import torch.nn.functional as F   
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle
import json
import time

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    ):
    seed_assign(my_seed)
    
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    # JSON으로 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'w') as f:
        json.dump(hyperparameters, f, indent=4)

    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset2", summary="max")

    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])


    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'

    n_sample = spike_length


    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            net = Autoencoder_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, 4], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            net = SAE_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first)
            net = torch.nn.DataParallel(net)
        else:
            net = SAE_fc_only(encoder_ch=[96, 64, 32, 4], 
                                decoder_ch=[32,64,96,n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마




    wandb.watch(net, log="all", log_freq = 10)





    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    net = net.to(device)
    print(net)
    print('Device:',device)

    criterion = nn.MSELoss()
    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0


    for epoch in range(max_epoch):

        ae_train_start_time = time.time()
        running_loss = 0.0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike = data
            spike = spike.to(device)
            if 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
            spike_class = net(spike)

            # if 'SAE' in net.module.__class__.__name__:
            #     spike = spike.mean(dim=1)# Time 방향으로 평균
            #     spike_class = spike_class.mean(dim=1)# Time 방향으로 평균

            if 'SAE' in net.module.__class__.__name__:
                loss1 = criterion(spike_class[:, :, 5:25], spike[:, :, 5:25])
                loss2 = criterion(spike_class[:, :, 0:5], spike[:, :, 0:5])
                loss3 = criterion(spike_class[:, :, 25:spike_length], spike[:, :, 25:spike_length])
            else:
                loss1 = criterion(spike_class[:, 5:25], spike[:, 5:25])
                loss2 = criterion(spike_class[:, 0:5], spike[:, 0:5])
                loss3 = criterion(spike_class[:, 25:spike_length], spike[:, 25:spike_length])

            loss = loss1 * 2.125 + (loss2 + loss3)/4
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            # print(f'\nepoch-{epoch} running_loss : {running_loss:.5f}')
        avg_loss = running_loss / len(train_loader)
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')
        print(f"ae train 실행 시간: {time.time()-ae_train_start_time:.3f}초")





        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    

        if(epoch %5 ==0 or epoch == 1 or epoch == max_epoch-1): 
            accuracy_check_start_time = time.time()
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = 4*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else 4

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    spike_torch = torch.from_numpy(spike_template)
                    spike_torch = spike_torch.float().to(device)
                    if 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                    inner_inf = net.module.encoder(spike_torch)
                    # if 'SAE' in net.module.__class__.__name__:
                    #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                    #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                    #     print(all_equal, inner_inf)

                    if 'SAE' in net.module.__class__.__name__:
                        if SAE_hidden_nomean == True:
                            inner_inf = inner_inf.reshape(spike_template.shape[0],-1)# time*feature 펼치기
                        else:
                            inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                    Cluster = inner_inf.cpu().detach().numpy()

                encoder_batch = 128
                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    now_index = 0
                    while (1):
                        now_end_index = now_index+encoder_batch if now_index+encoder_batch < len(spike) else len(spike)
                        spike_batch = spike[now_index:now_end_index] 
                        spike_torch = torch.from_numpy(spike_batch)
                        spike_torch = spike_torch.float().to(device)
                        if 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.reshape(spike_batch.shape[0],-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[now_index:now_end_index] = inner_inf.cpu().detach().numpy()
                        now_index += encoder_batch
                        if (now_index >= len(spike)):
                            break
                    
                spike_id = np.zeros(len(spike))
                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                            tau[q] = tau[q] / denominator

                    # for i in range(num_cluster): # l2 distance
                    #     distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))
                    distance_sm = np.sum(np.power(np.abs(Cluster - spike_hidden[spike_index, :]), 2), axis=1)

                    m = np.argmin(distance_sm)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16
                
                # print('Cluster',Cluster)
                # print('spike_id', spike_id)

                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                perm_start_time = time.time()
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1
                # print(f"perm 실행 시간: {time.time()-perm_start_time:.3f}초")
                
                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                # print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
            print(f"accuracy_check 실행 시간: {time.time()-accuracy_check_start_time:.3f}초")

        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset2": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


        # 저장
        with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
            pickle.dump({
                "loss_history": loss_history,
                "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
            }, f)

# %%
gpu = 5
Conv_net = True
SAE_net = True

# hyperparameter
dataset_num = 16
spike_length = 50
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 1400 #1400 2400 # 그 초기 몇개까지만 cluster update할지


batch_size = 16
max_epoch = 7000
learning_rate = 0.001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 8 # SAE일 때만 유효
v_decay = 0.5 # -cor
v_threshold = 0.25 # -cor
v_reset = 0.0 # -cor # 10000이상 일 시 hard reset
BPTT_on = True # +cor

SAE_hidden_nomean = False # False가 나았다 이상하게.

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'Adam' #'Adam', 'SGD' # 둘다 준수함. loss 줄이는 거는 adam이 좋긴한데, cluster accuracy는 비슷함.

wandb.init(project= f'spike_sorting just run',save_code=False)

cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    current_time = current_time,
    optimizer = optimizer, #'Adam', 'SGD'
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250102_225245-b6nafjtg</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/b6nafjtg' target="_blank">warm-oath-144</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/b6nafjtg' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/b6nafjtg</a>
# {'gpu': 5, 'Conv_net': True, 'SAE_net': True, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 1400, 'batch_size': 16, 'max_epoch': 7000, 'learning_rate': 0.001, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 8, 'v_decay': 0.5, 'v_threshold': 0.25, 'v_reset': 0.0, 'BPTT_on': True, 'SAE_hidden_nomean': False, 'current_time': '20250102_225243_972', 'optimizer': 'Adam'}
# DataParallel(
#   (module): SAE_conv1(
#     (encoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_unsuqeeze()
#       (2): SSBH_DimChanger_for_one_two_coupling()
#       (3): Conv1d(1, 32, kernel_size=(3,), stride=(2,), bias=False)
#       (4): SSBH_DimChanger_for_one_two_decoupling()
#       (5): LIF_layer()
#       (6): SSBH_DimChanger_for_one_two_coupling()
#       (7): Conv1d(32, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (8): SSBH_DimChanger_for_one_two_decoupling()
#       (9): LIF_layer()
#       (10): SSBH_DimChanger_for_one_two_coupling()
#       (11): Conv1d(64, 96, kernel_size=(3,), stride=(2,), bias=False)
#       (12): SSBH_DimChanger_for_one_two_decoupling()
#       (13): LIF_layer()
#       (14): SSBH_DimChanger_for_one_two_coupling()
#       (15): SSBH_DimChanger_for_fc()
#       (16): Linear(in_features=480, out_features=4, bias=False)
#       (17): SSBH_L2NormLayer()
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_one_two()
#     )
#     (decoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_one_two_coupling()
#       (2): Linear(in_features=4, out_features=480, bias=False)
#       (3): SSBH_DimChanger_for_one_two_decoupling()
#       (4): LIF_layer()
#       (5): SSBH_DimChanger_for_one_two_coupling()
#       (6): SSBH_DimChanger_for_conv1()
#       (7): SSBH_DimChanger_for_one_two_decoupling()
#       (8): SSBH_DimChanger_for_one_two_coupling()
#       (9): ConvTranspose1d(96, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (10): SSBH_DimChanger_for_one_two_decoupling()
#       (11): LIF_layer()
#       (12): SSBH_DimChanger_for_one_two_coupling()
#       (13): ConvTranspose1d(64, 32, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (14): SSBH_DimChanger_for_one_two_decoupling()
#       (15): LIF_layer()
#       (16): SSBH_DimChanger_for_one_two_coupling()
#       (17): ConvTranspose1d(32, 1, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_for_suqeeze()
#       (20): SSBH_DimChanger_one_two()
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250102_225243_972
#
# epoch-0 loss : 0.15305
# ae train 실행 시간: 85.759초
#
# epoch-0 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9736098  0.96966779 0.95467695 0.96567164 0.90424528
#  0.82993536 0.7144873  0.95663137 0.89990234 0.81708494 0.57944389
#  0.92922607 0.90349176 0.57745098 0.70998567]
# mean_cluster_accuracy_during_training_cycle : 83.75%, post_traincycle_acc : 85.36%, total_acc : 84.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 85.36%
# accuracy_check 실행 시간: 10.812초
#
# epoch-1 loss : 0.03864
# ae train 실행 시간: 89.491초
#
# epoch-1 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97313855 0.9682234  0.95467695 0.96368159 0.92122642
#  0.86076579 0.74082785 0.96066566 0.91552734 0.83832046 0.60079444
#  0.95315682 0.93646945 0.4877451  0.72479694]
# mean_cluster_accuracy_during_training_cycle : 85.10%, post_traincycle_acc : 86.08%, total_acc : 85.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 86.08%
# accuracy_check 실행 시간: 10.809초
#
# epoch-2 loss : 0.03492
# ae train 실행 시간: 88.296초
#
# epoch-3 loss : 0.03293
# ae train 실행 시간: 97.260초
#
# epoch-4 loss : 0.03183
# ae train 실행 시간: 92.885초
#
# epoch-5 loss : 0.03114
# ae train 실행 시간: 94.502초
#
# epoch-5 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97682119 0.97596607 0.97255657 0.95515911 0.9641791  0.94386792
#  0.8776728  0.71119473 0.96520424 0.93261719 0.85569498 0.53574975
#  0.95570265 0.93501455 0.84705882 0.69804109]
# mean_cluster_accuracy_during_training_cycle : 86.62%, post_traincycle_acc : 88.14%, total_acc : 87.52%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.14%
# accuracy_check 실행 시간: 10.186초
#
# epoch-6 loss : 0.03057
# ae train 실행 시간: 88.047초
#
# epoch-7 loss : 0.03005
# ae train 실행 시간: 86.076초
#
# epoch-8 loss : 0.02956
# ae train 실행 시간: 85.903초
#
# epoch-9 loss : 0.02927
# ae train 실행 시간: 86.876초
#
# epoch-10 loss : 0.02903
# ae train 실행 시간: 86.080초
#
# epoch-10 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97682119 0.97502356 0.97207511 0.95708775 0.96368159 0.94669811
#  0.89109896 0.78504233 0.96217852 0.93310547 0.85376448 0.50595829
#  0.95824847 0.93404462 0.56715686 0.71046345]
# mean_cluster_accuracy_during_training_cycle : 86.67%, post_traincycle_acc : 86.83%, total_acc : 86.77%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.14%
# accuracy_check 실행 시간: 10.499초
#
# epoch-11 loss : 0.02873
# ae train 실행 시간: 86.362초
#
# epoch-12 loss : 0.02854
# ae train 실행 시간: 86.616초
#
# epoch-13 loss : 0.02830
# ae train 실행 시간: 86.342초
#
# epoch-14 loss : 0.02817
# ae train 실행 시간: 86.634초
#
# epoch-15 loss : 0.02807
# ae train 실행 시간: 85.273초
#
# epoch-15 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97587512 0.97502356 0.97207511 0.95708775 0.9641791  0.94811321
#  0.92143212 0.79727187 0.96016137 0.93701172 0.85617761 0.6266137
#  0.95824847 0.92580019 0.52156863 0.72384138]
# mean_cluster_accuracy_during_training_cycle : 87.28%, post_traincycle_acc : 87.63%, total_acc : 87.49%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.14%
# accuracy_check 실행 시간: 11.004초
#
# epoch-16 loss : 0.02806
# ae train 실행 시간: 84.944초
#
# epoch-17 loss : 0.02800
# ae train 실행 시간: 84.553초
#
# epoch-18 loss : 0.02796
# ae train 실행 시간: 85.755초
#
# epoch-19 loss : 0.02814
# ae train 실행 시간: 86.430초
#
# epoch-20 loss : 0.02819
# ae train 실행 시간: 85.933초
#
# epoch-20 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.98013245 0.97643732 0.97207511 0.95515911 0.96467662 0.9490566
#  0.92093486 0.80385701 0.96016137 0.93896484 0.8523166  0.61171797
#  0.95824847 0.93840931 0.70294118 0.71333015]
# mean_cluster_accuracy_during_training_cycle : 87.77%, post_traincycle_acc : 88.74%, total_acc : 88.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.74%
# accuracy_check 실행 시간: 10.884초
#
# epoch-21 loss : 0.02820
# ae train 실행 시간: 86.407초
#
# epoch-22 loss : 0.02813
# ae train 실행 시간: 84.519초
#
# epoch-23 loss : 0.02803
# ae train 실행 시간: 87.404초
#
# epoch-24 loss : 0.02796
# ae train 실행 시간: 86.259초
#
# epoch-25 loss : 0.02789
# ae train 실행 시간: 85.069초
#
# epoch-25 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97596607 0.97207511 0.95515911 0.9641791  0.94858491
#  0.90154152 0.81749765 0.96217852 0.93945312 0.85183398 0.62810328
#  0.95977597 0.93937924 0.47794118 0.72193024]
# mean_cluster_accuracy_during_training_cycle : 86.58%, post_traincycle_acc : 87.47%, total_acc : 87.11%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.74%
# accuracy_check 실행 시간: 10.967초
#
# epoch-26 loss : 0.02784
# ae train 실행 시간: 87.828초
#
# epoch-27 loss : 0.02769
# ae train 실행 시간: 84.019초
#
# epoch-28 loss : 0.02763
# ae train 실행 시간: 85.837초
#
# epoch-29 loss : 0.02786
# ae train 실행 시간: 86.049초
#
# epoch-30 loss : 0.02960
# ae train 실행 시간: 85.221초
#
# epoch-30 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97918638 0.97643732 0.97207511 0.95949855 0.96368159 0.95471698
#  0.91347588 0.84477893 0.96217852 0.93896484 0.86486486 0.76663357
#  0.85539715 0.78031038 0.59411765 0.54897277]
# mean_cluster_accuracy_during_training_cycle : 85.85%, post_traincycle_acc : 86.72%, total_acc : 86.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.74%
# accuracy_check 실행 시간: 10.953초
#
# epoch-31 loss : 0.03018
# ae train 실행 시간: 85.632초
#
# epoch-32 loss : 0.02969
# ae train 실행 시간: 87.050초
#
# epoch-33 loss : 0.02906
# ae train 실행 시간: 86.169초
#
# epoch-34 loss : 0.02858
# ae train 실행 시간: 85.645초
#
# epoch-35 loss : 0.02860
# ae train 실행 시간: 85.332초
#
# epoch-35 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97785108 0.97207511 0.95853423 0.96865672 0.95660377
#  0.93585281 0.87300094 0.96570852 0.94824219 0.86583012 0.4428997
#  0.9490835  0.91707081 0.82647059 0.52842809]
# mean_cluster_accuracy_during_training_cycle : 86.92%, post_traincycle_acc : 87.91%, total_acc : 87.51%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 88.74%
# accuracy_check 실행 시간: 9.673초
#
# epoch-36 loss : 0.02831
# ae train 실행 시간: 83.607초
#
# epoch-37 loss : 0.02817
# ae train 실행 시간: 85.066초
#
# epoch-38 loss : 0.02816
# ae train 실행 시간: 81.517초
#
# epoch-39 loss : 0.02804
# ae train 실행 시간: 83.100초
#
# epoch-40 loss : 0.02817
# ae train 실행 시간: 85.262초
#
# epoch-40 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97918638 0.97737983 0.97063072 0.95612343 0.96517413 0.96084906
#  0.94728991 0.90122295 0.9591528  0.93359375 0.85955598 0.6633565
#  0.95468432 0.92725509 0.84705882 0.5733397 ]
# mean_cluster_accuracy_during_training_cycle : 88.81%, post_traincycle_acc : 89.85%, total_acc : 89.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.85%
# accuracy_check 실행 시간: 10.992초
#
# epoch-41 loss : 0.02812
# ae train 실행 시간: 90.098초
#
# epoch-42 loss : 0.02784
# ae train 실행 시간: 91.278초
#
# epoch-43 loss : 0.02835
# ae train 실행 시간: 90.809초
#
# epoch-44 loss : 0.02867
# ae train 실행 시간: 93.911초
#
# epoch-45 loss : 0.03004
# ae train 실행 시간: 89.257초
#
# epoch-45 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97871334 0.9726673  0.93500241 0.91947927 0.9119403  0.8495283
#  0.75634013 0.58607714 0.95108422 0.91503906 0.84266409 0.70953327
#  0.95468432 0.93501455 0.8254902  0.67319637]
# mean_cluster_accuracy_during_training_cycle : 84.35%, post_traincycle_acc : 85.73%, total_acc : 85.17%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.85%
# accuracy_check 실행 시간: 11.367초
#
# epoch-46 loss : 0.02980
# ae train 실행 시간: 87.930초
#
# epoch-47 loss : 0.02928
# ae train 실행 시간: 81.967초
#
# epoch-48 loss : 0.02891
# ae train 실행 시간: 83.063초
#
# epoch-49 loss : 0.02883
# ae train 실행 시간: 81.876초
#
# epoch-50 loss : 0.02870
# ae train 실행 시간: 82.557초
#
# epoch-50 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.91958373 0.93119698 0.90129995 0.8707811  0.96218905 0.92358491
#  0.85529587 0.7046096  0.94906707 0.92529297 0.8503861  0.39076465
#  0.95519348 0.92870999 0.81176471 0.59483994]
# mean_cluster_accuracy_during_training_cycle : 83.70%, post_traincycle_acc : 84.22%, total_acc : 84.01%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.85%
# accuracy_check 실행 시간: 10.209초
#
# epoch-51 loss : 0.02858
# ae train 실행 시간: 82.251초
#
# epoch-52 loss : 0.02844
# ae train 실행 시간: 81.134초
#
# epoch-53 loss : 0.02919
# ae train 실행 시간: 82.373초
#
# epoch-54 loss : 0.02918
# ae train 실행 시간: 82.282초
#
# epoch-55 loss : 0.02952
# ae train 실행 시간: 82.553초
#
# epoch-55 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.91012299 0.92884072 0.92441021 0.90163934 0.96169154 0.93113208
#  0.86424664 0.72765757 0.91729702 0.89648438 0.8503861  0.61866931
#  0.95468432 0.93404462 0.84362745 0.63115146]
# mean_cluster_accuracy_during_training_cycle : 84.87%, post_traincycle_acc : 86.23%, total_acc : 85.67%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.85%
# accuracy_check 실행 시간: 10.079초
#
# epoch-56 loss : 0.02903
# ae train 실행 시간: 81.653초
#
# epoch-57 loss : 0.02858
# ae train 실행 시간: 81.930초
#
# epoch-58 loss : 0.02830
# ae train 실행 시간: 83.110초
#
# epoch-59 loss : 0.02817
# ae train 실행 시간: 81.953초
#
# epoch-60 loss : 0.02806
# ae train 실행 시간: 92.938초
#
# epoch-60 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97408106 0.96726047 0.95371263 0.96069652 0.93396226
#  0.88015912 0.73706491 0.97327282 0.94775391 0.86245174 0.78550149
#  0.95519348 0.93792435 0.85196078 0.71428571]
# mean_cluster_accuracy_during_training_cycle : 88.38%, post_traincycle_acc : 90.04%, total_acc : 89.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.177초
#
# epoch-61 loss : 0.02786
# ae train 실행 시간: 96.553초
#
# epoch-62 loss : 0.02766
# ae train 실행 시간: 93.366초
#
# epoch-63 loss : 0.02767
# ae train 실행 시간: 89.584초
#
# epoch-64 loss : 0.02749
# ae train 실행 시간: 98.347초
#
# epoch-65 loss : 0.02749
# ae train 실행 시간: 92.016초
#
# epoch-65 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97408106 0.96870486 0.95226615 0.96119403 0.93632075
#  0.86971656 0.73847601 0.96974281 0.94677734 0.85472973 0.44637537
#  0.95417515 0.93501455 0.8495098  0.69517439]
# mean_cluster_accuracy_during_training_cycle : 86.96%, post_traincycle_acc : 87.65%, total_acc : 87.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 10.163초
#
# epoch-66 loss : 0.02738
# ae train 실행 시간: 89.375초
#
# epoch-67 loss : 0.02735
# ae train 실행 시간: 91.520초
#
# epoch-68 loss : 0.02715
# ae train 실행 시간: 95.021초
#
# epoch-69 loss : 0.02697
# ae train 실행 시간: 89.439초
#
# epoch-70 loss : 0.02703
# ae train 실행 시간: 91.110초
#
# epoch-70 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.96972564 0.9726673  0.96677901 0.94985535 0.960199   0.94056604
#  0.88612631 0.75964252 0.9702471  0.9453125  0.86920849 0.46722939
#  0.95672098 0.93452958 0.84362745 0.69947444]
# mean_cluster_accuracy_during_training_cycle : 87.02%, post_traincycle_acc : 88.07%, total_acc : 87.65%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.931초
#
# epoch-71 loss : 0.02684
# ae train 실행 시간: 87.778초
#
# epoch-72 loss : 0.02678
# ae train 실행 시간: 89.155초
#
# epoch-73 loss : 0.02670
# ae train 실행 시간: 97.220초
#
# epoch-74 loss : 0.02671
# ae train 실행 시간: 102.511초
#
# epoch-75 loss : 0.02658
# ae train 실행 시간: 96.058초
#
# epoch-75 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.96972564 0.9726673  0.96581608 0.95274831 0.96069652 0.93773585
#  0.88115365 0.74412041 0.96923853 0.94824219 0.86486486 0.37586892
#  0.95366599 0.93404462 0.84460784 0.6722408 ]
# mean_cluster_accuracy_during_training_cycle : 86.79%, post_traincycle_acc : 87.17%, total_acc : 87.02%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.998초
#
# epoch-76 loss : 0.02658
# ae train 실행 시간: 98.911초
#
# epoch-77 loss : 0.02646
# ae train 실행 시간: 88.856초
#
# epoch-78 loss : 0.02636
# ae train 실행 시간: 87.993초
#
# epoch-79 loss : 0.02642
# ae train 실행 시간: 90.581초
#
# epoch-80 loss : 0.02629
# ae train 실행 시간: 91.544초
#
# epoch-80 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97219604 0.96774194 0.95274831 0.96119403 0.93396226
#  0.86921929 0.73565381 0.96822995 0.94775391 0.87403475 0.57447865
#  0.95315682 0.93501455 0.8377451  0.70186335]
# mean_cluster_accuracy_during_training_cycle : 87.64%, post_traincycle_acc : 88.47%, total_acc : 88.14%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.920초
#
# epoch-81 loss : 0.02635
# ae train 실행 시간: 90.071초
#
# epoch-82 loss : 0.02633
# ae train 실행 시간: 92.788초
#
# epoch-83 loss : 0.02637
# ae train 실행 시간: 92.103초
#
# epoch-84 loss : 0.02626
# ae train 실행 시간: 90.979초
#
# epoch-85 loss : 0.02622
# ae train 실행 시간: 97.939초
#
# epoch-85 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97219604 0.96726047 0.95033751 0.96169154 0.94811321
#  0.8876181  0.76669802 0.96873424 0.9453125  0.86148649 0.46474677
#  0.95723014 0.93210475 0.84656863 0.4180602 ]
# mean_cluster_accuracy_during_training_cycle : 87.15%, post_traincycle_acc : 86.37%, total_acc : 86.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.369초
#
# epoch-86 loss : 0.02630
# ae train 실행 시간: 105.294초
#
# epoch-87 loss : 0.02611
# ae train 실행 시간: 94.145초
#
# epoch-88 loss : 0.02616
# ae train 실행 시간: 98.279초
#
# epoch-89 loss : 0.02615
# ae train 실행 시간: 96.147초
#
# epoch-90 loss : 0.02614
# ae train 실행 시간: 89.593초
#
# epoch-90 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97219604 0.96677901 0.95274831 0.96119403 0.94056604
#  0.87518647 0.76716839 0.96822995 0.95068359 0.86920849 0.47517378
#  0.95570265 0.93355965 0.85245098 0.70520784]
# mean_cluster_accuracy_during_training_cycle : 87.18%, post_traincycle_acc : 88.23%, total_acc : 87.81%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.221초
#
# epoch-91 loss : 0.02602
# ae train 실행 시간: 90.469초
#
# epoch-92 loss : 0.02609
# ae train 실행 시간: 94.426초
#
# epoch-93 loss : 0.02602
# ae train 실행 시간: 88.965초
#
# epoch-94 loss : 0.02590
# ae train 실행 시간: 93.919초
#
# epoch-95 loss : 0.02591
# ae train 실행 시간: 92.392초
#
# epoch-95 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97219604 0.96677901 0.95323047 0.96218905 0.94198113
#  0.89259075 0.76058325 0.97125567 0.94824219 0.88175676 0.54766634
#  0.95875764 0.93355965 0.86029412 0.67892977]
# mean_cluster_accuracy_during_training_cycle : 87.05%, post_traincycle_acc : 88.75%, total_acc : 88.06%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 10.785초
#
# epoch-96 loss : 0.02594
# ae train 실행 시간: 89.572초
#
# epoch-97 loss : 0.02592
# ae train 실행 시간: 94.195초
#
# epoch-98 loss : 0.02591
# ae train 실행 시간: 91.104초
#
# epoch-99 loss : 0.02592
# ae train 실행 시간: 100.690초
#
# epoch-100 loss : 0.02575
# ae train 실행 시간: 98.570초
#
# epoch-100 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97219604 0.96677901 0.95226615 0.96069652 0.94716981
#  0.88662357 0.75634995 0.96570852 0.9453125  0.87258687 0.49950348
#  0.95570265 0.93452958 0.86519608 0.69899666]
# mean_cluster_accuracy_during_training_cycle : 87.88%, post_traincycle_acc : 88.44%, total_acc : 88.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.700초
#
# epoch-101 loss : 0.02576
# ae train 실행 시간: 89.375초
#
# epoch-102 loss : 0.02581
# ae train 실행 시간: 90.176초
#
# epoch-103 loss : 0.02571
# ae train 실행 시간: 87.561초
#
# epoch-104 loss : 0.02577
# ae train 실행 시간: 92.119초
#
# epoch-105 loss : 0.02574
# ae train 실행 시간: 93.484초
#
# epoch-105 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97313855 0.9682234  0.95323047 0.96218905 0.94716981
#  0.88513178 0.76152399 0.96873424 0.95068359 0.8730695  0.56554121
#  0.95366599 0.92967992 0.83529412 0.57668419]
# mean_cluster_accuracy_during_training_cycle : 87.35%, post_traincycle_acc : 87.97%, total_acc : 87.72%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.842초
#
# epoch-106 loss : 0.02566
# ae train 실행 시간: 87.684초
#
# epoch-107 loss : 0.02571
# ae train 실행 시간: 90.567초
#
# epoch-108 loss : 0.02567
# ae train 실행 시간: 88.531초
#
# epoch-109 loss : 0.02569
# ae train 실행 시간: 88.280초
#
# epoch-110 loss : 0.02567
# ae train 실행 시간: 89.093초
#
# epoch-110 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9726673  0.96774194 0.95467695 0.96169154 0.94103774
#  0.89109896 0.75352775 0.9667171  0.95068359 0.87982625 0.58838133
#  0.95264766 0.92531523 0.8372549  0.60009556]
# mean_cluster_accuracy_during_training_cycle : 87.02%, post_traincycle_acc : 88.21%, total_acc : 87.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.736초
#
# epoch-111 loss : 0.02563
# ae train 실행 시간: 91.619초
#
# epoch-112 loss : 0.02555
# ae train 실행 시간: 91.080초
#
# epoch-113 loss : 0.02570
# ae train 실행 시간: 90.744초
#
# epoch-114 loss : 0.02562
# ae train 실행 시간: 91.225초
#
# epoch-115 loss : 0.02559
# ae train 실행 시간: 94.455초
#
# epoch-115 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97219604 0.96726047 0.95323047 0.96218905 0.94386792
#  0.88214818 0.76434619 0.96722138 0.94921875 0.87017375 0.63853029
#  0.95519348 0.93549952 0.84264706 0.69804109]
# mean_cluster_accuracy_during_training_cycle : 87.61%, post_traincycle_acc : 89.20%, total_acc : 88.55%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.307초
#
# epoch-116 loss : 0.02556
# ae train 실행 시간: 88.794초
#
# epoch-117 loss : 0.02560
# ae train 실행 시간: 93.551초
#
# epoch-118 loss : 0.02554
# ae train 실행 시간: 95.776초
#
# epoch-119 loss : 0.02558
# ae train 실행 시간: 91.370초
#
# epoch-120 loss : 0.02565
# ae train 실행 시간: 91.041초
#
# epoch-120 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97172479 0.96726047 0.95467695 0.95920398 0.94811321
#  0.90054699 0.76011289 0.9702471  0.94628906 0.8730695  0.48460775
#  0.95570265 0.93161979 0.84656863 0.70998567]
# mean_cluster_accuracy_during_training_cycle : 87.67%, post_traincycle_acc : 88.44%, total_acc : 88.13%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.671초
#
# epoch-121 loss : 0.02564
# ae train 실행 시간: 90.853초
#
# epoch-122 loss : 0.02560
# ae train 실행 시간: 94.671초
#
# epoch-123 loss : 0.02562
# ae train 실행 시간: 90.189초
#
# epoch-124 loss : 0.02557
# ae train 실행 시간: 90.987초
#
# epoch-125 loss : 0.02560
# ae train 실행 시간: 91.392초
#
# epoch-125 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97125353 0.96774194 0.95419479 0.960199   0.94339623
#  0.89060169 0.75352775 0.96772567 0.94580078 0.87934363 0.33912612
#  0.95621181 0.94083414 0.84656863 0.66650741]
# mean_cluster_accuracy_during_training_cycle : 86.95%, post_traincycle_acc : 87.21%, total_acc : 87.11%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 10.110초
#
# epoch-126 loss : 0.02556
# ae train 실행 시간: 90.437초
#
# epoch-127 loss : 0.02564
# ae train 실행 시간: 89.973초
#
# epoch-128 loss : 0.02561
# ae train 실행 시간: 88.595초
#
# epoch-129 loss : 0.02563
# ae train 실행 시간: 91.364초
#
# epoch-130 loss : 0.02564
# ae train 실행 시간: 93.265초
#
# epoch-130 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97125353 0.96629754 0.95419479 0.96069652 0.94292453
#  0.8876181  0.74365005 0.96621281 0.94921875 0.86389961 0.5163853
#  0.95621181 0.93549952 0.84558824 0.45293837]
# mean_cluster_accuracy_during_training_cycle : 87.09%, post_traincycle_acc : 86.77%, total_acc : 86.89%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.875초
#
# epoch-131 loss : 0.02560
# ae train 실행 시간: 90.309초
#
# epoch-132 loss : 0.02553
# ae train 실행 시간: 88.016초
#
# epoch-133 loss : 0.02561
# ae train 실행 시간: 95.278초
#
# epoch-134 loss : 0.02557
# ae train 실행 시간: 92.684초
#
# epoch-135 loss : 0.02554
# ae train 실행 시간: 93.267초
#
# epoch-135 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97125353 0.96774194 0.95274831 0.96119403 0.94245283
#  0.88115365 0.75493885 0.9667171  0.94628906 0.878861   0.51241311
#  0.95468432 0.92870999 0.84166667 0.6469183 ]
# mean_cluster_accuracy_during_training_cycle : 87.38%, post_traincycle_acc : 87.99%, total_acc : 87.74%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.791초
#
# epoch-136 loss : 0.02555
# ae train 실행 시간: 94.816초
#
# epoch-137 loss : 0.02550
# ae train 실행 시간: 91.279초
#
# epoch-138 loss : 0.02540
# ae train 실행 시간: 93.454초
#
# epoch-139 loss : 0.02542
# ae train 실행 시간: 91.871초
#
# epoch-140 loss : 0.02546
# ae train 실행 시간: 90.891초
#
# epoch-140 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9726673  0.96726047 0.95371263 0.96119403 0.94716981
#  0.8891099  0.76575729 0.96621281 0.94677734 0.86245174 0.74131082
#  0.95773931 0.93258972 0.84362745 0.5480172 ]
# mean_cluster_accuracy_during_training_cycle : 87.75%, post_traincycle_acc : 88.91%, total_acc : 88.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.631초
#
# epoch-141 loss : 0.02549
# ae train 실행 시간: 94.931초
#
# epoch-142 loss : 0.02540
# ae train 실행 시간: 92.808초
#
# epoch-143 loss : 0.02537
# ae train 실행 시간: 98.535초
#
# epoch-144 loss : 0.02537
# ae train 실행 시간: 93.308초
#
# epoch-145 loss : 0.02536
# ae train 실행 시간: 89.209초
#
# epoch-145 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9726673  0.96726047 0.95371263 0.960199   0.94528302
#  0.87916459 0.74882408 0.96722138 0.95068359 0.86148649 0.38182721
#  0.95519348 0.93258972 0.82598039 0.46297181]
# mean_cluster_accuracy_during_training_cycle : 86.73%, post_traincycle_acc : 85.85%, total_acc : 86.20%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.364초
#
# epoch-146 loss : 0.02542
# ae train 실행 시간: 90.247초
#
# epoch-147 loss : 0.02540
# ae train 실행 시간: 90.511초
#
# epoch-148 loss : 0.02543
# ae train 실행 시간: 89.185초
#
# epoch-149 loss : 0.02543
# ae train 실행 시간: 88.891초
#
# epoch-150 loss : 0.02543
# ae train 실행 시간: 90.527초
#
# epoch-150 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97219604 0.96774194 0.95419479 0.96169154 0.94669811
#  0.89010443 0.76105362 0.96318709 0.94287109 0.85955598 0.57845084
#  0.95773931 0.94034918 0.85294118 0.69039656]
# mean_cluster_accuracy_during_training_cycle : 87.52%, post_traincycle_acc : 88.81%, total_acc : 88.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.181초
#
# epoch-151 loss : 0.02543
# ae train 실행 시간: 89.348초
#
# epoch-152 loss : 0.02544
# ae train 실행 시간: 91.593초
#
# epoch-153 loss : 0.02538
# ae train 실행 시간: 87.984초
#
# epoch-154 loss : 0.02529
# ae train 실행 시간: 89.218초
#
# epoch-155 loss : 0.02537
# ae train 실행 시간: 88.542초
#
# epoch-155 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97172479 0.96774194 0.95323047 0.96169154 0.94858491
#  0.89358528 0.76857949 0.96722138 0.94873047 0.86534749 0.46276068
#  0.95468432 0.92870999 0.82745098 0.69708552]
# mean_cluster_accuracy_during_training_cycle : 87.21%, post_traincycle_acc : 88.05%, total_acc : 87.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 10.294초
#
# epoch-156 loss : 0.02536
# ae train 실행 시간: 89.708초
#
# epoch-157 loss : 0.02534
# ae train 실행 시간: 91.267초
#
# epoch-158 loss : 0.02534
# ae train 실행 시간: 96.656초
#
# epoch-159 loss : 0.02536
# ae train 실행 시간: 91.606초
#
# epoch-160 loss : 0.02531
# ae train 실행 시간: 85.363초
#
# epoch-160 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97219604 0.96966779 0.95323047 0.96069652 0.94858491
#  0.90054699 0.77046096 0.96923853 0.94677734 0.85762548 0.5163853
#  0.95468432 0.92870999 0.825      0.70664118]
# mean_cluster_accuracy_during_training_cycle : 87.38%, post_traincycle_acc : 88.44%, total_acc : 88.01%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.285초
#
# epoch-161 loss : 0.02537
# ae train 실행 시간: 88.163초
#
# epoch-162 loss : 0.02528
# ae train 실행 시간: 90.471초
#
# epoch-163 loss : 0.02531
# ae train 실행 시간: 92.690초
#
# epoch-164 loss : 0.02533
# ae train 실행 시간: 88.524초
#
# epoch-165 loss : 0.02525
# ae train 실행 시간: 86.176초
#
# epoch-165 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97313855 0.9682234  0.95515911 0.96169154 0.94811321
#  0.8891099  0.76011289 0.96570852 0.94091797 0.86052124 0.65541212
#  0.95621181 0.94228904 0.83970588 0.69899666]
# mean_cluster_accuracy_during_training_cycle : 88.11%, post_traincycle_acc : 89.29%, total_acc : 88.81%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.090초
#
# epoch-166 loss : 0.02525
# ae train 실행 시간: 88.191초
#
# epoch-167 loss : 0.02532
# ae train 실행 시간: 89.456초
#
# epoch-168 loss : 0.02527
# ae train 실행 시간: 90.432초
#
# epoch-169 loss : 0.02528
# ae train 실행 시간: 97.555초
#
# epoch-170 loss : 0.02527
# ae train 실행 시간: 94.302초
#
# epoch-170 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97172479 0.9682234  0.95467695 0.96119403 0.94669811
#  0.89855793 0.77939793 0.96873424 0.94677734 0.86245174 0.4836147
#  0.95417515 0.92774006 0.85       0.69326326]
# mean_cluster_accuracy_during_training_cycle : 87.41%, post_traincycle_acc : 88.36%, total_acc : 87.97%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.508초
#
# epoch-171 loss : 0.02531
# ae train 실행 시간: 93.047초
#
# epoch-172 loss : 0.02530
# ae train 실행 시간: 88.675초
#
# epoch-173 loss : 0.02523
# ae train 실행 시간: 94.546초
#
# epoch-174 loss : 0.02523
# ae train 실행 시간: 92.895초
#
# epoch-175 loss : 0.02524
# ae train 실행 시간: 94.627초
#
# epoch-175 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9726673  0.9682234  0.95323047 0.96169154 0.94339623
#  0.89060169 0.76481656 0.96772567 0.94580078 0.87210425 0.50645482
#  0.95468432 0.93064985 0.83039216 0.68179646]
# mean_cluster_accuracy_during_training_cycle : 87.02%, post_traincycle_acc : 88.22%, total_acc : 87.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.321초
#
# epoch-176 loss : 0.02522
# ae train 실행 시간: 91.450초
#
# epoch-177 loss : 0.02524
# ae train 실행 시간: 91.878초
#
# epoch-178 loss : 0.02520
# ae train 실행 시간: 88.805초
#
# epoch-179 loss : 0.02518
# ae train 실행 시간: 95.530초
#
# epoch-180 loss : 0.02518
# ae train 실행 시간: 102.261초
#
# epoch-180 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97172479 0.9682234  0.95371263 0.960199   0.94811321
#  0.88960716 0.76763876 0.96822995 0.94580078 0.86486486 0.44985104
#  0.95366599 0.92386033 0.84313725 0.69708552]
# mean_cluster_accuracy_during_training_cycle : 87.33%, post_traincycle_acc : 87.98%, total_acc : 87.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.464초
#
# epoch-181 loss : 0.02525
# ae train 실행 시간: 88.831초
#
# epoch-182 loss : 0.02519
# ae train 실행 시간: 86.399초
#
# epoch-183 loss : 0.02528
# ae train 실행 시간: 90.502초
#
# epoch-184 loss : 0.02527
# ae train 실행 시간: 89.814초
#
# epoch-185 loss : 0.02526
# ae train 실행 시간: 89.562초
#
# epoch-185 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9726673  0.9682234  0.95515911 0.96119403 0.94575472
#  0.88861263 0.75964252 0.96772567 0.94726562 0.86341699 0.49851043
#  0.94602851 0.92919496 0.84852941 0.67128524]
# mean_cluster_accuracy_during_training_cycle : 87.24%, post_traincycle_acc : 88.09%, total_acc : 87.75%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 10.419초
#
# epoch-186 loss : 0.02522
# ae train 실행 시간: 88.617초
#
# epoch-187 loss : 0.02528
# ae train 실행 시간: 93.558초
#
# epoch-188 loss : 0.02519
# ae train 실행 시간: 87.359초
#
# epoch-189 loss : 0.02520
# ae train 실행 시간: 91.424초
#
# epoch-190 loss : 0.02519
# ae train 실행 시간: 88.002초
#
# epoch-190 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.9726673  0.96774194 0.95515911 0.96119403 0.95
#  0.90551964 0.7812794  0.9702471  0.94726562 0.86631274 0.6142006
#  0.95366599 0.93598448 0.84264706 0.70043   ]
# mean_cluster_accuracy_during_training_cycle : 87.54%, post_traincycle_acc : 89.35%, total_acc : 88.61%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.440초
#
# epoch-191 loss : 0.02527
# ae train 실행 시간: 93.886초
#
# epoch-192 loss : 0.02523
# ae train 실행 시간: 88.422초
#
# epoch-193 loss : 0.02524
# ae train 실행 시간: 92.840초
#
# epoch-194 loss : 0.02525
# ae train 실행 시간: 88.649초
#
# epoch-195 loss : 0.02518
# ae train 실행 시간: 89.809초
#
# epoch-195 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97172479 0.96774194 0.95419479 0.960199   0.94669811
#  0.89159622 0.76575729 0.96822995 0.94970703 0.86920849 0.58341609
#  0.95621181 0.92870999 0.52058824 0.69708552]
# mean_cluster_accuracy_during_training_cycle : 86.29%, post_traincycle_acc : 86.89%, total_acc : 86.65%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.183초
#
# epoch-196 loss : 0.02521
# ae train 실행 시간: 85.203초
#
# epoch-197 loss : 0.02525
# ae train 실행 시간: 94.242초
#
# epoch-198 loss : 0.02524
# ae train 실행 시간: 100.495초
#
# epoch-199 loss : 0.02525
# ae train 실행 시간: 101.122초
#
# epoch-200 loss : 0.02527
# ae train 실행 시간: 94.104초
#
# epoch-200 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.9726673  0.96774194 0.95515911 0.96119403 0.94716981
#  0.89656887 0.76575729 0.96822995 0.94628906 0.86679537 0.5387289
#  0.95417515 0.92628516 0.84656863 0.67606307]
# mean_cluster_accuracy_during_training_cycle : 87.58%, post_traincycle_acc : 88.50%, total_acc : 88.13%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.281초
#
# epoch-201 loss : 0.02527
# ae train 실행 시간: 85.644초
#
# epoch-202 loss : 0.02528
# ae train 실행 시간: 88.548초
#
# epoch-203 loss : 0.02526
# ae train 실행 시간: 93.106초
#
# epoch-204 loss : 0.02523
# ae train 실행 시간: 88.516초
#
# epoch-205 loss : 0.02526
# ae train 실행 시간: 86.584초
#
# epoch-205 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.97172479 0.96774194 0.95371263 0.96119403 0.9509434
#  0.91148682 0.78880527 0.9702471  0.95361328 0.86969112 0.57447865
#  0.95875764 0.93792435 0.85196078 0.70568562]
# mean_cluster_accuracy_during_training_cycle : 87.98%, post_traincycle_acc : 89.37%, total_acc : 88.80%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.04%
# accuracy_check 실행 시간: 11.179초
#
# epoch-206 loss : 0.02523
# ae train 실행 시간: 87.564초
#
# epoch-207 loss : 0.02518
# ae train 실행 시간: 91.563초
#
# epoch-208 loss : 0.02519
# ae train 실행 시간: 86.882초
#
# epoch-209 loss : 0.02520
# ae train 실행 시간: 91.162초
#
# epoch-210 loss : 0.02526
# ae train 실행 시간: 89.049초
#
# epoch-210 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97219604 0.9682234  0.95178399 0.96268657 0.94811321
#  0.90353058 0.7855127  0.96923853 0.94433594 0.85859073 0.76315789
#  0.95875764 0.94228904 0.85       0.70711897]
# mean_cluster_accuracy_during_training_cycle : 88.31%, post_traincycle_acc : 90.35%, total_acc : 89.52%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.076초
#
# epoch-211 loss : 0.02522
# ae train 실행 시간: 88.565초
#
# epoch-212 loss : 0.02518
# ae train 실행 시간: 88.580초
#
# epoch-213 loss : 0.02529
# ae train 실행 시간: 89.034초
#
# epoch-214 loss : 0.02523
# ae train 실행 시간: 86.393초
#
# epoch-215 loss : 0.02522
# ae train 실행 시간: 89.833초
#
# epoch-215 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.9736098  0.9682234  0.95515911 0.96119403 0.94764151
#  0.89706614 0.77469426 0.97125567 0.95117188 0.86534749 0.74726912
#  0.95366599 0.93792435 0.84411765 0.69469661]
# mean_cluster_accuracy_during_training_cycle : 88.04%, post_traincycle_acc : 90.09%, total_acc : 89.25%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 10.287초
#
# epoch-216 loss : 0.02524
# ae train 실행 시간: 85.283초
#
# epoch-217 loss : 0.02517
# ae train 실행 시간: 87.831초
#
# epoch-218 loss : 0.02521
# ae train 실행 시간: 91.059초
#
# epoch-219 loss : 0.02512
# ae train 실행 시간: 88.564초
#
# epoch-220 loss : 0.02511
# ae train 실행 시간: 86.989초
#
# epoch-220 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.97125353 0.9682234  0.95419479 0.96069652 0.9495283
#  0.89010443 0.77422389 0.96822995 0.95068359 0.871139   0.48311817
#  0.95672098 0.93404462 0.8377451  0.68705208]
# mean_cluster_accuracy_during_training_cycle : 87.75%, post_traincycle_acc : 88.30%, total_acc : 88.08%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 10.832초
#
# epoch-221 loss : 0.02511
# ae train 실행 시간: 88.954초
#
# epoch-222 loss : 0.02517
# ae train 실행 시간: 88.111초
#
# epoch-223 loss : 0.02508
# ae train 실행 시간: 87.463초
#
# epoch-224 loss : 0.02504
# ae train 실행 시간: 94.652초
#
# epoch-225 loss : 0.02509
# ae train 실행 시간: 90.214초
#
# epoch-225 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97313855 0.96870486 0.95564127 0.96268657 0.94716981
#  0.88562904 0.7770461  0.96822995 0.94775391 0.86969112 0.59930487
#  0.95112016 0.93016489 0.83137255 0.68036312]
# mean_cluster_accuracy_during_training_cycle : 87.65%, post_traincycle_acc : 88.87%, total_acc : 88.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.219초
#
# epoch-226 loss : 0.02504
# ae train 실행 시간: 94.994초
#
# epoch-227 loss : 0.02503
# ae train 실행 시간: 87.707초
#
# epoch-228 loss : 0.02510
# ae train 실행 시간: 86.770초
#
# epoch-229 loss : 0.02504
# ae train 실행 시간: 86.313초
#
# epoch-230 loss : 0.02498
# ae train 실행 시간: 93.713초
#
# epoch-230 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97125353 0.96726047 0.95756991 0.96119403 0.94716981
#  0.88463451 0.78363123 0.96772567 0.95117188 0.87403475 0.56703078
#  0.95621181 0.93501455 0.83235294 0.67271859]
# mean_cluster_accuracy_during_training_cycle : 88.20%, post_traincycle_acc : 88.76%, total_acc : 88.53%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.604초
#
# epoch-231 loss : 0.02518
# ae train 실행 시간: 88.307초
#
# epoch-232 loss : 0.02503
# ae train 실행 시간: 90.663초
#
# epoch-233 loss : 0.02509
# ae train 실행 시간: 91.468초
#
# epoch-234 loss : 0.02496
# ae train 실행 시간: 89.268초
#
# epoch-235 loss : 0.02502
# ae train 실행 시간: 88.548초
#
# epoch-235 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97219604 0.96774194 0.95660559 0.96069652 0.94858491
#  0.90104426 0.78363123 0.96722138 0.95019531 0.87403475 0.50297915
#  0.95264766 0.93695441 0.84901961 0.69565217]
# mean_cluster_accuracy_during_training_cycle : 87.92%, post_traincycle_acc : 88.70%, total_acc : 88.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.555초
#
# epoch-236 loss : 0.02508
# ae train 실행 시간: 95.435초
#
# epoch-237 loss : 0.02508
# ae train 실행 시간: 90.877초
#
# epoch-238 loss : 0.02499
# ae train 실행 시간: 87.824초
#
# epoch-239 loss : 0.02503
# ae train 실행 시간: 90.172초
#
# epoch-240 loss : 0.02499
# ae train 실행 시간: 88.768초
#
# epoch-240 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9726673  0.9682234  0.95467695 0.96218905 0.9495283
#  0.89706614 0.789746   0.96772567 0.95263672 0.87451737 0.72095333
#  0.95672098 0.94374394 0.83970588 0.69851887]
# mean_cluster_accuracy_during_training_cycle : 88.34%, post_traincycle_acc : 90.12%, total_acc : 89.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.237초
#
# epoch-241 loss : 0.02504
# ae train 실행 시간: 90.992초
#
# epoch-242 loss : 0.02502
# ae train 실행 시간: 89.852초
#
# epoch-243 loss : 0.02506
# ae train 실행 시간: 90.584초
#
# epoch-244 loss : 0.02497
# ae train 실행 시간: 88.628초
#
# epoch-245 loss : 0.02497
# ae train 실행 시간: 88.873초
#
# epoch-245 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97172479 0.96774194 0.95660559 0.96069652 0.94764151
#  0.89308802 0.7770461  0.96974281 0.95166016 0.88079151 0.44240318
#  0.95672098 0.93889428 0.84166667 0.69612996]
# mean_cluster_accuracy_during_training_cycle : 87.93%, post_traincycle_acc : 88.27%, total_acc : 88.14%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 10.228초
#
# epoch-246 loss : 0.02502
# ae train 실행 시간: 90.606초
#
# epoch-247 loss : 0.02505
# ae train 실행 시간: 92.205초
#
# epoch-248 loss : 0.02501
# ae train 실행 시간: 85.861초
#
# epoch-249 loss : 0.02503
# ae train 실행 시간: 92.273초
#
# epoch-250 loss : 0.02510
# ae train 실행 시간: 93.004초
#
# epoch-250 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97219604 0.9682234  0.95515911 0.96069652 0.94622642
#  0.89507708 0.7784572  0.96722138 0.94384766 0.86824324 0.58788481
#  0.95468432 0.93743938 0.83970588 0.68848543]
# mean_cluster_accuracy_during_training_cycle : 87.94%, post_traincycle_acc : 88.97%, total_acc : 88.55%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.926초
#
# epoch-251 loss : 0.02502
# ae train 실행 시간: 90.971초
#
# epoch-252 loss : 0.02506
# ae train 실행 시간: 90.660초
#
# epoch-253 loss : 0.02496
# ae train 실행 시간: 90.308초
#
# epoch-254 loss : 0.02498
# ae train 실행 시간: 91.942초
#
# epoch-255 loss : 0.02501
# ae train 실행 시간: 90.134초
#
# epoch-255 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.97125353 0.96918633 0.95708775 0.96169154 0.94858491
#  0.90253605 0.7826905  0.96722138 0.94677734 0.878861   0.48063555
#  0.95773931 0.94228904 0.81715686 0.68561873]
# mean_cluster_accuracy_during_training_cycle : 87.91%, post_traincycle_acc : 88.38%, total_acc : 88.19%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.35%
# accuracy_check 실행 시간: 11.627초
#
# epoch-256 loss : 0.02501
# ae train 실행 시간: 95.449초
#
# epoch-257 loss : 0.02497
# ae train 실행 시간: 91.347초
#
# epoch-258 loss : 0.02497
# ae train 실행 시간: 97.060초
#
# epoch-259 loss : 0.02502
# ae train 실행 시간: 99.036초
#
# epoch-260 loss : 0.02492
# ae train 실행 시간: 96.240초
#
# epoch-260 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9736098  0.96774194 0.95515911 0.96069652 0.94811321
#  0.89259075 0.78316087 0.96873424 0.95117188 0.88127413 0.76415094
#  0.95723014 0.93549952 0.85       0.70090779]
# mean_cluster_accuracy_during_training_cycle : 88.58%, post_traincycle_acc : 90.38%, total_acc : 89.64%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.990초
#
# epoch-261 loss : 0.02501
# ae train 실행 시간: 98.632초
#
# epoch-262 loss : 0.02491
# ae train 실행 시간: 88.631초
#
# epoch-263 loss : 0.02501
# ae train 실행 시간: 92.842초
#
# epoch-264 loss : 0.02504
# ae train 실행 시간: 92.851초
#
# epoch-265 loss : 0.02497
# ae train 실행 시간: 86.993초
#
# epoch-265 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9736098  0.96870486 0.95467695 0.95970149 0.94669811
#  0.89656887 0.78222013 0.96772567 0.94921875 0.87548263 0.56256207
#  0.95621181 0.93598448 0.82794118 0.6808409 ]
# mean_cluster_accuracy_during_training_cycle : 87.38%, post_traincycle_acc : 88.81%, total_acc : 88.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.329초
#
# epoch-266 loss : 0.02498
# ae train 실행 시간: 94.023초
#
# epoch-267 loss : 0.02492
# ae train 실행 시간: 90.677초
#
# epoch-268 loss : 0.02495
# ae train 실행 시간: 89.087초
#
# epoch-269 loss : 0.02496
# ae train 실행 시간: 87.998초
#
# epoch-270 loss : 0.02498
# ae train 실행 시간: 86.532초
#
# epoch-270 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9726673  0.96966779 0.95371263 0.96119403 0.9509434
#  0.90203879 0.79068674 0.96772567 0.95117188 0.8769305  0.4632572
#  0.95468432 0.93646945 0.85539216 0.70234114]
# mean_cluster_accuracy_during_training_cycle : 88.15%, post_traincycle_acc : 88.63%, total_acc : 88.44%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 10.941초
#
# epoch-271 loss : 0.02493
# ae train 실행 시간: 87.210초
#
# epoch-272 loss : 0.02497
# ae train 실행 시간: 90.510초
#
# epoch-273 loss : 0.02491
# ae train 실행 시간: 89.103초
#
# epoch-274 loss : 0.02482
# ae train 실행 시간: 89.067초
#
# epoch-275 loss : 0.02491
# ae train 실행 시간: 88.228초
#
# epoch-275 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.9736098  0.9682234  0.95564127 0.960199   0.94858491
#  0.88662357 0.78739417 0.96923853 0.94873047 0.87162162 0.78003972
#  0.95723014 0.93064985 0.84411765 0.68896321]
# mean_cluster_accuracy_during_training_cycle : 88.84%, post_traincycle_acc : 90.26%, total_acc : 89.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 10.593초
#
# epoch-276 loss : 0.02488
# ae train 실행 시간: 89.021초
#
# epoch-277 loss : 0.02487
# ae train 실행 시간: 96.369초
#
# epoch-278 loss : 0.02483
# ae train 실행 시간: 97.132초
#
# epoch-279 loss : 0.02482
# ae train 실행 시간: 96.479초
#
# epoch-280 loss : 0.02477
# ae train 실행 시간: 92.127초
#
# epoch-280 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.97313855 0.96677901 0.95419479 0.96069652 0.95141509
#  0.91098956 0.78598307 0.96923853 0.94824219 0.87789575 0.59731877
#  0.95519348 0.92919496 0.85931373 0.69517439]
# mean_cluster_accuracy_during_training_cycle : 88.30%, post_traincycle_acc : 89.41%, total_acc : 88.96%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.387초
#
# epoch-281 loss : 0.02484
# ae train 실행 시간: 98.000초
#
# epoch-282 loss : 0.02481
# ae train 실행 시간: 91.612초
#
# epoch-283 loss : 0.02481
# ae train 실행 시간: 96.377초
#
# epoch-284 loss : 0.02481
# ae train 실행 시간: 94.205초
#
# epoch-285 loss : 0.02488
# ae train 실행 시간: 88.498초
#
# epoch-285 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9736098  0.96918633 0.95564127 0.96169154 0.9504717
#  0.90551964 0.7798683  0.96923853 0.94921875 0.87741313 0.46871897
#  0.95723014 0.93307468 0.8504902  0.68705208]
# mean_cluster_accuracy_during_training_cycle : 88.13%, post_traincycle_acc : 88.50%, total_acc : 88.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.147초
#
# epoch-286 loss : 0.02480
# ae train 실행 시간: 89.610초
#
# epoch-287 loss : 0.02483
# ae train 실행 시간: 89.928초
#
# epoch-288 loss : 0.02481
# ae train 실행 시간: 89.728초
#
# epoch-289 loss : 0.02485
# ae train 실행 시간: 93.987초
#
# epoch-290 loss : 0.02481
# ae train 실행 시간: 88.205초
#
# epoch-290 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97019868 0.97172479 0.96870486 0.95612343 0.96119403 0.95188679
#  0.90701144 0.78457197 0.96873424 0.95703125 0.87451737 0.43346574
#  0.95570265 0.92919496 0.85882353 0.7032967 ]
# mean_cluster_accuracy_during_training_cycle : 87.91%, post_traincycle_acc : 88.45%, total_acc : 88.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.484초
#
# epoch-291 loss : 0.02485
# ae train 실행 시간: 91.294초
#
# epoch-292 loss : 0.02483
# ae train 실행 시간: 90.591초
#
# epoch-293 loss : 0.02483
# ae train 실행 시간: 93.821초
#
# epoch-294 loss : 0.02484
# ae train 실행 시간: 94.384초
#
# epoch-295 loss : 0.02482
# ae train 실행 시간: 103.106초
#
# epoch-295 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9736098  0.96966779 0.95564127 0.96119403 0.9490566
#  0.89806067 0.78739417 0.96974281 0.95361328 0.875      0.56305859
#  0.95621181 0.93646945 0.8377451  0.69565217]
# mean_cluster_accuracy_during_training_cycle : 87.69%, post_traincycle_acc : 89.09%, total_acc : 88.52%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.620초
#
# epoch-296 loss : 0.02485
# ae train 실행 시간: 92.446초
#
# epoch-297 loss : 0.02483
# ae train 실행 시간: 92.803초
#
# epoch-298 loss : 0.02483
# ae train 실행 시간: 89.835초
#
# epoch-299 loss : 0.02488
# ae train 실행 시간: 98.903초
#
# epoch-300 loss : 0.02483
# ae train 실행 시간: 87.147초
#
# epoch-300 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9726673  0.96918633 0.95756991 0.96169154 0.95141509
#  0.90054699 0.77422389 0.96923853 0.95458984 0.87837838 0.60973188
#  0.95723014 0.94034918 0.84019608 0.70138557]
# mean_cluster_accuracy_during_training_cycle : 88.25%, post_traincycle_acc : 89.44%, total_acc : 88.95%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.38%
# accuracy_check 실행 시간: 11.277초
#
# epoch-301 loss : 0.02487
# ae train 실행 시간: 97.034초
#
# epoch-302 loss : 0.02490
# ae train 실행 시간: 95.966초
#
# epoch-303 loss : 0.02484
# ae train 실행 시간: 99.296초
#
# epoch-304 loss : 0.02481
# ae train 실행 시간: 95.909초
#
# epoch-305 loss : 0.02483
# ae train 실행 시간: 99.945초
#
# epoch-305 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97455231 0.9682234  0.95515911 0.96119403 0.95
#  0.90054699 0.77939793 0.96873424 0.94775391 0.88223938 0.76216485
#  0.95672098 0.94034918 0.86127451 0.68848543]
# mean_cluster_accuracy_during_training_cycle : 88.43%, post_traincycle_acc : 90.42%, total_acc : 89.61%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.42%
# accuracy_check 실행 시간: 10.246초
#
# epoch-306 loss : 0.02488
# ae train 실행 시간: 91.375초
#
# epoch-307 loss : 0.02487
# ae train 실행 시간: 99.027초
#
# epoch-308 loss : 0.02479
# ae train 실행 시간: 94.573초
#
# ...
#  0.90800597 0.7841016  0.97075139 0.95166016 0.87789575 0.63505462
#  0.95977597 0.9442289  0.85882353 0.69374104]
# mean_cluster_accuracy_during_training_cycle : 88.29%, post_traincycle_acc : 89.76%, total_acc : 89.16%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.448초
#
# epoch-451 loss : 0.02465
# ae train 실행 시간: 92.116초
#
# epoch-452 loss : 0.02467
# ae train 실행 시간: 90.605초
#
# epoch-453 loss : 0.02469
# ae train 실행 시간: 91.374초
#
# epoch-454 loss : 0.02469
# ae train 실행 시간: 91.642초
#
# epoch-455 loss : 0.02459
# ae train 실행 시간: 90.603초
#
# epoch-455 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97408106 0.9682234  0.95419479 0.96069652 0.95141509
#  0.90154152 0.79350894 0.97125567 0.94921875 0.878861   0.49950348
#  0.95824847 0.94277401 0.84313725 0.69278548]
# mean_cluster_accuracy_during_training_cycle : 87.50%, post_traincycle_acc : 88.83%, total_acc : 88.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 10.636초
#
# epoch-456 loss : 0.02476
# ae train 실행 시간: 92.607초
#
# epoch-457 loss : 0.02466
# ae train 실행 시간: 91.187초
#
# epoch-458 loss : 0.02471
# ae train 실행 시간: 93.737초
#
# epoch-459 loss : 0.02470
# ae train 실행 시간: 91.680초
#
# epoch-460 loss : 0.02468
# ae train 실행 시간: 92.515초
#
# epoch-460 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9726673  0.9682234  0.95708775 0.960199   0.95141509
#  0.90601691 0.7770461  0.96873424 0.94726562 0.87548263 0.78053625
#  0.95875764 0.94325897 0.84705882 0.68036312]
# mean_cluster_accuracy_during_training_cycle : 88.84%, post_traincycle_acc : 90.41%, total_acc : 89.77%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.982초
#
# epoch-461 loss : 0.02464
# ae train 실행 시간: 90.741초
#
# epoch-462 loss : 0.02470
# ae train 실행 시간: 95.549초
#
# epoch-463 loss : 0.02467
# ae train 실행 시간: 95.385초
#
# epoch-464 loss : 0.02466
# ae train 실행 시간: 97.158초
#
# epoch-465 loss : 0.02466
# ae train 실행 시간: 92.333초
#
# epoch-465 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9736098  0.96774194 0.95612343 0.960199   0.9490566
#  0.90154152 0.77751646 0.97075139 0.94873047 0.878861   0.74031778
#  0.95570265 0.93937924 0.79754902 0.66411849]
# mean_cluster_accuracy_during_training_cycle : 87.96%, post_traincycle_acc : 89.71%, total_acc : 88.99%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.657초
#
# epoch-466 loss : 0.02474
# ae train 실행 시간: 87.547초
#
# epoch-467 loss : 0.02472
# ae train 실행 시간: 91.963초
#
# epoch-468 loss : 0.02466
# ae train 실행 시간: 91.565초
#
# epoch-469 loss : 0.02471
# ae train 실행 시간: 94.164초
#
# epoch-470 loss : 0.02472
# ae train 실행 시간: 97.898초
#
# epoch-470 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97313855 0.96870486 0.95467695 0.960199   0.95
#  0.90402785 0.79162747 0.97075139 0.94873047 0.86679537 0.62462761
#  0.95875764 0.93986421 0.84803922 0.68036312]
# mean_cluster_accuracy_during_training_cycle : 88.04%, post_traincycle_acc : 89.46%, total_acc : 88.88%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.366초
#
# epoch-471 loss : 0.02467
# ae train 실행 시간: 92.428초
#
# epoch-472 loss : 0.02476
# ae train 실행 시간: 91.190초
#
# epoch-473 loss : 0.02474
# ae train 실행 시간: 92.211초
#
# epoch-474 loss : 0.02477
# ae train 실행 시간: 91.627초
#
# epoch-475 loss : 0.02474
# ae train 실행 시간: 99.261초
#
# epoch-475 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9736098  0.9682234  0.95564127 0.960199   0.9490566
#  0.90452511 0.79021637 0.9702471  0.94921875 0.88079151 0.58093347
#  0.96028513 0.94325897 0.8372549  0.68514095]
# mean_cluster_accuracy_during_training_cycle : 87.89%, post_traincycle_acc : 89.26%, total_acc : 88.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.290초
#
# epoch-476 loss : 0.02470
# ae train 실행 시간: 97.914초
#
# epoch-477 loss : 0.02477
# ae train 실행 시간: 94.618초
#
# epoch-478 loss : 0.02477
# ae train 실행 시간: 99.837초
#
# epoch-479 loss : 0.02469
# ae train 실행 시간: 97.152초
#
# epoch-480 loss : 0.02470
# ae train 실행 시간: 96.517초
#
# epoch-480 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.97313855 0.96774194 0.95564127 0.960199   0.95141509
#  0.89955246 0.789746   0.96974281 0.94042969 0.85183398 0.74528302
#  0.96028513 0.94034918 0.84166667 0.69708552]
# mean_cluster_accuracy_during_training_cycle : 88.72%, post_traincycle_acc : 90.10%, total_acc : 89.54%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.735초
#
# epoch-481 loss : 0.02475
# ae train 실행 시간: 90.053초
#
# epoch-482 loss : 0.02465
# ae train 실행 시간: 94.780초
#
# epoch-483 loss : 0.02469
# ae train 실행 시간: 100.428초
#
# epoch-484 loss : 0.02459
# ae train 실행 시간: 96.510초
#
# epoch-485 loss : 0.02471
# ae train 실행 시간: 95.416초
#
# epoch-485 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.97313855 0.97063072 0.95756991 0.95970149 0.95
#  0.90651417 0.7911571  0.9702471  0.94091797 0.88079151 0.71549156
#  0.9592668  0.94665373 0.8004902  0.69182991]
# mean_cluster_accuracy_during_training_cycle : 88.30%, post_traincycle_acc : 89.91%, total_acc : 89.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 10.911초
#
# epoch-486 loss : 0.02465
# ae train 실행 시간: 94.041초
#
# epoch-487 loss : 0.02464
# ae train 실행 시간: 91.382초
#
# epoch-488 loss : 0.02466
# ae train 실행 시간: 92.665초
#
# epoch-489 loss : 0.02468
# ae train 실행 시간: 89.842초
#
# epoch-490 loss : 0.02482
# ae train 실행 시간: 90.529초
#
# epoch-490 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9726673  0.96774194 0.95756991 0.95970149 0.9509434
#  0.90253605 0.7855127  0.96974281 0.94580078 0.88127413 0.4632572
#  0.96028513 0.94131911 0.84362745 0.69182991]
# mean_cluster_accuracy_during_training_cycle : 87.73%, post_traincycle_acc : 88.54%, total_acc : 88.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 12.075초
#
# epoch-491 loss : 0.02474
# ae train 실행 시간: 88.576초
#
# epoch-492 loss : 0.02467
# ae train 실행 시간: 91.475초
#
# epoch-493 loss : 0.02467
# ae train 실행 시간: 94.651초
#
# epoch-494 loss : 0.02465
# ae train 실행 시간: 92.963초
#
# epoch-495 loss : 0.02470
# ae train 실행 시간: 92.150초
#
# epoch-495 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97408106 0.97063072 0.95419479 0.96119403 0.94858491
#  0.90452511 0.78174976 0.96621281 0.9453125  0.87065637 0.70059583
#  0.9592668  0.94374394 0.80147059 0.69135213]
# mean_cluster_accuracy_during_training_cycle : 88.28%, post_traincycle_acc : 89.66%, total_acc : 89.10%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 10.962초
#
# epoch-496 loss : 0.02469
# ae train 실행 시간: 94.826초
#
# epoch-497 loss : 0.02469
# ae train 실행 시간: 90.844초
#
# epoch-498 loss : 0.02472
# ae train 실행 시간: 89.056초
#
# epoch-499 loss : 0.02467
# ae train 실행 시간: 89.945초
#
# epoch-500 loss : 0.02464
# ae train 실행 시간: 90.954초
#
# epoch-500 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97161779 0.9736098  0.9682234  0.95612343 0.96069652 0.95
#  0.90203879 0.7883349  0.96974281 0.94189453 0.86872587 0.77656405
#  0.96181263 0.94034918 0.84362745 0.67558528]
# mean_cluster_accuracy_during_training_cycle : 89.03%, post_traincycle_acc : 90.31%, total_acc : 89.78%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.567초
#
# epoch-501 loss : 0.02462
# ae train 실행 시간: 89.473초
#
# epoch-502 loss : 0.02463
# ae train 실행 시간: 91.318초
#
# epoch-503 loss : 0.02482
# ae train 실행 시간: 96.513초
#
# epoch-504 loss : 0.02463
# ae train 실행 시간: 90.551초
#
# epoch-505 loss : 0.02459
# ae train 실행 시간: 92.598초
#
# epoch-505 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97219604 0.9682234  0.95467695 0.95970149 0.9504717
#  0.90402785 0.78316087 0.96722138 0.94140625 0.86872587 0.74875869
#  0.9607943  0.94131911 0.83627451 0.68179646]
# mean_cluster_accuracy_during_training_cycle : 88.63%, post_traincycle_acc : 90.07%, total_acc : 89.48%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.309초
#
# epoch-506 loss : 0.02463
# ae train 실행 시간: 88.529초
#
# epoch-507 loss : 0.02468
# ae train 실행 시간: 94.319초
#
# epoch-508 loss : 0.02460
# ae train 실행 시간: 96.316초
#
# epoch-509 loss : 0.02466
# ae train 실행 시간: 94.555초
#
# epoch-510 loss : 0.02466
# ae train 실행 시간: 94.299초
#
# epoch-510 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97219604 0.96870486 0.95660559 0.96069652 0.94858491
#  0.90054699 0.77375353 0.96772567 0.94677734 0.8503861  0.37537239
#  0.95977597 0.94034918 0.84460784 0.69708552]
# mean_cluster_accuracy_during_training_cycle : 87.87%, post_traincycle_acc : 87.72%, total_acc : 87.78%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 11.255초
#
# epoch-511 loss : 0.02465
# ae train 실행 시간: 92.321초
#
# epoch-512 loss : 0.02471
# ae train 실행 시간: 88.546초
#
# epoch-513 loss : 0.02467
# ae train 실행 시간: 92.535초
#
# epoch-514 loss : 0.02464
# ae train 실행 시간: 87.474초
#
# epoch-515 loss : 0.02465
# ae train 실행 시간: 82.483초
#
# epoch-515 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9726673  0.9682234  0.95564127 0.960199   0.9495283
#  0.9075087  0.77798683 0.96722138 0.94433594 0.87837838 0.64101291
#  0.9592668  0.94325897 0.84705882 0.66841854]
# mean_cluster_accuracy_during_training_cycle : 88.13%, post_traincycle_acc : 89.46%, total_acc : 88.92%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.038초
#
# epoch-516 loss : 0.02456
# ae train 실행 시간: 84.168초
#
# epoch-517 loss : 0.02466
# ae train 실행 시간: 81.755초
#
# epoch-518 loss : 0.02467
# ae train 실행 시간: 82.174초
#
# epoch-519 loss : 0.02460
# ae train 실행 시간: 81.970초
#
# epoch-520 loss : 0.02461
# ae train 실행 시간: 81.944초
#
# epoch-520 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.9736098  0.96966779 0.95612343 0.95970149 0.9490566
#  0.90701144 0.78457197 0.9667171  0.94238281 0.85183398 0.76961271
#  0.96028513 0.94228904 0.81078431 0.68800764]
# mean_cluster_accuracy_during_training_cycle : 88.80%, post_traincycle_acc : 90.02%, total_acc : 89.52%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.729초
#
# epoch-521 loss : 0.02457
# ae train 실행 시간: 81.821초
#
# epoch-522 loss : 0.02455
# ae train 실행 시간: 84.620초
#
# epoch-523 loss : 0.02453
# ae train 실행 시간: 82.746초
#
# epoch-524 loss : 0.02461
# ae train 실행 시간: 82.188초
#
# epoch-525 loss : 0.02457
# ae train 실행 시간: 81.806초
#
# epoch-525 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97313855 0.9682234  0.95564127 0.960199   0.9504717
#  0.90502238 0.78174976 0.96923853 0.94726562 0.83590734 0.68619662
#  0.95723014 0.93501455 0.83823529 0.67128524]
# mean_cluster_accuracy_during_training_cycle : 88.25%, post_traincycle_acc : 89.42%, total_acc : 88.94%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.628초
#
# epoch-526 loss : 0.02458
# ae train 실행 시간: 81.881초
#
# epoch-527 loss : 0.02451
# ae train 실행 시간: 81.888초
#
# epoch-528 loss : 0.02461
# ae train 실행 시간: 81.842초
#
# epoch-529 loss : 0.02459
# ae train 실행 시간: 81.767초
#
# epoch-530 loss : 0.02459
# ae train 실행 시간: 81.528초
#
# epoch-530 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97114475 0.97219604 0.96918633 0.95756991 0.960199   0.95
#  0.90154152 0.79774224 0.96873424 0.94726562 0.84507722 0.58887786
#  0.95977597 0.93937924 0.84019608 0.67654085]
# mean_cluster_accuracy_during_training_cycle : 88.11%, post_traincycle_acc : 89.03%, total_acc : 88.66%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.537초
#
# epoch-531 loss : 0.02458
# ae train 실행 시간: 81.765초
#
# epoch-532 loss : 0.02454
# ae train 실행 시간: 82.232초
#
# epoch-533 loss : 0.02450
# ae train 실행 시간: 82.121초
#
# epoch-534 loss : 0.02451
# ae train 실행 시간: 82.159초
#
# epoch-535 loss : 0.02462
# ae train 실행 시간: 82.350초
#
# epoch-535 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.9726673  0.9682234  0.95564127 0.960199   0.9509434
#  0.8990552  0.80103481 0.96822995 0.94335938 0.84459459 0.70307845
#  0.96028513 0.9442289  0.84411765 0.68418538]
# mean_cluster_accuracy_during_training_cycle : 88.32%, post_traincycle_acc : 89.83%, total_acc : 89.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.448초
#
# epoch-536 loss : 0.02454
# ae train 실행 시간: 82.092초
#
# epoch-537 loss : 0.02453
# ae train 실행 시간: 82.032초
#
# epoch-538 loss : 0.02452
# ae train 실행 시간: 81.927초
#
# epoch-539 loss : 0.02449
# ae train 실행 시간: 81.954초
#
# epoch-540 loss : 0.02451
# ae train 실행 시간: 81.892초
#
# epoch-540 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97313855 0.9682234  0.95612343 0.96069652 0.9490566
#  0.9075087  0.7855127  0.96923853 0.94775391 0.86872587 0.74230387
#  0.9592668  0.92774006 0.83529412 0.67940755]
# mean_cluster_accuracy_during_training_cycle : 88.57%, post_traincycle_acc : 90.01%, total_acc : 89.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.603초
#
# epoch-541 loss : 0.02446
# ae train 실행 시간: 81.974초
#
# epoch-542 loss : 0.02447
# ae train 실행 시간: 82.222초
#
# epoch-543 loss : 0.02445
# ae train 실행 시간: 81.909초
#
# epoch-544 loss : 0.02445
# ae train 실행 시간: 82.180초
#
# epoch-545 loss : 0.02444
# ae train 실행 시간: 81.999초
#
# epoch-545 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9736098  0.96870486 0.95612343 0.95970149 0.95
#  0.90452511 0.77093133 0.97125567 0.94775391 0.85135135 0.74975174
#  0.95773931 0.93986421 0.85196078 0.67319637]
# mean_cluster_accuracy_during_training_cycle : 88.71%, post_traincycle_acc : 89.99%, total_acc : 89.47%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 8.852초
#
# epoch-546 loss : 0.02438
# ae train 실행 시간: 82.045초
#
# epoch-547 loss : 0.02451
# ae train 실행 시간: 83.198초
#
# epoch-548 loss : 0.02439
# ae train 실행 시간: 82.291초
#
# epoch-549 loss : 0.02437
# ae train 실행 시간: 82.607초
#
# epoch-550 loss : 0.02433
# ae train 실행 시간: 82.167초
#
# epoch-550 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97313855 0.96918633 0.95612343 0.960199   0.94858491
#  0.90551964 0.78033866 0.96822995 0.94775391 0.85617761 0.69960278
#  0.9592668  0.93355965 0.83235294 0.67367415]
# mean_cluster_accuracy_during_training_cycle : 87.96%, post_traincycle_acc : 89.60%, total_acc : 88.93%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.567초
#
# epoch-551 loss : 0.02432
# ae train 실행 시간: 82.361초
#
# epoch-552 loss : 0.02451
# ae train 실행 시간: 82.151초
#
# epoch-553 loss : 0.02432
# ae train 실행 시간: 82.297초
#
# epoch-554 loss : 0.02438
# ae train 실행 시간: 81.983초
#
# epoch-555 loss : 0.02439
# ae train 실행 시간: 81.961초
#
# epoch-555 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97219604 0.96870486 0.95708775 0.960199   0.94858491
#  0.91098956 0.77798683 0.96873424 0.9453125  0.83349421 0.75273088
#  0.95977597 0.93549952 0.84166667 0.67462972]
# mean_cluster_accuracy_during_training_cycle : 88.34%, post_traincycle_acc : 89.88%, total_acc : 89.25%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.628초
#
# epoch-556 loss : 0.02439
# ae train 실행 시간: 81.896초
#
# epoch-557 loss : 0.02432
# ae train 실행 시간: 82.961초
#
# epoch-558 loss : 0.02435
# ae train 실행 시간: 82.411초
#
# epoch-559 loss : 0.02436
# ae train 실행 시간: 82.060초
#
# epoch-560 loss : 0.02429
# ae train 실행 시간: 81.816초
#
# epoch-560 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.9736098  0.96966779 0.95612343 0.960199   0.9490566
#  0.90949776 0.7770461  0.97125567 0.94482422 0.85279923 0.74478649
#  0.95824847 0.93355965 0.85147059 0.67558528]
# mean_cluster_accuracy_during_training_cycle : 88.59%, post_traincycle_acc : 90.00%, total_acc : 89.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.61%
# accuracy_check 실행 시간: 9.560초
#
# epoch-561 loss : 0.02433
# ae train 실행 시간: 81.758초
#
# epoch-562 loss : 0.02427
# ae train 실행 시간: 83.163초
#
# epoch-563 loss : 0.02433
# ae train 실행 시간: 83.729초
#
# epoch-564 loss : 0.02431
# ae train 실행 시간: 83.821초

# %%
# # Sweep code


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [True]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400, 2400]}, # [1400, 2400]

#         "batch_size": {"values": [32]}, 
#         "max_epoch": {"values": [10]}, 
#         "learning_rate": {"values": [0.001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [False]}, 

#         "lif_add_at_first": {"values": [True, False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [4,6,8,10]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True, False]}, # [True, False]

#         # "current_time": {"values": [current_time]}, 

#         "optimizer": {"values": ['Adam', 'SGD']}, # ['Adam', 'SGD']
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  1
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer


#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'
#         )
    
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_loss</td><td>█▁</td></tr><tr><td>best_mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>▁▁</td></tr><tr><td>mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_loss</td><td>0.04723</td></tr><tr><td>mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>0.85754</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dry-water-8</strong> at: <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/3h22zjyf' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/3h22zjyf</a><br/> View project at: <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250102_172820-3h22zjyf/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle
import json

# current_time = '20250102_174013_409'

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)


# JSON으로 저장
with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'r') as f:
    loaded_hyperparameters = json.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']
print(data)
max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {loaded_hyperparameters['dataset_num']}, Conv {loaded_hyperparameters['Conv_net']}, SAE {loaded_hyperparameters['SAE_net']}, Current time {loaded_hyperparameters['current_time']}, Spike Length: {loaded_hyperparameters['spike_length']}, Num Cluster: {loaded_hyperparameters['num_cluster']}, "
    f"Training Cycle: {loaded_hyperparameters['training_cycle']}, Batch Size: {loaded_hyperparameters['batch_size']}, Max Epoch: {loaded_hyperparameters['max_epoch']}, \n"
    f"Learning Rate: {loaded_hyperparameters['learning_rate']}, Input Normalize: {loaded_hyperparameters['normalize_on']}, Need Bias: {loaded_hyperparameters['need_bias']}, "
    f"LIF Add at First: {loaded_hyperparameters['lif_add_at_first']}, TIME: {loaded_hyperparameters['TIME']}, Seed: {loaded_hyperparameters['my_seed']}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
# Out:
# {'loss_history': [(0, 0.18730856161254147), (1, 0.047603290310750404), (2, 0.04239892876551797), (3, 0.03985585139753918), (4, 0.03726986728298167), (5, 0.036172446253088616), (6, 0.03550038663980862), (7, 0.034944336139597), (8, 0.034647901627856), (9, 0.03429996207201232), (10, 0.03384012920471529), (11, 0.033482864315932), (12, 0.03317516221975287), (13, 0.03268646733059238), (14, 0.03232689795705179), (15, 0.03211458158213645), (16, 0.03184037478175014), (17, 0.031791644270221395), (18, 0.03155548967110614), (19, 0.03153269092552364), (20, 0.031365693906943), (21, 0.031137633469576636), (22, 0.03090939124270032), (23, 0.030685637216083705), (24, 0.03056494041190793), (25, 0.030573960773957274), (26, 0.030447985478676855), (27, 0.03023172974276046), (28, 0.030174091526617607), (29, 0.030018824651682128), (30, 0.029999862622159222), (31, 0.029925607581002017), (32, 0.029756850114402673), (33, 0.029710914373087385), (34, 0.029679838695252935), (35, 0.029602644285187125), (36, 0.029469300465813527), (37, 0.02932856032003959), (38, 0.029387956944604714), (39, 0.029240494589321316), (40, 0.029202853239451845), (41, 0.029181641202109556), (42, 0.02916055751654009)], 'mean_cluster_accuracy_during_training_cycle_all_dataset_history': [(0, 83.95982142857143), (1, 85.02232142857142)], 'mean_cluster_accuracy_post_training_cycle_all_dataset_history': [(0, 84.83554657856209), (1, 86.84524896482168)], 'mean_cluster_accuracy_total_all_dataset_history': [(0, 84.48512748877992), (1, 86.10543199362921)]}
