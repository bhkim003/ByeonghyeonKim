# %% [markdown]
# # ssp.train.py

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    ):
    
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset", summary="max")

    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])


    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'

    n_sample = spike_length

    seed_assign(my_seed)

    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            net = Autoencoder_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, 4], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            net = SAE_conv1(input_channels=1, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first)
            net = torch.nn.DataParallel(net)
        else:
            net = SAE_fc_only(encoder_ch=[96, 64, 32, 4], 
                                decoder_ch=[32,64,96,n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마





    wandb.watch(net, log="all", log_freq = 10)









    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    net = net.to(device)
    print(net)
    print('Device:',device)

    criterion = nn.MSELoss()
    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    for epoch in range(max_epoch):

        running_loss = 0.0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike = data
            spike = spike.to(device)
            if 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
            spike_class = net(spike)

            # if 'SAE' in net.module.__class__.__name__:
            #     spike = spike.mean(dim=1)# Time 방향으로 평균
            #     spike_class = spike_class.mean(dim=1)# Time 방향으로 평균

            if 'SAE' in net.module.__class__.__name__:
                loss1 = criterion(spike_class[:, :, 5:25], spike[:, :, 5:25])
                loss2 = criterion(spike_class[:, :, 0:5], spike[:, :, 0:5])
                loss3 = criterion(spike_class[:, :, 25:spike_length], spike[:, :, 25:spike_length])
            else:
                loss1 = criterion(spike_class[:, 5:25], spike[:, 5:25])
                loss2 = criterion(spike_class[:, 0:5], spike[:, 0:5])
                loss3 = criterion(spike_class[:, 25:spike_length], spike[:, 25:spike_length])

            loss = loss1 * 2.125 + (loss2 + loss3)/4
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        avg_loss = running_loss / len(train_loader)
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')






        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    
        
        if(epoch %50 ==0): 
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = 4*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else 4

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    for i in range(num_cluster):
                        spike_torch = torch.from_numpy(spike_template[i, :])
                        spike_torch = spike_torch.float().to(device)
                        if 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
                        else:
                            spike_torch = spike_torch.unsqueeze(0)
                        inner_inf = net.module.encoder(spike_torch)
                        # if 'SAE' in net.module.__class__.__name__:
                        #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                        #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                        #     print(all_equal, inner_inf)

                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.view(1,-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        Cluster[i, :] = inner_inf.cpu().detach().numpy()

                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    for i in range(len(spike)):
                        spike_torch = torch.from_numpy(spike[i, :])
                        spike_torch = spike_torch.float().to(device)
                        if 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
                        else:
                            spike_torch = spike_torch.unsqueeze(0)
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.view(1,-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[i, :] = inner_inf.cpu().detach().numpy()
                    
                spike_id = np.zeros(len(spike))


                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                            tau[q] = tau[q] / denominator
                        # print(np.linalg.norm(spike_hidden[spike_index, :]))
                        # print(np.linalg.norm(Cluster[q, :]))
                    # tau = np.dot(Cluster, spike_hidden[spike_index, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.

                    for i in range(num_cluster): # l2 distance
                        distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))

                    m = np.argmin(distance_sm)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16
                                
                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1

                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                # print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
        
        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


    # 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
        pickle.dump({
            "loss_history": loss_history,
            "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
            "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
            "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
        }, f)

# %%
gpu = 0
Conv_net = True
SAE_net = True

# hyperparameter
dataset_num = 16
spike_length = 50
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 1400 # 그 초기 몇개까지만 cluster update할지


batch_size = 32
max_epoch = 7000
learning_rate = 0.001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 8 # SAE일 때만 유효
v_decay = 0.75
v_threshold = 0.25
v_reset = 0 # 10000이상 일 시 hard reset
BPTT_on = True

SAE_hidden_nomean = False

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'Adam' #'Adam', 'SGD'

wandb.init(project= f'spike_sorting just run',save_code=False)

cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    current_time = current_time,
    optimizer = optimizer, #'Adam', 'SGD'
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250102_023420-j3a3r4m7</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/j3a3r4m7' target="_blank">swept-mountain-4</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/j3a3r4m7' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/j3a3r4m7</a>
# {'gpu': 0, 'Conv_net': True, 'SAE_net': True, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 1400, 'batch_size': 32, 'max_epoch': 7000, 'learning_rate': 0.001, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 8, 'v_decay': 0.75, 'v_threshold': 0.25, 'v_reset': 0, 'BPTT_on': True, 'SAE_hidden_nomean': False, 'current_time': '20250102_023418_612', 'optimizer': 'Adam'}
# DataParallel(
#   (module): SAE_conv1(
#     (encoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_unsuqeeze()
#       (2): SSBH_DimChanger_for_one_two_coupling()
#       (3): Conv1d(1, 32, kernel_size=(3,), stride=(2,), bias=False)
#       (4): SSBH_DimChanger_for_one_two_decoupling()
#       (5): LIF_layer()
#       (6): SSBH_DimChanger_for_one_two_coupling()
#       (7): Conv1d(32, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (8): SSBH_DimChanger_for_one_two_decoupling()
#       (9): LIF_layer()
#       (10): SSBH_DimChanger_for_one_two_coupling()
#       (11): Conv1d(64, 96, kernel_size=(3,), stride=(2,), bias=False)
#       (12): SSBH_DimChanger_for_one_two_decoupling()
#       (13): LIF_layer()
#       (14): SSBH_DimChanger_for_one_two_coupling()
#       (15): SSBH_DimChanger_for_fc()
#       (16): Linear(in_features=480, out_features=4, bias=False)
#       (17): SSBH_L2NormLayer()
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_one_two()
#     )
#     (decoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_one_two_coupling()
#       (2): Linear(in_features=4, out_features=480, bias=False)
#       (3): SSBH_DimChanger_for_one_two_decoupling()
#       (4): LIF_layer()
#       (5): SSBH_DimChanger_for_one_two_coupling()
#       (6): SSBH_DimChanger_for_conv1()
#       (7): SSBH_DimChanger_for_one_two_decoupling()
#       (8): SSBH_DimChanger_for_one_two_coupling()
#       (9): ConvTranspose1d(96, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (10): SSBH_DimChanger_for_one_two_decoupling()
#       (11): LIF_layer()
#       (12): SSBH_DimChanger_for_one_two_coupling()
#       (13): ConvTranspose1d(64, 32, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (14): SSBH_DimChanger_for_one_two_decoupling()
#       (15): LIF_layer()
#       (16): SSBH_DimChanger_for_one_two_coupling()
#       (17): ConvTranspose1d(32, 1, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (18): SSBH_DimChanger_for_one_two_decoupling()
#       (19): SSBH_DimChanger_for_suqeeze()
#       (20): SSBH_DimChanger_one_two()
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250102_023418_612
#
# epoch-0 loss : 0.24791
#
# epoch-0 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97587512 0.97596607 0.97111218 0.95467695 0.96218905 0.92358491
#  0.86176032 0.70555033 0.95057993 0.93261719 0.83349421 0.71052632
#  0.95010183 0.91367604 0.67990196 0.72097468]
# mean_cluster_accuracy_during_training_cycle : 86.37%, post_traincycle_acc : 87.64%, total_acc : 87.12%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 87.64%
#
# epoch-1 loss : 0.04614
#
# epoch-2 loss : 0.03997
#
# epoch-3 loss : 0.03717
#
# epoch-4 loss : 0.03563
#
# epoch-5 loss : 0.03436
#
# epoch-6 loss : 0.03348
#
# epoch-7 loss : 0.03279
#
# epoch-8 loss : 0.03209
#
# epoch-9 loss : 0.03172
#
# epoch-10 loss : 0.03119
#
# epoch-11 loss : 0.03091
#
# epoch-12 loss : 0.03073
#
# epoch-13 loss : 0.03046
#
# epoch-14 loss : 0.03029
#
# epoch-15 loss : 0.03013
#
# epoch-16 loss : 0.03007
#
# epoch-17 loss : 0.02992
#
# epoch-18 loss : 0.02985
#
# epoch-19 loss : 0.02977
#
# epoch-20 loss : 0.02970
#
# epoch-21 loss : 0.02959
#
# epoch-22 loss : 0.02946
#
# epoch-23 loss : 0.02944
#
# epoch-24 loss : 0.02935
#
# epoch-25 loss : 0.02929
#
# epoch-26 loss : 0.02927
#
# epoch-27 loss : 0.02924
#
# epoch-28 loss : 0.02931
#
# epoch-29 loss : 0.02940
#
# epoch-30 loss : 0.02964
#
# epoch-31 loss : 0.02967
#
# epoch-32 loss : 0.02970
#
# epoch-33 loss : 0.02962
#
# epoch-34 loss : 0.02961
#
# epoch-35 loss : 0.02939
#
# epoch-36 loss : 0.02929
#
# epoch-37 loss : 0.02917
#
# epoch-38 loss : 0.02907
#
# epoch-39 loss : 0.02911
#
# epoch-40 loss : 0.02911
#
# epoch-41 loss : 0.02894
#
# epoch-42 loss : 0.02906
#
# epoch-43 loss : 0.02891
#
# epoch-44 loss : 0.02894
#
# epoch-45 loss : 0.02876
#
# epoch-46 loss : 0.02876
#
# epoch-47 loss : 0.02863
#
# epoch-48 loss : 0.02859
#
# epoch-49 loss : 0.02854
#
# epoch-50 loss : 0.02847
#
# epoch-50 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97776727 0.97596607 0.97111218 0.95467695 0.96218905 0.94009434
#  0.87817006 0.75870179 0.96520424 0.93994141 0.83301158 0.69513406
#  0.95672098 0.93646945 0.80343137 0.48542762]
# mean_cluster_accuracy_during_training_cycle : 86.29%, post_traincycle_acc : 87.71%, total_acc : 87.13%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 87.71%
#
# epoch-51 loss : 0.02849
#
# epoch-52 loss : 0.02846
#
# epoch-53 loss : 0.02827
#
# epoch-54 loss : 0.02823
#
# epoch-55 loss : 0.02820
#
# epoch-56 loss : 0.02826
#
# epoch-57 loss : 0.02816
#
# epoch-58 loss : 0.02828
#
# epoch-59 loss : 0.02828
#
# epoch-60 loss : 0.02830
#
# epoch-61 loss : 0.02823
#
# epoch-62 loss : 0.02831
#
# epoch-63 loss : 0.02825
#
# epoch-64 loss : 0.02828
#
# epoch-65 loss : 0.02821
#
# epoch-66 loss : 0.02810
#
# epoch-67 loss : 0.02809
#
# epoch-68 loss : 0.02805
#
# epoch-69 loss : 0.02803
#
# epoch-70 loss : 0.02794
#
# epoch-71 loss : 0.02800
#
# epoch-72 loss : 0.02789
#
# epoch-73 loss : 0.02784
#
# epoch-74 loss : 0.02786
#
# epoch-75 loss : 0.02776
#
# epoch-76 loss : 0.02776
#
# epoch-77 loss : 0.02764
#
# epoch-78 loss : 0.02762
#
# epoch-79 loss : 0.02754
#
# epoch-80 loss : 0.02752
#
# epoch-81 loss : 0.02750
#
# epoch-82 loss : 0.02750
#
# epoch-83 loss : 0.02739
#
# epoch-84 loss : 0.02742
#
# epoch-85 loss : 0.02739
#
# epoch-86 loss : 0.02736
#
# epoch-87 loss : 0.02731
#
# epoch-88 loss : 0.02730
#
# epoch-89 loss : 0.02734
#
# epoch-90 loss : 0.02739
#
# epoch-91 loss : 0.02731
#
# epoch-92 loss : 0.02732
#
# epoch-93 loss : 0.02729
#
# epoch-94 loss : 0.02728
#
# epoch-95 loss : 0.02729
#
# epoch-96 loss : 0.02722
#
# epoch-97 loss : 0.02717
#
# epoch-98 loss : 0.02729
#
# epoch-99 loss : 0.02719
#
# epoch-100 loss : 0.02717
#
# epoch-100 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97729423 0.97455231 0.97014925 0.95853423 0.96218905 0.93349057
#  0.8662357  0.74741298 0.96570852 0.94970703 0.88320463 0.68867925
#  0.95977597 0.94083414 0.82401961 0.68896321]
# mean_cluster_accuracy_during_training_cycle : 87.42%, post_traincycle_acc : 89.32%, total_acc : 88.54%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.32%
#
# epoch-101 loss : 0.02711
#
# epoch-102 loss : 0.02715
#
# epoch-103 loss : 0.02714
#
# epoch-104 loss : 0.02720
#
# epoch-105 loss : 0.02716
#
# epoch-106 loss : 0.02717
#
# epoch-107 loss : 0.02707
#
# epoch-108 loss : 0.02717
#
# epoch-109 loss : 0.02711
#
# epoch-110 loss : 0.02704
#
# epoch-111 loss : 0.02706
#
# epoch-112 loss : 0.02709
#
# epoch-113 loss : 0.02709
#
# epoch-114 loss : 0.02709
#
# epoch-115 loss : 0.02708
#
# epoch-116 loss : 0.02706
#
# epoch-117 loss : 0.02704
#
# epoch-118 loss : 0.02703
#
# epoch-119 loss : 0.02696
#
# epoch-120 loss : 0.02701
#
# epoch-121 loss : 0.02690
#
# epoch-122 loss : 0.02687
#
# epoch-123 loss : 0.02693
#
# epoch-124 loss : 0.02690
#
# epoch-125 loss : 0.02691
#
# epoch-126 loss : 0.02694
#
# epoch-127 loss : 0.02686
#
# epoch-128 loss : 0.02685
#
# epoch-129 loss : 0.02689
#
# epoch-130 loss : 0.02687
#
# epoch-131 loss : 0.02691
#
# epoch-132 loss : 0.02691
#
# epoch-133 loss : 0.02683
#
# epoch-134 loss : 0.02684
#
# epoch-135 loss : 0.02684
#
# epoch-136 loss : 0.02682
#
# epoch-137 loss : 0.02682
#
# epoch-138 loss : 0.02677
#
# epoch-139 loss : 0.02681
#
# epoch-140 loss : 0.02670
#
# epoch-141 loss : 0.02679
#
# epoch-142 loss : 0.02673
#
# epoch-143 loss : 0.02671
#
# epoch-144 loss : 0.02672
#
# epoch-145 loss : 0.02667
#
# epoch-146 loss : 0.02675
#
# epoch-147 loss : 0.02672
#
# epoch-148 loss : 0.02671
#
# epoch-149 loss : 0.02676
#
# epoch-150 loss : 0.02667
#
# epoch-150 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97682119 0.97549482 0.97014925 0.95901639 0.96119403 0.93396226
#  0.86524117 0.76810913 0.96570852 0.94873047 0.88223938 0.79692155
#  0.9592668  0.93355965 0.84509804 0.66746297]
# mean_cluster_accuracy_during_training_cycle : 88.36%, post_traincycle_acc : 90.06%, total_acc : 89.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-151 loss : 0.02671
#
# epoch-152 loss : 0.02666
#
# epoch-153 loss : 0.02664
#
# epoch-154 loss : 0.02677
#
# epoch-155 loss : 0.02661
#
# epoch-156 loss : 0.02674
#
# epoch-157 loss : 0.02664
#
# epoch-158 loss : 0.02662
#
# epoch-159 loss : 0.02658
#
# epoch-160 loss : 0.02661
#
# epoch-161 loss : 0.02656
#
# epoch-162 loss : 0.02660
#
# epoch-163 loss : 0.02657
#
# epoch-164 loss : 0.02651
#
# epoch-165 loss : 0.02655
#
# epoch-166 loss : 0.02654
#
# epoch-167 loss : 0.02651
#
# epoch-168 loss : 0.02653
#
# epoch-169 loss : 0.02643
#
# epoch-170 loss : 0.02647
#
# epoch-171 loss : 0.02649
#
# epoch-172 loss : 0.02648
#
# epoch-173 loss : 0.02652
#
# epoch-174 loss : 0.02650
#
# epoch-175 loss : 0.02643
#
# epoch-176 loss : 0.02641
#
# epoch-177 loss : 0.02646
#
# epoch-178 loss : 0.02648
#
# epoch-179 loss : 0.02647
#
# epoch-180 loss : 0.02650
#
# epoch-181 loss : 0.02639
#
# epoch-182 loss : 0.02643
#
# epoch-183 loss : 0.02642
#
# epoch-184 loss : 0.02636
#
# epoch-185 loss : 0.02635
#
# epoch-186 loss : 0.02643
#
# epoch-187 loss : 0.02645
#
# epoch-188 loss : 0.02637
#
# epoch-189 loss : 0.02630
#
# epoch-190 loss : 0.02635
#
# epoch-191 loss : 0.02638
#
# epoch-192 loss : 0.02644
#
# epoch-193 loss : 0.02631
#
# epoch-194 loss : 0.02634
#
# epoch-195 loss : 0.02631
#
# epoch-196 loss : 0.02626
#
# epoch-197 loss : 0.02628
#
# epoch-198 loss : 0.02627
#
# epoch-199 loss : 0.02632
#
# epoch-200 loss : 0.02624
#
# epoch-200 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97785108 0.97303804 0.95998071 0.96268657 0.93962264
#  0.87419194 0.76199436 0.96621281 0.94726562 0.87982625 0.74577954
#  0.96028513 0.93452958 0.51666667 0.68275203]
# mean_cluster_accuracy_during_training_cycle : 87.24%, post_traincycle_acc : 87.89%, total_acc : 87.62%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-201 loss : 0.02624
#
# epoch-202 loss : 0.02625
#
# epoch-203 loss : 0.02626
#
# epoch-204 loss : 0.02625
#
# epoch-205 loss : 0.02628
#
# epoch-206 loss : 0.02621
#
# epoch-207 loss : 0.02626
#
# epoch-208 loss : 0.02628
#
# epoch-209 loss : 0.02628
#
# epoch-210 loss : 0.02626
#
# epoch-211 loss : 0.02627
#
# epoch-212 loss : 0.02624
#
# epoch-213 loss : 0.02622
#
# epoch-214 loss : 0.02622
#
# epoch-215 loss : 0.02618
#
# epoch-216 loss : 0.02620
#
# epoch-217 loss : 0.02606
#
# epoch-218 loss : 0.02619
#
# epoch-219 loss : 0.02610
#
# epoch-220 loss : 0.02611
#
# epoch-221 loss : 0.02609
#
# epoch-222 loss : 0.02612
#
# epoch-223 loss : 0.02620
#
# epoch-224 loss : 0.02617
#
# epoch-225 loss : 0.02613
#
# epoch-226 loss : 0.02609
#
# epoch-227 loss : 0.02617
#
# epoch-228 loss : 0.02605
#
# epoch-229 loss : 0.02611
#
# epoch-230 loss : 0.02611
#
# epoch-231 loss : 0.02610
#
# epoch-232 loss : 0.02609
#
# epoch-233 loss : 0.02619
#
# epoch-234 loss : 0.02621
#
# epoch-235 loss : 0.02610
#
# epoch-236 loss : 0.02604
#
# epoch-237 loss : 0.02610
#
# epoch-238 loss : 0.02619
#
# epoch-239 loss : 0.02607
#
# epoch-240 loss : 0.02619
#
# epoch-241 loss : 0.02608
#
# epoch-242 loss : 0.02612
#
# epoch-243 loss : 0.02603
#
# epoch-244 loss : 0.02601
#
# epoch-245 loss : 0.02606
#
# epoch-246 loss : 0.02606
#
# epoch-247 loss : 0.02611
#
# epoch-248 loss : 0.02601
#
# epoch-249 loss : 0.02606
#
# epoch-250 loss : 0.02611
#
# epoch-250 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97737983 0.97255657 0.95949855 0.96169154 0.93301887
#  0.8562904  0.74788335 0.96570852 0.94677734 0.87065637 0.76762661
#  0.95977597 0.93792435 0.49705882 0.67606307]
# mean_cluster_accuracy_during_training_cycle : 86.86%, post_traincycle_acc : 87.56%, total_acc : 87.27%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-251 loss : 0.02609
#
# epoch-252 loss : 0.02603
#
# epoch-253 loss : 0.02601
#
# epoch-254 loss : 0.02599
#
# epoch-255 loss : 0.02598
#
# epoch-256 loss : 0.02606
#
# epoch-257 loss : 0.02599
#
# epoch-258 loss : 0.02606
#
# epoch-259 loss : 0.02597
#
# epoch-260 loss : 0.02599
#
# epoch-261 loss : 0.02603
#
# epoch-262 loss : 0.02595
#
# epoch-263 loss : 0.02596
#
# epoch-264 loss : 0.02593
#
# epoch-265 loss : 0.02597
#
# epoch-266 loss : 0.02585
#
# epoch-267 loss : 0.02597
#
# epoch-268 loss : 0.02587
#
# epoch-269 loss : 0.02588
#
# epoch-270 loss : 0.02589
#
# epoch-271 loss : 0.02583
#
# epoch-272 loss : 0.02587
#
# epoch-273 loss : 0.02591
#
# epoch-274 loss : 0.02591
#
# epoch-275 loss : 0.02594
#
# epoch-276 loss : 0.02593
#
# epoch-277 loss : 0.02586
#
# epoch-278 loss : 0.02592
#
# epoch-279 loss : 0.02583
#
# epoch-280 loss : 0.02588
#
# epoch-281 loss : 0.02589
#
# epoch-282 loss : 0.02584
#
# epoch-283 loss : 0.02579
#
# epoch-284 loss : 0.02577
#
# epoch-285 loss : 0.02586
#
# epoch-286 loss : 0.02586
#
# epoch-287 loss : 0.02583
#
# epoch-288 loss : 0.02576
#
# epoch-289 loss : 0.02590
#
# epoch-290 loss : 0.02589
#
# epoch-291 loss : 0.02586
#
# epoch-292 loss : 0.02581
#
# epoch-293 loss : 0.02588
#
# epoch-294 loss : 0.02580
#
# epoch-295 loss : 0.02588
#
# epoch-296 loss : 0.02583
#
# epoch-297 loss : 0.02573
#
# epoch-298 loss : 0.02573
#
# epoch-299 loss : 0.02580
#
# epoch-300 loss : 0.02578
#
# epoch-300 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97871334 0.97737983 0.97159364 0.95949855 0.960199   0.93915094
#  0.87717553 0.75776105 0.96722138 0.94238281 0.87934363 0.47517378
#  0.95672098 0.93598448 0.81715686 0.67176302]
# mean_cluster_accuracy_during_training_cycle : 87.38%, post_traincycle_acc : 87.92%, total_acc : 87.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-301 loss : 0.02584
#
# epoch-302 loss : 0.02580
#
# epoch-303 loss : 0.02589
#
# epoch-304 loss : 0.02580
#
# epoch-305 loss : 0.02589
#
# epoch-306 loss : 0.02586
#
# epoch-307 loss : 0.02581
#
# epoch-308 loss : 0.02588
#
# epoch-309 loss : 0.02575
#
# epoch-310 loss : 0.02580
#
# epoch-311 loss : 0.02585
#
# epoch-312 loss : 0.02579
#
# epoch-313 loss : 0.02578
#
# epoch-314 loss : 0.02573
#
# epoch-315 loss : 0.02584
#
# epoch-316 loss : 0.02584
#
# epoch-317 loss : 0.02573
#
# epoch-318 loss : 0.02571
#
# epoch-319 loss : 0.02573
#
# epoch-320 loss : 0.02569
#
# epoch-321 loss : 0.02575
#
# epoch-322 loss : 0.02578
#
# epoch-323 loss : 0.02574
#
# epoch-324 loss : 0.02581
#
# epoch-325 loss : 0.02583
#
# epoch-326 loss : 0.02581
#
# epoch-327 loss : 0.02581
#
# epoch-328 loss : 0.02571
#
# epoch-329 loss : 0.02578
#
# epoch-330 loss : 0.02571
#
# epoch-331 loss : 0.02579
#
# epoch-332 loss : 0.02581
#
# epoch-333 loss : 0.02587
#
# epoch-334 loss : 0.02579
#
# epoch-335 loss : 0.02578
#
# epoch-336 loss : 0.02585
#
# epoch-337 loss : 0.02581
#
# epoch-338 loss : 0.02577
#
# epoch-339 loss : 0.02581
#
# epoch-340 loss : 0.02586
#
# epoch-341 loss : 0.02594
#
# epoch-342 loss : 0.02587
#
# epoch-343 loss : 0.02579
#
# epoch-344 loss : 0.02577
#
# epoch-345 loss : 0.02579
#
# epoch-346 loss : 0.02580
#
# epoch-347 loss : 0.02581
#
# epoch-348 loss : 0.02572
#
# epoch-349 loss : 0.02580
#
# epoch-350 loss : 0.02584
#
# epoch-350 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97776727 0.97643732 0.97111218 0.95853423 0.96119403 0.93679245
#  0.87170562 0.75070555 0.96419566 0.94335938 0.88368726 0.39473684
#  0.95977597 0.93210475 0.5        0.67988533]
# mean_cluster_accuracy_during_training_cycle : 85.83%, post_traincycle_acc : 85.39%, total_acc : 85.57%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-351 loss : 0.02576
#
# epoch-352 loss : 0.02571
#
# epoch-353 loss : 0.02565
#
# epoch-354 loss : 0.02572
#
# epoch-355 loss : 0.02571
#
# epoch-356 loss : 0.02576
#
# epoch-357 loss : 0.02576
#
# epoch-358 loss : 0.02572
#
# epoch-359 loss : 0.02573
#
# epoch-360 loss : 0.02575
#
# epoch-361 loss : 0.02580
#
# epoch-362 loss : 0.02565
#
# epoch-363 loss : 0.02569
#
# epoch-364 loss : 0.02567
#
# epoch-365 loss : 0.02566
#
# epoch-366 loss : 0.02561
#
# epoch-367 loss : 0.02560
#
# epoch-368 loss : 0.02560
#
# epoch-369 loss : 0.02562
#
# epoch-370 loss : 0.02563
#
# epoch-371 loss : 0.02562
#
# epoch-372 loss : 0.02561
#
# epoch-373 loss : 0.02566
#
# epoch-374 loss : 0.02561
#
# epoch-375 loss : 0.02563
#
# epoch-376 loss : 0.02557
#
# epoch-377 loss : 0.02560
#
# epoch-378 loss : 0.02561
#
# epoch-379 loss : 0.02555
#
# epoch-380 loss : 0.02560
#
# epoch-381 loss : 0.02554
#
# epoch-382 loss : 0.02556
#
# epoch-383 loss : 0.02566
#
# epoch-384 loss : 0.02547
#
# epoch-385 loss : 0.02550
#
# epoch-386 loss : 0.02547
#
# epoch-387 loss : 0.02548
#
# epoch-388 loss : 0.02548
#
# epoch-389 loss : 0.02547
#
# epoch-390 loss : 0.02549
#
# epoch-391 loss : 0.02545
#
# epoch-392 loss : 0.02544
#
# epoch-393 loss : 0.02546
#
# epoch-394 loss : 0.02546
#
# epoch-395 loss : 0.02547
#
# epoch-396 loss : 0.02534
#
# epoch-397 loss : 0.02545
#
# epoch-398 loss : 0.02539
#
# epoch-399 loss : 0.02555
#
# epoch-400 loss : 0.02543
#
# epoch-400 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97871334 0.97737983 0.97255657 0.96046287 0.96169154 0.93632075
#  0.87319741 0.76011289 0.96873424 0.94970703 0.88368726 0.71300894
#  0.9592668  0.93355965 0.52009804 0.67319637]
# mean_cluster_accuracy_during_training_cycle : 86.94%, post_traincycle_acc : 87.64%, total_acc : 87.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-401 loss : 0.02535
#
# epoch-402 loss : 0.02547
#
# epoch-403 loss : 0.02551
#
# epoch-404 loss : 0.02546
#
# epoch-405 loss : 0.02551
#
# epoch-406 loss : 0.02543
#
# epoch-407 loss : 0.02546
#
# epoch-408 loss : 0.02542
#
# epoch-409 loss : 0.02534
#
# epoch-410 loss : 0.02534
#
# epoch-411 loss : 0.02540
#
# epoch-412 loss : 0.02541
#
# epoch-413 loss : 0.02545
#
# epoch-414 loss : 0.02539
#
# epoch-415 loss : 0.02532
#
# epoch-416 loss : 0.02536
#
# epoch-417 loss : 0.02531
#
# epoch-418 loss : 0.02538
#
# epoch-419 loss : 0.02532
#
# epoch-420 loss : 0.02540
#
# epoch-421 loss : 0.02530
#
# epoch-422 loss : 0.02535
#
# epoch-423 loss : 0.02544
#
# epoch-424 loss : 0.02534
#
# epoch-425 loss : 0.02530
#
# epoch-426 loss : 0.02532
#
# epoch-427 loss : 0.02538
#
# epoch-428 loss : 0.02543
#
# epoch-429 loss : 0.02540
#
# epoch-430 loss : 0.02538
#
# epoch-431 loss : 0.02547
#
# epoch-432 loss : 0.02538
#
# epoch-433 loss : 0.02539
#
# epoch-434 loss : 0.02544
#
# epoch-435 loss : 0.02541
#
# epoch-436 loss : 0.02539
#
# epoch-437 loss : 0.02540
#
# epoch-438 loss : 0.02544
#
# epoch-439 loss : 0.02543
#
# epoch-440 loss : 0.02547
#
# epoch-441 loss : 0.02546
#
# epoch-442 loss : 0.02554
#
# epoch-443 loss : 0.02546
#
# epoch-444 loss : 0.02547
#
# epoch-445 loss : 0.02543
#
# epoch-446 loss : 0.02550
#
# epoch-447 loss : 0.02548
#
# epoch-448 loss : 0.02542
#
# epoch-449 loss : 0.02550
#
# epoch-450 loss : 0.02544
#
# epoch-450 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97690858 0.97207511 0.95998071 0.95970149 0.93537736
#  0.87270015 0.75917215 0.96822995 0.94970703 0.88610039 0.82423039
#  0.95977597 0.93210475 0.53921569 0.66364071]
# mean_cluster_accuracy_during_training_cycle : 87.22%, post_traincycle_acc : 88.37%, total_acc : 87.90%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-451 loss : 0.02550
#
# epoch-452 loss : 0.02544
#
# epoch-453 loss : 0.02546
#
# epoch-454 loss : 0.02543
#
# epoch-455 loss : 0.02542
#
# epoch-456 loss : 0.02541
#
# epoch-457 loss : 0.02532
#
# epoch-458 loss : 0.02536
#
# epoch-459 loss : 0.02535
#
# epoch-460 loss : 0.02533
#
# epoch-461 loss : 0.02542
#
# epoch-462 loss : 0.02541
#
# epoch-463 loss : 0.02541
#
# epoch-464 loss : 0.02542
#
# epoch-465 loss : 0.02546
#
# epoch-466 loss : 0.02531
#
# epoch-467 loss : 0.02537
#
# epoch-468 loss : 0.02536
#
# epoch-469 loss : 0.02542
#
# epoch-470 loss : 0.02536
#
# epoch-471 loss : 0.02543
#
# epoch-472 loss : 0.02542
#
# epoch-473 loss : 0.02536
#
# epoch-474 loss : 0.02536
#
# epoch-475 loss : 0.02546
#
# epoch-476 loss : 0.02534
#
# epoch-477 loss : 0.02542
#
# epoch-478 loss : 0.02526
#
# epoch-479 loss : 0.02537
#
# epoch-480 loss : 0.02535
#
# epoch-481 loss : 0.02533
#
# epoch-482 loss : 0.02536
#
# epoch-483 loss : 0.02532
#
# epoch-484 loss : 0.02533
#
# epoch-485 loss : 0.02539
#
# epoch-486 loss : 0.02549
#
# epoch-487 loss : 0.02532
#
# epoch-488 loss : 0.02532
#
# epoch-489 loss : 0.02530
#
# epoch-490 loss : 0.02540
#
# epoch-491 loss : 0.02533
#
# epoch-492 loss : 0.02537
#
# epoch-493 loss : 0.02537
#
# epoch-494 loss : 0.02532
#
# epoch-495 loss : 0.02540
#
# epoch-496 loss : 0.02530
#
# epoch-497 loss : 0.02533
#
# epoch-498 loss : 0.02528
#
# epoch-499 loss : 0.02531
#
# epoch-500 loss : 0.02527
#
# epoch-500 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97918638 0.97690858 0.97207511 0.96046287 0.96119403 0.93915094
#  0.87717553 0.76528692 0.96570852 0.9453125  0.88272201 0.83416087
#  0.96028513 0.93695441 0.50833333 0.67462972]
# mean_cluster_accuracy_during_training_cycle : 87.52%, post_traincycle_acc : 88.37%, total_acc : 88.02%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-501 loss : 0.02536
#
# epoch-502 loss : 0.02524
#
# epoch-503 loss : 0.02524
#
# epoch-504 loss : 0.02529
#
# epoch-505 loss : 0.02537
#
# epoch-506 loss : 0.02517
#
# epoch-507 loss : 0.02529
#
# epoch-508 loss : 0.02525
#
# epoch-509 loss : 0.02532
#
# epoch-510 loss : 0.02537
#
# epoch-511 loss : 0.02537
#
# epoch-512 loss : 0.02528
#
# epoch-513 loss : 0.02535
#
# epoch-514 loss : 0.02527
#
# epoch-515 loss : 0.02524
#
# epoch-516 loss : 0.02526
#
# epoch-517 loss : 0.02524
#
# epoch-518 loss : 0.02534
#
# epoch-519 loss : 0.02526
#
# epoch-520 loss : 0.02523
#
# epoch-521 loss : 0.02528
#
# epoch-522 loss : 0.02525
#
# epoch-523 loss : 0.02525
#
# epoch-524 loss : 0.02519
#
# epoch-525 loss : 0.02527
#
# epoch-526 loss : 0.02526
#
# epoch-527 loss : 0.02520
#
# epoch-528 loss : 0.02526
#
# epoch-529 loss : 0.02525
#
# epoch-530 loss : 0.02522
#
# epoch-531 loss : 0.02519
#
# epoch-532 loss : 0.02521
#
# epoch-533 loss : 0.02524
#
# epoch-534 loss : 0.02524
#
# epoch-535 loss : 0.02525
#
# epoch-536 loss : 0.02510
#
# epoch-537 loss : 0.02536
#
# epoch-538 loss : 0.02527
#
# epoch-539 loss : 0.02524
#
# epoch-540 loss : 0.02517
#
# epoch-541 loss : 0.02519
#
# epoch-542 loss : 0.02527
#
# epoch-543 loss : 0.02520
#
# epoch-544 loss : 0.02521
#
# epoch-545 loss : 0.02519
#
# epoch-546 loss : 0.02513
#
# epoch-547 loss : 0.02514
#
# epoch-548 loss : 0.02519
#
# epoch-549 loss : 0.02517
#
# epoch-550 loss : 0.02511
#
# epoch-550 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97871334 0.97737983 0.97111218 0.96046287 0.95771144 0.93160377
#  0.85877673 0.74506115 0.96822995 0.94628906 0.89189189 0.8326713
#  0.9607943  0.92967992 0.79558824 0.66364071]
# mean_cluster_accuracy_during_training_cycle : 88.25%, post_traincycle_acc : 89.81%, total_acc : 89.17%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-551 loss : 0.02519
#
# epoch-552 loss : 0.02514
#
# epoch-553 loss : 0.02509
#
# epoch-554 loss : 0.02514
#
# epoch-555 loss : 0.02515
#
# epoch-556 loss : 0.02515
#
# epoch-557 loss : 0.02512
#
# epoch-558 loss : 0.02505
#
# epoch-559 loss : 0.02510
#
# epoch-560 loss : 0.02506
#
# epoch-561 loss : 0.02506
#
# epoch-562 loss : 0.02514
#
# epoch-563 loss : 0.02506
#
# epoch-564 loss : 0.02495
#
# epoch-565 loss : 0.02509
#
# epoch-566 loss : 0.02505
#
# epoch-567 loss : 0.02502
#
# epoch-568 loss : 0.02507
#
# epoch-569 loss : 0.02511
#
# epoch-570 loss : 0.02509
#
# epoch-571 loss : 0.02509
#
# epoch-572 loss : 0.02502
#
# epoch-573 loss : 0.02518
#
# epoch-574 loss : 0.02508
#
# epoch-575 loss : 0.02506
#
# epoch-576 loss : 0.02501
#
# epoch-577 loss : 0.02506
#
# epoch-578 loss : 0.02507
#
# epoch-579 loss : 0.02512
#
# epoch-580 loss : 0.02504
#
# epoch-581 loss : 0.02512
#
# epoch-582 loss : 0.02512
#
# epoch-583 loss : 0.02502
#
# epoch-584 loss : 0.02504
#
# epoch-585 loss : 0.02508
#
# epoch-586 loss : 0.02498
#
# epoch-587 loss : 0.02501
#
# epoch-588 loss : 0.02507
#
# epoch-589 loss : 0.02505
#
# epoch-590 loss : 0.02502
#
# epoch-591 loss : 0.02507
#
# epoch-592 loss : 0.02504
#
# epoch-593 loss : 0.02504
#
# epoch-594 loss : 0.02497
#
# epoch-595 loss : 0.02503
#
# epoch-596 loss : 0.02498
#
# epoch-597 loss : 0.02501
#
# epoch-598 loss : 0.02507
#
# epoch-599 loss : 0.02506
#
# epoch-600 loss : 0.02503
#
# epoch-600 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97918638 0.97690858 0.97159364 0.96046287 0.95970149 0.93490566
#  0.87468921 0.75352775 0.96621281 0.9453125  0.89044402 0.46276068
#  0.96028513 0.93840931 0.51176471 0.65360726]
# mean_cluster_accuracy_during_training_cycle : 86.35%, post_traincycle_acc : 85.87%, total_acc : 86.07%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-601 loss : 0.02497
#
# epoch-602 loss : 0.02506
#
# epoch-603 loss : 0.02508
#
# epoch-604 loss : 0.02503
#
# epoch-605 loss : 0.02504
#
# epoch-606 loss : 0.02493
#
# epoch-607 loss : 0.02491
#
# epoch-608 loss : 0.02497
#
# epoch-609 loss : 0.02499
#
# epoch-610 loss : 0.02496
#
# epoch-611 loss : 0.02498
#
# epoch-612 loss : 0.02504
#
# epoch-613 loss : 0.02504
#
# epoch-614 loss : 0.02498
#
# epoch-615 loss : 0.02499
#
# epoch-616 loss : 0.02507
#
# epoch-617 loss : 0.02490
#
# epoch-618 loss : 0.02504
#
# epoch-619 loss : 0.02492
#
# epoch-620 loss : 0.02496
#
# epoch-621 loss : 0.02503
#
# epoch-622 loss : 0.02485
#
# epoch-623 loss : 0.02496
#
# epoch-624 loss : 0.02498
#
# epoch-625 loss : 0.02481
#
# epoch-626 loss : 0.02496
#
# epoch-627 loss : 0.02489
#
# epoch-628 loss : 0.02488
#
# epoch-629 loss : 0.02499
#
# epoch-630 loss : 0.02488
#
# epoch-631 loss : 0.02489
#
# epoch-632 loss : 0.02494
#
# epoch-633 loss : 0.02500
#
# epoch-634 loss : 0.02498
#
# epoch-635 loss : 0.02494
#
# epoch-636 loss : 0.02489
#
# epoch-637 loss : 0.02490
#
# epoch-638 loss : 0.02490
#
# epoch-639 loss : 0.02493
#
# epoch-640 loss : 0.02494
#
# epoch-641 loss : 0.02485
#
# epoch-642 loss : 0.02493
#
# epoch-643 loss : 0.02510
#
# epoch-644 loss : 0.02501
#
# epoch-645 loss : 0.02496
#
# epoch-646 loss : 0.02488
#
# epoch-647 loss : 0.02486
#
# epoch-648 loss : 0.02496
#
# epoch-649 loss : 0.02505
#
# epoch-650 loss : 0.02497
#
# epoch-650 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97737983 0.97255657 0.96046287 0.96169154 0.93679245
#  0.87220288 0.74223895 0.96419566 0.94384766 0.88851351 0.75173784
#  0.96028513 0.93113482 0.52892157 0.66172957]
# mean_cluster_accuracy_during_training_cycle : 86.67%, post_traincycle_acc : 87.71%, total_acc : 87.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-651 loss : 0.02499
#
# epoch-652 loss : 0.02510
#
# epoch-653 loss : 0.02514
#
# epoch-654 loss : 0.02496
#
# epoch-655 loss : 0.02485
#
# epoch-656 loss : 0.02493
#
# epoch-657 loss : 0.02489
#
# epoch-658 loss : 0.02494
#
# epoch-659 loss : 0.02497
#
# epoch-660 loss : 0.02491
#
# epoch-661 loss : 0.02490
#
# epoch-662 loss : 0.02485
#
# epoch-663 loss : 0.02487
#
# epoch-664 loss : 0.02486
#
# epoch-665 loss : 0.02486
#
# epoch-666 loss : 0.02483
#
# epoch-667 loss : 0.02492
#
# epoch-668 loss : 0.02492
#
# epoch-669 loss : 0.02503
#
# epoch-670 loss : 0.02487
#
# epoch-671 loss : 0.02498
#
# epoch-672 loss : 0.02485
#
# epoch-673 loss : 0.02486
#
# epoch-674 loss : 0.02484
#
# epoch-675 loss : 0.02492
#
# epoch-676 loss : 0.02494
#
# epoch-677 loss : 0.02493
#
# epoch-678 loss : 0.02485
#
# epoch-679 loss : 0.02483
#
# epoch-680 loss : 0.02489
#
# epoch-681 loss : 0.02475
#
# epoch-682 loss : 0.02475
#
# epoch-683 loss : 0.02483
#
# epoch-684 loss : 0.02481
#
# epoch-685 loss : 0.02481
#
# epoch-686 loss : 0.02481
#
# epoch-687 loss : 0.02479
#
# epoch-688 loss : 0.02482
#
# epoch-689 loss : 0.02478
#
# epoch-690 loss : 0.02488
#
# epoch-691 loss : 0.02476
#
# epoch-692 loss : 0.02471
#
# epoch-693 loss : 0.02478
#
# epoch-694 loss : 0.02481
#
# epoch-695 loss : 0.02472
#
# epoch-696 loss : 0.02483
#
# epoch-697 loss : 0.02475
#
# epoch-698 loss : 0.02482
#
# epoch-699 loss : 0.02475
#
# epoch-700 loss : 0.02469
#
# epoch-700 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97690858 0.97111218 0.95949855 0.96119403 0.93773585
#  0.85479861 0.75211665 0.95965709 0.93896484 0.88803089 0.63505462
#  0.9607943  0.92192047 0.77941176 0.64548495]
# mean_cluster_accuracy_during_training_cycle : 87.17%, post_traincycle_acc : 88.26%, total_acc : 87.82%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-701 loss : 0.02475
#
# epoch-702 loss : 0.02474
#
# epoch-703 loss : 0.02470
#
# epoch-704 loss : 0.02468
#
# epoch-705 loss : 0.02472
#
# epoch-706 loss : 0.02475
#
# epoch-707 loss : 0.02480
#
# epoch-708 loss : 0.02471
#
# epoch-709 loss : 0.02473
#
# epoch-710 loss : 0.02472
#
# epoch-711 loss : 0.02481
#
# epoch-712 loss : 0.02477
#
# epoch-713 loss : 0.02473
#
# epoch-714 loss : 0.02480
#
# epoch-715 loss : 0.02472
#
# epoch-716 loss : 0.02469
#
# epoch-717 loss : 0.02474
#
# epoch-718 loss : 0.02467
#
# epoch-719 loss : 0.02470
#
# epoch-720 loss : 0.02469
#
# epoch-721 loss : 0.02461
#
# epoch-722 loss : 0.02472
#
# epoch-723 loss : 0.02469
#
# epoch-724 loss : 0.02481
#
# epoch-725 loss : 0.02464
#
# epoch-726 loss : 0.02465
#
# epoch-727 loss : 0.02467
#
# epoch-728 loss : 0.02470
#
# epoch-729 loss : 0.02461
#
# epoch-730 loss : 0.02458
#
# epoch-731 loss : 0.02462
#
# epoch-732 loss : 0.02460
#
# epoch-733 loss : 0.02459
#
# epoch-734 loss : 0.02463
#
# epoch-735 loss : 0.02445
#
# epoch-736 loss : 0.02455
#
# epoch-737 loss : 0.02465
#
# epoch-738 loss : 0.02458
#
# epoch-739 loss : 0.02460
#
# epoch-740 loss : 0.02460
#
# epoch-741 loss : 0.02452
#
# epoch-742 loss : 0.02458
#
# epoch-743 loss : 0.02460
#
# epoch-744 loss : 0.02470
#
# epoch-745 loss : 0.02453
#
# epoch-746 loss : 0.02448
#
# epoch-747 loss : 0.02465
#
# epoch-748 loss : 0.02454
#
# epoch-749 loss : 0.02461
#
# epoch-750 loss : 0.02460
#
# epoch-750 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97690858 0.97207511 0.96046287 0.96169154 0.93632075
#  0.86374938 0.74176858 0.96419566 0.94482422 0.88851351 0.69414101
#  0.9607943  0.92967992 0.51078431 0.65074056]
# mean_cluster_accuracy_during_training_cycle : 86.72%, post_traincycle_acc : 87.10%, total_acc : 86.94%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-751 loss : 0.02456
#
# epoch-752 loss : 0.02450
#
# epoch-753 loss : 0.02452
#
# epoch-754 loss : 0.02458
#
# epoch-755 loss : 0.02459
#
# epoch-756 loss : 0.02458
#
# epoch-757 loss : 0.02469
#
# epoch-758 loss : 0.02472
#
# epoch-759 loss : 0.02457
#
# epoch-760 loss : 0.02453
#
# epoch-761 loss : 0.02453
#
# epoch-762 loss : 0.02461
#
# epoch-763 loss : 0.02459
#
# epoch-764 loss : 0.02456
#
# epoch-765 loss : 0.02456
#
# epoch-766 loss : 0.02457
#
# epoch-767 loss : 0.02455
#
# epoch-768 loss : 0.02458
#
# epoch-769 loss : 0.02454
#
# epoch-770 loss : 0.02457
#
# epoch-771 loss : 0.02452
#
# epoch-772 loss : 0.02458
#
# epoch-773 loss : 0.02458
#
# epoch-774 loss : 0.02453
#
# epoch-775 loss : 0.02449
#
# epoch-776 loss : 0.02450
#
# epoch-777 loss : 0.02455
#
# epoch-778 loss : 0.02464
#
# epoch-779 loss : 0.02468
#
# epoch-780 loss : 0.02468
#
# epoch-781 loss : 0.02456
#
# epoch-782 loss : 0.02459
#
# epoch-783 loss : 0.02451
#
# epoch-784 loss : 0.02458
#
# epoch-785 loss : 0.02453
#
# epoch-786 loss : 0.02466
#
# epoch-787 loss : 0.02456
#
# epoch-788 loss : 0.02456
#
# epoch-789 loss : 0.02456
#
# epoch-790 loss : 0.02450
#
# epoch-791 loss : 0.02461
#
# epoch-792 loss : 0.02456
#
# epoch-793 loss : 0.02455
#
# epoch-794 loss : 0.02446
#
# epoch-795 loss : 0.02447
#
# epoch-796 loss : 0.02450
#
# epoch-797 loss : 0.02444
#
# epoch-798 loss : 0.02445
#
# epoch-799 loss : 0.02443
#
# epoch-800 loss : 0.02460
#
# epoch-800 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97965941 0.97596607 0.97063072 0.95949855 0.96169154 0.93915094
#  0.8577822  0.75164628 0.96066566 0.93994141 0.88175676 0.65590864
#  0.95977597 0.92240543 0.51911765 0.65504061]
# mean_cluster_accuracy_during_training_cycle : 86.83%, post_traincycle_acc : 86.82%, total_acc : 86.82%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.06%
#
# epoch-801 loss : 0.02455
#
# epoch-802 loss : 0.02452
#
# epoch-803 loss : 0.02451
#
# epoch-804 loss : 0.02448
#
# epoch-805 loss : 0.02463
#
# epoch-806 loss : 0.02456
#
# epoch-807 loss : 0.02442
#
# epoch-808 loss : 0.02440
#
# epoch-809 loss : 0.02448
#
# epoch-810 loss : 0.02459
#
# epoch-811 loss : 0.02447
#
# epoch-812 loss : 0.02447
#
# epoch-813 loss : 0.02454

# %%
# # Sweep code


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [True]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400, 2400]}, # [1400, 2400]

#         "batch_size": {"values": [32]}, 
#         "max_epoch": {"values": [10]}, 
#         "learning_rate": {"values": [0.001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [False]}, 

#         "lif_add_at_first": {"values": [True, False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [4,6,8,10]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True, False]}, # [True, False]

#         # "current_time": {"values": [current_time]}, 

#         "optimizer": {"values": ['Adam', 'SGD']}, # ['Adam', 'SGD']
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  1
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer


#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'
#         )
    
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']

max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {dataset_num}, Conv {Conv_net}, SAE {SAE_net}, Current time {current_time}, Spike Length: {spike_length}, Num Cluster: {num_cluster}, "
    f"Training Cycle: {training_cycle}, Batch Size: {batch_size}, Max Epoch: {max_epoch}, \n"
    f"Learning Rate: {learning_rate}, Input Normalize: {normalize_on}, Need Bias: {need_bias}, "
    f"LIF Add at First: {lif_add_at_first}, TIME: {TIME}, Seed: {my_seed}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
# Out:
# {'loss_history': [(0, 0.17107908539784453), (1, 0.06888550750600796), (2, 0.05841751467746993), (3, 0.052596477043504515), (4, 0.049875431233085694), (5, 0.048334632351373634), (6, 0.04726186483787993), (7, 0.04644121899424742), (8, 0.045873045907355844), (9, 0.0452855231333524)], 'mean_cluster_accuracy_during_training_cycle_all_dataset_history': [(9, 81.60677083333333)], 'mean_cluster_accuracy_post_training_cycle_all_dataset_history': [(9, 81.27168719042213)], 'mean_cluster_accuracy_total_all_dataset_history': [(9, 81.50152212131302)]}

# %%
wandb.finish()
