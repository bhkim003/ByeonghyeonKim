# %%
import sys
import os
import argparse
import torch
import torch.nn as nn 
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import time

from snntorch import spikegen
import matplotlib.pyplot as plt
import snntorch.spikeplot as splt
from IPython.display import HTML

from tqdm import tqdm

from apex.parallel import DistributedDataParallel as DDP

import random
import datetime

import json

from sklearn.utils import shuffle

''' 레퍼런스
https://spikingjelly.readthedocs.io/zh-cn/0.0.0.0.4/spikingjelly.datasets.html#module-spikingjelly.datasets
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/datasets.py
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/how_to.md
https://github.com/nmi-lab/torchneuromorphic
https://snntorch.readthedocs.io/en/latest/snntorch.spikevision.spikedata.html#shd
'''

import snntorch
from snntorch.spikevision import spikedata

import modules.spikingjelly;
from modules.spikingjelly.datasets.dvs128_gesture import DVS128Gesture
from modules.spikingjelly.datasets.cifar10_dvs import CIFAR10DVS
from modules.spikingjelly.datasets.n_mnist import NMNIST
# from modules.spikingjelly.datasets.es_imagenet import ESImageNet
from modules.spikingjelly.datasets import split_to_train_test_set
from modules.spikingjelly.datasets.n_caltech101 import NCaltech101
from modules.spikingjelly.datasets import pad_sequence_collate, padded_sequence_mask

import modules.torchneuromorphic as torchneuromorphic

import wandb

from torchviz import make_dot
import graphviz
from turtle import shape
# Out:
# /tmp/ipykernel_20819/3748606120.py:46: DeprecationWarning: The module snntorch.spikevision is deprecated. For loading neuromorphic datasets, we recommend using the Tonic project: https://github.com/neuromorphs/tonic
#   from snntorch.spikevision import spikedata

# %%
# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
from matplotlib.ft2font import EXTERNAL_STREAM


def my_snn_system(devices = "0,1,2,3",
                    single_step = False, # True # False
                    unique_name = 'main',
                    my_seed = 42,
                    TIME = 10,
                    BATCH = 256,
                    IMAGE_SIZE = 32,
                    which_data = 'CIFAR10',
                    # CLASS_NUM = 10,
                    data_path = '/data2',
                    rate_coding = True,
    
                    lif_layer_v_init = 0.0,
                    lif_layer_v_decay = 0.6,
                    lif_layer_v_threshold = 1.2,
                    lif_layer_v_reset = 0.0,
                    lif_layer_sg_width = 1,

                    # synapse_conv_in_channels = IMAGE_PIXEL_CHANNEL,
                    synapse_conv_kernel_size = 3,
                    synapse_conv_stride = 1,
                    synapse_conv_padding = 1,

                    synapse_trace_const1 = 1,
                    synapse_trace_const2 = 0.6,

                    # synapse_fc_out_features = CLASS_NUM,

                    pre_trained = False,
                    convTrue_fcFalse = True,

                    cfg = [64, 64],
                    net_print = False, # True # False
                    
                    pre_trained_path = "net_save/save_now_net.pth",
                    learning_rate = 0.0001,
                    epoch_num = 200,
                    tdBN_on = False,
                    BN_on = False,

                    surrogate = 'sigmoid',

                    BPTT_on = False,

                    optimizer_what = 'SGD', # 'SGD' 'Adam', 'RMSprop'
                    scheduler_name = 'no',
                    
                    ddp_on = False, # DECREPATED # fALSE

                    dvs_clipping = 1, 
                    dvs_duration = 25_000,


                    DFA_on = False, # True # False
                    trace_on = False, 
                    OTTT_input_trace_on = False, # True # False
                    
                    exclude_class = True, # True # False # gesture에서 10번째 클래스 제외

                    merge_polarities = False, # True # False # tonic dvs dataset 에서 polarities 합치기
                    denoise_on = True, 

                    extra_train_dataset = 0, # DECREPATED # data_loader에서 train dataset을 몇개 더 쓸건지 

                    num_workers = 2,
                    chaching_on = True,
                    pin_memory = True, # True # False
                    
                    UDA_on = False,  # DECREPATED # uda
                    alpha_uda = 1.0, # DECREPATED # uda

                    bias = True,

                    last_lif = False,
                        
                    temporal_filter = 1, 
                    initial_pooling = 1,

                    temporal_filter_accumulation = False,

                    quantize_bit_list=[],
                    scale_exp=[],
                    lif_layer_sg_width2 = None,
                    lif_layer_v_threshold2 = None,
                    learning_rate2 = None,
                    init_scaling = None,
                    learning_rate3 = None,
                    ):
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print('param', hyperparameters,'\n')
    hyperparameters['current epoch'] = 0
    ######################################################################################

    ## hyperparameter check #############################################################
    if single_step == True:
        assert BPTT_on == False and tdBN_on == False 
    if tdBN_on == True:
        assert BPTT_on == True
    if pre_trained == True:
        print('\n\n')
        print("Caution! pre_trained is True\n\n"*3)    
    if DFA_on == True:
        assert single_step == True and BPTT_on == False 
    # assert single_step == DFA_on, 'DFA랑 single_step공존하게해라'
    if trace_on:
        assert BPTT_on == False and single_step == True
    if OTTT_input_trace_on == True:
        assert BPTT_on == False and single_step == True #and trace_on == True
    if temporal_filter > 1:
        assert convTrue_fcFalse == False
    ######################################################################################


    

    ## wandb 세팅 ###################################################################
    current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    wandb.config.update(hyperparameters)
    wandb.run.name = f'lr_{learning_rate}_{unique_name}_{which_data}_tstep{TIME}'
    wandb.define_metric("summary_val_acc", summary="max")
    # wandb.run.log_code(".", 
    #                     include_fn=lambda path: path.endswith(".py") or path.endswith(".ipynb"),
    #                     exclude_fn=lambda path: 'logs/' in path or 'net_save/' in path or 'result_save/' in path or 'trying/' in path or 'wandb/' in path or 'private/' in path or '.git/' in path or 'tonic' in path or 'torchneuromorphic' in path or 'spikingjelly' in path 
    #                     )
    ###################################################################################



    ## gpu setting ##################################################################################################################
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= devices
    ###################################################################################################################################


    ## seed setting ##################################################################################################################
    seed_assign(my_seed)
    ###################################################################################################################################
    

    ## data_loader 가져오기 ##################################################################################################################
    # data loader, pixel channel, class num
    train_data_split_indices = []
    train_loader, test_loader, synapse_conv_in_channels, CLASS_NUM, train_data_count = data_loader(
            which_data,
            data_path, 
            rate_coding, 
            BATCH, 
            IMAGE_SIZE,
            ddp_on,
            TIME*temporal_filter, 
            dvs_clipping,
            dvs_duration,
            exclude_class,
            merge_polarities,
            denoise_on,
            my_seed,
            extra_train_dataset,
            num_workers,
            chaching_on,
            pin_memory,
            train_data_split_indices,) 
    synapse_fc_out_features = CLASS_NUM

    print('\nlen(train_loader):', len(train_loader), 'BATCH:', BATCH, 'train_data_count:', train_data_count) 
    print('len(test_loader):', len(test_loader), 'BATCH:', BATCH)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"\ndevice ==> {device}\n")
    if device == "cpu":
        print("="*50,"\n[WARNING]\n[WARNING]\n[WARNING]\n: cpu mode\n\n","="*50)

    ### network setting #######################################################################################################################
    if (convTrue_fcFalse == False):
        net = REBORN_MY_SNN_FC(cfg, synapse_conv_in_channels*temporal_filter, IMAGE_SIZE//initial_pooling, synapse_fc_out_features,
                    synapse_trace_const1, synapse_trace_const2, 
                    lif_layer_v_init, lif_layer_v_decay, 
                    lif_layer_v_threshold, lif_layer_v_reset,
                    lif_layer_sg_width,
                    tdBN_on,
                    BN_on, TIME,
                    surrogate,
                    BPTT_on,
                    DFA_on,
                    bias,
                    single_step,
                    last_lif,
                    trace_on,
                    quantize_bit_list,
                    scale_exp,
                    ANPI_MODE=False,
                    lif_layer_sg_width2=lif_layer_sg_width2,
                    lif_layer_v_threshold2=lif_layer_v_threshold2,
                    init_scaling=init_scaling).to(device)
    else:
        net = REBORN_MY_SNN_CONV(cfg, synapse_conv_in_channels, IMAGE_SIZE//initial_pooling,
                    synapse_conv_kernel_size, synapse_conv_stride, 
                    synapse_conv_padding, synapse_trace_const1, 
                    synapse_trace_const2, 
                    lif_layer_v_init, lif_layer_v_decay, 
                    lif_layer_v_threshold, lif_layer_v_reset,
                    lif_layer_sg_width,
                    synapse_fc_out_features, 
                    tdBN_on,
                    BN_on, TIME,
                    surrogate,
                    BPTT_on,
                    DFA_on,
                    bias,
                    single_step,
                    last_lif,
                    trace_on,
                    quantize_bit_list,
                    scale_exp).to(device)

    net = torch.nn.DataParallel(net) 
    
    if pre_trained == True:
        # 1. 전체 state_dict 로드
        checkpoint = torch.load(pre_trained_path)

        # 2. 현재 모델의 state_dict 가져오기
        model_dict = net.state_dict()

        # 3. 'SYNAPSE'가 포함된 key만 필터링 (현재 모델에도 존재하는 key만)
        filtered_dict = {k: v for k, v in checkpoint.items() if ('weight' in k or 'bias' in k) and k in model_dict}

        # 4. 업데이트된 키 출력
        print("🔄 업데이트된 SYNAPSE 관련 레이어들:")
        for k in filtered_dict.keys():
            print(f" - {k}")

        # 5. 모델 dict 업데이트 및 로딩
        model_dict.update(filtered_dict)
        net.load_state_dict(model_dict)
    
    net = net.to(device)
    if (net_print == True):
        print(net)    

    print(f"\n========================================================\nTrainable parameters: {sum(p.numel() for p in net.parameters() if p.requires_grad):,}\n========================================================\n")
    ####################################################################################################################################
    

    ## wandb logging ###########################################
    # wandb.watch(net, log="all", log_freq = 10) #gradient, parameter logging해줌
    ############################################################

    ## criterion ########################################## # loss 구해주는 친구
    def my_cross_entropy_loss(logits, targets):
        # logits: (batch_size, num_classes)
        # targets: (batch_size,) -> 클래스 인덱스
        log_probs = F.log_softmax(logits, dim=1)  # log(p_i)
        loss = F.nll_loss(log_probs, targets)
        # print(loss.shape)
        return loss
    
    class CustomLossFunction(torch.autograd.Function):
        @staticmethod
        def forward(ctx, input, target):
            ctx.save_for_backward(input, target)
            return F.cross_entropy(input, target)

        @staticmethod
        def backward(ctx, grad_output):
            # MAE 스타일의 gradient를 흉내냄
            input, target = ctx.saved_tensors
            input_argmax = input.argmax(dim=1)
            input_one_hot = torch.zeros_like(input).scatter_(1, input_argmax.unsqueeze(1), 1.0)
            target_one_hot = torch.zeros_like(input).scatter_(1, target.unsqueeze(1), 1.0)

            # print('grad_output', grad_output) # 이거 걍 1.0임
            return input_one_hot - target_one_hot, None  # target에는 gradient 없음

    # Wrapper module
    class CustomCriterion(torch.nn.Module):
        def __init__(self):
            super().__init__()

        def forward(self, input, target):
            return CustomLossFunction.apply(input, target)

    # Wrapper module
    class CustomCriterionMSE(nn.Module):
        def __init__(self):
            super().__init__()

        def forward(self, input, target):
            # return CustomCriterion_mseloss.apply(input, target)

            # target을 one-hot 벡터로 변환
            target_one_hot = torch.zeros_like(input)
            target_one_hot.scatter_(1, target.unsqueeze(1), 1.0)

            # MSE 계산
            loss = F.mse_loss(input, target_one_hot, reduction='mean')
            # print(f'input {input}', f'target_one_hot {target_one_hot}', f'loss {loss}')
            return loss

    # criterion = nn.CrossEntropyLoss().to(device)
    # criterion = CustomCriterion().to(device)
    criterion = CustomCriterionMSE().to(device)
    
    # if (OTTT_sWS_on == True):
    #     # criterion = nn.CrossEntropyLoss().to(device)
        # criterion = lambda y_t, target_t: ((1 - 0.05) * F.cross_entropy(y_t, target_t) + 0.05 * F.mse_loss(y_t, F.one_hot(target_t, CLASS_NUM).float())) / TIME 
    #     if which_data == 'DVS_GESTURE':
    #         criterion = lambda y_t, target_t: ((1 - 0.001) * F.cross_entropy(y_t, target_t) + 0.001 * F.mse_loss(y_t, F.one_hot(target_t, CLASS_NUM).float())) / TIME 
    ####################################################

    ## optimizer, scheduler ########################################################################
    class MySGD(torch.optim.Optimizer):
        def __init__(self, params, lr=0.01, momentum=0.0, quantize_bit_list=[], scale_exp=[], net=None):
            if momentum < 0.0 or momentum >= 1.0:
                raise ValueError(f"Invalid momentum value: {momentum}")
            
            defaults = {'lr': lr, 'momentum': momentum}
            super(MySGD, self).__init__(params, defaults)
            self.step_count = 0
            self.quantize_bit_list = quantize_bit_list
            # self.quantize_bit_list = []
            self.scale_exp = scale_exp
            self.param_to_name = {param: name for name, param in net.module.named_parameters()} if net else {}

        @torch.no_grad()
        def step(self):
            """모든 파라미터에 대해 gradient descent 수행"""
            loss = None
            for group in self.param_groups:
                # lr = group['lr']

                momentum = group['momentum']
                for param in group['params']:
                    if param.grad is None:
                        continue
                    name = self.param_to_name.get(param, 'unknown')

                    if 'layers.1.fc.weight' in name:
                        lr = learning_rate
                        assert learning_rate != None
                    elif 'layers.3.fc.weight' in name:
                        lr = learning_rate2
                        assert learning_rate2 != None
                    elif 'layers.5.fc.weight' in name:
                        # lr = 1.0
                        lr = learning_rate3
                        assert learning_rate3 != None

                    # gradient를 이용해 파라미터 업데이트
                    d_p = param.grad

                    if momentum > 0.0:
                        assert False
                        param_state = self.state[param]
                        if 'momentum_buffer' not in param_state:
                            # momentum buffer 초기화
                            buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
                        else:
                            buf = param_state['momentum_buffer']
                            buf.mul_(momentum).add_(d_p)
                            # buf *= momentum 
                            # buf += d_p
                        d_p = buf

                    dw = -lr*d_p
                    param.add_(dw)
            return loss
    
    if(optimizer_what == 'SGD'):
        optimizer = MySGD(net.parameters(), lr=learning_rate, momentum=0.0, quantize_bit_list=quantize_bit_list, scale_exp=scale_exp, net=net)
        # optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.0)
        print(optimizer)
    elif(optimizer_what == 'Adam'):
        optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
        # optimizer = torch.optim.Adam(net.parameters(), lr=0.00001)
        # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate/256 * BATCH, weight_decay=1e-4)
        # optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0, betas=(0.9, 0.999))
    elif(optimizer_what == 'RMSprop'):
        pass


    if (scheduler_name == 'StepLR'):
        scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif (scheduler_name == 'ExponentialLR'):
        scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
    elif (scheduler_name == 'ReduceLROnPlateau'):
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10)
    elif (scheduler_name == 'CosineAnnealingLR'):
        # scheduler = lr_scheduler.CosineAnnealingLR(optimizer, eta_min=0, T_max=50)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=0, T_max=epoch_num)
    elif (scheduler_name == 'OneCycleLR'):
        scheduler = lr_scheduler.OneCycleLR(optimizer, max_lr=0.1, steps_per_epoch=len(train_loader), epochs=epoch_num)
    else:
        pass # 'no' scheduler
    ## optimizer, scheduler ########################################################################


    tr_acc = 0
    tr_correct = 0
    tr_total = 0
    tr_acc_best = 0
    tr_epoch_loss_temp = 0
    tr_epoch_loss = 0
    val_acc_best = 0
    val_acc_now = 0
    val_loss = 0
    iter_of_val = False
    total_backward_count = 0
    real_backward_count = 0
    #======== EPOCH START ==========================================================================================
    for epoch in range(epoch_num):
        epoch_start_time = time.time()
        print('total_backward_count', total_backward_count, 'real_backward_count',real_backward_count, f'{100*real_backward_count/(total_backward_count+0.00000001):7.3f}%')
        if epoch == 1:
            for name, module in net.named_modules():
                if isinstance(module, Feedback_Receiver):
                    print(f"[{name}] weight_fb parameter count: {module.weight_fb.numel():,}")

        max_val_box = []
        max_val_scale_exp_8bit_box = []
        max_val_scale_exp_16bit_box = []
        perc_95_box = []
        perc_95_scale_exp_8bit_box = []
        perc_95_scale_exp_16bit_box = []
        perc_99_box = []
        perc_99_scale_exp_8bit_box = []
        perc_99_scale_exp_16bit_box = []
        perc_999_box = []
        perc_999_scale_exp_8bit_box = []
        perc_999_scale_exp_16bit_box = []
        ##### weight 프린트 ######################################################################
        for name, param in net.module.named_parameters():
            if ('weight' in name or 'bias' in name) and ('1' in name or '3' in name or '5' in name):
                data = param.detach().cpu().numpy().flatten()
                abs_data = np.abs(data)

                # 통계량 계산
                mean = np.mean(data)
                std = np.std(data)
                abs_mean = np.mean(abs_data)
                abs_std = np.std(abs_data)
                eps = 1e-15

                # 절대값 기반 max, percentiles
                max_val = abs_data.max()
                print(name, f'epoch {epoch}: mean={mean:.4f}, std={std:.4f}, |mean|={abs_mean:.4f}, |std|={abs_std:.4f}, max={max_val:.4f}')
                max_val_scale_exp_8bit = math.ceil(math.log2((eps+max_val)/ (2**(8-1) -1)))
                max_val_scale_exp_16bit = math.ceil(math.log2((eps+max_val)/ (2**(16-1) -1)))
                perc_95 = np.percentile(abs_data, 95)
                perc_95_scale_exp_8bit = math.ceil(math.log2((eps+perc_95)/ (2**(8-1) -1)))
                perc_95_scale_exp_16bit = math.ceil(math.log2((eps+perc_95)/ (2**(16-1) -1)))
                perc_99 = np.percentile(abs_data, 99)
                perc_99_scale_exp_8bit = math.ceil(math.log2((eps+perc_99)/ (2**(8-1) -1)))
                perc_99_scale_exp_16bit = math.ceil(math.log2((eps+perc_99)/ (2**(16-1) -1)))
                perc_999 = np.percentile(abs_data, 99.9)
                perc_999_scale_exp_8bit = math.ceil(math.log2((eps+perc_999)/ (2**(8-1) -1)))
                perc_999_scale_exp_16bit = math.ceil(math.log2((eps+perc_999)/ (2**(16-1) -1)))
                
                max_val_box.append(max_val)
                max_val_scale_exp_8bit_box.append(max_val_scale_exp_8bit)
                max_val_scale_exp_16bit_box.append(max_val_scale_exp_16bit)
                perc_95_box.append(perc_95)
                perc_95_scale_exp_8bit_box.append(perc_95_scale_exp_8bit)
                perc_95_scale_exp_16bit_box.append(perc_95_scale_exp_16bit)
                perc_99_box.append(perc_99)
                perc_99_scale_exp_8bit_box.append(perc_99_scale_exp_8bit)
                perc_99_scale_exp_16bit_box.append(perc_99_scale_exp_16bit)
                perc_999_box.append(perc_999)
                perc_999_scale_exp_8bit_box.append(perc_999_scale_exp_8bit)
                perc_999_scale_exp_16bit_box.append(perc_999_scale_exp_16bit)




                # if epoch % 5 == 0 or epoch < 3:
                #     print("=> Plotting weight and bias distributions...")
                #     # 그래프 그리기
                #     plt.figure(figsize=(6, 4))
                #     plt.hist(data, bins=100, alpha=0.7, color='skyblue')
                #     plt.axvline(x=max_val, color='red', linestyle='--', label=f'Max: {max_val:.4f}')
                #     plt.axvline(x=-max_val, color='red', linestyle='--')
                #     plt.axvline(x=perc_95, color='green', linestyle='--', label=f'95%: {perc_95:.4f}')
                #     plt.axvline(x=-perc_95, color='green', linestyle='--')
                #     plt.axvline(x=perc_99, color='orange', linestyle='--', label=f'99%: {perc_99:.4f}')
                #     plt.axvline(x=-perc_99, color='orange', linestyle='--')
                #     plt.axvline(x=perc_999, color='purple', linestyle='--', label=f'99.9%: {perc_999:.4f}')
                #     plt.axvline(x=-perc_999, color='purple', linestyle='--')
                    
                #     # 제목에 통계값 포함
                #     title = (
                #         f"{name}, Epoch {epoch}\n"
                #         f"mean={mean:.4f}, std={std:.4f}, "
                #         f"|mean|={abs_mean:.4f}, |std|={abs_std:.4f}\n"
                #         f"Scale 8bit max = { max_val_scale_exp_8bit}, "
                #         f"Scale 16bit max = {max_val_scale_exp_16bit}\n"
                #         f"Scale 8bit p999 = {perc_999_scale_exp_8bit }, "
                #         f"Scale 16bit p999 = {perc_999_scale_exp_16bit }\n"
                #         f"Scale 8bit p99 = {perc_99_scale_exp_8bit }, "
                #         f"Scale 16bit p99 = { perc_99_scale_exp_16bit}\n"
                #         f"Scale 8bit p95 = { perc_95_scale_exp_8bit}, "
                #         f"Scale 16bit p95 = { perc_95_scale_exp_16bit}"
                #     )
                #     plt.title(title)
                #     plt.xlabel('Value')
                #     plt.ylabel('Frequency')
                #     plt.grid(True)
                #     plt.legend()
                #     plt.tight_layout()
                #     plt.show()
        ##### weight 프린트 ######################################################################

        ####### iterator : input_loading & tqdm을 통한 progress_bar 생성###################
        iterator = enumerate(train_loader, 0)
        # iterator = tqdm(iterator, total=len(train_loader), desc='train', dynamic_ncols=True, position=0, leave=True)
        ##################################################################################   

        ###### ITERATION START ##########################################################################################################
        for i, data in iterator:
            net.train() # train 모드로 바꿔줘야함
            ### data loading & semi-pre-processing ################################################################################
            if len(data) == 2:
                inputs, labels = data
                # 처리 로직 작성
            elif len(data) == 3:
                inputs, labels, x_len = data
            else:
                assert False, 'data length is not 2 or 3'
            #######################################################################################################################
            if extra_train_dataset == -1:
                # print(inputs.shape)
                assert BATCH == 1
                now_T = inputs.shape[1]
                now_time_steps = temporal_filter*TIME
                # start_idx = random.randint(0, now_T - now_time_steps)
                start_idx = random.choice(range(0, now_T - now_time_steps + 1, now_time_steps))
                # start_idx = random.choice([i for i in range(0, now_T - now_time_steps + 1, now_time_steps)])
                inputs = inputs[:, start_idx : start_idx + now_time_steps]
                if dvs_clipping != 0:
                    inputs[inputs<dvs_clipping] = 0.0
                    inputs[inputs>=dvs_clipping] = 1.0
            ## batch 크기 ######################################
            real_batch = labels.size(0)
            ###########################################################

            # 차원 전처리
            ###########################################################################################################################        
            if (which_data == 'DVS_CIFAR10' or which_data == 'DVS_GESTURE' or which_data == 'DVS_GESTURE_TONIC' or which_data == 'DVS_CIFAR10_2' or which_data == 'NMNIST' or which_data == 'NMNIST_TONIC' or which_data == 'N_CALTECH101' or which_data == 'n_tidigits' or which_data == 'heidelberg'):
                inputs = inputs.permute(1, 0, 2, 3, 4)
            elif rate_coding == True :
                inputs = spikegen.rate(inputs, num_steps=TIME)
            else :
                inputs = inputs.repeat(TIME, 1, 1, 1, 1)
            # inputs: [Time, Batch, Channel, Height, Width]  
            ####################################################################################################################### 
                
            # if i % 1000 == 999:
            #     # SYNAPSE_FC에 있는 sparsity_print_and_reset() 실행
            #     for name, module in net.module.named_modules():
            #         if isinstance(module, SYNAPSE_FC):
            #             module.sparsity_print_and_reset()

                            
            ## initial pooling #######################################################################
            if (initial_pooling > 1):
                pool = nn.MaxPool2d(kernel_size=2)
                num_pooling_layers = int(math.log2(initial_pooling))
                # Time, Batch, Channel 차원은 그대로 두고, Height, Width 차원에 대해서만 pooling 적용
                shape_temp = inputs.shape
                inputs = inputs.reshape(shape_temp[0]*shape_temp[1], shape_temp[2], shape_temp[3], shape_temp[4])
                for _ in range(num_pooling_layers):
                    inputs = pool(inputs)
                inputs = inputs.reshape(shape_temp[0], shape_temp[1], shape_temp[2], shape_temp[3]//initial_pooling, shape_temp[4]//initial_pooling)
            ## initial pooling #######################################################################
            ## temporal filtering ####################################################################
            shape_temp = inputs.shape
            if (temporal_filter > 1):
                slice_bucket = []
                for t_temp in range(TIME):
                    start = t_temp * temporal_filter
                    end = start + temporal_filter
                    slice_concat = torch.movedim(inputs[start:end], 0, -2).reshape(shape_temp[1],shape_temp[2],shape_temp[3],-1)
                    
                    if temporal_filter_accumulation == True:
                        if t_temp == 0:
                            slice_bucket.append(slice_concat)
                        else:
                            slice_bucket.append(slice_concat+slice_bucket[t_temp-1])
                    else:
                        slice_bucket.append(slice_concat)

                inputs = torch.stack(slice_bucket, dim=0)
                if temporal_filter_accumulation == True and dvs_clipping > 0:
                    inputs = (inputs != 0.0).float()
            ## temporal filtering ####################################################################
            ####################################################################################################################### 
                

            # # dvs 데이터 시각화 코드 (확인 필요할 시 써라)
            # ##############################################################################################
            # dvs_visualization(inputs, labels, TIME, BATCH, my_seed)
            # #####################################################################################################

            ## to (device) #######################################
            inputs = inputs.to(device)
            labels = labels.to(device)
            ###########################################################

            # ## gradient 초기화 #######################################
            # optimizer.zero_grad()
            # ###########################################################
                            
            if merge_polarities == True:
                inputs = inputs[:,:,0:1,:,:]

            if single_step == False:
                # net에 넣어줄때는 batch가 젤 앞 차원으로 와야함. # dataparallel때매##############################
                # inputs: [Time, Batch, Channel, Height, Width]   
                inputs = inputs.permute(1, 0, 2, 3, 4) # net에 넣어줄때는 batch가 젤 앞 차원으로 와야함. # dataparallel때매
                # inputs: [Batch, Time, Channel, Height, Width] 
                #################################################################################################
            else:
                labels = labels.repeat(TIME, 1)
                ## first input도 ottt trace 적용하기 위한 코드 (validation 시에는 필요X) ##########################
                if trace_on == True and OTTT_input_trace_on == True:
                    spike = inputs
                    trace = torch.full_like(spike, fill_value = 0.0, dtype = torch.float, requires_grad=False)
                    inputs = []
                    for t in range(TIME):
                        trace[t] = trace[t-1]*synapse_trace_const2 + spike[t]*synapse_trace_const1
                        inputs += [[spike[t], trace[t]]]
                ##################################################################################################


            if single_step == False:
                optimizer.zero_grad()
                outputs = net(inputs)
                outputs = outputs.sum(dim=0)
                ##################################################################################
                ## loss, backward ##########################################
                iter_loss = criterion(outputs, labels)
                iter_loss.backward()
                ############################################################
                ## weight 업데이트!! ##################################
                optimizer.step()
                ################################################################
            else:
                outputs_all = []
                iter_loss = 0.0
                for t in range(TIME):
                    optimizer.step() # full step time update
                    optimizer.zero_grad()
                    ### input[t] --> net --> output_one_time #########################################
                    outputs_one_time = net(inputs[t])
                    ##################################################################################
                    one_time_loss = criterion(outputs_one_time, labels[t].contiguous())
                    one_time_loss.backward() # one_time backward
                    iter_loss += one_time_loss.data
                    outputs_all.append(outputs_one_time.detach())

                    total_backward_count = total_backward_count + 1
                    outputs_one_time_argmax = (outputs_one_time.detach()).argmax(dim=1)
                    real_backward_count = real_backward_count + (outputs_one_time_argmax != labels[t]).sum().item()


                outputs_all = torch.stack(outputs_all, dim=1)
                outputs = outputs_all.mean(1) # ottt꺼 쓸때
                labels = labels[0]
                iter_loss /= TIME

            tr_epoch_loss_temp += iter_loss.data/len(train_loader)

            ## net 그림 출력해보기 #################################################################
            # print('시각화')
            # make_dot(outputs, params=dict(list(net.named_parameters()))).render("net_torchviz", format="png")
            # return 0
            ##################################################################################

            #### batch 어긋남 방지 ###############################################
            assert real_batch == outputs.size(0), f'batch size is not same. real_batch: {real_batch}, outputs.size(0): {outputs.size(0)}'
            #######################################################################
            

            ####### training accruacy save for print ###############################
            _, predicted = torch.max(outputs.data, 1)
            total = real_batch
            correct = (predicted == labels).sum().item()
            iter_acc = correct / total
            tr_total += total
            tr_correct += correct
            iter_acc_string = f'epoch-{epoch:<3} iter_acc:{100 * iter_acc:7.2f}%, lr={[f"{lr:9.7f}" for lr in (param_group["lr"] for param_group in optimizer.param_groups)]}'
            iter_acc_string2 = f'epoch-{epoch:<3} lr={[f"{lr:9.7f}" for lr in (param_group["lr"] for param_group in optimizer.param_groups)]}'
            ################################################################
            

            ##### validation ##################################################################################################################################
            if i == len(train_loader)-1 :
                iter_of_val = True

                tr_acc = tr_correct/tr_total
                tr_correct = 0
                tr_total = 0

                val_loss = 0
                correct_val = 0
                total_val = 0

                with torch.no_grad():
                    net.eval() # eval 모드로 바꿔줘야함 
                    for data_val in test_loader:
                        ## data_val loading & semi-pre-processing ##########################################################
                        if len(data_val) == 2:
                            inputs_val, labels_val = data_val
                        elif len(data_val) == 3:
                            inputs_val, labels_val, x_len = data_val
                        else:
                            assert False, 'data_val length is not 2 or 3'

                        if extra_train_dataset == -1:
                            assert BATCH == 1
                            now_T = inputs_val.shape[1]
                            now_time_steps = temporal_filter*TIME
                            start_idx = 0
                            inputs_val = inputs_val[:, start_idx : start_idx + now_time_steps]

                            if dvs_clipping != 0:
                                inputs_val[inputs_val<dvs_clipping] = 0.0
                                inputs_val[inputs_val>=dvs_clipping] = 1.0

                        if (which_data == 'DVS_CIFAR10' or which_data == 'DVS_GESTURE' or which_data == 'DVS_GESTURE_TONIC' or which_data == 'DVS_CIFAR10_2' or which_data == 'NMNIST' or which_data == 'NMNIST_TONIC' or which_data == 'N_CALTECH101' or which_data == 'n_tidigits' or which_data == 'heidelberg'):
                            inputs_val = inputs_val.permute(1, 0, 2, 3, 4)
                        elif rate_coding == True :
                            inputs_val = spikegen.rate(inputs_val, num_steps=TIME)
                        else :
                            inputs_val = inputs_val.repeat(TIME, 1, 1, 1, 1)
                        # inputs_val: [Time, Batch, Channel, Height, Width]  
                        ###################################################################################################

                        
                        ## initial pooling #######################################################################
                        if (initial_pooling > 1):
                            pool = nn.MaxPool2d(kernel_size=2)
                            num_pooling_layers = int(math.log2(initial_pooling))
                            # Time, Batch, Channel 차원은 그대로 두고, Height, Width 차원에 대해서만 pooling 적용
                            shape_temp = inputs_val.shape
                            inputs_val = inputs_val.reshape(shape_temp[0]*shape_temp[1], shape_temp[2], shape_temp[3], shape_temp[4])
                            for _ in range(num_pooling_layers):
                                inputs_val = pool(inputs_val)
                            inputs_val = inputs_val.reshape(shape_temp[0], shape_temp[1], shape_temp[2], shape_temp[3]//initial_pooling, shape_temp[4]//initial_pooling)
                        ## initial pooling #######################################################################

                        ## temporal filtering ####################################################################
                        shape_temp = inputs_val.shape
                        if (temporal_filter > 1):
                            slice_bucket = []
                            for t_temp in range(TIME):
                                start = t_temp * temporal_filter
                                end = start + temporal_filter
                                slice_concat = torch.movedim(inputs_val[start:end], 0, -2).reshape(shape_temp[1],shape_temp[2],shape_temp[3],-1)
                                
                                if temporal_filter_accumulation == True:
                                    if t_temp == 0:
                                        slice_bucket.append(slice_concat)
                                    else:
                                        slice_bucket.append(slice_concat+slice_bucket[t_temp-1])
                                else:
                                    slice_bucket.append(slice_concat)

                            inputs_val = torch.stack(slice_bucket, dim=0)
                            if temporal_filter_accumulation == True and dvs_clipping > 0:
                                inputs = (inputs != 0.0).float()
                        ## temporal filtering ####################################################################
                            
                        inputs_val = inputs_val.to(device)
                        labels_val = labels_val.to(device)
                        real_batch = labels_val.size(0)
                        
                        if merge_polarities == True:
                            inputs_val = inputs_val[:,:,0:1,:,:]

                        ## network 연산 시작 ############################################################################################################
                        if single_step == False:
                            outputs = net(inputs_val.permute(1, 0, 2, 3, 4)) #inputs_val: [Batch, Time, Channel, Height, Width]  
                            outputs = outputs.sum(dim=0)
                            val_loss += criterion(outputs, labels_val)/len(test_loader)
                        else:
                            outputs_all = []
                            for t in range(TIME):
                                outputs = net(inputs_val[t])
                                val_loss_temp = criterion(outputs, labels_val)
                                outputs_all.append(outputs.detach())
                                val_loss += (val_loss_temp.data/TIME)/len(test_loader)
                            outputs_all = torch.stack(outputs_all, dim=1)
                            outputs = outputs_all.mean(1)
                        #################################################################################################################################

                        _, predicted = torch.max(outputs.data, 1)
                        total_val += real_batch
                        assert real_batch == outputs.size(0), f'batch size is not same. real_batch: {real_batch}, outputs.size(0): {outputs.size(0)}'
                        correct_val += (predicted == labels_val).sum().item()

                    val_acc_now = correct_val / total_val

                if val_acc_best < val_acc_now:
                    val_acc_best = val_acc_now
                    # wandb 키면 state_dict아닌거는 저장 안됨
                    # network save
                    torch.save(net.state_dict(), f"net_save/save_now_net_weights_{unique_name}.pth")

                if tr_acc_best < tr_acc:
                    tr_acc_best = tr_acc

                tr_epoch_loss = tr_epoch_loss_temp
                tr_epoch_loss_temp = 0

            ####################################################################################################################################################
            
            ## progress bar update ############################################################################################################
            epoch_end_time = time.time()
            epoch_time = epoch_end_time - epoch_start_time
            if iter_of_val == False:
                # iterator.set_description(f"{iter_acc_string}, iter_loss:{iter_loss:10.6f}") 
                pass 
            else:
                # iterator.set_description(f"{iter_acc_string2}, tr/val_loss:{tr_epoch_loss:10.6f}/{val_loss:10.6f}, tr:{100 * tr_acc:7.2f}%, tr_best:{100 * tr_acc_best:7.2f}%, val:{100 * val_acc_now:7.2f}%, val_best:{100 * val_acc_best:7.2f}%")  
                print(f"{iter_acc_string2}, tr/val_loss:{tr_epoch_loss:10.6f}/{val_loss:10.6f}, val:{100 * val_acc_now:7.2f}%, val_best:{100 * val_acc_best:7.2f}%, tr:{100 * tr_acc:7.2f}%, tr_best:{100 * tr_acc_best:7.2f}%, epoch time: {epoch_time:.2f} seconds, {epoch_time/60:.2f} minutes")
                iter_of_val = False
            ####################################################################################################################################
            
            ## wandb logging ############################################################################################################
            if i == len(train_loader)-1 :
                wandb.log({"iter_acc": iter_acc})
                wandb.log({"tr_acc": tr_acc})
                wandb.log({"val_acc_now": val_acc_now})
                wandb.log({"val_acc_best": val_acc_best})
                wandb.log({"summary_val_acc": val_acc_now})
                wandb.log({"epoch": epoch})
                wandb.log({"val_loss": val_loss}) 
                wandb.log({"tr_epoch_loss": tr_epoch_loss}) 
                # wandb.log({"max_val_scale_exp_8bit_1w": max_val_scale_exp_8bit_box[0]}) 
                # wandb.log({"max_val_scale_exp_8bit_1b": max_val_scale_exp_8bit_box[1]})
                # wandb.log({"max_val_scale_exp_8bit_2w": max_val_scale_exp_8bit_box[2]}) 
                # wandb.log({"max_val_scale_exp_8bit_2b": max_val_scale_exp_8bit_box[3]}) 
                # wandb.log({"max_val_scale_exp_8bit_3w": max_val_scale_exp_8bit_box[4]}) 
                # wandb.log({"max_val_scale_exp_8bit_3b": max_val_scale_exp_8bit_box[5]})

                # wandb.log({"perc_999_scale_exp_8bit_1w": perc_999_scale_exp_8bit_box[0]}) 
                # wandb.log({"perc_999_scale_exp_8bit_1b": perc_999_scale_exp_8bit_box[1]})
                # wandb.log({"perc_999_scale_exp_8bit_2w": perc_999_scale_exp_8bit_box[2]}) 
                # wandb.log({"perc_999_scale_exp_8bit_2b": perc_999_scale_exp_8bit_box[3]}) 
                # wandb.log({"perc_999_scale_exp_8bit_3w": perc_999_scale_exp_8bit_box[4]}) 
                # wandb.log({"perc_999_scale_exp_8bit_3b": perc_999_scale_exp_8bit_box[5]}) 

                for name, module in net.module.named_modules():
                    if isinstance(module, SYNAPSE_FC):
                        module.sparsity_print_and_reset()
                
                if epoch > 10:
                    assert val_acc_best > 0.2
                elif epoch > 50:
                    assert val_acc_best > 0.4
                elif epoch > 60:
                    assert val_acc_best > 0.5
                elif epoch > 100:
                    assert val_acc_best > 0.6
                        
                # if epoch > 100:
                #     assert val_acc_best > 0.6
                    
            ####################################################################################################################################
            
        ###### ITERATION END ##########################################################################################################

        ## scheduler update #############################################################################
        if (scheduler_name != 'no'):
            if (scheduler_name == 'ReduceLROnPlateau'):
                scheduler.step(val_loss)
            else:
                scheduler.step()
        #################################################################################################
        
    #======== EPOCH END ==========================================================================================

# %%
# unique_name = 'main' ## 이거 설정하면 새로운 경로에 모두 save
# wandb.init(project= f'my_snn {unique_name}',save_code=False, dir='/data2/bh_wandb', tags=["common"])
# ## wandb 과거 하이퍼파라미터 가져와서 붙여넣기 (devices unique_name은 니가 할당해라)#################################
# param = {'devices': '3', 'single_step': True, 'unique_name': 'main', 'my_seed': 42, 'TIME': 10, 'BATCH': 16, 'IMAGE_SIZE': 128, 'which_data': 'DVS_GESTURE_TONIC', 'data_path': '/data2', 'rate_coding': False, 'lif_layer_v_init': 0, 'lif_layer_v_decay': 0.25, 'lif_layer_v_threshold': 0.75, 'lif_layer_v_reset': 0, 'lif_layer_sg_width': 4, 'synapse_conv_kernel_size': 3, 'synapse_conv_stride': 1, 'synapse_conv_padding': 1, 'synapse_trace_const1': 1, 'synapse_trace_const2': 0, 'pre_trained': False, 'convTrue_fcFalse': False, 'cfg': [200, 200], 'net_print': True, 'pre_trained_path': 'net_save/save_now_net_weights_{unique_name}.pth', 'learning_rate': 0.001, 'epoch_num': 100, 'tdBN_on': False, 'BN_on': False, 'surrogate': 'hard_sigmoid', 'BPTT_on': False, 'optimizer_what': 'SGD', 'scheduler_name': 'no', 'ddp_on': False, 'dvs_clipping': 2, 'dvs_duration': 25000, 'DFA_on': True, 'trace_on': True, 'OTTT_input_trace_on': False, 'exclude_class': True, 'merge_polarities': False, 'denoise_on': True, 'extra_train_dataset': 0, 'num_workers': 2, 'chaching_on': True, 'pin_memory': True, 'UDA_on': False, 'alpha_uda': 1, 'bias': True, 'last_lif': False, 'temporal_filter': 5, 'initial_pooling': 8}
# my_snn_system(devices = '0',single_step = param['single_step'],unique_name = unique_name,my_seed = param['my_seed'],TIME = param['TIME'],BATCH = param['BATCH'],IMAGE_SIZE = param['IMAGE_SIZE'],which_data = param['which_data'],data_path = param['data_path'],rate_coding = param['rate_coding'],lif_layer_v_init = param['lif_layer_v_init'],lif_layer_v_decay = param['lif_layer_v_decay'],lif_layer_v_threshold = param['lif_layer_v_threshold'],lif_layer_v_reset = param['lif_layer_v_reset'],lif_layer_sg_width = param['lif_layer_sg_width'],synapse_conv_kernel_size = param['synapse_conv_kernel_size'],synapse_conv_stride = param['synapse_conv_stride'],synapse_conv_padding = param['synapse_conv_padding'],synapse_trace_const1 = param['synapse_trace_const1'],synapse_trace_const2 = param['synapse_trace_const2'],pre_trained = param['pre_trained'],convTrue_fcFalse = param['convTrue_fcFalse'],cfg = param['cfg'],net_print = param['net_print'],pre_trained_path = param['pre_trained_path'],learning_rate = param['learning_rate'],epoch_num = param['epoch_num'],tdBN_on = param['tdBN_on'],BN_on = param['BN_on'],surrogate = param['surrogate'],BPTT_on = param['BPTT_on'],optimizer_what = param['optimizer_what'],scheduler_name = param['scheduler_name'],ddp_on = param['ddp_on'],dvs_clipping = param['dvs_clipping'],dvs_duration = param['dvs_duration'],DFA_on = param['DFA_on'],trace_on = param['trace_on'],OTTT_input_trace_on = param['OTTT_input_trace_on'],exclude_class = param['exclude_class'],merge_polarities = param['merge_polarities'],denoise_on = param['denoise_on'],extra_train_dataset = param['extra_train_dataset'],num_workers = param['num_workers'],chaching_on = param['chaching_on'],pin_memory = param['pin_memory'],UDA_on = param['UDA_on'],alpha_uda = param['alpha_uda'],bias = param['bias'],last_lif = param['last_lif'],temporal_filter = param['temporal_filter'],initial_pooling = param['initial_pooling'],temporal_filter_accumulation= param['temporal_filter_accumulation'])
# #############################################################################

# %%
# ### my_snn control board (Gesture) ########################
# decay = 0.5 # 0.0 # 0.875 0.25 0.125 0.75 0.5
# # nda 0.25 # ottt 0.5

# unique_name = 'main'
# run_name = datetime.datetime.now().strftime("%Y%m%d_%H%M%S_") + f"{datetime.datetime.now().microsecond // 1000:03d}"


# wandb.init(project= f'my_snn {unique_name}',save_code=False, dir='/data2/bh_wandb', tags=["common"])

# my_snn_system(  devices = "5",
#                 single_step = False, # True # False # DFA_on이랑 같이 가라
#                 unique_name = run_name,
#                 my_seed = 3,
#                 TIME = 10, # dvscifar 10 # ottt 6 or 10 # nda 10  # 제작하는 dvs에서 TIME넘거나 적으면 자르거나 PADDING함
#                 BATCH = 1, # batch norm 할거면 2이상으로 해야함   # nda 256   #  ottt 128
#                 IMAGE_SIZE = 14, # dvscifar 48 # MNIST 28 # CIFAR10 32 # PMNIST 28 #NMNIST 34 # GESTURE 128
#                 # dvsgesture 128, dvs_cifar2 128, nmnist 34, n_caltech101 180,240, n_tidigits 64, heidelberg 700, 

#                 # DVS_CIFAR10 할거면 time 10으로 해라
#                 which_data = 'DVS_GESTURE_TONIC',
# # 'CIFAR100' 'CIFAR10' 'MNIST' 'FASHION_MNIST' 'DVS_CIFAR10' 'PMNIST'아직
# # 'DVS_GESTURE', 'DVS_GESTURE_TONIC','DVS_CIFAR10_2','NMNIST','NMNIST_TONIC','CIFAR10','N_CALTECH101','n_tidigits','heidelberg'
#                 # CLASS_NUM = 10,
#                 data_path = '/data2', # YOU NEED TO CHANGE THIS
#                 rate_coding = False, # True # False

#                 lif_layer_v_init = 0.0,
#                 lif_layer_v_decay = decay,
#                 lif_layer_v_threshold = 1.0,   #nda 0.5  #ottt 1.0
#                 lif_layer_v_reset = 0.0, # 10000이상은 hardreset (내 LIF쓰기는 함 ㅇㅇ)
#                 lif_layer_sg_width = 4.0, # 2.570969004857107 # sigmoid류에서는 alpha값 4.0, rectangle류에서는 width값 0.5

#                 # synapse_conv_in_channels = IMAGE_PIXEL_CHANNEL,
#                 synapse_conv_kernel_size = 3,
#                 synapse_conv_stride = 1,
#                 synapse_conv_padding = 1,

#                 synapse_trace_const1 = 1, # 현재 trace구할 때 현재 spike에 곱해지는 상수. 걍 1로 두셈.
#                 synapse_trace_const2 = decay, # 현재 trace구할 때 직전 trace에 곱해지는 상수. lif_layer_v_decay와 같게 할 것을 추천

#                 # synapse_fc_out_features = CLASS_NUM,

#                 pre_trained = False, # True # False
#                 convTrue_fcFalse = False, # True # False

#                 # 'P' for average pooling, 'D' for (1,1) aver pooling, 'M' for maxpooling, 'L' for linear classifier, [  ] for residual block
#                 # conv에서 10000 이상은 depth-wise separable (BPTT만 지원), 20000이상은 depth-wise (BPTT만 지원)
#                 # cfg = ['M', 'M', 32, 'P', 32, 'P', 32, 'P'], 
#                 # cfg = ['M', 'M', 64, 'P', 64, 'P', 64, 'P'], 
#                 # cfg = ['M', 'M', 64, 'M', 96, 'M', 128, 'M'], 
#                 cfg = [200, 200], 
#                 # cfg = ['M', 'M', 64, 'M', 96], 
#                 # cfg = ['M', 'M', 64, 'M', 96, 'L', 512, 512], 
#                 # cfg = ['M', 'M', 64], 
#                 # cfg = [64, 124, 64, 124],
#                 # cfg = ['M','M',512], 
#                 # cfg = [512], 
#                 # cfg = ['M', 'M', 64, 128, 'P', 128, 'P'], 
#                 # cfg = ['M','M',512],
#                 # cfg = ['M',200],
#                 # cfg = [200,200],
#                 # cfg = ['M','M',200,200],
#                 # cfg = ([200],[200],[200],[2]), # (feature extractor, classifier, domain adapter, # of domain)
#                 # cfg = (['M','M',200],[200],[200],[2]), # (feature extractor, classifier, domain adapter, # of domain)
#                 # cfg = ['M',200,200],
#                 # cfg = ['M','M',1024,512,256,128,64],
#                 # cfg = [200,200],
#                 # cfg = [12], #fc
#                 # cfg = [12, 'M', 48, 'M', 12], 
#                 # cfg = [64,[64,64],64], # 끝에 linear classifier 하나 자동으로 붙습니다
#                 # cfg = [64, 128, 'P', 256, 256, 'P', 512, 512, 'P', 512, 512, 'D'], #ottt
#                 # cfg = [64, 128, 'P', 256, 256, 'P', 512, 512, 'P', 512, 512], 
#                 # cfg = [64, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512], 
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512, 'D'], # nda
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512], # nda 128pixel
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512, 'L', 4096, 4096],
#                 # cfg = [20001,10001], # depthwise, separable
#                 # cfg = [64,20064,10001], # vanilla conv, depthwise, separable
#                 # cfg = [8, 'P', 8, 'P', 8, 'P', 8,'P', 8, 'P'],
#                 # cfg = [],        
                
#                 net_print = True, # True # False # True로 하길 추천
                
#                 pre_trained_path = f"net_save/save_now_net_weights_{unique_name}.pth",
#                 # learning_rate = 0.001, #0.1 bptt, #0.01 ottt, # default 0.001  # ottt 0.1 # nda 0.001 # 0.00936191669529645
#                 learning_rate = 0.01, #0.1 bptt, #0.01 ottt, # default 0.001  # ottt 0.1 # nda 0.001 # 0.00936191669529645
#                 epoch_num = 200,
#                 tdBN_on = False,  # True # False
#                 BN_on = False,  # True # False
                
#                 surrogate = 'sigmoid', # 'sigmoid' 'rectangle' 'rough_rectangle' 'hard_sigmoid'
                
#                 BPTT_on = True,  # True # False # True이면 BPTT, False이면 OTTT  # depthwise, separable은 BPTT만 가능
                
#                 optimizer_what = 'SGD', # 'SGD' 'Adam', 'RMSprop'
#                 scheduler_name = 'no', # 'no' 'StepLR' 'ExponentialLR' 'ReduceLROnPlateau' 'CosineAnnealingLR' 'OneCycleLR'
                
#                 ddp_on = False, # DECREPATED # fALSE

#                 dvs_clipping = 14, #일반적으로 1 또는 2 # 100ms때는 5 # 숫자만큼 크면 spike 아니면 걍 0
#                 # gesture, cifar-dvs2, nmnist, ncaltech101
#                 # gesture: 100_000c1-5, 25_000c5, 10_000c5, 1_000c5, 1_000_000c5

#                 dvs_duration = 25_000, # 0 아니면 time sampling # dvs number sampling OR time sampling # gesture, cifar-dvs2, nmnist, ncaltech101
#                 # 있는 데이터들 #gesture 100_000 25_000 10_000 1_000 1_000_000 #nmnist 10000 #nmnist_tonic 10_000 25_000
#                 # 한 숫자가 1us인듯 (spikingjelly코드에서)
#                 # 한 장에 50 timestep만 생산함. 싫으면 my_snn/trying/spikingjelly_dvsgesture의__init__.py 를 참고해봐
#                 # nmnist 5_000us, gesture는 100_000us, 25_000us

#                 DFA_on = False, # True # False # single_step이랑 같이 켜야 됨.

#                 trace_on = False,   # True # False
#                 OTTT_input_trace_on = False, # True # False # 맨 처음 input에 trace 적용 # trace_on False면 의미없음.

#                 exclude_class = True, # True # False # gesture에서 10번째 클래스 제외

#                 merge_polarities = True, # True # False # tonic dvs dataset 에서 polarities 합치기
#                 denoise_on = False, # True # False # &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&

#                 extra_train_dataset = -1, 

#                 num_workers = 2, # local wsl에서는 2가 맞고, 서버에서는 4가 좋더라.
#                 chaching_on = True, # True # False # only for certain datasets (gesture_tonic, nmnist_tonic)
#                 pin_memory = True, # True # False 

#                 UDA_on = False,  # DECREPATED # uda
#                 alpha_uda = 1.0, # DECREPATED # uda

#                 bias = False, # True # False 

#                 last_lif = False, # True # False 

#                 temporal_filter = 5, 
#                 initial_pooling = 1,

#                 temporal_filter_accumulation = False, # True # False 

#                 quantize_bit_list  =  [],
#                 scale_exp = [[999,999],[999,999],[999,999]],
#                 lif_layer_sg_width2 = 4.0,
#                 lif_layer_v_threshold2 = 1.0,
#                 learning_rate2 = 0.01,
#                 init_scaling = None,
#                 learning_rate3 = 0.01,
#                 ) 

# # num_workers = 4 * num_GPU (or 8, 16, 2 * num_GPU)
# # entry * batch_size * num_worker = num_GPU * GPU_throughtput
# # num_workers = batch_size / num_GPU
# # num_workers = batch_size / num_CPU

# # sigmoid와 BN이 있어야 잘된다.
# # average pooling  
# # 이 낫다. 

# # nda에서는 decay = 0.25, threshold = 0.5, width =1, surrogate = rectangle, batch = 256, tdBN = True
# ## OTTT 에서는 decay = 0.5, threshold = 1.0, surrogate = sigmoid, batch = 128, BN = True

# wandb.finish()

# %%
# sweep 하는 코드, 위 셀 주석처리 해야 됨.

# 이런 워닝 뜨는 거는 걍 너가 main 안에서  wandb.config.update(hyperparameters)할 때 물려서임. 어차피 근데 sweep에서 지정한 걸로 덮어짐 
# wandb: WARNING Config item 'BATCH' was locked by 'sweep' (ignored update).

unique_name_hyper = 'main'
sweep_configuration = {
    'method': 'random', # 'random', 'bayes', 'grid'
    'name': f'my_snn_sweep{datetime.datetime.now().strftime("%Y%m%d_%H%M%S")}',
    'metric': {'goal': 'maximize', 'name': 'val_acc_best'},
    'parameters': 
    {
        # "devices": {"values": ["1"]},
        "single_step": {"values": [False]},
        # "unique_name": {"values": [unique_name_hyper]},
        "my_seed": {"min": 1, "max": 42000},
        # "my_seed": {"values": [1]},
        "TIME": {"values": [10]},
        "BATCH": {"values": [1]},
        "IMAGE_SIZE": {"values": [14]},
        "which_data": {"values": ['DVS_GESTURE_TONIC']},
        "data_path": {"values": ['/data2']},
        "rate_coding": {"values": [False]},
        "lif_layer_v_init": {"values": [0.0]},
        "lif_layer_v_decay": {"values": [0.0625]},
        # "lif_layer_v_decay": {"min": 0.1, "max": 0.9},
        "lif_layer_v_threshold": {"values": [0.001]},
        # "lif_layer_v_threshold": {"min": 0.001, "max": 10.0},
        "lif_layer_v_reset": {"values": [0.0]},
        "lif_layer_sg_width": {"values": [2.0]},
        # "lif_layer_sg_width": {"min": 1.0, "max": 32.0},

        "synapse_conv_kernel_size": {"values": [3]},
        "synapse_conv_stride": {"values": [1]},
        "synapse_conv_padding": {"values": [1]},

        "synapse_trace_const1": {"values": [1]},
        # "synapse_trace_const2": {"values": [0.5]},

        "pre_trained": {"values": [False]},
        "convTrue_fcFalse": {"values": [False]},

        "cfg": {"values": [[200,200]]},

        "net_print": {"values": [True]},

        "pre_trained_path": {"values": [""]},

        "learning_rate": {"values": [1.0]}, 
        # "learning_rate": {"min": 0.00001, "max": 1.0},
        
        "epoch_num": {"values": [200]}, 
        "tdBN_on": {"values": [False]},
        "BN_on": {"values": [False]},

        "surrogate": {"values": ['sigmoid']},

        "BPTT_on": {"values": [True]},

        "optimizer_what": {"values": ['SGD']},
        "scheduler_name": {"values": ['no']},

        "ddp_on": {"values": [False]},

        "dvs_clipping": {"values": [14]}, 

        "dvs_duration": {"values": [25_000]}, 

        "DFA_on": {"values": [False]},

        "trace_on": {"values": [False]},
        "OTTT_input_trace_on": {"values": [False]},

        "exclude_class": {"values": [True]},

        "merge_polarities": {"values": [True]},
        "denoise_on": {"values": [False]},

        "extra_train_dataset": {"values": [-1]},

        "num_workers": {"values": [2]},
        "chaching_on": {"values": [True]},
        "pin_memory": {"values": [True]},

        "UDA_on": {"values": [False]},
        "alpha_uda": {"values": [1.0]},

        "bias": {"values": [False]},

        "last_lif": {"values": [False]},

        "temporal_filter": {"values": [5]},
        "initial_pooling": {"values": [1]},

        "temporal_filter_accumulation": {"values": [False]},
        "lif_layer_sg_width2": {"values": [0.5]},
        # "lif_layer_sg_width2": {"min": 1.0, "max": 32.0},
        "lif_layer_v_threshold2": {"values": [2.5]},
        # "lif_layer_v_threshold2": {"min": 0.001, "max": 10.0},
        "learning_rate2": {"values": [1.0]}, 
        "init_scaling": {"values": [None]},
        "learning_rate3": {"values": [0.01]}, 
     }
}

def hyper_iter():
    ### my_snn control board ########################
    wandb.init(save_code=False, dir='/data2/bh_wandb', tags=["sweep"])

    my_snn_system(  
        devices  =  "5",
        single_step  =  wandb.config.single_step,
        unique_name  =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S_") + f"{datetime.datetime.now().microsecond // 1000:03d}",
        my_seed  =  wandb.config.my_seed,
        TIME  =  wandb.config.TIME,
        BATCH  =  wandb.config.BATCH,
        IMAGE_SIZE  =  wandb.config.IMAGE_SIZE,
        which_data  =  wandb.config.which_data,
        data_path  =  wandb.config.data_path,
        rate_coding  =  wandb.config.rate_coding,
        lif_layer_v_init  =  wandb.config.lif_layer_v_init,
        lif_layer_v_decay  =  wandb.config.lif_layer_v_decay,
        lif_layer_v_threshold  =  wandb.config.lif_layer_v_threshold,
        lif_layer_v_reset  =  wandb.config.lif_layer_v_reset,
        lif_layer_sg_width  =  wandb.config.lif_layer_sg_width,
        synapse_conv_kernel_size  =  wandb.config.synapse_conv_kernel_size,
        synapse_conv_stride  =  wandb.config.synapse_conv_stride,
        synapse_conv_padding  =  wandb.config.synapse_conv_padding,
        synapse_trace_const1  =  wandb.config.synapse_trace_const1,
        synapse_trace_const2  =  wandb.config.lif_layer_v_decay,
        pre_trained  =  wandb.config.pre_trained,
        convTrue_fcFalse  =  wandb.config.convTrue_fcFalse,
        cfg  =  wandb.config.cfg,
        net_print  =  wandb.config.net_print,
        pre_trained_path  =  wandb.config.pre_trained_path,
        learning_rate  =  wandb.config.learning_rate,
        epoch_num  =  wandb.config.epoch_num,
        tdBN_on  =  wandb.config.tdBN_on,
        BN_on  =  wandb.config.BN_on,
        surrogate  =  wandb.config.surrogate,
        BPTT_on  =  wandb.config.BPTT_on,
        optimizer_what  =  wandb.config.optimizer_what,
        scheduler_name  =  wandb.config.scheduler_name,
        ddp_on  =  wandb.config.ddp_on,
        dvs_clipping  =  wandb.config.dvs_clipping,
        dvs_duration  =  wandb.config.dvs_duration,
        DFA_on  =  wandb.config.DFA_on,
        trace_on  =  wandb.config.trace_on,
        OTTT_input_trace_on  =  wandb.config.OTTT_input_trace_on,
        exclude_class  =  wandb.config.exclude_class,
        merge_polarities  =  wandb.config.merge_polarities,
        denoise_on  =  wandb.config.denoise_on,
        extra_train_dataset  =  wandb.config.extra_train_dataset,
        num_workers  =  wandb.config.num_workers,
        chaching_on  =  wandb.config.chaching_on,
        pin_memory  =  wandb.config.pin_memory,
        UDA_on  =  wandb.config.UDA_on,
        alpha_uda  =  wandb.config.alpha_uda,
        bias  =  wandb.config.bias,
        last_lif  =  wandb.config.last_lif,
        temporal_filter  =  wandb.config.temporal_filter,
        initial_pooling  =  wandb.config.initial_pooling,
        temporal_filter_accumulation  =  wandb.config.temporal_filter_accumulation,
        quantize_bit_list  =  [],
        scale_exp = [[999,999],[999,999],[999,999]],
        lif_layer_sg_width2 = wandb.config.lif_layer_sg_width2,
        lif_layer_v_threshold2 = wandb.config.lif_layer_v_threshold2,
        learning_rate2 = wandb.config.learning_rate2,
        init_scaling = wandb.config.init_scaling,
        learning_rate3 = wandb.config.learning_rate3,
                        ) 
    # sigmoid와 BN이 있어야 잘된다.
    # average pooling
    # 이 낫다. 
    
    # nda에서는 decay = 0.25, threshold = 0.5, width =1, surrogate = rectangle, batch = 256, tdBN = True
    ## OTTT 에서는 decay = 0.5, threshold = 1.0, surrogate = sigmoid, batch = 128, BN = True

sweep_id = 'o0d5q9gn'
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'my_snn {unique_name_hyper}')
wandb.agent(sweep_id, function=hyper_iter, count=10000, project=f'my_snn {unique_name_hyper}')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: o0d5q9gn
# Sweep URL: https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/o0d5q9gn
# wandb: Agent Starting Run: olydvozi with config:
# wandb: 	BATCH: 1
# wandb: 	BN_on: False
# wandb: 	BPTT_on: True
# wandb: 	DFA_on: False
# wandb: 	IMAGE_SIZE: 14
# wandb: 	OTTT_input_trace_on: False
# wandb: 	TIME: 10
# wandb: 	UDA_on: False
# wandb: 	alpha_uda: 1
# wandb: 	bias: False
# wandb: 	cfg: [200, 200]
# wandb: 	chaching_on: True
# wandb: 	convTrue_fcFalse: False
# wandb: 	data_path: /data2
# wandb: 	ddp_on: False
# wandb: 	denoise_on: False
# wandb: 	dvs_clipping: 14
# wandb: 	dvs_duration: 25000
# wandb: 	epoch_num: 200
# wandb: 	exclude_class: True
# wandb: 	extra_train_dataset: -1
# wandb: 	init_scaling: None
# wandb: 	initial_pooling: 1
# wandb: 	last_lif: False
# wandb: 	learning_rate: 1
# wandb: 	learning_rate2: 1
# wandb: 	learning_rate3: 0.01
# wandb: 	lif_layer_sg_width: 2
# wandb: 	lif_layer_sg_width2: 0.5
# wandb: 	lif_layer_v_decay: 0.0625
# wandb: 	lif_layer_v_init: 0
# wandb: 	lif_layer_v_reset: 0
# wandb: 	lif_layer_v_threshold: 0.001
# wandb: 	lif_layer_v_threshold2: 2.5
# wandb: 	merge_polarities: True
# wandb: 	my_seed: 21863
# wandb: 	net_print: True
# wandb: 	num_workers: 2
# wandb: 	optimizer_what: SGD
# wandb: 	pin_memory: True
# wandb: 	pre_trained: False
# wandb: 	pre_trained_path:
# wandb: 	rate_coding: False
# wandb: 	scheduler_name: no
# wandb: 	single_step: False
# wandb: 	surrogate: sigmoid
# wandb: 	synapse_conv_kernel_size: 3
# wandb: 	synapse_conv_padding: 1
# wandb: 	synapse_conv_stride: 1
# wandb: 	synapse_trace_const1: 1
# wandb: 	tdBN_on: False
# wandb: 	temporal_filter: 5
# wandb: 	temporal_filter_accumulation: False
# wandb: 	trace_on: False
# wandb: 	which_data: DVS_GESTURE_TONIC
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/data2/bh_wandb/wandb/run-20251214_024522-olydvozi</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/olydvozi' target="_blank">likely-sweep-1</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/o0d5q9gn' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/o0d5q9gn</a>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main</a>
#  View sweep at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/o0d5q9gn' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/o0d5q9gn</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/olydvozi' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/olydvozi</a>
# wandb: WARNING Config item 'single_step' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'my_seed' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'TIME' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BATCH' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'IMAGE_SIZE' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'which_data' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'data_path' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'rate_coding' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_init' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_decay' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_threshold' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_reset' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_sg_width' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_kernel_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_stride' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_padding' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_trace_const1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pre_trained' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'convTrue_fcFalse' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'cfg' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'net_print' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pre_trained_path' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'epoch_num' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'tdBN_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BN_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'surrogate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BPTT_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer_what' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'scheduler_name' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'ddp_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dvs_clipping' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dvs_duration' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'DFA_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'trace_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'OTTT_input_trace_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'exclude_class' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'merge_polarities' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'denoise_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'extra_train_dataset' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'num_workers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'chaching_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pin_memory' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'UDA_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'alpha_uda' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'bias' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'last_lif' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'temporal_filter' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'initial_pooling' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'temporal_filter_accumulation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_sg_width2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_threshold2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'init_scaling' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate3' was locked by 'sweep' (ignored update).
# param {'devices': '5', 'single_step': False, 'unique_name': '20251214_024530_741', 'my_seed': 21863, 'TIME': 10, 'BATCH': 1, 'IMAGE_SIZE': 14, 'which_data': 'DVS_GESTURE_TONIC', 'data_path': '/data2', 'rate_coding': False, 'lif_layer_v_init': 0, 'lif_layer_v_decay': 0.0625, 'lif_layer_v_threshold': 0.001, 'lif_layer_v_reset': 0, 'lif_layer_sg_width': 2, 'synapse_conv_kernel_size': 3, 'synapse_conv_stride': 1, 'synapse_conv_padding': 1, 'synapse_trace_const1': 1, 'synapse_trace_const2': 0.0625, 'pre_trained': False, 'convTrue_fcFalse': False, 'cfg': [200, 200], 'net_print': True, 'pre_trained_path': '', 'epoch_num': 200, 'tdBN_on': False, 'BN_on': False, 'surrogate': 'sigmoid', 'BPTT_on': True, 'optimizer_what': 'SGD', 'scheduler_name': 'no', 'ddp_on': False, 'dvs_clipping': 14, 'dvs_duration': 25000, 'DFA_on': False, 'trace_on': False, 'OTTT_input_trace_on': False, 'exclude_class': True, 'merge_polarities': True, 'denoise_on': False, 'extra_train_dataset': -1, 'num_workers': 2, 'chaching_on': True, 'pin_memory': True, 'UDA_on': False, 'alpha_uda': 1, 'bias': False, 'last_lif': False, 'temporal_filter': 5, 'initial_pooling': 1, 'temporal_filter_accumulation': False, 'quantize_bit_list': [], 'scale_exp': [[999, 999], [999, 999], [999, 999]], 'lif_layer_sg_width2': 0.5, 'lif_layer_v_threshold2': 2.5, 'init_scaling': None, 'learning_rate': 1, 'learning_rate2': 1, 'learning_rate3': 0.01}
#
# 이 데이터셋의 데이터 개수는 979 입니다. (test set은 안바뀌게 해놨다 알제)
# 이 데이터셋의 데이터 개수는 240 입니다. (test set은 안바뀌게 해놨다 알제)
# dataset_hash = 0e8a8f2d81b4fe037308b5d792c4a037
# cache path exists
#
# len(train_loader): 979 BATCH: 1 train_data_count: 979
# len(test_loader): 240 BATCH: 1
#
# device ==> cuda
#
#
#
#
#  layer_count 1
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
#
#
#
# LIF 1 sg_bit 0 self.sg_width 2, self.v_threshold 0.001
#
#
# ++++++++++++++++++++++++
#
#  lif layer 1 v_bit: 0, v_exp: None
#
# ++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#  layer_count 2
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
#
#
#
# LIF 2 sg_bit 0 self.sg_width 0.5, self.v_threshold 2.5
#
#
# ++++++++++++++++++++++++
#
#  lif layer 2 v_bit: 0, v_exp: None
#
# ++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#  layer_count 3
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
# DataParallel(
#   (module): REBORN_MY_SNN_FC(
#     (layers): REBORN_MY_Sequential(
#       (0): DimChanger_for_FC()
#       (1): SYNAPSE_FC(in_features=980, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=1, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (2): LIF_layer(v_init=0, v_decay=0.0625, v_threshold=0.001, v_reset=0, sg_width=2, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.0625, TIME=10, sstep=False, trace_on=False, layer_count=1, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (3): SYNAPSE_FC(in_features=200, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=2, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (4): LIF_layer(v_init=0, v_decay=0.0625, v_threshold=2.5, v_reset=0, sg_width=0.5, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.0625, TIME=10, sstep=False, trace_on=False, layer_count=2, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (5): SYNAPSE_FC(in_features=200, out_features=10, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=3, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#     )
#   )
# )
#
# ========================================================
# Trainable parameters: 238,000
# ========================================================
#
# MySGD (
# Parameter Group 0
#     lr: 1
#     momentum: 0.0
# )
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 0: mean=-0.0000, std=0.0184, |mean|=0.0159, |std|=0.0092, max=0.0319
# layers.3.fc.weight epoch 0: mean=-0.0000, std=0.0408, |mean|=0.0353, |std|=0.0203, max=0.0707
# layers.5.fc.weight epoch 0: mean=-0.0015, std=0.0397, |mean|=0.0341, |std|=0.0204, max=0.0706
# epoch-0   lr=['1.0000000'], tr/val_loss:  0.114263/  0.077805, val:  43.75%, val_best:  43.75%, tr:  36.36%, tr_best:  36.36%, epoch time: 21.66 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0915%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.9295%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.0740%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 1: mean=-0.0043, std=0.0273, |mean|=0.0216, |std|=0.0172, max=0.1761
# layers.3.fc.weight epoch 1: mean=-0.0246, std=0.0749, |mean|=0.0608, |std|=0.0502, max=0.3933
# layers.5.fc.weight epoch 1: mean=-0.0049, std=0.0306, |mean|=0.0242, |std|=0.0194, max=0.0994
# epoch-1   lr=['1.0000000'], tr/val_loss:  0.073743/  0.070169, val:  56.67%, val_best:  56.67%, tr:  52.81%, tr_best:  52.81%, epoch time: 21.57 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0607%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.3792%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5555%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 2: mean=-0.0044, std=0.0296, |mean|=0.0229, |std|=0.0192, max=0.2050
# layers.3.fc.weight epoch 2: mean=-0.0276, std=0.0828, |mean|=0.0664, |std|=0.0567, max=0.4758
# layers.5.fc.weight epoch 2: mean=-0.0046, std=0.0273, |mean|=0.0202, |std|=0.0189, max=0.0994
# epoch-2   lr=['1.0000000'], tr/val_loss:  0.064385/  0.063072, val:  61.67%, val_best:  61.67%, tr:  59.65%, tr_best:  59.65%, epoch time: 21.57 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0826%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.4501%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.4523%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 3: mean=-0.0050, std=0.0311, |mean|=0.0238, |std|=0.0206, max=0.2239
# layers.3.fc.weight epoch 3: mean=-0.0282, std=0.0878, |mean|=0.0695, |std|=0.0605, max=0.4965
# layers.5.fc.weight epoch 3: mean=-0.0043, std=0.0251, |mean|=0.0178, |std|=0.0182, max=0.0994
# epoch-3   lr=['1.0000000'], tr/val_loss:  0.058728/  0.057739, val:  57.50%, val_best:  61.67%, tr:  60.98%, tr_best:  60.98%, epoch time: 21.03 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1146%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.6571%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.4843%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 4: mean=-0.0051, std=0.0323, |mean|=0.0245, |std|=0.0216, max=0.2395
# layers.3.fc.weight epoch 4: mean=-0.0292, std=0.0908, |mean|=0.0715, |std|=0.0632, max=0.5467
# layers.5.fc.weight epoch 4: mean=-0.0040, std=0.0236, |mean|=0.0160, |std|=0.0179, max=0.0994
# epoch-4   lr=['1.0000000'], tr/val_loss:  0.053396/  0.056532, val:  61.67%, val_best:  61.67%, tr:  65.17%, tr_best:  65.17%, epoch time: 21.19 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0525%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.5038%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.4336%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 5: mean=-0.0052, std=0.0331, |mean|=0.0250, |std|=0.0223, max=0.2518
# layers.3.fc.weight epoch 5: mean=-0.0300, std=0.0931, |mean|=0.0730, |std|=0.0651, max=0.5794
# layers.5.fc.weight epoch 5: mean=-0.0039, std=0.0227, |mean|=0.0149, |std|=0.0176, max=0.0994
# epoch-5   lr=['1.0000000'], tr/val_loss:  0.049064/  0.058286, val:  53.75%, val_best:  61.67%, tr:  69.36%, tr_best:  69.36%, epoch time: 20.96 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1078%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.4514%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.4773%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 6: mean=-0.0053, std=0.0338, |mean|=0.0254, |std|=0.0229, max=0.2481
# layers.3.fc.weight epoch 6: mean=-0.0305, std=0.0951, |mean|=0.0744, |std|=0.0667, max=0.5970
# layers.5.fc.weight epoch 6: mean=-0.0039, std=0.0221, |mean|=0.0142, |std|=0.0173, max=0.0994
# epoch-6   lr=['1.0000000'], tr/val_loss:  0.047289/  0.056097, val:  58.75%, val_best:  61.67%, tr:  70.48%, tr_best:  70.48%, epoch time: 20.86 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0727%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.6287%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5105%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 7: mean=-0.0054, std=0.0344, |mean|=0.0257, |std|=0.0234, max=0.2651
# layers.3.fc.weight epoch 7: mean=-0.0309, std=0.0968, |mean|=0.0755, |std|=0.0680, max=0.6034
# layers.5.fc.weight epoch 7: mean=-0.0038, std=0.0218, |mean|=0.0136, |std|=0.0174, max=0.0994
# epoch-7   lr=['1.0000000'], tr/val_loss:  0.044764/  0.058033, val:  57.92%, val_best:  61.67%, tr:  71.60%, tr_best:  71.60%, epoch time: 20.86 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0772%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.6135%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5258%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 8: mean=-0.0055, std=0.0351, |mean|=0.0262, |std|=0.0240, max=0.2776
# layers.3.fc.weight epoch 8: mean=-0.0310, std=0.0985, |mean|=0.0766, |std|=0.0693, max=0.6069
# layers.5.fc.weight epoch 8: mean=-0.0039, std=0.0215, |mean|=0.0133, |std|=0.0174, max=0.0994
# epoch-8   lr=['1.0000000'], tr/val_loss:  0.043036/  0.050499, val:  67.50%, val_best:  67.50%, tr:  71.40%, tr_best:  71.60%, epoch time: 20.74 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0723%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.6936%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5748%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 9: mean=-0.0057, std=0.0357, |mean|=0.0265, |std|=0.0246, max=0.2903
# layers.3.fc.weight epoch 9: mean=-0.0315, std=0.1000, |mean|=0.0776, |std|=0.0705, max=0.6102
# layers.5.fc.weight epoch 9: mean=-0.0037, std=0.0212, |mean|=0.0130, |std|=0.0172, max=0.0994
# epoch-9   lr=['1.0000000'], tr/val_loss:  0.040922/  0.049628, val:  63.75%, val_best:  67.50%, tr:  74.46%, tr_best:  74.46%, epoch time: 20.72 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0579%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.8120%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.6802%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 10: mean=-0.0056, std=0.0364, |mean|=0.0269, |std|=0.0251, max=0.2931
# layers.3.fc.weight epoch 10: mean=-0.0320, std=0.1014, |mean|=0.0787, |std|=0.0716, max=0.6224
# layers.5.fc.weight epoch 10: mean=-0.0037, std=0.0210, |mean|=0.0127, |std|=0.0171, max=0.0994
# epoch-10  lr=['1.0000000'], tr/val_loss:  0.037772/  0.045205, val:  73.75%, val_best:  73.75%, tr:  75.89%, tr_best:  75.89%, epoch time: 21.28 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0882%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.7235%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7519%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 11: mean=-0.0056, std=0.0370, |mean|=0.0273, |std|=0.0256, max=0.3003
# layers.3.fc.weight epoch 11: mean=-0.0325, std=0.1027, |mean|=0.0796, |std|=0.0726, max=0.6576
# layers.5.fc.weight epoch 11: mean=-0.0037, std=0.0208, |mean|=0.0125, |std|=0.0170, max=0.0996
# epoch-11  lr=['1.0000000'], tr/val_loss:  0.036638/  0.043286, val:  73.75%, val_best:  73.75%, tr:  77.94%, tr_best:  77.94%, epoch time: 20.86 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0888%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.6321%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7912%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 12: mean=-0.0056, std=0.0377, |mean|=0.0277, |std|=0.0262, max=0.3053
# layers.3.fc.weight epoch 12: mean=-0.0331, std=0.1040, |mean|=0.0806, |std|=0.0737, max=0.6935
# layers.5.fc.weight epoch 12: mean=-0.0036, std=0.0205, |mean|=0.0124, |std|=0.0167, max=0.1057
# epoch-12  lr=['1.0000000'], tr/val_loss:  0.031270/  0.053605, val:  64.17%, val_best:  73.75%, tr:  82.12%, tr_best:  82.12%, epoch time: 21.14 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1030%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.5142%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7845%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 13: mean=-0.0057, std=0.0384, |mean|=0.0281, |std|=0.0267, max=0.3064
# layers.3.fc.weight epoch 13: mean=-0.0336, std=0.1052, |mean|=0.0813, |std|=0.0747, max=0.6921
# layers.5.fc.weight epoch 13: mean=-0.0036, std=0.0203, |mean|=0.0121, |std|=0.0167, max=0.1154
# epoch-13  lr=['1.0000000'], tr/val_loss:  0.030007/  0.047798, val:  71.25%, val_best:  73.75%, tr:  83.15%, tr_best:  83.15%, epoch time: 20.88 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0884%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.5774%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7852%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 14: mean=-0.0058, std=0.0391, |mean|=0.0285, |std|=0.0273, max=0.3052
# layers.3.fc.weight epoch 14: mean=-0.0339, std=0.1065, |mean|=0.0822, |std|=0.0757, max=0.7132
# layers.5.fc.weight epoch 14: mean=-0.0036, std=0.0202, |mean|=0.0120, |std|=0.0167, max=0.1062
# epoch-14  lr=['1.0000000'], tr/val_loss:  0.027746/  0.039334, val:  78.75%, val_best:  78.75%, tr:  85.70%, tr_best:  85.70%, epoch time: 21.21 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0922%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.0105%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8246%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 15: mean=-0.0057, std=0.0397, |mean|=0.0289, |std|=0.0279, max=0.3150
# layers.3.fc.weight epoch 15: mean=-0.0345, std=0.1076, |mean|=0.0830, |std|=0.0767, max=0.7270
# layers.5.fc.weight epoch 15: mean=-0.0037, std=0.0201, |mean|=0.0117, |std|=0.0167, max=0.1141
# epoch-15  lr=['1.0000000'], tr/val_loss:  0.026448/  0.049956, val:  70.00%, val_best:  78.75%, tr:  87.84%, tr_best:  87.84%, epoch time: 20.87 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0559%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 79.0810%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8094%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 16: mean=-0.0058, std=0.0404, |mean|=0.0293, |std|=0.0284, max=0.3474
# layers.3.fc.weight epoch 16: mean=-0.0349, std=0.1087, |mean|=0.0837, |std|=0.0776, max=0.7585
# layers.5.fc.weight epoch 16: mean=-0.0037, std=0.0199, |mean|=0.0116, |std|=0.0166, max=0.1079
# epoch-16  lr=['1.0000000'], tr/val_loss:  0.022882/  0.043655, val:  68.75%, val_best:  78.75%, tr:  90.09%, tr_best:  90.09%, epoch time: 21.16 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0808%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.9109%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7732%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 17: mean=-0.0058, std=0.0409, |mean|=0.0296, |std|=0.0289, max=0.3681
# layers.3.fc.weight epoch 17: mean=-0.0353, std=0.1096, |mean|=0.0844, |std|=0.0784, max=0.7706
# layers.5.fc.weight epoch 17: mean=-0.0037, std=0.0198, |mean|=0.0114, |std|=0.0166, max=0.1115
# epoch-17  lr=['1.0000000'], tr/val_loss:  0.023796/  0.036091, val:  80.42%, val_best:  80.42%, tr:  88.97%, tr_best:  90.09%, epoch time: 20.96 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0652%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.7026%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8356%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 18: mean=-0.0058, std=0.0415, |mean|=0.0299, |std|=0.0294, max=0.3945
# layers.3.fc.weight epoch 18: mean=-0.0358, std=0.1105, |mean|=0.0850, |std|=0.0792, max=0.7727
# layers.5.fc.weight epoch 18: mean=-0.0037, std=0.0196, |mean|=0.0113, |std|=0.0165, max=0.1039
# epoch-18  lr=['1.0000000'], tr/val_loss:  0.020567/  0.037129, val:  79.58%, val_best:  80.42%, tr:  92.24%, tr_best:  92.24%, epoch time: 21.30 seconds, 0.36 minutes
# layer   1  Sparsity: 91.1014%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.5329%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8546%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 19: mean=-0.0058, std=0.0420, |mean|=0.0302, |std|=0.0298, max=0.3892
# layers.3.fc.weight epoch 19: mean=-0.0361, std=0.1114, |mean|=0.0856, |std|=0.0799, max=0.8082
# layers.5.fc.weight epoch 19: mean=-0.0037, std=0.0196, |mean|=0.0112, |std|=0.0166, max=0.1131
# epoch-19  lr=['1.0000000'], tr/val_loss:  0.021377/  0.040009, val:  75.42%, val_best:  80.42%, tr:  91.01%, tr_best:  92.24%, epoch time: 21.27 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0472%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.7037%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8730%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 20: mean=-0.0059, std=0.0426, |mean|=0.0305, |std|=0.0303, max=0.4138
# layers.3.fc.weight epoch 20: mean=-0.0365, std=0.1122, |mean|=0.0861, |std|=0.0807, max=0.8173
# layers.5.fc.weight epoch 20: mean=-0.0036, std=0.0194, |mean|=0.0111, |std|=0.0163, max=0.1027
# epoch-20  lr=['1.0000000'], tr/val_loss:  0.018970/  0.035136, val:  80.42%, val_best:  80.42%, tr:  91.62%, tr_best:  92.24%, epoch time: 21.32 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0733%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.6423%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8758%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 21: mean=-0.0058, std=0.0430, |mean|=0.0307, |std|=0.0307, max=0.4280
# layers.3.fc.weight epoch 21: mean=-0.0369, std=0.1130, |mean|=0.0867, |std|=0.0814, max=0.8310
# layers.5.fc.weight epoch 21: mean=-0.0037, std=0.0194, |mean|=0.0111, |std|=0.0164, max=0.1143
# epoch-21  lr=['1.0000000'], tr/val_loss:  0.018567/  0.037663, val:  76.25%, val_best:  80.42%, tr:  92.54%, tr_best:  92.54%, epoch time: 21.56 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0624%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.6664%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8698%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 22: mean=-0.0059, std=0.0434, |mean|=0.0310, |std|=0.0310, max=0.4383
# layers.3.fc.weight epoch 22: mean=-0.0373, std=0.1136, |mean|=0.0871, |std|=0.0819, max=0.8470
# layers.5.fc.weight epoch 22: mean=-0.0036, std=0.0193, |mean|=0.0110, |std|=0.0163, max=0.1130
# epoch-22  lr=['1.0000000'], tr/val_loss:  0.017597/  0.047150, val:  75.00%, val_best:  80.42%, tr:  93.26%, tr_best:  93.26%, epoch time: 21.03 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0726%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.7846%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8701%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 23: mean=-0.0059, std=0.0438, |mean|=0.0312, |std|=0.0314, max=0.4521
# layers.3.fc.weight epoch 23: mean=-0.0375, std=0.1143, |mean|=0.0876, |std|=0.0825, max=0.8540
# layers.5.fc.weight epoch 23: mean=-0.0036, std=0.0193, |mean|=0.0109, |std|=0.0163, max=0.1147
# epoch-23  lr=['1.0000000'], tr/val_loss:  0.017790/  0.034609, val:  82.08%, val_best:  82.08%, tr:  92.34%, tr_best:  93.26%, epoch time: 21.47 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0602%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.8230%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8678%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 24: mean=-0.0060, std=0.0442, |mean|=0.0314, |std|=0.0317, max=0.4474
# layers.3.fc.weight epoch 24: mean=-0.0378, std=0.1150, |mean|=0.0881, |std|=0.0831, max=0.8655
# layers.5.fc.weight epoch 24: mean=-0.0036, std=0.0192, |mean|=0.0108, |std|=0.0163, max=0.1088
# epoch-24  lr=['1.0000000'], tr/val_loss:  0.017622/  0.040686, val:  73.75%, val_best:  82.08%, tr:  92.65%, tr_best:  93.26%, epoch time: 21.25 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0478%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.7789%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8520%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 25: mean=-0.0059, std=0.0446, |mean|=0.0316, |std|=0.0321, max=0.4698
# layers.3.fc.weight epoch 25: mean=-0.0382, std=0.1156, |mean|=0.0885, |std|=0.0836, max=0.8880
# layers.5.fc.weight epoch 25: mean=-0.0036, std=0.0191, |mean|=0.0107, |std|=0.0162, max=0.1153
# epoch-25  lr=['1.0000000'], tr/val_loss:  0.016341/  0.036131, val:  79.58%, val_best:  82.08%, tr:  94.38%, tr_best:  94.38%, epoch time: 21.23 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0643%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.7142%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8660%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 26: mean=-0.0059, std=0.0450, |mean|=0.0318, |std|=0.0324, max=0.4766
# layers.3.fc.weight epoch 26: mean=-0.0385, std=0.1162, |mean|=0.0889, |std|=0.0841, max=0.8928
# layers.5.fc.weight epoch 26: mean=-0.0036, std=0.0191, |mean|=0.0107, |std|=0.0162, max=0.1163
# epoch-26  lr=['1.0000000'], tr/val_loss:  0.015209/  0.033373, val:  83.75%, val_best:  83.75%, tr:  94.79%, tr_best:  94.79%, epoch time: 21.19 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0825%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4483%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8528%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 27: mean=-0.0059, std=0.0454, |mean|=0.0320, |std|=0.0327, max=0.4891
# layers.3.fc.weight epoch 27: mean=-0.0388, std=0.1168, |mean|=0.0893, |std|=0.0847, max=0.9067
# layers.5.fc.weight epoch 27: mean=-0.0036, std=0.0191, |mean|=0.0107, |std|=0.0162, max=0.1146
# epoch-27  lr=['1.0000000'], tr/val_loss:  0.014965/  0.037000, val:  79.17%, val_best:  83.75%, tr:  94.28%, tr_best:  94.79%, epoch time: 21.37 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0864%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.3791%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8403%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 28: mean=-0.0060, std=0.0457, |mean|=0.0322, |std|=0.0330, max=0.5022
# layers.3.fc.weight epoch 28: mean=-0.0391, std=0.1174, |mean|=0.0897, |std|=0.0852, max=0.9344
# layers.5.fc.weight epoch 28: mean=-0.0036, std=0.0191, |mean|=0.0106, |std|=0.0162, max=0.1147
# epoch-28  lr=['1.0000000'], tr/val_loss:  0.014741/  0.032417, val:  82.08%, val_best:  83.75%, tr:  95.10%, tr_best:  95.10%, epoch time: 21.36 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0809%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.3242%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8767%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 29: mean=-0.0060, std=0.0461, |mean|=0.0324, |std|=0.0333, max=0.5162
# layers.3.fc.weight epoch 29: mean=-0.0395, std=0.1179, |mean|=0.0901, |std|=0.0856, max=0.9551
# layers.5.fc.weight epoch 29: mean=-0.0036, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1048
# epoch-29  lr=['1.0000000'], tr/val_loss:  0.014688/  0.034455, val:  80.42%, val_best:  83.75%, tr:  95.81%, tr_best:  95.81%, epoch time: 21.38 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0527%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4985%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8706%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 30: mean=-0.0061, std=0.0464, |mean|=0.0326, |std|=0.0336, max=0.5267
# layers.3.fc.weight epoch 30: mean=-0.0397, std=0.1184, |mean|=0.0905, |std|=0.0861, max=0.9504
# layers.5.fc.weight epoch 30: mean=-0.0037, std=0.0190, |mean|=0.0106, |std|=0.0162, max=0.1102
# epoch-30  lr=['1.0000000'], tr/val_loss:  0.013825/  0.034102, val:  80.42%, val_best:  83.75%, tr:  96.22%, tr_best:  96.22%, epoch time: 21.56 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0663%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.6523%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8502%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 31: mean=-0.0061, std=0.0468, |mean|=0.0328, |std|=0.0339, max=0.5453
# layers.3.fc.weight epoch 31: mean=-0.0399, std=0.1189, |mean|=0.0908, |std|=0.0866, max=0.9678
# layers.5.fc.weight epoch 31: mean=-0.0037, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1154
# epoch-31  lr=['1.0000000'], tr/val_loss:  0.013061/  0.033835, val:  82.08%, val_best:  83.75%, tr:  96.12%, tr_best:  96.22%, epoch time: 21.19 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0793%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4200%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8589%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 32: mean=-0.0060, std=0.0471, |mean|=0.0330, |std|=0.0341, max=0.5520
# layers.3.fc.weight epoch 32: mean=-0.0401, std=0.1195, |mean|=0.0912, |std|=0.0870, max=0.9867
# layers.5.fc.weight epoch 32: mean=-0.0036, std=0.0192, |mean|=0.0106, |std|=0.0164, max=0.1202
# epoch-32  lr=['1.0000000'], tr/val_loss:  0.013276/  0.031779, val:  82.92%, val_best:  83.75%, tr:  96.63%, tr_best:  96.63%, epoch time: 21.30 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0688%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4417%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8857%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 33: mean=-0.0060, std=0.0474, |mean|=0.0331, |std|=0.0344, max=0.5516
# layers.3.fc.weight epoch 33: mean=-0.0405, std=0.1199, |mean|=0.0915, |std|=0.0874, max=1.0011
# layers.5.fc.weight epoch 33: mean=-0.0037, std=0.0192, |mean|=0.0106, |std|=0.0164, max=0.1149
# epoch-33  lr=['1.0000000'], tr/val_loss:  0.012780/  0.037178, val:  81.25%, val_best:  83.75%, tr:  96.32%, tr_best:  96.63%, epoch time: 20.72 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1043%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.3614%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8764%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 34: mean=-0.0060, std=0.0477, |mean|=0.0333, |std|=0.0346, max=0.5575
# layers.3.fc.weight epoch 34: mean=-0.0407, std=0.1203, |mean|=0.0918, |std|=0.0878, max=0.9917
# layers.5.fc.weight epoch 34: mean=-0.0037, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1216
# epoch-34  lr=['1.0000000'], tr/val_loss:  0.012712/  0.032577, val:  82.92%, val_best:  83.75%, tr:  96.42%, tr_best:  96.63%, epoch time: 21.46 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0712%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4645%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8276%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 35: mean=-0.0061, std=0.0480, |mean|=0.0335, |std|=0.0349, max=0.5624
# layers.3.fc.weight epoch 35: mean=-0.0409, std=0.1208, |mean|=0.0921, |std|=0.0882, max=1.0146
# layers.5.fc.weight epoch 35: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1091
# epoch-35  lr=['1.0000000'], tr/val_loss:  0.012197/  0.034081, val:  79.58%, val_best:  83.75%, tr:  95.91%, tr_best:  96.63%, epoch time: 21.13 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0411%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.6233%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8333%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 36: mean=-0.0061, std=0.0483, |mean|=0.0337, |std|=0.0351, max=0.5644
# layers.3.fc.weight epoch 36: mean=-0.0412, std=0.1213, |mean|=0.0924, |std|=0.0887, max=1.0242
# layers.5.fc.weight epoch 36: mean=-0.0037, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1167
# epoch-36  lr=['1.0000000'], tr/val_loss:  0.012477/  0.032198, val:  82.08%, val_best:  83.75%, tr:  96.73%, tr_best:  96.73%, epoch time: 21.13 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0687%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.5509%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8573%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 37: mean=-0.0061, std=0.0486, |mean|=0.0338, |std|=0.0354, max=0.5721
# layers.3.fc.weight epoch 37: mean=-0.0414, std=0.1217, |mean|=0.0927, |std|=0.0891, max=1.0404
# layers.5.fc.weight epoch 37: mean=-0.0037, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1105
# epoch-37  lr=['1.0000000'], tr/val_loss:  0.010595/  0.033844, val:  79.58%, val_best:  83.75%, tr:  97.34%, tr_best:  97.34%, epoch time: 21.51 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0559%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.4471%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8710%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 38: mean=-0.0061, std=0.0488, |mean|=0.0340, |std|=0.0356, max=0.5832
# layers.3.fc.weight epoch 38: mean=-0.0416, std=0.1221, |mean|=0.0930, |std|=0.0894, max=1.0416
# layers.5.fc.weight epoch 38: mean=-0.0037, std=0.0191, |mean|=0.0106, |std|=0.0163, max=0.1154
# epoch-38  lr=['1.0000000'], tr/val_loss:  0.011191/  0.033574, val:  82.50%, val_best:  83.75%, tr:  97.55%, tr_best:  97.55%, epoch time: 21.24 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0723%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.3665%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8600%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 39: mean=-0.0061, std=0.0491, |mean|=0.0341, |std|=0.0358, max=0.5892
# layers.3.fc.weight epoch 39: mean=-0.0419, std=0.1225, |mean|=0.0933, |std|=0.0898, max=1.0429
# layers.5.fc.weight epoch 39: mean=-0.0037, std=0.0191, |mean|=0.0105, |std|=0.0163, max=0.1167
# epoch-39  lr=['1.0000000'], tr/val_loss:  0.011896/  0.032805, val:  83.33%, val_best:  83.75%, tr:  96.42%, tr_best:  97.55%, epoch time: 21.44 seconds, 0.36 minutes
# layer   1  Sparsity: 91.1127%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1836%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8268%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 40: mean=-0.0062, std=0.0493, |mean|=0.0343, |std|=0.0360, max=0.5961
# layers.3.fc.weight epoch 40: mean=-0.0420, std=0.1230, |mean|=0.0936, |std|=0.0902, max=1.0579
# layers.5.fc.weight epoch 40: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1105
# epoch-40  lr=['1.0000000'], tr/val_loss:  0.011750/  0.033827, val:  82.92%, val_best:  83.75%, tr:  97.45%, tr_best:  97.55%, epoch time: 20.81 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1174%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.2179%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8098%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 41: mean=-0.0061, std=0.0496, |mean|=0.0344, |std|=0.0362, max=0.6044
# layers.3.fc.weight epoch 41: mean=-0.0422, std=0.1233, |mean|=0.0938, |std|=0.0905, max=1.0651
# layers.5.fc.weight epoch 41: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1114
# epoch-41  lr=['1.0000000'], tr/val_loss:  0.009582/  0.033357, val:  81.25%, val_best:  83.75%, tr:  98.37%, tr_best:  98.37%, epoch time: 21.24 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0275%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.2227%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8097%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 42: mean=-0.0062, std=0.0498, |mean|=0.0346, |std|=0.0364, max=0.6124
# layers.3.fc.weight epoch 42: mean=-0.0424, std=0.1237, |mean|=0.0941, |std|=0.0909, max=1.0743
# layers.5.fc.weight epoch 42: mean=-0.0037, std=0.0191, |mean|=0.0105, |std|=0.0163, max=0.1143
# epoch-42  lr=['1.0000000'], tr/val_loss:  0.010351/  0.035958, val:  80.42%, val_best:  83.75%, tr:  98.06%, tr_best:  98.37%, epoch time: 21.35 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0834%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1168%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7947%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 43: mean=-0.0062, std=0.0501, |mean|=0.0347, |std|=0.0366, max=0.6179
# layers.3.fc.weight epoch 43: mean=-0.0426, std=0.1241, |mean|=0.0943, |std|=0.0912, max=1.0729
# layers.5.fc.weight epoch 43: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1121
# epoch-43  lr=['1.0000000'], tr/val_loss:  0.010532/  0.032206, val:  85.42%, val_best:  85.42%, tr:  98.16%, tr_best:  98.37%, epoch time: 21.17 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0851%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1343%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8120%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 44: mean=-0.0062, std=0.0503, |mean|=0.0348, |std|=0.0368, max=0.6280
# layers.3.fc.weight epoch 44: mean=-0.0427, std=0.1245, |mean|=0.0945, |std|=0.0915, max=1.0728
# layers.5.fc.weight epoch 44: mean=-0.0037, std=0.0191, |mean|=0.0105, |std|=0.0163, max=0.1076
# epoch-44  lr=['1.0000000'], tr/val_loss:  0.010709/  0.031687, val:  85.42%, val_best:  85.42%, tr:  97.65%, tr_best:  98.37%, epoch time: 20.98 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0797%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.0937%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7862%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 45: mean=-0.0062, std=0.0506, |mean|=0.0350, |std|=0.0370, max=0.6251
# layers.3.fc.weight epoch 45: mean=-0.0429, std=0.1249, |mean|=0.0948, |std|=0.0919, max=1.0947
# layers.5.fc.weight epoch 45: mean=-0.0037, std=0.0191, |mean|=0.0105, |std|=0.0163, max=0.1215
# epoch-45  lr=['1.0000000'], tr/val_loss:  0.010486/  0.032348, val:  83.33%, val_best:  85.42%, tr:  97.85%, tr_best:  98.37%, epoch time: 21.56 seconds, 0.36 minutes
# layer   1  Sparsity: 91.1017%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1754%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7811%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 46: mean=-0.0062, std=0.0508, |mean|=0.0351, |std|=0.0372, max=0.6193
# layers.3.fc.weight epoch 46: mean=-0.0431, std=0.1252, |mean|=0.0950, |std|=0.0922, max=1.0870
# layers.5.fc.weight epoch 46: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1139
# epoch-46  lr=['1.0000000'], tr/val_loss:  0.009363/  0.032986, val:  83.33%, val_best:  85.42%, tr:  98.37%, tr_best:  98.37%, epoch time: 21.34 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0776%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1315%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7804%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 47: mean=-0.0062, std=0.0510, |mean|=0.0352, |std|=0.0374, max=0.6227
# layers.3.fc.weight epoch 47: mean=-0.0432, std=0.1255, |mean|=0.0953, |std|=0.0925, max=1.0912
# layers.5.fc.weight epoch 47: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1138
# epoch-47  lr=['1.0000000'], tr/val_loss:  0.009983/  0.030478, val:  83.75%, val_best:  85.42%, tr:  98.16%, tr_best:  98.37%, epoch time: 21.42 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0904%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.0353%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7821%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 48: mean=-0.0062, std=0.0512, |mean|=0.0354, |std|=0.0376, max=0.6352
# layers.3.fc.weight epoch 48: mean=-0.0433, std=0.1259, |mean|=0.0955, |std|=0.0928, max=1.1113
# layers.5.fc.weight epoch 48: mean=-0.0037, std=0.0190, |mean|=0.0104, |std|=0.0163, max=0.1119
# epoch-48  lr=['1.0000000'], tr/val_loss:  0.009013/  0.030049, val:  86.67%, val_best:  86.67%, tr:  98.57%, tr_best:  98.57%, epoch time: 21.07 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0784%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 78.1491%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7615%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 49: mean=-0.0062, std=0.0514, |mean|=0.0355, |std|=0.0377, max=0.6415
# layers.3.fc.weight epoch 49: mean=-0.0435, std=0.1262, |mean|=0.0957, |std|=0.0931, max=1.1155
# layers.5.fc.weight epoch 49: mean=-0.0037, std=0.0190, |mean|=0.0105, |std|=0.0163, max=0.1168
# ...
# layer   1  Sparsity: 91.1023%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 87.1187%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7831%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 34: mean=-0.0137, std=0.0527, |mean|=0.0372, |std|=0.0398, max=0.7239
# layers.3.fc.weight epoch 34: mean=-0.0458, std=0.1365, |mean|=0.0986, |std|=0.1049, max=1.0748
# layers.5.fc.weight epoch 34: mean=-0.0035, std=0.0198, |mean|=0.0113, |std|=0.0166, max=0.1103
# epoch-34  lr=['1.0000000'], tr/val_loss:  0.013311/  0.034643, val:  81.67%, val_best:  85.42%, tr:  96.12%, tr_best:  96.53%, epoch time: 20.89 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0824%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 87.0339%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8014%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 35: mean=-0.0137, std=0.0530, |mean|=0.0373, |std|=0.0400, max=0.7316
# layers.3.fc.weight epoch 35: mean=-0.0459, std=0.1369, |mean|=0.0989, |std|=0.1053, max=1.0796
# layers.5.fc.weight epoch 35: mean=-0.0035, std=0.0197, |mean|=0.0112, |std|=0.0165, max=0.1077
# epoch-35  lr=['1.0000000'], tr/val_loss:  0.012045/  0.033657, val:  81.67%, val_best:  85.42%, tr:  96.73%, tr_best:  96.73%, epoch time: 20.88 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0374%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 87.1580%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8032%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 36: mean=-0.0137, std=0.0532, |mean|=0.0374, |std|=0.0402, max=0.7482
# layers.3.fc.weight epoch 36: mean=-0.0461, std=0.1374, |mean|=0.0991, |std|=0.1057, max=1.0829
# layers.5.fc.weight epoch 36: mean=-0.0034, std=0.0199, |mean|=0.0113, |std|=0.0167, max=0.1106
# epoch-36  lr=['1.0000000'], tr/val_loss:  0.012530/  0.030674, val:  85.42%, val_best:  85.42%, tr:  96.73%, tr_best:  96.73%, epoch time: 20.67 seconds, 0.34 minutes
# layer   1  Sparsity: 91.0937%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 87.0287%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8084%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 37: mean=-0.0137, std=0.0534, |mean|=0.0375, |std|=0.0404, max=0.7554
# layers.3.fc.weight epoch 37: mean=-0.0463, std=0.1377, |mean|=0.0993, |std|=0.1060, max=1.0907
# layers.5.fc.weight epoch 37: mean=-0.0035, std=0.0197, |mean|=0.0112, |std|=0.0165, max=0.1077
# epoch-37  lr=['1.0000000'], tr/val_loss:  0.011894/  0.030467, val:  85.42%, val_best:  85.42%, tr:  97.24%, tr_best:  97.24%, epoch time: 21.12 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0673%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.9902%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8065%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 38: mean=-0.0137, std=0.0537, |mean|=0.0377, |std|=0.0406, max=0.7508
# layers.3.fc.weight epoch 38: mean=-0.0464, std=0.1381, |mean|=0.0996, |std|=0.1064, max=1.1050
# layers.5.fc.weight epoch 38: mean=-0.0034, std=0.0197, |mean|=0.0112, |std|=0.0166, max=0.1128
# epoch-38  lr=['1.0000000'], tr/val_loss:  0.011861/  0.032364, val:  85.00%, val_best:  85.42%, tr:  97.24%, tr_best:  97.24%, epoch time: 21.12 seconds, 0.35 minutes
# layer   1  Sparsity: 91.1000%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.8886%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8002%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 39: mean=-0.0137, std=0.0539, |mean|=0.0378, |std|=0.0408, max=0.7621
# layers.3.fc.weight epoch 39: mean=-0.0466, std=0.1385, |mean|=0.0998, |std|=0.1067, max=1.1128
# layers.5.fc.weight epoch 39: mean=-0.0035, std=0.0197, |mean|=0.0112, |std|=0.0165, max=0.1130
# epoch-39  lr=['1.0000000'], tr/val_loss:  0.010484/  0.030482, val:  85.83%, val_best:  85.83%, tr:  98.16%, tr_best:  98.16%, epoch time: 20.96 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0264%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.9142%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7815%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 40: mean=-0.0137, std=0.0541, |mean|=0.0379, |std|=0.0410, max=0.7608
# layers.3.fc.weight epoch 40: mean=-0.0467, std=0.1388, |mean|=0.1000, |std|=0.1070, max=1.1127
# layers.5.fc.weight epoch 40: mean=-0.0035, std=0.0196, |mean|=0.0112, |std|=0.0165, max=0.1108
# epoch-40  lr=['1.0000000'], tr/val_loss:  0.011198/  0.030065, val:  86.25%, val_best:  86.25%, tr:  97.45%, tr_best:  98.16%, epoch time: 21.12 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0438%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.9306%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7745%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 41: mean=-0.0137, std=0.0543, |mean|=0.0380, |std|=0.0412, max=0.7539
# layers.3.fc.weight epoch 41: mean=-0.0468, std=0.1392, |mean|=0.1002, |std|=0.1073, max=1.1249
# layers.5.fc.weight epoch 41: mean=-0.0035, std=0.0196, |mean|=0.0111, |std|=0.0165, max=0.1077
# epoch-41  lr=['1.0000000'], tr/val_loss:  0.010602/  0.030462, val:  85.00%, val_best:  86.25%, tr:  97.96%, tr_best:  98.16%, epoch time: 20.99 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0718%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.8669%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7852%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 42: mean=-0.0137, std=0.0546, |mean|=0.0381, |std|=0.0413, max=0.7538
# layers.3.fc.weight epoch 42: mean=-0.0470, std=0.1395, |mean|=0.1004, |std|=0.1076, max=1.1406
# layers.5.fc.weight epoch 42: mean=-0.0035, std=0.0196, |mean|=0.0111, |std|=0.0165, max=0.1100
# epoch-42  lr=['1.0000000'], tr/val_loss:  0.011058/  0.033468, val:  84.17%, val_best:  86.25%, tr:  97.45%, tr_best:  98.16%, epoch time: 21.14 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0618%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.8536%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8079%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 43: mean=-0.0138, std=0.0547, |mean|=0.0382, |std|=0.0415, max=0.7525
# layers.3.fc.weight epoch 43: mean=-0.0471, std=0.1398, |mean|=0.1006, |std|=0.1079, max=1.1453
# layers.5.fc.weight epoch 43: mean=-0.0035, std=0.0196, |mean|=0.0111, |std|=0.0165, max=0.1140
# epoch-43  lr=['1.0000000'], tr/val_loss:  0.010556/  0.029285, val:  84.17%, val_best:  86.25%, tr:  98.06%, tr_best:  98.16%, epoch time: 21.26 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0637%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.8202%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8002%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 44: mean=-0.0137, std=0.0549, |mean|=0.0383, |std|=0.0417, max=0.7729
# layers.3.fc.weight epoch 44: mean=-0.0473, std=0.1401, |mean|=0.1008, |std|=0.1082, max=1.1426
# layers.5.fc.weight epoch 44: mean=-0.0035, std=0.0196, |mean|=0.0110, |std|=0.0166, max=0.1099
# epoch-44  lr=['1.0000000'], tr/val_loss:  0.011254/  0.030014, val:  86.67%, val_best:  86.67%, tr:  97.04%, tr_best:  98.16%, epoch time: 21.10 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0713%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7370%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8128%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 45: mean=-0.0136, std=0.0552, |mean|=0.0384, |std|=0.0418, max=0.7689
# layers.3.fc.weight epoch 45: mean=-0.0474, std=0.1404, |mean|=0.1010, |std|=0.1085, max=1.1488
# layers.5.fc.weight epoch 45: mean=-0.0034, std=0.0195, |mean|=0.0110, |std|=0.0165, max=0.1110
# epoch-45  lr=['1.0000000'], tr/val_loss:  0.009953/  0.032511, val:  85.00%, val_best:  86.67%, tr:  98.77%, tr_best:  98.77%, epoch time: 21.48 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0847%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7220%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8030%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 46: mean=-0.0137, std=0.0554, |mean|=0.0386, |std|=0.0420, max=0.7988
# layers.3.fc.weight epoch 46: mean=-0.0475, std=0.1408, |mean|=0.1012, |std|=0.1088, max=1.1608
# layers.5.fc.weight epoch 46: mean=-0.0035, std=0.0196, |mean|=0.0110, |std|=0.0165, max=0.1077
# epoch-46  lr=['1.0000000'], tr/val_loss:  0.010301/  0.030855, val:  83.33%, val_best:  86.67%, tr:  98.16%, tr_best:  98.77%, epoch time: 20.85 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0854%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7579%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7892%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 47: mean=-0.0137, std=0.0555, |mean|=0.0387, |std|=0.0422, max=0.8174
# layers.3.fc.weight epoch 47: mean=-0.0476, std=0.1411, |mean|=0.1014, |std|=0.1091, max=1.1657
# layers.5.fc.weight epoch 47: mean=-0.0034, std=0.0196, |mean|=0.0110, |std|=0.0165, max=0.1096
# epoch-47  lr=['1.0000000'], tr/val_loss:  0.009574/  0.032068, val:  83.75%, val_best:  86.67%, tr:  98.88%, tr_best:  98.88%, epoch time: 21.08 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0392%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7474%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7722%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 48: mean=-0.0137, std=0.0557, |mean|=0.0388, |std|=0.0423, max=0.7910
# layers.3.fc.weight epoch 48: mean=-0.0477, std=0.1414, |mean|=0.1016, |std|=0.1094, max=1.1647
# layers.5.fc.weight epoch 48: mean=-0.0035, std=0.0195, |mean|=0.0110, |std|=0.0165, max=0.1077
# epoch-48  lr=['1.0000000'], tr/val_loss:  0.009618/  0.031899, val:  79.58%, val_best:  86.67%, tr:  98.67%, tr_best:  98.88%, epoch time: 21.36 seconds, 0.36 minutes
# layer   1  Sparsity: 91.1156%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7456%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7692%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 49: mean=-0.0137, std=0.0559, |mean|=0.0389, |std|=0.0425, max=0.7971
# layers.3.fc.weight epoch 49: mean=-0.0478, std=0.1417, |mean|=0.1017, |std|=0.1096, max=1.1688
# layers.5.fc.weight epoch 49: mean=-0.0034, std=0.0195, |mean|=0.0109, |std|=0.0165, max=0.1091
# epoch-49  lr=['1.0000000'], tr/val_loss:  0.009553/  0.032415, val:  82.92%, val_best:  86.67%, tr:  97.96%, tr_best:  98.88%, epoch time: 21.20 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0639%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.8127%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7918%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 50: mean=-0.0137, std=0.0561, |mean|=0.0390, |std|=0.0426, max=0.8028
# layers.3.fc.weight epoch 50: mean=-0.0480, std=0.1419, |mean|=0.1019, |std|=0.1099, max=1.1592
# layers.5.fc.weight epoch 50: mean=-0.0035, std=0.0195, |mean|=0.0110, |std|=0.0165, max=0.1078
# epoch-50  lr=['1.0000000'], tr/val_loss:  0.009828/  0.032139, val:  83.33%, val_best:  86.67%, tr:  98.06%, tr_best:  98.88%, epoch time: 21.50 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0684%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.5710%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7737%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 51: mean=-0.0136, std=0.0563, |mean|=0.0391, |std|=0.0428, max=0.8109
# layers.3.fc.weight epoch 51: mean=-0.0480, std=0.1423, |mean|=0.1021, |std|=0.1102, max=1.1800
# layers.5.fc.weight epoch 51: mean=-0.0034, std=0.0195, |mean|=0.0109, |std|=0.0165, max=0.1077
# epoch-51  lr=['1.0000000'], tr/val_loss:  0.009509/  0.030576, val:  82.92%, val_best:  86.67%, tr:  97.96%, tr_best:  98.88%, epoch time: 21.61 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0688%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.6207%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7769%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 52: mean=-0.0137, std=0.0565, |mean|=0.0392, |std|=0.0429, max=0.8119
# layers.3.fc.weight epoch 52: mean=-0.0482, std=0.1426, |mean|=0.1022, |std|=0.1104, max=1.1781
# layers.5.fc.weight epoch 52: mean=-0.0035, std=0.0194, |mean|=0.0109, |std|=0.0164, max=0.1102
# epoch-52  lr=['1.0000000'], tr/val_loss:  0.009141/  0.029126, val:  85.00%, val_best:  86.67%, tr:  98.47%, tr_best:  98.88%, epoch time: 21.70 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0750%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.6102%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7610%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 53: mean=-0.0137, std=0.0566, |mean|=0.0393, |std|=0.0430, max=0.8195
# layers.3.fc.weight epoch 53: mean=-0.0483, std=0.1429, |mean|=0.1024, |std|=0.1107, max=1.1904
# layers.5.fc.weight epoch 53: mean=-0.0034, std=0.0195, |mean|=0.0109, |std|=0.0165, max=0.1077
# epoch-53  lr=['1.0000000'], tr/val_loss:  0.010231/  0.029551, val:  85.42%, val_best:  86.67%, tr:  97.85%, tr_best:  98.88%, epoch time: 20.84 seconds, 0.35 minutes
# layer   1  Sparsity: 91.0613%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.5926%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7400%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 54: mean=-0.0137, std=0.0568, |mean|=0.0394, |std|=0.0432, max=0.8005
# layers.3.fc.weight epoch 54: mean=-0.0484, std=0.1432, |mean|=0.1026, |std|=0.1110, max=1.1909
# layers.5.fc.weight epoch 54: mean=-0.0034, std=0.0193, |mean|=0.0108, |std|=0.0164, max=0.1077
# epoch-54  lr=['1.0000000'], tr/val_loss:  0.008965/  0.028761, val:  84.58%, val_best:  86.67%, tr:  98.67%, tr_best:  98.88%, epoch time: 21.55 seconds, 0.36 minutes
# layer   1  Sparsity: 91.0691%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.5506%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7370%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 55: mean=-0.0137, std=0.0570, |mean|=0.0395, |std|=0.0433, max=0.8068
# layers.3.fc.weight epoch 55: mean=-0.0485, std=0.1435, |mean|=0.1028, |std|=0.1113, max=1.1914
# layers.5.fc.weight epoch 55: mean=-0.0035, std=0.0194, |mean|=0.0109, |std|=0.0164, max=0.1166
