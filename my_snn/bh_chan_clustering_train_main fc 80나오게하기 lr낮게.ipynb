# %% [markdown]
# # ssp.train.py

# %%
import torch   
import torch.nn as nn 
import torch.nn.functional as F   
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle
import json
import time
import sys

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    coarse_com_mode = True,
    coarse_com_config = (2.0, -2.0), # (max, min)

    sae_l2_norm_bridge = True,
    sae_lif_bridge = False,

    accuracy_check_epoch_term = 5,
    
    lif_add_at_last = False,

    two_channel_input = False,

    lateral_feature_num = 4,

    lc_adc_on = False, 
    ):
    if coarse_com_mode == True:
        assert coarse_com_config[0] > coarse_com_config[1], 'coarse_com_config[0] > coarse_com_config[1]이어야 함'
        assert SAE_net == True, 'coarse_com_mode는 SAE_net이 True일 때만 가능'
    if two_channel_input == True:
        assert Conv_net and coarse_com_mode, 'two_channel_input는 Conv_net이 True일 때만 가능'
    if lc_adc_on == True:
        assert coarse_com_mode and SAE_net, 'lc_adc_on은 coarse_com_mode와 SAE_net이 True일 때만 가능'

    seed_assign(my_seed)
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    # JSON으로 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'w') as f:
        json.dump(hyperparameters, f, indent=4)
    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset2", summary="max")


    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])
    # tem=0.8
    # cos_thr = np.array([tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, tem, ])

    print('cos_thr', cos_thr)
    
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'


    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    if coarse_com_mode == True:
        level_num = TIME
        TIME = spike_length
        spike_length = level_num
        level_interval = (coarse_com_config[0] - coarse_com_config[1]) / (level_num-1)  # max - min
        levels = [coarse_com_config[1] + level_interval * i for i in range(level_num)]
        levels = torch.tensor(levels).to(torch.float).to(device)
        levels = levels.repeat(TIME,1) 
        # print('levels', levels, levels.shape) # TIME, level_num

    n_sample = spike_length

    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            input_channels = 2 if two_channel_input else 1
            net = Autoencoder_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = lateral_feature_num, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, lateral_feature_num], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            input_channels = 2 if two_channel_input else 1
            net = SAE_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = lateral_feature_num, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)
        else:
            # net = SAE_fc_only(encoder_ch=[96, 64, 32, lateral_feature_num], 
            #                     decoder_ch=[32,64,96,n_sample], 
            #                     in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
            #                     synapse_fc_trace_const1=1,
            #                     synapse_fc_trace_const2=v_decay,  #안씀 
            #                     TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
            #                     sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
            #                     sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = SAE_fc_only(encoder_ch=[200, lateral_feature_num], 
                                decoder_ch=[200, n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마
    # net.module.load_state_dict(torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250108_211044_402.pth'))




    wandb.watch(net, log="all", log_freq = 10)





    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__



    net = net.to(device)
    print(f"Total number of encoder parameters: {sum(p.numel() for p in net.module.encoder.parameters())}")
    print(net)
    print('Device:',device)

    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0

    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__
    
    for epoch in range(max_epoch):
        print()
        ae_train_start_time = time.time()
        running_loss = 0.0
        iter = 0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike_backup = data
            spike = data
            spike = spike.to(device) # batch, feature
            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                spike = (spike > levels).to(torch.float) 

                spike = (spike == 0).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike

                # spike: batch, time, level_num
                # levels: time, level_num
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    if two_channel_input == True:
                        spike_backup = spike_backup.to(device)
                        spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_backup = (spike_backup <= levels).to(torch.float) 
                        spike_backup = (spike_backup == 1).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike_backup
                        spike_backup = spike_backup.unsqueeze(-2)
                        spike = torch.cat((spike, spike_backup), dim=-2)
                assert spike.shape[0] == batch_size and spike.shape[1] == TIME
            elif 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
            else:
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) #batch in_channel,feature

            # for i in range (3):
            #     plot_spike(spike[i,:,0,:].cpu().numpy())
            #     plot_spike(spike[i,:,1,:].cpu().numpy())
            # assert False
                    
            spike_class = net(spike) # batch, time, feature

            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                # loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                # loss1 = nn.MSELoss()(spike_class[..., 5:25, :], spike[..., 5:25, :])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5, :], spike[..., 0:5, :])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length, :], spike[..., 25:spike_length, :])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                loss = nn.MSELoss()(spike_class, spike)
            elif 'SAE' in net.module.__class__.__name__:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            else:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            sys.stdout.write(f'\repoch-{epoch}, running_loss : {running_loss:.5f}, iter percent {iter/len(train_loader)*100:.2f}%')
            sys.stdout.flush()
            # print(f'\nepoch-{epoch}, running_loss : {running_loss:.5f}, iter percent {iter/len(train_loader)*100:.2f}%')
            iter += 1
        avg_loss = running_loss / len(train_loader)
        assert not np.isnan(avg_loss), f"Error: avg_loss is NaN! Running loss: {running_loss}, Length of train_loader: {len(train_loader)}"
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')
        print(f"ae train 실행 시간: {time.time()-ae_train_start_time:.3f}초")





        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    

        if(epoch % accuracy_check_epoch_term == 0 or epoch == 1 or epoch == max_epoch-1): 
            accuracy_check_start_time = time.time()
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = lateral_feature_num*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else lateral_feature_num

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    spike_torch = torch.from_numpy(spike_template).float()
                    spike_torch = spike_torch[:num_cluster]
                    spike_backup = spike_torch
                    spike_torch = spike_torch.to(device)
                    if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_torch = (spike_torch > levels).to(torch.float) 
                        spike_torch = (spike_torch == 0).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike_torch
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                            if two_channel_input == True:
                                spike_backup = spike_backup.to(device)
                                spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                spike_backup = (spike_backup <= levels).to(torch.float) 
                                spike_backup = (spike_backup == 1).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike_backup
                                spike_backup = spike_backup.unsqueeze(-2) # batch, time, in_channel, feature
                                spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                    elif 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    else:
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                    inner_inf = net.module.encoder(spike_torch)

                    # for i in range(3):
                    #     plot_spike(spike_torch[i,:,:].cpu().numpy())
                    #     plot_spike(inner_inf[i,:].cpu().numpy())
                    #     plot_spike(net.module.decoder(inner_inf)[i,:,:].cpu().numpy())
                        
                    # if 'SAE' in net.module.__class__.__name__:
                    #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                    #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                    #     print(all_equal, inner_inf)

                    if 'SAE' in net.module.__class__.__name__:
                        if SAE_hidden_nomean == True:
                            inner_inf = inner_inf.reshape(inner_inf.shape[0],-1)# time*feature 펼치기
                        else:
                            inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균

                    Cluster = inner_inf.cpu().detach().numpy()

                encoder_batch = 128
                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    now_index = 0
                    while (1):
                        now_end_index = now_index+encoder_batch if now_index+encoder_batch < len(spike) else len(spike)
                        spike_batch = spike[now_index:now_end_index] 
                        spike_torch = torch.from_numpy(spike_batch)
                        spike_torch = spike_torch.float()
                        spike_backup = spike_torch
                        spike_torch = spike_torch.to(device)
                        if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                            spike_torch = (spike_torch > levels).to(torch.float) 
                            spike_torch = (spike_torch == 0).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike_torch
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                                if two_channel_input == True:
                                    spike_backup = spike_backup.to(device)
                                    spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                    spike_backup = (spike_backup <= levels).to(torch.float) 
                                    spike_backup = (spike_backup == 1).cumsum(dim=-1).eq(1).to(torch.float) if lc_adc_on == True else spike_backup
                                    spike_backup = spike_backup.unsqueeze(-2)
                                    spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                        elif 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                        else:
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                                
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.reshape(spike_batch.shape[0],-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[now_index:now_end_index] = inner_inf.cpu().detach().numpy()
                        now_index += encoder_batch
                        if (now_index >= len(spike)):
                            break
                    
                spike_id = np.zeros(len(spike))
                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                plot_tau = []
                plot_denominator = []
                plot_m = []
                plot_max_tau = []
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                        plot_denominator.append(denominator)
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            tau[q] = tau[q] / denominator

                        plot_tau.append(tau[q])

                    # for i in range(num_cluster): # l2 distance
                    #     distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))
                    distance_sm = np.sum(np.power(np.abs(Cluster - spike_hidden[spike_index, :]), 2), axis=1)

                    m = np.argmin(distance_sm)
                    plot_m.append(m)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    plot_max_tau.append(np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16

                
                # print('Cluster',Cluster)
                # print('spike_id', spike_id)

                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                perm_start_time = time.time()
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1
                # print(f"perm 실행 시간: {time.time()-perm_start_time:.3f}초")
                
                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]
                # plot_distributions(ds, plot_tau, plot_denominator, plot_m, plot_max_tau, cos_thr[ds],
                #                    cluster_accuracy_during_training_cycle_all_dataset[ds], cluster_accuracy_post_training_cycle_all_dataset[ds], cluster_accuracy_total_all_dataset[ds])

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                torch.save(net.module.state_dict(), f"net_save/save_now_net_{current_time}.pth")
                print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
            print(f"accuracy_check 실행 시간: {time.time()-accuracy_check_start_time:.3f}초")

        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset2": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


        # 저장
        with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
            pickle.dump({
                "loss_history": loss_history,
                "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
            }, f)

# %%
gpu = 0
Conv_net = False
SAE_net = True

# hyperparameter
dataset_num = 16
spike_length = 50 # coarse_com_mode일 때는 time step이 됨.
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 1400 #1400 2400 # 그 초기 몇개까지만 cluster update할지


batch_size = 32
max_epoch = 7000
learning_rate = 0.00001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 20 # SAE일 때만 유효. coarse_com_mode일 때는 level_num이 됨. 즉 feature 개수.
v_decay = 0.5 # -cor
v_threshold = 0.25 # -cor
v_reset = 10000.0 # -cor # 10000 이상 일 시 hard reset
BPTT_on = True # +cor # True False

SAE_hidden_nomean = True # True False

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'Adam' #'Adam', 'SGD' # 둘다 준수함. loss 줄이는 거는 adam이 좋긴한데, cluster accuracy는 비슷함.

coarse_com_mode = True # True False
coarse_com_config = (2.0, -2.0) # (max, min) (2.0, -2.0) (3.0 -3.0)

sae_l2_norm_bridge = False # True False
sae_lif_bridge = True # False True

accuracy_check_epoch_term = 1

lif_add_at_last = False # True False

two_channel_input = False # True False

lateral_feature_num = 4

lc_adc_on = False # True False

wandb.init(project= f'spike_sorting just run',save_code=False)


cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    
    current_time = current_time,

    optimizer = optimizer, #'Adam', 'SGD'

    coarse_com_mode = coarse_com_mode,
    coarse_com_config = coarse_com_config, # (max, min)

    
    sae_l2_norm_bridge = sae_l2_norm_bridge,
    sae_lif_bridge = sae_lif_bridge,

    accuracy_check_epoch_term = accuracy_check_epoch_term,
    
    lif_add_at_last = lif_add_at_last,

    two_channel_input = two_channel_input,

    lateral_feature_num = lateral_feature_num,

    lc_adc_on = lc_adc_on, 
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250109_012133-8rzx25r5</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/8rzx25r5' target="_blank">absurd-aardvark-393</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/8rzx25r5' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/8rzx25r5</a>
# {'gpu': 0, 'Conv_net': False, 'SAE_net': True, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 1400, 'batch_size': 32, 'max_epoch': 7000, 'learning_rate': 1e-05, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 20, 'v_decay': 0.5, 'v_threshold': 0.25, 'v_reset': 10000.0, 'BPTT_on': True, 'SAE_hidden_nomean': True, 'current_time': '20250109_012130_867', 'optimizer': 'Adam', 'coarse_com_mode': True, 'sae_l2_norm_bridge': False, 'sae_lif_bridge': True, 'accuracy_check_epoch_term': 1, 'lif_add_at_last': False, 'two_channel_input': False, 'lateral_feature_num': 4, 'lc_adc_on': False, 'coarse_com_config': (2.0, -2.0)}
# cos_thr [0.95 0.95 0.95 0.95 0.95 0.95 0.95 0.85 0.95 0.9  0.8  0.95 0.95 0.95
#  0.95 0.8 ]
# Total number of encoder parameters: 4800
# DataParallel(
#   (module): SAE_fc_only(
#     (encoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_one_two_coupling()
#       (2): Linear(in_features=20, out_features=200, bias=False)
#       (3): SSBH_DimChanger_for_one_two_decoupling()
#       (4): LIF_layer()
#       (5): SSBH_DimChanger_for_one_two_coupling()
#       (6): Linear(in_features=200, out_features=4, bias=False)
#       (7): SSBH_DimChanger_for_one_two_decoupling()
#       (8): LIF_layer()
#       (9): SSBH_DimChanger_for_one_two_coupling()
#       (10): SSBH_DimChanger_for_one_two_decoupling()
#       (11): LIF_layer()
#       (12): SSBH_DimChanger_one_two()
#     )
#     (decoder): Sequential(
#       (0): SSBH_DimChanger_one_two()
#       (1): SSBH_DimChanger_for_one_two_coupling()
#       (2): Linear(in_features=4, out_features=200, bias=False)
#       (3): SSBH_DimChanger_for_one_two_decoupling()
#       (4): LIF_layer()
#       (5): SSBH_DimChanger_for_one_two_coupling()
#       (6): Linear(in_features=200, out_features=20, bias=False)
#       (7): SSBH_DimChanger_for_one_two_decoupling()
#       (8): SSBH_DimChanger_one_two()
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250109_012130_867
#
# epoch-0, running_loss : 279.58475, iter percent 99.92%
# epoch-0 loss : 0.23299
# ae train 실행 시간: 130.401초
#
# epoch-0 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.45553453 0.47549482 0.44342802 0.45660559 0.51293532 0.39433962
#  0.36499254 0.35983067 0.3716591  0.35839844 0.36052124 0.37884806
#  0.36303462 0.38118332 0.40343137 0.36407071]
# mean_cluster_accuracy_during_training_cycle : 40.55%, post_traincycle_acc : 40.28%, total_acc : 40.39%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 40.28%
# accuracy_check 실행 시간: 22.299초
#
# epoch-1, running_loss : 71.67947, iter percent 99.92%
# epoch-1 loss : 0.05973
# ae train 실행 시간: 129.637초
#
# epoch-1 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.94843898 0.87558907 0.65912374 0.54339441 0.79552239 0.63537736
#  0.58528095 0.52492944 0.76601109 0.56005859 0.52702703 0.41608739
#  0.6410387  0.53297769 0.53382353 0.46344959]
# mean_cluster_accuracy_during_training_cycle : 62.62%, post_traincycle_acc : 62.55%, total_acc : 62.58%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 62.55%
# accuracy_check 실행 시간: 21.935초
#
# epoch-2, running_loss : 46.06364, iter percent 99.92%
# epoch-2 loss : 0.03839
# ae train 실행 시간: 127.663초
#
# epoch-2 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.80747398 0.9533459  0.88781897 0.62343298 0.66169154 0.52358491
#  0.49477872 0.43555974 0.64145234 0.50634766 0.44787645 0.4265144
#  0.95824847 0.88312318 0.71078431 0.43430483]
# mean_cluster_accuracy_during_training_cycle : 64.29%, post_traincycle_acc : 64.98%, total_acc : 64.70%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 64.98%
# accuracy_check 실행 시간: 21.313초
#
# epoch-3, running_loss : 39.54318, iter percent 99.92%
# epoch-3 loss : 0.03295
# ae train 실행 시간: 127.512초
#
# epoch-3 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97067171 0.89491046 0.77226769 0.7608486  0.90547264 0.8509434
#  0.63053207 0.62135466 0.89510842 0.40478516 0.66119691 0.50148957
#  0.8095723  0.7070805  0.64705882 0.59483994]
# mean_cluster_accuracy_during_training_cycle : 70.75%, post_traincycle_acc : 72.68%, total_acc : 71.88%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 72.68%
# accuracy_check 실행 시간: 20.889초
#
# epoch-4, running_loss : 28.70265, iter percent 99.92%
# epoch-4 loss : 0.02392
# ae train 실행 시간: 128.343초
#
# epoch-4 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.92648445 0.85411651 0.77097396 0.96616915 0.92641509
#  0.85678767 0.58607714 0.92637418 0.63378906 0.42664093 0.49006951
#  0.74083503 0.58971872 0.62352941 0.39799331]
# mean_cluster_accuracy_during_training_cycle : 73.78%, post_traincycle_acc : 73.06%, total_acc : 73.34%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 73.06%
# accuracy_check 실행 시간: 20.964초
#
# epoch-5, running_loss : 5.62029, iter percent 24.08%
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# epoch-5, running_loss : 13.40860, iter percent 59.25%
# wandb: Network error (ReadTimeout), entering retry loop.
# epoch-5, running_loss : 21.67767, iter percent 99.92%
# epoch-5 loss : 0.01806
# ae train 실행 시간: 126.344초
#
# epoch-5 accuracy check
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.95051838 0.88107848 0.76759884 0.96567164 0.90283019
#  0.84485331 0.48682973 0.95461422 0.70507812 0.50096525 0.49205561
#  0.84470468 0.54752667 0.50392157 0.4433827 ]
# mean_cluster_accuracy_during_training_cycle : 73.53%, post_traincycle_acc : 73.52%, total_acc : 73.52%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 73.52%
# accuracy_check 실행 시간: 20.364초
#
# epoch-6, running_loss : 16.73741, iter percent 99.92%
# epoch-6 loss : 0.01395
# ae train 실행 시간: 126.302초
#
# epoch-6 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97125353 0.93740973 0.84088717 0.96467662 0.89386792
#  0.62257583 0.43838194 0.95310136 0.71972656 0.44160232 0.47666336
#  0.85641548 0.64645975 0.54607843 0.41997133]
# mean_cluster_accuracy_during_training_cycle : 73.56%, post_traincycle_acc : 73.14%, total_acc : 73.31%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 73.52%
# accuracy_check 실행 시간: 21.124초
#
# epoch-7, running_loss : 13.65025, iter percent 99.92%
# epoch-7 loss : 0.01138
# ae train 실행 시간: 127.436초
#
# epoch-7 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.9726673  0.95377949 0.86692382 0.960199   0.87971698
#  0.79761313 0.33066792 0.94452849 0.73925781 0.46862934 0.4612711
#  0.95824847 0.64985451 0.55588235 0.45437172]
# mean_cluster_accuracy_during_training_cycle : 75.97%, post_traincycle_acc : 74.79%, total_acc : 75.26%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 74.79%
# accuracy_check 실행 시간: 20.841초
#
# epoch-8, running_loss : 9.67517, iter percent 99.92%
# epoch-8 loss : 0.00806
# ae train 실행 시간: 128.382초
#
# epoch-8 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9736098  0.92633606 0.86981678 0.96467662 0.89764151
#  0.8065639  0.34760113 0.95057993 0.890625   0.62934363 0.47219464
#  0.95162933 0.61639185 0.54264706 0.40850454]
# mean_cluster_accuracy_during_training_cycle : 76.15%, post_traincycle_acc : 76.40%, total_acc : 76.28%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 76.40%
# accuracy_check 실행 시간: 20.688초
#
# epoch-9, running_loss : 9.16278, iter percent 99.92%
# epoch-9 loss : 0.00764
# ae train 실행 시간: 127.871초
#
# epoch-9 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97587512 0.97502356 0.9523351  0.85776278 0.96467662 0.9009434
#  0.79114868 0.53292568 0.94957136 0.86328125 0.66843629 0.47120159
#  0.95315682 0.71580989 0.575      0.36359293]
# mean_cluster_accuracy_during_training_cycle : 77.01%, post_traincycle_acc : 78.19%, total_acc : 77.71%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.659초
#
# epoch-10, running_loss : 7.06609, iter percent 99.92%
# epoch-10 loss : 0.00589
# ae train 실행 시간: 126.921초
#
# epoch-10 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97596607 0.95666827 0.85438766 0.96517413 0.89669811
#  0.80208851 0.32267168 0.95108422 0.87402344 0.63127413 0.47169811
#  0.95977597 0.7870999  0.58186275 0.37983755]
# mean_cluster_accuracy_during_training_cycle : 77.17%, post_traincycle_acc : 77.41%, total_acc : 77.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.123초
#
# epoch-11, running_loss : 6.62397, iter percent 99.92%
# epoch-11 loss : 0.00552
# ae train 실행 시간: 127.691초
#
# epoch-11 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97502356 0.95426095 0.85245902 0.96517413 0.89622642
#  0.77374441 0.56491063 0.92637418 0.77783203 0.63127413 0.44389275
#  0.95723014 0.61445199 0.54803922 0.53846154]
# mean_cluster_accuracy_during_training_cycle : 76.75%, post_traincycle_acc : 77.46%, total_acc : 77.18%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.268초
#
# epoch-12, running_loss : 6.36672, iter percent 99.92%
# epoch-12 loss : 0.00531
# ae train 실행 시간: 128.212초
#
# epoch-12 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97408106 0.94270583 0.85969142 0.9641791  0.90518868
#  0.78170065 0.57855127 0.92990419 0.75390625 0.41843629 0.45531281
#  0.95162933 0.90106693 0.56519608 0.32393693]
# mean_cluster_accuracy_during_training_cycle : 77.95%, post_traincycle_acc : 76.76%, total_acc : 77.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.218초
#
# epoch-13, running_loss : 5.98232, iter percent 99.92%
# epoch-13 loss : 0.00499
# ae train 실행 시간: 127.759초
#
# epoch-13 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97455231 0.95329803 0.84570878 0.96467662 0.90801887
#  0.76578817 0.50517404 0.94856278 0.74121094 0.52364865 0.46921549
#  0.95570265 0.68525703 0.57990196 0.33349259]
# mean_cluster_accuracy_during_training_cycle : 76.27%, post_traincycle_acc : 75.81%, total_acc : 75.99%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.114초
#
# epoch-14, running_loss : 5.88553, iter percent 99.92%
# epoch-14 loss : 0.00490
# ae train 실행 시간: 127.913초
#
# epoch-14 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97587512 0.97172479 0.95474242 0.83944069 0.9641791  0.89056604
#  0.78070612 0.31232361 0.94402421 0.72216797 0.4469112  0.45531281
#  0.95824847 0.67555771 0.54068627 0.30482561]
# mean_cluster_accuracy_during_training_cycle : 74.83%, post_traincycle_acc : 73.36%, total_acc : 73.94%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.917초
#
# epoch-15, running_loss : 5.74137, iter percent 99.92%
# epoch-15 loss : 0.00478
# ae train 실행 시간: 127.865초
#
# epoch-15 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97634816 0.97408106 0.95618681 0.85294118 0.9641791  0.89716981
#  0.74738936 0.44920038 0.94503278 0.85888672 0.4734556  0.45283019
#  0.95824847 0.64548982 0.54264706 0.3870043 ]
# mean_cluster_accuracy_during_training_cycle : 75.78%, post_traincycle_acc : 75.51%, total_acc : 75.61%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.366초
#
# epoch-16, running_loss : 5.26581, iter percent 99.92%
# epoch-16 loss : 0.00439
# ae train 실행 시간: 128.428초
#
# epoch-16 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9736098  0.95329803 0.85438766 0.96368159 0.89245283
#  0.77374441 0.23142051 0.93948563 0.72363281 0.47828185 0.4468719
#  0.95315682 0.59505335 0.51323529 0.38079312]
# mean_cluster_accuracy_during_training_cycle : 75.15%, post_traincycle_acc : 72.80%, total_acc : 73.74%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.308초
#
# epoch-17, running_loss : 5.21085, iter percent 99.92%
# epoch-17 loss : 0.00434
# ae train 실행 시간: 128.069초
#
# epoch-17 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97634816 0.97219604 0.94848339 0.86499518 0.96218905 0.89481132
#  0.72998508 0.41439323 0.94957136 0.77441406 0.48069498 0.46971202
#  0.95672098 0.60669253 0.49558824 0.51505017]
# mean_cluster_accuracy_during_training_cycle : 75.84%, post_traincycle_acc : 75.07%, total_acc : 75.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.821초
#
# epoch-18, running_loss : 5.15972, iter percent 99.92%
# epoch-18 loss : 0.00430
# ae train 실행 시간: 128.041초
#
# epoch-18 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9726673  0.9576312  0.8659595  0.96368159 0.89103774
#  0.7339632  0.44543744 0.94553707 0.82666016 0.51061776 0.46276068
#  0.95672098 0.6013579  0.56715686 0.38079312]
# mean_cluster_accuracy_during_training_cycle : 75.95%, post_traincycle_acc : 75.36%, total_acc : 75.59%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.974초
#
# epoch-19, running_loss : 4.87303, iter percent 99.92%
# epoch-19 loss : 0.00406
# ae train 실행 시간: 125.989초
#
# epoch-19 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9736098  0.9576312  0.85197686 0.96467662 0.90188679
#  0.75882645 0.45719661 0.94654564 0.85351562 0.50675676 0.44736842
#  0.95723014 0.62512124 0.54313725 0.40038223]
# mean_cluster_accuracy_during_training_cycle : 76.46%, post_traincycle_acc : 75.76%, total_acc : 76.04%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.955초
#
# epoch-20, running_loss : 4.83486, iter percent 99.92%
# epoch-20 loss : 0.00403
# ae train 실행 시간: 127.251초
#
# epoch-20 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97634816 0.97502356 0.96100144 0.86740598 0.9641791  0.88867925
#  0.75186474 0.43979304 0.94957136 0.859375   0.628861   0.44885799
#  0.95773931 0.6813773  0.51960784 0.51075012]
# mean_cluster_accuracy_during_training_cycle : 76.26%, post_traincycle_acc : 77.38%, total_acc : 76.93%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.841초
#
# epoch-21, running_loss : 4.97191, iter percent 99.92%
# epoch-21 loss : 0.00414
# ae train 실행 시간: 126.377초
#
# epoch-21 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97219604 0.95666827 0.8659595  0.96467662 0.89575472
#  0.75634013 0.41768579 0.94704992 0.73388672 0.53040541 0.45233366
#  0.95824847 0.61057226 0.58382353 0.40611562]
# mean_cluster_accuracy_during_training_cycle : 75.82%, post_traincycle_acc : 75.17%, total_acc : 75.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.686초
#
# epoch-22, running_loss : 5.01224, iter percent 99.92%
# epoch-22 loss : 0.00418
# ae train 실행 시간: 126.447초
#
# epoch-22 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97408106 0.95714974 0.87270974 0.96368159 0.89669811
#  0.73644953 0.33631232 0.95007564 0.75341797 0.55550193 0.46971202
#  0.9490835  0.59990301 0.575      0.41184902]
# mean_cluster_accuracy_during_training_cycle : 75.45%, post_traincycle_acc : 74.85%, total_acc : 75.08%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.564초
#
# epoch-23, running_loss : 5.01596, iter percent 99.92%
# epoch-23 loss : 0.00418
# ae train 실행 시간: 128.259초
#
# epoch-23 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97313855 0.9576312  0.83317261 0.9641791  0.89150943
#  0.72451517 0.24882408 0.94604135 0.73681641 0.47876448 0.46077458
#  0.95417515 0.6842871  0.57058824 0.39034878]
# mean_cluster_accuracy_during_training_cycle : 75.17%, post_traincycle_acc : 73.69%, total_acc : 74.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.953초
#
# epoch-24, running_loss : 4.95195, iter percent 99.92%
# epoch-24 loss : 0.00413
# ae train 실행 시간: 128.161초
#
# epoch-24 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9736098  0.95618681 0.85583414 0.96467662 0.88537736
#  0.62754848 0.44214487 0.94452849 0.75537109 0.48841699 0.45233366
#  0.95468432 0.5242483  0.58186275 0.30960344]
# mean_cluster_accuracy_during_training_cycle : 74.66%, post_traincycle_acc : 73.07%, total_acc : 73.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.733초
#
# epoch-25, running_loss : 4.98131, iter percent 99.92%
# epoch-25 loss : 0.00415
# ae train 실행 시간: 128.347초
#
# epoch-25 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97219604 0.95714974 0.84570878 0.96368159 0.89386792
#  0.63500746 0.52069614 0.94251135 0.72021484 0.49034749 0.46623635
#  0.95824847 0.72647915 0.6127451  0.41471572]
# mean_cluster_accuracy_during_training_cycle : 75.66%, post_traincycle_acc : 75.59%, total_acc : 75.62%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.722초
#
# epoch-26, running_loss : 4.58965, iter percent 99.92%
# epoch-26 loss : 0.00382
# ae train 실행 시간: 127.647초
#
# epoch-26 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97455231 0.96003852 0.86740598 0.96517413 0.90235849
#  0.75783192 0.39840075 0.93746848 0.78515625 0.62982625 0.45332671
#  0.95773931 0.66537342 0.59117647 0.44672719]
# mean_cluster_accuracy_during_training_cycle : 76.52%, post_traincycle_acc : 76.67%, total_acc : 76.60%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.089초
#
# epoch-27, running_loss : 4.44493, iter percent 99.92%
# epoch-27 loss : 0.00370
# ae train 실행 시간: 129.112초
#
# epoch-27 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97125353 0.95474242 0.85679846 0.96268657 0.90283019
#  0.73247141 0.38005644 0.93645991 0.70996094 0.48503861 0.45481629
#  0.95519348 0.80843841 0.62696078 0.36741519]
# mean_cluster_accuracy_during_training_cycle : 76.58%, post_traincycle_acc : 75.49%, total_acc : 75.93%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.918초
#
# epoch-28, running_loss : 4.64570, iter percent 99.92%
# epoch-28 loss : 0.00387
# ae train 실행 시간: 128.287초
#
# epoch-28 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97078228 0.95185364 0.85342334 0.96467662 0.89858491
#  0.7667827  0.3593603  0.93948563 0.72070312 0.4469112  0.4612711
#  0.9607943  0.61542192 0.57009804 0.35785953]
# mean_cluster_accuracy_during_training_cycle : 74.51%, post_traincycle_acc : 73.82%, total_acc : 74.09%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.042초
#
# epoch-29, running_loss : 4.35244, iter percent 99.92%
# epoch-29 loss : 0.00363
# ae train 실행 시간: 128.151초
#
# epoch-29 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97219604 0.95426095 0.86258438 0.96368159 0.89009434
#  0.74639483 0.4261524  0.94452849 0.72070312 0.49758687 0.459285
#  0.95570265 0.58389913 0.56176471 0.41614907]
# mean_cluster_accuracy_during_training_cycle : 75.25%, post_traincycle_acc : 74.56%, total_acc : 74.83%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.584초
#
# epoch-30, running_loss : 4.09960, iter percent 99.92%
# epoch-30 loss : 0.00342
# ae train 실행 시간: 127.033초
#
# epoch-30 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97078228 0.9523351  0.86885246 0.9641791  0.89150943
#  0.73843859 0.37394167 0.93797277 0.72460938 0.45173745 0.45680238
#  0.95773931 0.61299709 0.55931373 0.44147157]
# mean_cluster_accuracy_during_training_cycle : 74.73%, post_traincycle_acc : 74.24%, total_acc : 74.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.984초
#
# epoch-31, running_loss : 4.06901, iter percent 99.92%
# epoch-31 loss : 0.00339
# ae train 실행 시간: 128.187초
#
# epoch-31 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97078228 0.95377949 0.87270974 0.96368159 0.89433962
#  0.77175535 0.45531515 0.93998991 0.71630859 0.4753861  0.46425025
#  0.95977597 0.57322987 0.5254902  0.40133779]
# mean_cluster_accuracy_during_training_cycle : 75.30%, post_traincycle_acc : 74.46%, total_acc : 74.79%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.164초
#
# epoch-32, running_loss : 4.38944, iter percent 99.92%
# epoch-32 loss : 0.00366
# ae train 실행 시간: 126.881초
#
# epoch-32 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97219604 0.95185364 0.86065574 0.96517413 0.89245283
#  0.76976629 0.38617121 0.93898134 0.71386719 0.48889961 0.46375372
#  0.95417515 0.83656644 0.58333333 0.42857143]
# mean_cluster_accuracy_during_training_cycle : 76.40%, post_traincycle_acc : 76.13%, total_acc : 76.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.197초
#
# epoch-33, running_loss : 4.40015, iter percent 99.92%
# epoch-33 loss : 0.00367
# ae train 실행 시간: 128.709초
#
# epoch-33 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97313855 0.95426095 0.84185149 0.9641791  0.89103774
#  0.73097961 0.44731891 0.93645991 0.73095703 0.45849421 0.45878848
#  0.94602851 0.6057226  0.57352941 0.3134257 ]
# mean_cluster_accuracy_during_training_cycle : 75.78%, post_traincycle_acc : 73.76%, total_acc : 74.57%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.781초
#
# epoch-34, running_loss : 4.61828, iter percent 99.92%
# epoch-34 loss : 0.00385
# ae train 실행 시간: 128.490초
#
# epoch-34 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95570534 0.85245902 0.9641791  0.89198113
#  0.76877176 0.41768579 0.94553707 0.77880859 0.52799228 0.45332671
#  0.95875764 0.56692532 0.55441176 0.29574773]
# mean_cluster_accuracy_during_training_cycle : 75.21%, post_traincycle_acc : 74.24%, total_acc : 74.63%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.488초
#
# epoch-35, running_loss : 4.39081, iter percent 99.92%
# epoch-35 loss : 0.00366
# ae train 실행 시간: 128.802초
#
# epoch-35 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97125353 0.95329803 0.86065574 0.96368159 0.89245283
#  0.75136748 0.39698965 0.94351992 0.74951172 0.48841699 0.44736842
#  0.9592668  0.58583899 0.49117647 0.42236025]
# mean_cluster_accuracy_during_training_cycle : 75.03%, post_traincycle_acc : 74.07%, total_acc : 74.45%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.840초
#
# epoch-36, running_loss : 4.11518, iter percent 99.92%
# epoch-36 loss : 0.00343
# ae train 실행 시간: 128.136초
#
# epoch-36 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97125353 0.95329803 0.8587271  0.96318408 0.90235849
#  0.73346594 0.40263405 0.93595562 0.71435547 0.44594595 0.45233366
#  0.95519348 0.77788555 0.56421569 0.42761586]
# mean_cluster_accuracy_during_training_cycle : 75.52%, post_traincycle_acc : 75.20%, total_acc : 75.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.787초
#
# epoch-37, running_loss : 4.33031, iter percent 99.92%
# epoch-37 loss : 0.00361
# ae train 실행 시간: 127.105초
#
# epoch-37 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97078228 0.95329803 0.86403086 0.96268657 0.89386792
#  0.75037295 0.37394167 0.93645991 0.70166016 0.46187259 0.45779543
#  0.9592668  0.60523763 0.54803922 0.40946011]
# mean_cluster_accuracy_during_training_cycle : 75.42%, post_traincycle_acc : 73.89%, total_acc : 74.50%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.200초
#
# epoch-38, running_loss : 4.34362, iter percent 99.92%
# epoch-38 loss : 0.00362
# ae train 실행 시간: 127.656초
#
# epoch-38 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97125353 0.95329803 0.8635487  0.96268657 0.89292453
#  0.76330184 0.39604892 0.93242562 0.73144531 0.51158301 0.45729891
#  0.95723014 0.60620757 0.54362745 0.39225991]
# mean_cluster_accuracy_during_training_cycle : 75.50%, post_traincycle_acc : 74.43%, total_acc : 74.86%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.044초
#
# epoch-39, running_loss : 4.33546, iter percent 99.92%
# epoch-39 loss : 0.00361
# ae train 실행 시간: 129.131초
#
# epoch-39 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95570534 0.8611379  0.96318408 0.9
#  0.66484336 0.47789276 0.94604135 0.74316406 0.5207529  0.45084409
#  0.9607943  0.61784675 0.58333333 0.25322504]
# mean_cluster_accuracy_during_training_cycle : 75.31%, post_traincycle_acc : 74.03%, total_acc : 74.54%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.628초
#
# epoch-40, running_loss : 4.64167, iter percent 99.92%
# epoch-40 loss : 0.00387
# ae train 실행 시간: 128.691초
#
# epoch-40 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97313855 0.95329803 0.87174542 0.96368159 0.89575472
#  0.71506713 0.40545626 0.94402421 0.73242188 0.51447876 0.46027805
#  0.95672098 0.60523763 0.57058824 0.36837076]
# mean_cluster_accuracy_during_training_cycle : 75.33%, post_traincycle_acc : 74.40%, total_acc : 74.78%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.603초
#
# epoch-41, running_loss : 4.51975, iter percent 99.92%
# epoch-41 loss : 0.00377
# ae train 실행 시간: 127.187초
#
# epoch-41 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95714974 0.87415622 0.96467662 0.90377358
#  0.75335654 0.38617121 0.94604135 0.74023438 0.31756757 0.45382324
#  0.95621181 0.83123181 0.50931373 0.33922599]
# mean_cluster_accuracy_during_training_cycle : 76.36%, post_traincycle_acc : 74.24%, total_acc : 75.09%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.601초
#
# epoch-42, running_loss : 4.43674, iter percent 99.92%
# epoch-42 loss : 0.00370
# ae train 실행 시간: 126.541초
#
# epoch-42 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97078228 0.95522388 0.86740598 0.96467662 0.89764151
#  0.77871706 0.47695202 0.94251135 0.71777344 0.4734556  0.45878848
#  0.95570265 0.68234724 0.54460784 0.40229336]
# mean_cluster_accuracy_during_training_cycle : 75.88%, post_traincycle_acc : 75.40%, total_acc : 75.59%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.861초
#
# epoch-43, running_loss : 4.47072, iter percent 99.92%
# epoch-43 loss : 0.00373
# ae train 실행 시간: 127.157초
#
# epoch-43 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97172479 0.95666827 0.86981678 0.96517413 0.89433962
#  0.6643461  0.41956726 0.93746848 0.73925781 0.51930502 0.45630586
#  0.95875764 0.67313288 0.57205882 0.41758242]
# mean_cluster_accuracy_during_training_cycle : 74.89%, post_traincycle_acc : 74.93%, total_acc : 74.92%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.928초
#
# epoch-44, running_loss : 4.51325, iter percent 99.92%
# epoch-44 loss : 0.00376
# ae train 실행 시간: 126.595초
#
# epoch-44 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.9736098  0.95666827 0.87367406 0.96467662 0.89481132
#  0.73097961 0.42285983 0.9404942  0.72363281 0.53474903 0.46027805
#  0.95672098 0.61251212 0.55343137 0.3277592 ]
# mean_cluster_accuracy_during_training_cycle : 74.24%, post_traincycle_acc : 74.38%, total_acc : 74.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.675초
#
# epoch-45, running_loss : 4.56629, iter percent 99.92%
# epoch-45 loss : 0.00381
# ae train 실행 시간: 127.912초
#
# epoch-45 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.9736098  0.95714974 0.86981678 0.9641791  0.9004717
#  0.7041273  0.41862653 0.93797277 0.77148438 0.4753861  0.45283019
#  0.95621181 0.65955383 0.50637255 0.44290492]
# mean_cluster_accuracy_during_training_cycle : 74.83%, post_traincycle_acc : 74.79%, total_acc : 74.81%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.858초
#
# epoch-46, running_loss : 4.49345, iter percent 99.92%
# epoch-46 loss : 0.00374
# ae train 실행 시간: 127.291초
#
# epoch-46 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.9736098  0.95666827 0.86306654 0.96467662 0.89481132
#  0.75584286 0.42285983 0.9404942  0.73388672 0.43870656 0.46722939
#  0.95723014 0.59456838 0.49705882 0.40993789]
# mean_cluster_accuracy_during_training_cycle : 74.37%, post_traincycle_acc : 74.03%, total_acc : 74.17%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.673초
#
# epoch-47, running_loss : 4.43952, iter percent 99.92%
# epoch-47 loss : 0.00370
# ae train 실행 시간: 127.039초
#
# epoch-47 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97313855 0.95281656 0.86885246 0.96318408 0.9004717
#  0.74490303 0.45484478 0.93444276 0.72509766 0.43532819 0.4652433
#  0.95672098 0.73181377 0.56813725 0.32823698]
# mean_cluster_accuracy_during_training_cycle : 75.77%, post_traincycle_acc : 74.86%, total_acc : 75.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.008초
#
# epoch-48, running_loss : 4.22860, iter percent 99.92%
# epoch-48 loss : 0.00352
# ae train 실행 시간: 128.084초
#
# epoch-48 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.9726673  0.95426095 0.86692382 0.96368159 0.8990566
#  0.73644953 0.44920038 0.9369642  0.71972656 0.43918919 0.45084409
#  0.95366599 0.6057226  0.56568627 0.38795987]
# mean_cluster_accuracy_during_training_cycle : 75.09%, post_traincycle_acc : 74.23%, total_acc : 74.58%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.201초
#
# epoch-49, running_loss : 4.17425, iter percent 99.92%
# epoch-49 loss : 0.00348
# ae train 실행 시간: 127.449초
#
# epoch-49 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97125353 0.95522388 0.86258438 0.9641791  0.89433962
#  0.64992541 0.39887112 0.9329299  0.76953125 0.49565637 0.45978153
#  0.95824847 0.59311348 0.53088235 0.41758242]
# mean_cluster_accuracy_during_training_cycle : 74.85%, post_traincycle_acc : 73.92%, total_acc : 74.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.904초
#
# epoch-50, running_loss : 4.08034, iter percent 99.92%
# epoch-50 loss : 0.00340
# ae train 실행 시간: 127.166초
#
# epoch-50 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9726673  0.95426095 0.86547734 0.96318408 0.89056604
#  0.74092491 0.39322672 0.93444276 0.76904297 0.43967181 0.45878848
#  0.95773931 0.67895247 0.45539216 0.41184902]
# mean_cluster_accuracy_during_training_cycle : 75.30%, post_traincycle_acc : 74.13%, total_acc : 74.60%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.001초
#
# epoch-51, running_loss : 4.00839, iter percent 99.92%
# epoch-51 loss : 0.00334
# ae train 실행 시간: 127.884초
#
# epoch-51 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97313855 0.95377949 0.86981678 0.96318408 0.89716981
#  0.73495773 0.38146754 0.93494705 0.72167969 0.43243243 0.46673287
#  0.95570265 0.59359845 0.51862745 0.4123268 ]
# mean_cluster_accuracy_during_training_cycle : 74.55%, post_traincycle_acc : 73.65%, total_acc : 74.01%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.543초
#
# epoch-52, running_loss : 3.92053, iter percent 99.92%
# epoch-52 loss : 0.00327
# ae train 실행 시간: 128.925초
#
# epoch-52 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97313855 0.95426095 0.86740598 0.96318408 0.89764151
#  0.6643461  0.39322672 0.93746848 0.76220703 0.43484556 0.45332671
#  0.95977597 0.62754607 0.56029412 0.4180602 ]
# mean_cluster_accuracy_during_training_cycle : 74.67%, post_traincycle_acc : 74.00%, total_acc : 74.27%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.570초
#
# epoch-53, running_loss : 4.11285, iter percent 99.92%
# epoch-53 loss : 0.00343
# ae train 실행 시간: 128.604초
#
# epoch-53 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.9726673  0.95522388 0.86981678 0.96368159 0.89669811
#  0.69865738 0.23988711 0.93797277 0.76269531 0.43050193 0.45531281
#  0.95875764 0.66488846 0.50343137 0.44863832]
# mean_cluster_accuracy_during_training_cycle : 74.84%, post_traincycle_acc : 73.33%, total_acc : 73.94%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.474초
#
# epoch-54, running_loss : 4.15137, iter percent 99.92%
# epoch-54 loss : 0.00346
# ae train 실행 시간: 129.021초
#
# epoch-54 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.9726673  0.95426095 0.86306654 0.9641791  0.89433962
#  0.60467429 0.37441204 0.93595562 0.76660156 0.43774131 0.46921549
#  0.95519348 0.58729389 0.45245098 0.52460583]
# mean_cluster_accuracy_during_training_cycle : 74.42%, post_traincycle_acc : 73.31%, total_acc : 73.77%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.431초
#
# epoch-55, running_loss : 4.18282, iter percent 99.92%
# epoch-55 loss : 0.00349
# ae train 실행 시간: 128.712초
#
# epoch-55 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97256386 0.97313855 0.95281656 0.86499518 0.9641791  0.89575472
#  0.66534063 0.29962371 0.93494705 0.75927734 0.43677606 0.46871897
#  0.95723014 0.5800194  0.52598039 0.40516006]
# mean_cluster_accuracy_during_training_cycle : 74.79%, post_traincycle_acc : 72.85%, total_acc : 73.63%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.751초
#
# epoch-56, running_loss : 4.25428, iter percent 99.92%
# epoch-56 loss : 0.00355
# ae train 실행 시간: 128.110초
#
# epoch-56 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97125353 0.95474242 0.85583414 0.96567164 0.89528302
#  0.76877176 0.37723424 0.9329299  0.76464844 0.48648649 0.44736842
#  0.95773931 0.57322987 0.53333333 0.38079312]
# mean_cluster_accuracy_during_training_cycle : 75.01%, post_traincycle_acc : 74.00%, total_acc : 74.40%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.712초
#
# epoch-57, running_loss : 4.22695, iter percent 99.92%
# epoch-57 loss : 0.00352
# ae train 실행 시간: 128.890초
#
# epoch-57 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97313855 0.95377949 0.8635487  0.96368159 0.89622642
#  0.66136251 0.45390405 0.93746848 0.78027344 0.43581081 0.45183714
#  0.95875764 0.66488846 0.50931373 0.3559484 ]
# mean_cluster_accuracy_during_training_cycle : 75.18%, post_traincycle_acc : 73.96%, total_acc : 74.45%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.617초
#
# epoch-58, running_loss : 4.21553, iter percent 99.92%
# epoch-58 loss : 0.00351
# ae train 실행 시간: 129.053초
#
# epoch-58 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.97313855 0.95426095 0.85728062 0.9641791  0.90518868
#  0.6131278  0.38758231 0.93393848 0.71777344 0.51351351 0.45431976
#  0.95519348 0.59650824 0.57401961 0.44768275]
# mean_cluster_accuracy_during_training_cycle : 74.71%, post_traincycle_acc : 73.89%, total_acc : 74.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.966초
#
# epoch-59, running_loss : 4.13943, iter percent 99.92%
# epoch-59 loss : 0.00345
# ae train 실행 시간: 127.339초
#
# epoch-59 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.9726673  0.95570534 0.87367406 0.96368159 0.89858491
#  0.72948782 0.45202258 0.93847705 0.72070312 0.47249035 0.46027805
#  0.9592668  0.58777886 0.56127451 0.4209269 ]
# mean_cluster_accuracy_during_training_cycle : 74.85%, post_traincycle_acc : 74.63%, total_acc : 74.72%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.759초
#
# epoch-60, running_loss : 4.30037, iter percent 99.92%
# epoch-60 loss : 0.00358
# ae train 실행 시간: 127.672초
#
# epoch-60 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97455231 0.95811266 0.85920926 0.96318408 0.89386792
#  0.73794132 0.41110066 0.93141704 0.76416016 0.43822394 0.46276068
#  0.95621181 0.66440349 0.47156863 0.42188247]
# mean_cluster_accuracy_during_training_cycle : 75.59%, post_traincycle_acc : 74.27%, total_acc : 74.81%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.695초
#
# epoch-61, running_loss : 4.49173, iter percent 99.92%
# epoch-61 loss : 0.00374
# ae train 실행 시간: 126.962초
#
# epoch-61 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.9736098  0.95329803 0.86788814 0.96318408 0.89858491
#  0.72153158 0.45719661 0.93847705 0.61572266 0.43677606 0.46077458
#  0.95723014 0.65324927 0.5877451  0.40611562]
# mean_cluster_accuracy_during_training_cycle : 74.81%, post_traincycle_acc : 74.16%, total_acc : 74.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.239초
#
# epoch-62, running_loss : 4.54216, iter percent 99.92%
# epoch-62 loss : 0.00379
# ae train 실행 시간: 127.603초
#
# epoch-62 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97313855 0.95377949 0.86258438 0.9641791  0.89245283
#  0.75484833 0.39510818 0.93192133 0.77636719 0.43725869 0.44935452
#  0.95672098 0.62463628 0.51960784 0.30243669]
# mean_cluster_accuracy_during_training_cycle : 74.76%, post_traincycle_acc : 73.56%, total_acc : 74.04%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.962초
#
# epoch-63, running_loss : 4.49884, iter percent 99.92%
# epoch-63 loss : 0.00375
# ae train 실행 시간: 128.860초
#
# epoch-63 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97172479 0.95377949 0.86065574 0.9641791  0.9004717
#  0.73346594 0.40122295 0.9369642  0.76855469 0.4507722  0.44637537
#  0.95672098 0.61930165 0.54852941 0.39464883]
# mean_cluster_accuracy_during_training_cycle : 74.71%, post_traincycle_acc : 74.26%, total_acc : 74.44%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.033초
#
# epoch-64, running_loss : 4.34761, iter percent 99.92%
# epoch-64 loss : 0.00362
# ae train 실행 시간: 129.266초
#
# epoch-64 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97455231 0.95811266 0.87367406 0.96368159 0.89716981
#  0.65638986 0.49247413 0.93343419 0.77197266 0.53667954 0.44637537
#  0.9592668  0.69786615 0.53823529 0.42140468]
# mean_cluster_accuracy_during_training_cycle : 75.42%, post_traincycle_acc : 75.60%, total_acc : 75.53%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.017초
#
# epoch-65, running_loss : 4.33966, iter percent 99.92%
# epoch-65 loss : 0.00362
# ae train 실행 시간: 127.989초
#
# epoch-65 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95185364 0.86499518 0.96368159 0.88915094
#  0.76479364 0.45484478 0.9329299  0.75048828 0.48503861 0.45283019
#  0.95468432 0.57419981 0.4877451  0.42188247]
# mean_cluster_accuracy_during_training_cycle : 74.29%, post_traincycle_acc : 74.34%, total_acc : 74.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.568초
#
# epoch-66, running_loss : 4.13949, iter percent 99.92%
# epoch-66 loss : 0.00345
# ae train 실행 시간: 127.729초
#
# epoch-66 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97219604 0.95329803 0.86644166 0.9641791  0.89528302
#  0.78319244 0.41674506 0.93645991 0.78271484 0.45415058 0.46077458
#  0.95875764 0.59747818 0.54509804 0.35403727]
# mean_cluster_accuracy_during_training_cycle : 75.91%, post_traincycle_acc : 74.47%, total_acc : 75.05%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.994초
#
# epoch-67, running_loss : 4.07672, iter percent 99.92%
# epoch-67 loss : 0.00340
# ae train 실행 시간: 127.042초
#
# epoch-67 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.97219604 0.95426095 0.86017358 0.96318408 0.88962264
#  0.73943312 0.38052681 0.9369642  0.76416016 0.49710425 0.45978153
#  0.95875764 0.57225994 0.53578431 0.40802676]
# mean_cluster_accuracy_during_training_cycle : 74.90%, post_traincycle_acc : 74.17%, total_acc : 74.46%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.737초
#
# epoch-68, running_loss : 4.21423, iter percent 99.92%
# epoch-68 loss : 0.00351
# ae train 실행 시간: 126.595초
#
# epoch-68 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97172479 0.95329803 0.86451302 0.96268657 0.89009434
#  0.72153158 0.40498589 0.93444276 0.76171875 0.45125483 0.46375372
#  0.95315682 0.58098933 0.57205882 0.40993789]
# mean_cluster_accuracy_during_training_cycle : 75.49%, post_traincycle_acc : 74.19%, total_acc : 74.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.117초
#
# epoch-69, running_loss : 4.23161, iter percent 99.92%
# epoch-69 loss : 0.00353
# ae train 실행 시간: 127.546초
#
# epoch-69 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95570534 0.86451302 0.96318408 0.89009434
#  0.74788662 0.4233302  0.93242562 0.74462891 0.45704633 0.46077458
#  0.95519348 0.57953443 0.51666667 0.43669374]
# mean_cluster_accuracy_during_training_cycle : 74.34%, post_traincycle_acc : 74.21%, total_acc : 74.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.107초
#
# epoch-70, running_loss : 4.16790, iter percent 99.92%
# epoch-70 loss : 0.00347
# ae train 실행 시간: 128.353초
#
# epoch-70 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97172479 0.95426095 0.86162006 0.96368159 0.89245283
#  0.75683739 0.4261524  0.93393848 0.76855469 0.45222008 0.46027805
#  0.96028513 0.57759457 0.54803922 0.42188247]
# mean_cluster_accuracy_during_training_cycle : 75.22%, post_traincycle_acc : 74.53%, total_acc : 74.81%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.603초
#
# epoch-71, running_loss : 4.04891, iter percent 99.92%
# epoch-71 loss : 0.00337
# ae train 실행 시간: 126.863초
#
# epoch-71 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97313855 0.95474242 0.86451302 0.96368159 0.89433962
#  0.75087021 0.41110066 0.93545134 0.765625   0.45704633 0.46772592
#  0.95773931 0.58632396 0.52941176 0.41949355]
# mean_cluster_accuracy_during_training_cycle : 75.50%, post_traincycle_acc : 74.41%, total_acc : 74.85%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.596초
#
# epoch-72, running_loss : 4.10246, iter percent 99.92%
# epoch-72 loss : 0.00342
# ae train 실행 시간: 128.619초
#
# epoch-72 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97313855 0.95618681 0.86933462 0.96368159 0.89669811
#  0.70860269 0.41392286 0.93948563 0.72119141 0.47972973 0.45878848
#  0.95723014 0.67895247 0.57990196 0.43382704]
# mean_cluster_accuracy_during_training_cycle : 75.25%, post_traincycle_acc : 75.03%, total_acc : 75.11%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 19.939초
#
# epoch-73, running_loss : 4.14602, iter percent 99.92%
# epoch-73 loss : 0.00346
# ae train 실행 시간: 129.043초
#
# epoch-73 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.9726673  0.95522388 0.86981678 0.9641791  0.9
#  0.7667827  0.38476011 0.92788704 0.71630859 0.43098456 0.46623635
#  0.9607943  0.68380213 0.56862745 0.41471572]
# mean_cluster_accuracy_during_training_cycle : 75.38%, post_traincycle_acc : 74.73%, total_acc : 74.99%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.303초
#
# epoch-74, running_loss : 4.18938, iter percent 99.92%
# epoch-74 loss : 0.00349
# ae train 실행 시간: 128.093초
#
# epoch-74 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97540208 0.9726673  0.95714974 0.86499518 0.96368159 0.89528302
#  0.74440577 0.38287865 0.93595562 0.77392578 0.44063707 0.44885799
#  0.95366599 0.60087294 0.55833333 0.42044912]
# mean_cluster_accuracy_during_training_cycle : 75.14%, post_traincycle_acc : 74.31%, total_acc : 74.64%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.059초
#
# epoch-75, running_loss : 4.19142, iter percent 99.92%
# epoch-75 loss : 0.00349
# ae train 실행 시간: 128.171초
#
# epoch-75 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97219604 0.95666827 0.86210222 0.96368159 0.89528302
#  0.76877176 0.33490122 0.94200706 0.78857422 0.48889961 0.45233366
#  0.95723014 0.67167798 0.53431373 0.44051601]
# mean_cluster_accuracy_during_training_cycle : 75.41%, post_traincycle_acc : 75.02%, total_acc : 75.18%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.363초
#
# epoch-76, running_loss : 4.24441, iter percent 99.92%
# epoch-76 loss : 0.00354
# ae train 실행 시간: 129.239초
#
# epoch-76 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.9726673  0.95618681 0.86788814 0.9641791  0.89528302
#  0.72003978 0.39369708 0.93141704 0.76757812 0.43436293 0.45680238
#  0.95570265 0.62366634 0.50294118 0.40850454]
# mean_cluster_accuracy_during_training_cycle : 75.31%, post_traincycle_acc : 73.91%, total_acc : 74.48%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 21.221초
#
# epoch-77, running_loss : 4.17990, iter percent 99.92%
# epoch-77 loss : 0.00348
# ae train 실행 시간: 128.520초
#
# epoch-77 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97125353 0.95522388 0.86692382 0.96567164 0.89764151
#  0.7553456  0.40874882 0.93494705 0.71875    0.46428571 0.45978153
#  0.96130346 0.68186227 0.54509804 0.40133779]
# mean_cluster_accuracy_during_training_cycle : 75.43%, post_traincycle_acc : 74.77%, total_acc : 75.03%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.907초
#
# epoch-78, running_loss : 4.32830, iter percent 99.92%
# epoch-78 loss : 0.00361
# ae train 실행 시간: 127.888초
#
# epoch-78 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97125353 0.95618681 0.86499518 0.96268657 0.89056604
#  0.74142218 0.46142992 0.92687847 0.68505859 0.51689189 0.45431976
#  0.95570265 0.67167798 0.58480392 0.3191591 ]
# mean_cluster_accuracy_during_training_cycle : 75.55%, post_traincycle_acc : 74.61%, total_acc : 74.99%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 78.19%
# accuracy_check 실행 시간: 20.931초
#
# epoch-79, running_loss : 4.28151, iter percent 99.92%
# epoch-79 loss : 0.00357
# ae train 실행 시간: 127.841초
#
# ...
# epoch-240 loss : 0.00391
# ae train 실행 시간: 127.721초
#
# epoch-240 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97219604 0.94800193 0.8466731  0.96616915 0.91792453
#  0.83092989 0.47412982 0.93242562 0.76318359 0.61969112 0.47418073
#  0.95213849 0.7099903  0.53627451 0.41710463]
# mean_cluster_accuracy_during_training_cycle : 75.74%, post_traincycle_acc : 77.09%, total_acc : 76.54%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.968초
#
# epoch-241, running_loss : 4.73111, iter percent 99.92%
# epoch-241 loss : 0.00394
# ae train 실행 시간: 128.345초
#
# epoch-241 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97313855 0.94896485 0.89103182 0.96616915 0.92311321
#  0.83092989 0.48588899 0.9480585  0.78662109 0.61341699 0.48113208
#  0.95315682 0.75460718 0.53578431 0.41280459]
# mean_cluster_accuracy_during_training_cycle : 76.34%, post_traincycle_acc : 78.00%, total_acc : 77.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.934초
#
# epoch-242, running_loss : 4.75820, iter percent 99.92%
# epoch-242 loss : 0.00397
# ae train 실행 시간: 129.647초
#
# epoch-242 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97219604 0.95377949 0.8514947  0.96616915 0.91226415
#  0.77274988 0.48353716 0.93847705 0.77246094 0.46814672 0.46425025
#  0.95213849 0.74393792 0.51421569 0.38604873]
# mean_cluster_accuracy_during_training_cycle : 75.28%, post_traincycle_acc : 75.78%, total_acc : 75.58%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.833초
#
# epoch-243, running_loss : 5.18817, iter percent 99.92%
# epoch-243 loss : 0.00432
# ae train 실행 시간: 128.204초
#
# epoch-243 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97313855 0.9417429  0.83317261 0.96766169 0.93396226
#  0.75335654 0.48541863 0.94200706 0.78710938 0.57335907 0.47418073
#  0.94501018 0.63918526 0.50784314 0.40372671]
# mean_cluster_accuracy_during_training_cycle : 74.42%, post_traincycle_acc : 75.84%, total_acc : 75.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.615초
#
# epoch-244, running_loss : 5.34734, iter percent 99.92%
# epoch-244 loss : 0.00446
# ae train 실행 시간: 128.203초
#
# epoch-244 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97219604 0.95329803 0.80954677 0.96616915 0.9245283
#  0.79711586 0.62182502 0.93242562 0.76855469 0.60328185 0.44240318
#  0.91700611 0.63045587 0.4872549  0.43526039]
# mean_cluster_accuracy_during_training_cycle : 74.44%, post_traincycle_acc : 76.48%, total_acc : 75.65%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 21.056초
#
# epoch-245, running_loss : 5.27863, iter percent 99.92%
# epoch-245 loss : 0.00440
# ae train 실행 시간: 127.393초
#
# epoch-245 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97219604 0.94896485 0.79508197 0.96716418 0.91933962
#  0.82048732 0.45484478 0.94150277 0.79443359 0.41650579 0.44885799
#  0.94857434 0.63773036 0.53431373 0.43812709]
# mean_cluster_accuracy_during_training_cycle : 74.16%, post_traincycle_acc : 75.07%, total_acc : 74.69%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.948초
#
# epoch-246, running_loss : 5.12766, iter percent 99.92%
# epoch-246 loss : 0.00427
# ae train 실행 시간: 126.890초
#
# epoch-246 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9736098  0.94415022 0.85535198 0.96666667 0.9240566
#  0.70561909 0.40028222 0.94200706 0.75976562 0.40009653 0.45531281
#  0.94602851 0.65130941 0.52696078 0.28189202]
# mean_cluster_accuracy_during_training_cycle : 73.43%, post_traincycle_acc : 73.17%, total_acc : 73.27%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.808초
#
# epoch-247, running_loss : 5.20842, iter percent 99.92%
# epoch-247 loss : 0.00434
# ae train 실행 시간: 126.493초
#
# epoch-247 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97313855 0.9417429  0.83799421 0.96666667 0.91556604
#  0.77573347 0.3508937  0.93898134 0.76074219 0.48841699 0.45332671
#  0.94144603 0.64112512 0.50343137 0.4605829 ]
# mean_cluster_accuracy_during_training_cycle : 73.97%, post_traincycle_acc : 74.52%, total_acc : 74.29%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.829초
#
# epoch-248, running_loss : 5.28789, iter percent 99.92%
# epoch-248 loss : 0.00441
# ae train 실행 시간: 128.824초
#
# epoch-248 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97492904 0.97313855 0.9099663  0.82015429 0.96567164 0.92169811
#  0.77324714 0.65098777 0.93192133 0.77001953 0.47490347 0.44885799
#  0.93839104 0.6328807  0.51372549 0.3956044 ]
# mean_cluster_accuracy_during_training_cycle : 74.64%, post_traincycle_acc : 75.60%, total_acc : 75.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.749초
#
# epoch-249, running_loss : 5.11504, iter percent 99.92%
# epoch-249 loss : 0.00426
# ae train 실행 시간: 129.788초
#
# epoch-249 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97455231 0.95570534 0.85245902 0.96467662 0.90896226
#  0.76827449 0.20649106 0.94251135 0.79199219 0.6230695  0.44389275
#  0.94857434 0.65373424 0.52598039 0.50931677]
# mean_cluster_accuracy_during_training_cycle : 74.97%, post_traincycle_acc : 75.27%, total_acc : 75.13%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.873초
#
# epoch-250, running_loss : 5.13768, iter percent 99.92%
# epoch-250 loss : 0.00428
# ae train 실행 시간: 128.523초
#
# epoch-250 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97313855 0.96003852 0.8442623  0.96517413 0.91698113
#  0.73993038 0.53904045 0.93797277 0.77685547 0.60907336 0.45183714
#  0.94653768 0.64985451 0.52303922 0.47539417]
# mean_cluster_accuracy_during_training_cycle : 74.64%, post_traincycle_acc : 76.77%, total_acc : 75.91%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.703초
#
# epoch-251, running_loss : 5.07965, iter percent 99.92%
# epoch-251 loss : 0.00423
# ae train 실행 시간: 128.648초
#
# epoch-251 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9736098  0.95137217 0.8539055  0.96616915 0.91556604
#  0.78766783 0.51975541 0.93645991 0.76806641 0.60907336 0.45084409
#  0.95468432 0.66100873 0.51372549 0.50358337]
# mean_cluster_accuracy_during_training_cycle : 74.95%, post_traincycle_acc : 77.12%, total_acc : 76.25%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 21.213초
#
# epoch-252, running_loss : 5.11595, iter percent 99.92%
# epoch-252 loss : 0.00426
# ae train 실행 시간: 128.401초
#
# epoch-252 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.9726673  0.94270583 0.84378014 0.96567164 0.91603774
#  0.75484833 0.59642521 0.9293999  0.73828125 0.62403475 0.45134062
#  0.94602851 0.63530553 0.53529412 0.3841376 ]
# mean_cluster_accuracy_during_training_cycle : 74.46%, post_traincycle_acc : 76.31%, total_acc : 75.57%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.849초
#
# epoch-253, running_loss : 5.10189, iter percent 99.92%
# epoch-253 loss : 0.00425
# ae train 실행 시간: 128.414초
#
# epoch-253 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97209082 0.97172479 0.95185364 0.86162006 0.96616915 0.91603774
#  0.70810542 0.46660395 0.92839133 0.74414062 0.57046332 0.47219464
#  0.95417515 0.66440349 0.50441176 0.44577162]
# mean_cluster_accuracy_during_training_cycle : 74.26%, post_traincycle_acc : 75.61%, total_acc : 75.07%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.675초
#
# epoch-254, running_loss : 5.26181, iter percent 99.92%
# epoch-254 loss : 0.00438
# ae train 실행 시간: 128.421초
#
# epoch-254 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9726673  0.95377949 0.85004822 0.96666667 0.8990566
#  0.72302337 0.5056444  0.92788704 0.73779297 0.60955598 0.46822244
#  0.94501018 0.63967022 0.51813725 0.33970377]
# mean_cluster_accuracy_during_training_cycle : 73.78%, post_traincycle_acc : 75.19%, total_acc : 74.62%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.826초
#
# epoch-255, running_loss : 5.18145, iter percent 99.92%
# epoch-255 loss : 0.00432
# ae train 실행 시간: 127.089초
#
# epoch-255 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97219604 0.947039   0.85776278 0.96616915 0.91650943
#  0.80059672 0.51552211 0.92133132 0.74316406 0.50772201 0.4468719
#  0.95875764 0.68089234 0.525      0.39034878]
# mean_cluster_accuracy_during_training_cycle : 74.32%, post_traincycle_acc : 75.77%, total_acc : 75.19%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 21.307초
#
# epoch-256, running_loss : 5.12665, iter percent 99.92%
# epoch-256 loss : 0.00427
# ae train 실행 시간: 128.056초
#
# epoch-256 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.9730369  0.97219604 0.93981704 0.85101254 0.96467662 0.91084906
#  0.78915962 0.52634055 0.92788704 0.73828125 0.57287645 0.46573982
#  0.95264766 0.64985451 0.51519608 0.4151935 ]
# mean_cluster_accuracy_during_training_cycle : 74.31%, post_traincycle_acc : 76.03%, total_acc : 75.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.613초
#
# epoch-257, running_loss : 5.12939, iter percent 99.92%
# epoch-257 loss : 0.00427
# ae train 실행 시간: 128.097초
#
# epoch-257 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9726673  0.94800193 0.84474446 0.96517413 0.90566038
#  0.74689209 0.51505174 0.91780131 0.74511719 0.61486486 0.45034757
#  0.95417515 0.63821532 0.5127451  0.29957   ]
# mean_cluster_accuracy_during_training_cycle : 73.92%, post_traincycle_acc : 75.03%, total_acc : 74.58%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.994초
#
# epoch-258, running_loss : 5.03050, iter percent 99.92%
# epoch-258 loss : 0.00419
# ae train 실행 시간: 127.913초
#
# epoch-258 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97350993 0.97313855 0.9364468  0.86981678 0.96567164 0.91886792
#  0.74092491 0.60771402 0.91780131 0.75390625 0.48696911 0.45134062
#  0.95213849 0.63676043 0.51470588 0.35929288]
# mean_cluster_accuracy_during_training_cycle : 74.14%, post_traincycle_acc : 75.37%, total_acc : 74.87%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.741초
#
# epoch-259, running_loss : 5.22615, iter percent 99.92%
# epoch-259 loss : 0.00436
# ae train 실행 시간: 128.564초
#
# epoch-259 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9726673  0.9417429  0.82304725 0.96567164 0.91745283
#  0.79811039 0.37158984 0.92788704 0.75976562 0.41457529 0.46276068
#  0.94501018 0.65664403 0.52058824 0.45437172]
# mean_cluster_accuracy_during_training_cycle : 74.31%, post_traincycle_acc : 74.41%, total_acc : 74.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.535초
#
# epoch-260, running_loss : 5.31002, iter percent 99.92%
# epoch-260 loss : 0.00443
# ae train 실행 시간: 127.969초
#
# epoch-260 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97398297 0.9726673  0.94222436 0.85486982 0.96517413 0.91650943
#  0.80109398 0.6335842  0.90418558 0.74755859 0.60183398 0.44389275
#  0.95315682 0.63676043 0.5377451  0.34209269]
# mean_cluster_accuracy_during_training_cycle : 74.56%, post_traincycle_acc : 76.42%, total_acc : 75.67%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.091초
#
# epoch-261, running_loss : 5.25517, iter percent 99.92%
# epoch-261 loss : 0.00438
# ae train 실행 시간: 127.544초
#
# epoch-261 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97445601 0.97313855 0.89985556 0.85245902 0.96567164 0.91132075
#  0.73794132 0.53339605 0.92889561 0.71630859 0.48696911 0.44786495
#  0.92922607 0.64936954 0.51813725 0.47826087]
# mean_cluster_accuracy_during_training_cycle : 75.09%, post_traincycle_acc : 75.02%, total_acc : 75.05%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 79.45%
# accuracy_check 실행 시간: 20.973초
#
# epoch-262, running_loss : 2.41735, iter percent 46.83%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 52
#      47 lc_adc_on = False # True False
#      49 wandb.init(project= f'spike_sorting just run',save_code=False)
# ---> 52 cluster_train_system(
#      53     gpu = gpu,
#      54     Conv_net = Conv_net,
#      55     SAE_net = SAE_net,
#      56
#      57     # hyperparameter
#      58     dataset_num = dataset_num,
#      59     spike_length = spike_length,
#      60     num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#      61     training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지
#      62
#      63
#      64     batch_size = batch_size,
#      65     max_epoch = max_epoch,
#      66     learning_rate = learning_rate,
#      67     normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#      68     need_bias = need_bias,
#      69     # first_layer_no_train = False
#      70     lif_add_at_first = lif_add_at_first,
#      71     my_seed = my_seed,
#      72
#      73     TIME = TIME, # SAE일 때만 유효
#      74     v_decay = v_decay,
#      75     v_threshold = v_threshold,
#      76     v_reset = v_reset, # 10000이상 일 시 hard reset
#      77     BPTT_on = BPTT_on,
#      78
#      79     SAE_hidden_nomean = SAE_hidden_nomean,
#      80
#      81     current_time = current_time,
#      82
#      83     optimizer = optimizer, #'Adam', 'SGD'
#      84
#      85     coarse_com_mode = coarse_com_mode,
#      86     coarse_com_config = coarse_com_config, # (max, min)
#      87
#      88
#      89     sae_l2_norm_bridge = sae_l2_norm_bridge,
#      90     sae_lif_bridge = sae_lif_bridge,
#      91
#      92     accuracy_check_epoch_term = accuracy_check_epoch_term,
#      93
#      94     lif_add_at_last = lif_add_at_last,
#      95
#      96     two_channel_input = two_channel_input,
#      97
#      98     lateral_feature_num = lateral_feature_num,
#      99
#     100     lc_adc_on = lc_adc_on,
#     101     )
#
# Cell In[2], line 304, in cluster_train_system(gpu, Conv_net, SAE_net, dataset_num, spike_length, num_cluster, training_cycle, batch_size, max_epoch, learning_rate, normalize_on, need_bias, lif_add_at_first, my_seed, TIME, v_decay, v_threshold, v_reset, BPTT_on, SAE_hidden_nomean, current_time, optimizer, coarse_com_mode, coarse_com_config, sae_l2_norm_bridge, sae_lif_bridge, accuracy_check_epoch_term, lif_add_at_last, two_channel_input, lateral_feature_num, lc_adc_on)
#     302     loss = loss1 * 2.125 + (loss2 + loss3)/4
#     303     assert spike_length > 25, 'spike_length가 25보다 작음'
# --> 304 loss.backward()
#     305 optimizer.step()
#     306 running_loss += loss.item()
#
# File ~/anaconda3/envs/aedat2/lib/python3.8/site-packages/torch/_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     298 if has_torch_function_unary(self):
#     299     return handle_torch_function(
#     300         Tensor.backward,
#     301         (self,),
#    (...)
#     305         create_graph=create_graph,
#     306         inputs=inputs)
# --> 307 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/anaconda3/envs/aedat2/lib/python3.8/site-packages/torch/autograd/__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     151 if retain_graph is None:
#     152     retain_graph = create_graph
# --> 154 Variable._execution_engine.run_backward(
#     155     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# # Sweep code


# from unittest import TextTestRunner


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [False]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400]}, # [1400, 2400]

#         "batch_size": {"values": [32]}, 
#         "max_epoch": {"values": [5]}, 
#         "learning_rate": {"values": [0.001, 0.0001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [True, False]}, # [True, False]

#         "lif_add_at_first": {"values": [False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [50,40,30,20]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75,0.875]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75,1.0]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True]}, # [True, False]

#         # "current_time": {"values": [current_time]} #밑에서 직접설정됨.

#         "optimizer": {"values": ['Adam', 'SGD']}, # ['Adam', 'SGD']

#         "coarse_com_mode": {"values": [True]}, # ['Adam', 'SGD']
#         "coarse_com_config": {"values": [(2.0, -2.0), (3.0, -3.0)]}, # ['Adam', 'SGD']

#         "sae_l2_norm_bridge": {"values": [False]}, # [True, False]
#         "sae_lif_bridge": {"values": [True]}, # [False, True]
        
#         "accuracy_check_epoch_term": {"values": [1]}, 

#         "lif_add_at_last": {"values": [True, False]},# [True, False]

#         "two_channel_input": {"values": [False]},# [True, False]

#         "lateral_feature_num": {"values": [4, 5]},# [True, False]

#         "lc_adc_on": {"values": [True, False]},# [True, False]
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  2
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer

#     coarse_com_mode = wandb.config.coarse_com_mode
#     coarse_com_config = wandb.config.coarse_com_config # (max, min)

#     sae_l2_norm_bridge = wandb.config.sae_l2_norm_bridge
#     sae_lif_bridge = wandb.config.sae_lif_bridge

#     accuracy_check_epoch_term = wandb.config.accuracy_check_epoch_term

#     lif_add_at_last = wandb.config.lif_add_at_last

#     two_channel_input = wandb.config.two_channel_input

#     lateral_feature_num = wandb.config.lateral_feature_num

#     lc_adc_on = wandb.config.lc_adc_on

#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'

#         coarse_com_mode = coarse_com_mode,
#         coarse_com_config = coarse_com_config, # (max, min)
        
#         sae_l2_norm_bridge = sae_l2_norm_bridge,
#         sae_lif_bridge = sae_lif_bridge,

#         accuracy_check_epoch_term = accuracy_check_epoch_term,

#         lif_add_at_last = lif_add_at_last,
        
#         two_channel_input = two_channel_input,
        
#         lateral_feature_num = lateral_feature_num,

#         lc_adc_on = lc_adc_on,
#         )
    
# # sweep_id = 'ygoj9jt4'
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.006 MB of 0.006 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_loss</td><td>▁</td></tr><tr><td>best_mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>▁</td></tr><tr><td>best_mean_cluster_accuracy_post_training_cycle_all_dataset2</td><td>▁</td></tr><tr><td>mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_loss</td><td>0.0</td></tr><tr><td>best_mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>0.71997</td></tr><tr><td>mean_cluster_accuracy_post_training_cycle_all_dataset</td><td>0.71997</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">apricot-dragon-365</strong> at: <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/348erua8' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/348erua8</a><br/> View project at: <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250108_222154-348erua8/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle
import json

# current_time = '20250102_225243_972'

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)


# JSON으로 저장
with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'r') as f:
    loaded_hyperparameters = json.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']
print(data)
max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {loaded_hyperparameters['dataset_num']}, Conv {loaded_hyperparameters['Conv_net']}, SAE {loaded_hyperparameters['SAE_net']}, Current time {loaded_hyperparameters['current_time']}, Spike Length: {loaded_hyperparameters['spike_length']}, Num Cluster: {loaded_hyperparameters['num_cluster']}, "
    f"Training Cycle: {loaded_hyperparameters['training_cycle']}, Batch Size: {loaded_hyperparameters['batch_size']}, Max Epoch: {loaded_hyperparameters['max_epoch']}, \n"
    f"Learning Rate: {loaded_hyperparameters['learning_rate']}, Input Normalize: {loaded_hyperparameters['normalize_on']}, Need Bias: {loaded_hyperparameters['need_bias']}, "
    f"LIF Add at First: {loaded_hyperparameters['lif_add_at_first']}, TIME: {loaded_hyperparameters['TIME']}, Seed: {loaded_hyperparameters['my_seed']}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
# Out:
# {'loss_history': [(0, 0.23298729282493394), (1, 0.05973288904254635), (2, 0.03838636319618672), (3, 0.03295264588513722), (4, 0.023918877782610554), (5, 0.018064727449479203), (6, 0.013947841927098732), (7, 0.011375211612321436), (8, 0.008062637965194882), (9, 0.0076356497465167195), (10, 0.005888408183818683), (11, 0.005519975029552976), (12, 0.005305597399516652), (13, 0.004985269531413602), (14, 0.004904608914706235), (15, 0.004784473064161527), (16, 0.004388173153468718), (17, 0.004342372467508539), (18, 0.004299765953522486), (19, 0.004060858252923936), (20, 0.004029051740653813), (21, 0.004143255846962954), (22, 0.00417686493252404), (23, 0.004179963650143084), (24, 0.004126621006095472), (25, 0.004151093475714637), (26, 0.0038247104740003124), (27, 0.0037041069111243513), (28, 0.003871416973803813), (29, 0.003627035661872166), (30, 0.003416333299634668), (31, 0.0033908450085436926), (32, 0.0036578690964961425), (33, 0.0036667928571114316), (34, 0.0038485670724185185), (35, 0.003659004574874416), (36, 0.0034293146342194328), (37, 0.0036085919863156355), (38, 0.003619685743081694), (39, 0.003612885751645081), (40, 0.0038680584548274055), (41, 0.003766455319904101), (42, 0.003697284761001356), (43, 0.00372560122263773), (44, 0.003761042830495474), (45, 0.003805245704522046), (46, 0.003744542664887073), (47, 0.003699601363623515), (48, 0.003523837324270668), (49, 0.003478542011968481), (50, 0.0034002818118703242), (51, 0.003340321480257747), (52, 0.0032671052881050855), (53, 0.003427376260709328), (54, 0.0034594769845716655), (55, 0.003485686517960858), (56, 0.0035452303371857853), (57, 0.003522459829497772), (58, 0.0035129404351270446), (59, 0.0034495276961630833), (60, 0.003583641806617379), (61, 0.0037431060899204265), (62, 0.003785133526350061), (63, 0.0037490327407916388), (64, 0.0036230045198074852), (65, 0.0036163823415214817), (66, 0.003449573211255483), (67, 0.003397265880873116), (68, 0.003511855979838098), (69, 0.0035263391403714196), (70, 0.003473249840705345), (71, 0.0033740879853333657), (72, 0.0034187159091622257), (73, 0.003455019482062198), (74, 0.003491152312490158), (75, 0.00349285240265696), (76, 0.0035370043548755346), (77, 0.0034832466203564157), (78, 0.00360691602982115), (79, 0.003567925768632752), (80, 0.003539639004933027), (81, 0.003504457557379889), (82, 0.0034901858282197886), (83, 0.0034476748925711337), (84, 0.0033732715227718776), (85, 0.0031577503306713574), (86, 0.003267441242739248), (87, 0.0032771256692164267), (88, 0.0032401808702464526), (89, 0.0032817885460099203), (90, 0.00338487521376616), (91, 0.0034957710397429762), (92, 0.0036217946380687257), (93, 0.0035430871216037), (94, 0.003641677030439799), (95, 0.003553181928000413), (96, 0.003579749991962065), (97, 0.003913502489643482), (98, 0.003716295704167957), (99, 0.0035161242635998254), (100, 0.00358940613475473), (101, 0.004241336944978684), (102, 0.004266119414047959), (103, 0.004236541641682076), (104, 0.004185850043431856), (105, 0.004204311312447923), (106, 0.004083801660647926), (107, 0.003936852857392903), (108, 0.003914837567135692), (109, 0.0037852829987726484), (110, 0.004026352162860955), (111, 0.0039293830911628904), (112, 0.003797366436338052), (113, 0.003741221816162579), (114, 0.003590437862051961), (115, 0.003813631931746689), (116, 0.003806268081922705), (117, 0.0037627654609968886), (118, 0.0038257174434450764), (119, 0.003773523539227123), (120, 0.0035917497666863103), (121, 0.003788552900465826), (122, 0.0038751732478461537), (123, 0.0037886062124744056), (124, 0.0037855581770418214), (125, 0.0038155127499097338), (126, 0.0037603437394136564), (127, 0.0038664745459876335), (128, 0.004157280783983879), (129, 0.004514746523345821), (130, 0.004769106538345416), (131, 0.004890916407069502), (132, 0.005015285690897145), (133, 0.004903883187992808), (134, 0.0051834750722628085), (135, 0.005604903908291211), (136, 0.005198187216107423), (137, 0.00501037641991085), (138, 0.004518559580901638), (139, 0.004350761731620878) ...
