# %%
import sys
import os
import argparse
import torch
import torch.nn as nn 
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import time

from snntorch import spikegen
import matplotlib.pyplot as plt
import snntorch.spikeplot as splt
from IPython.display import HTML

from tqdm import tqdm

from apex.parallel import DistributedDataParallel as DDP

import random
import datetime

import json

from sklearn.utils import shuffle

''' 레퍼런스
https://spikingjelly.readthedocs.io/zh-cn/0.0.0.0.4/spikingjelly.datasets.html#module-spikingjelly.datasets
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/datasets.py
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/how_to.md
https://github.com/nmi-lab/torchneuromorphic
https://snntorch.readthedocs.io/en/latest/snntorch.spikevision.spikedata.html#shd
'''

import snntorch
from snntorch.spikevision import spikedata

import modules.spikingjelly;
from modules.spikingjelly.datasets.dvs128_gesture import DVS128Gesture
from modules.spikingjelly.datasets.cifar10_dvs import CIFAR10DVS
from modules.spikingjelly.datasets.n_mnist import NMNIST
# from modules.spikingjelly.datasets.es_imagenet import ESImageNet
from modules.spikingjelly.datasets import split_to_train_test_set
from modules.spikingjelly.datasets.n_caltech101 import NCaltech101
from modules.spikingjelly.datasets import pad_sequence_collate, padded_sequence_mask

import modules.torchneuromorphic as torchneuromorphic

import wandb

from torchviz import make_dot
import graphviz
from turtle import shape
# Out:
# /tmp/ipykernel_35262/3748606120.py:46: DeprecationWarning: The module snntorch.spikevision is deprecated. For loading neuromorphic datasets, we recommend using the Tonic project: https://github.com/neuromorphs/tonic
#   from snntorch.spikevision import spikedata

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import snntorch as snn
from snntorch import surrogate
from snntorch import functional as SF
from snntorch import utils
from torchvision import datasets, transforms
from torch.utils.data import DataLoader# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
seed_assign(42)

# %%
# def fire_function(gamma):
#     class ZIF(torch.autograd.Function): # zero is firing
#         @staticmethod
#         def forward(ctx, input):
#             out = (input >= 0).float()
#             ctx.save_for_backward(input)
#             return out


#         # 걍 근데 이건 1/2보다 작으면 1
#         # 1/2보다 크면 0인데?
#         @staticmethod
#         def backward(ctx, grad_output):
#             (input, ) = ctx.saved_tensors
#             grad_input = grad_output.clone()
#             tmp = (input.abs() < gamma/2).float() / gamma
#             grad_input = grad_input * tmp
#             return grad_input, None

#     return ZIF.apply


# class LIFSpike(nn.Module):
#     def __init__(self, thresh=0.5, tau=0.25, gamma=4.0):
#         super(LIFSpike, self).__init__()
#         self.thresh = thresh
#         self.tau = tau
#         self.gamma = gamma

#     def forward(self, x):
#         mem = torch.zeros_like(x[0])

#         spikes = []
#         T = x.shape[0]
#         for t in range(T):
#             mem = mem.detach() * self.tau + x[t] #걍 인덱스별로 각각 덧셈
#             # mem = mem * self.tau + x[t] #걍 인덱스별로 각각 덧셈
#             spike = fire_function(self.gamma)(mem - self.thresh)
#             # mem = (1 - spike.detach()) * mem #spike나감과 동시에 reset
#             mem = mem - spike.detach() * self.thresh
#             spikes.append(spike)

        
#         return torch.stack(spikes, dim=0)

# %%
for kkk in range(4):
    if kkk == 0:
        v_reset = 0.0
        BPTT_on = True
    elif kkk == 1:
        v_reset = 0.0
        BPTT_on = False

    elif kkk == 2:
        v_reset = 10000.0
        BPTT_on = True
    elif kkk == 3:
        v_reset = 10000.0
        BPTT_on = False

    print('\n\n\n',v_reset, BPTT_on, '\n\n\n')

    hyper_run_time = 10
    goat_val_acc = 0
    for iii in range(hyper_run_time):
        print(f"\nHyper Run Time : {iii+1}/{hyper_run_time}\n\n")

        # 1. 하이퍼파라미터 설정
        batch_size = 32
        num_epochs = 10
        learning_rate = 0.00001
        num_steps = 10  # SNN에서 사용할 time step

        v_init = 0.0
        v_decay = 0.5
        v_threshold = 1.0
        v_reset = v_reset
        sg_width = 4.0
        # surrogate = 'sigmoid'
        surrogate = 'rectangle'
        BPTT_on = BPTT_on # True False

        # 2. 데이터셋 로드 (MNIST)
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])

        train_dataset = datasets.MNIST(root="/data2", train=True, download=True, transform=transform)
        test_dataset = datasets.MNIST(root="/data2", train=False, download=True, transform=transform)

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)




        # 3. SNN 모델 정의
        class SNN(nn.Module):
            def __init__(self, v_init, v_decay, v_threshold, v_reset, sg_width, surrogate, BPTT_on):
                super().__init__()
                self.fc1 = nn.Linear(28 * 28, 200)  # 출력 크기를 10으로 변경
                self.lif1 = LIF_layer(v_init, v_decay, v_threshold, v_reset, sg_width, surrogate, BPTT_on)
                # self.lif1 = LIFSpike(thresh = v_threshold, tau = v_decay, gamma = sg_width)
                
                self.fc2 = nn.Linear(200, 10)  # 출력 크기를 10으로 변경

            def forward(self, x):
                # x : T B C H W
                # print(x.shape)
                T = x.size(0)
                B = x.size(1)
                x = x.view(x.size(0), x.size(1), -1) # T B HW
                # print(x.shape)
                x = x.view(T*B, -1)# TB HW
                # print(x.shape)
                x = self.fc1(x)
                # print(x.shape)
                x = x.view(T, B, -1)
                # print(x.shape)
                x = self.lif1(x)
                x = x.view(T*B, -1)# TB HW
                x = self.fc2(x)
                x = x.view(T, B, -1)
                # 0차원 mean
                # print(x.shape)
                # x = x.mean(dim=0) # B 10
                # print(x.shape)
                # print(x[0])
                return x

        # 4. 모델 초기화
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model = SNN(v_init, v_decay, v_threshold, v_reset, sg_width, surrogate, BPTT_on).to(device)
        criterion = nn.CrossEntropyLoss().to(device)
        criterion_count = SF.ce_count_loss()  # 손실 함수
        # sgd optimizer
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
        # optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        print(model)

        # 6. 모델 평가
        def test(model, test_loader):
            model.eval()
            correct = 0
            total = 0

            with torch.no_grad():
                for images, labels in test_loader:
                    images, labels = images.to(device), labels.to(device)
                    images = images.unsqueeze(0).repeat(num_steps, 1, 1, 1, 1)
                    spk_out = model(images)
                    spk_out = spk_out.mean(dim=0) # B 10
                    pred = spk_out.argmax(dim=1) 
                    correct += (pred == labels).sum().item()
                    total += labels.size(0)

            return correct / total

        # 5. 모델 학습
        print("Training Start...")
        best_val_acc = 0
        for epoch in range(num_epochs):
            train_loss = 0
            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)
                optimizer.zero_grad()
                # images : B C H W

                images = images.unsqueeze(0).repeat(num_steps, 1, 1, 1, 1)
                # images : T B C H W

                spk_out = model(images)

                # loss = criterion_count(spk_out, labels)
                spk_out = spk_out.sum(dim=0) # B 10
                loss = criterion(spk_out, labels)

                pred = spk_out.argmax(dim=1)
                
                loss.backward()
                optimizer.step()
                
                correct = (pred == labels).sum().item()
                total = labels.size(0)
                acc = correct / total

                train_loss += loss.item()
            val_acc = test(model, test_loader)
            best_val_acc = max(best_val_acc, val_acc)
            goat_val_acc = max(goat_val_acc, val_acc)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss/len(train_loader):.8f}, tr_acc: {acc*100:.2f}%, val_acc: {val_acc*100:.2f}%, best_acc: {best_val_acc*100:.2f}%, goat_acc: {goat_val_acc*100:.2f}%, v_reset: {v_reset}, BPTT_on: {BPTT_on}")
# Out:
#  0.0 True
#
#
#
#
# Hyper Run Time : 1/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.17799506, tr_acc: 87.50%, val_acc: 80.13%, best_acc: 80.13%, goat_acc: 80.13%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.59639512, tr_acc: 78.12%, val_acc: 84.62%, best_acc: 84.62%, goat_acc: 84.62%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.49229595, tr_acc: 84.38%, val_acc: 86.61%, best_acc: 86.61%, goat_acc: 86.61%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.44024273, tr_acc: 84.38%, val_acc: 87.94%, best_acc: 87.94%, goat_acc: 87.94%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40777720, tr_acc: 96.88%, val_acc: 88.63%, best_acc: 88.63%, goat_acc: 88.63%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.38418022, tr_acc: 84.38%, val_acc: 89.26%, best_acc: 89.26%, goat_acc: 89.26%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36674538, tr_acc: 93.75%, val_acc: 89.76%, best_acc: 89.76%, goat_acc: 89.76%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35201493, tr_acc: 84.38%, val_acc: 90.01%, best_acc: 90.01%, goat_acc: 90.01%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33989909, tr_acc: 84.38%, val_acc: 90.45%, best_acc: 90.45%, goat_acc: 90.45%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.32957156, tr_acc: 90.62%, val_acc: 90.57%, best_acc: 90.57%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 2/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.16292641, tr_acc: 84.38%, val_acc: 79.37%, best_acc: 79.37%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.59189102, tr_acc: 81.25%, val_acc: 84.55%, best_acc: 84.55%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.48703704, tr_acc: 87.50%, val_acc: 86.87%, best_acc: 86.87%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.43531556, tr_acc: 93.75%, val_acc: 88.14%, best_acc: 88.14%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40252919, tr_acc: 84.38%, val_acc: 88.99%, best_acc: 88.99%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.37932884, tr_acc: 87.50%, val_acc: 89.35%, best_acc: 89.35%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36168970, tr_acc: 87.50%, val_acc: 89.73%, best_acc: 89.73%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.34746593, tr_acc: 93.75%, val_acc: 90.25%, best_acc: 90.25%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33568147, tr_acc: 96.88%, val_acc: 90.39%, best_acc: 90.39%, goat_acc: 90.57%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.32492601, tr_acc: 81.25%, val_acc: 90.65%, best_acc: 90.65%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 3/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.14284987, tr_acc: 87.50%, val_acc: 80.32%, best_acc: 80.32%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.57578710, tr_acc: 90.62%, val_acc: 85.28%, best_acc: 85.28%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.47632561, tr_acc: 87.50%, val_acc: 87.28%, best_acc: 87.28%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.42827585, tr_acc: 84.38%, val_acc: 88.43%, best_acc: 88.43%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.39839491, tr_acc: 78.12%, val_acc: 89.17%, best_acc: 89.17%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.37661348, tr_acc: 90.62%, val_acc: 89.57%, best_acc: 89.57%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.35970654, tr_acc: 93.75%, val_acc: 89.92%, best_acc: 89.92%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.34597317, tr_acc: 84.38%, val_acc: 90.23%, best_acc: 90.23%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33409982, tr_acc: 84.38%, val_acc: 90.33%, best_acc: 90.33%, goat_acc: 90.65%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.32418323, tr_acc: 93.75%, val_acc: 90.74%, best_acc: 90.74%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 4/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.17464725, tr_acc: 87.50%, val_acc: 79.97%, best_acc: 79.97%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.57260217, tr_acc: 75.00%, val_acc: 85.53%, best_acc: 85.53%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.47465765, tr_acc: 90.62%, val_acc: 87.31%, best_acc: 87.31%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.42711211, tr_acc: 78.12%, val_acc: 88.45%, best_acc: 88.45%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.39704257, tr_acc: 87.50%, val_acc: 89.06%, best_acc: 89.06%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.37578224, tr_acc: 93.75%, val_acc: 89.63%, best_acc: 89.63%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.35902792, tr_acc: 93.75%, val_acc: 90.06%, best_acc: 90.06%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.34559170, tr_acc: 84.38%, val_acc: 90.31%, best_acc: 90.31%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33405460, tr_acc: 87.50%, val_acc: 90.67%, best_acc: 90.67%, goat_acc: 90.74%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.32418760, tr_acc: 93.75%, val_acc: 91.00%, best_acc: 91.00%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 5/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.17606554, tr_acc: 81.25%, val_acc: 80.00%, best_acc: 80.00%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.59058280, tr_acc: 90.62%, val_acc: 84.82%, best_acc: 84.82%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.49138865, tr_acc: 90.62%, val_acc: 86.88%, best_acc: 86.88%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.44287737, tr_acc: 84.38%, val_acc: 87.96%, best_acc: 87.96%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.41171887, tr_acc: 81.25%, val_acc: 88.61%, best_acc: 88.61%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.39000662, tr_acc: 90.62%, val_acc: 89.28%, best_acc: 89.28%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.37238380, tr_acc: 75.00%, val_acc: 89.70%, best_acc: 89.70%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35806507, tr_acc: 90.62%, val_acc: 89.97%, best_acc: 89.97%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.34599847, tr_acc: 90.62%, val_acc: 90.32%, best_acc: 90.32%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.33547763, tr_acc: 87.50%, val_acc: 90.52%, best_acc: 90.52%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 6/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.17022579, tr_acc: 78.12%, val_acc: 80.09%, best_acc: 80.09%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.60274501, tr_acc: 78.12%, val_acc: 85.20%, best_acc: 85.20%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.49471186, tr_acc: 87.50%, val_acc: 87.33%, best_acc: 87.33%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.44197429, tr_acc: 96.88%, val_acc: 88.28%, best_acc: 88.28%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40945455, tr_acc: 90.62%, val_acc: 89.21%, best_acc: 89.21%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.38602057, tr_acc: 96.88%, val_acc: 89.59%, best_acc: 89.59%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36821194, tr_acc: 78.12%, val_acc: 90.00%, best_acc: 90.00%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35404014, tr_acc: 90.62%, val_acc: 90.13%, best_acc: 90.13%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.34163754, tr_acc: 93.75%, val_acc: 90.50%, best_acc: 90.50%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.33116387, tr_acc: 93.75%, val_acc: 90.71%, best_acc: 90.71%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 7/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.13436246, tr_acc: 84.38%, val_acc: 80.38%, best_acc: 80.38%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.56500026, tr_acc: 87.50%, val_acc: 85.43%, best_acc: 85.43%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.47374366, tr_acc: 81.25%, val_acc: 87.39%, best_acc: 87.39%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.42928832, tr_acc: 90.62%, val_acc: 88.31%, best_acc: 88.31%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40107649, tr_acc: 90.62%, val_acc: 89.01%, best_acc: 89.01%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.38013207, tr_acc: 90.62%, val_acc: 89.71%, best_acc: 89.71%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36437136, tr_acc: 90.62%, val_acc: 90.19%, best_acc: 90.19%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35137872, tr_acc: 93.75%, val_acc: 90.52%, best_acc: 90.52%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33996596, tr_acc: 93.75%, val_acc: 90.75%, best_acc: 90.75%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.33051079, tr_acc: 90.62%, val_acc: 90.89%, best_acc: 90.89%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 8/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.14853315, tr_acc: 75.00%, val_acc: 79.85%, best_acc: 79.85%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.59097089, tr_acc: 90.62%, val_acc: 84.78%, best_acc: 84.78%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.48993954, tr_acc: 90.62%, val_acc: 86.90%, best_acc: 86.90%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.43989453, tr_acc: 96.88%, val_acc: 87.83%, best_acc: 87.83%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40824024, tr_acc: 90.62%, val_acc: 88.67%, best_acc: 88.67%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.38565116, tr_acc: 100.00%, val_acc: 89.10%, best_acc: 89.10%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36798956, tr_acc: 93.75%, val_acc: 89.54%, best_acc: 89.54%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35404206, tr_acc: 78.12%, val_acc: 89.71%, best_acc: 89.71%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.34200610, tr_acc: 93.75%, val_acc: 90.15%, best_acc: 90.15%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.33156119, tr_acc: 93.75%, val_acc: 90.40%, best_acc: 90.40%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 9/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.16485613, tr_acc: 84.38%, val_acc: 79.99%, best_acc: 79.99%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.59410492, tr_acc: 78.12%, val_acc: 84.80%, best_acc: 84.80%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.49200877, tr_acc: 84.38%, val_acc: 86.93%, best_acc: 86.93%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.44160311, tr_acc: 78.12%, val_acc: 88.26%, best_acc: 88.26%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.41019481, tr_acc: 93.75%, val_acc: 88.84%, best_acc: 88.84%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.38718300, tr_acc: 87.50%, val_acc: 89.30%, best_acc: 89.30%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.36914668, tr_acc: 93.75%, val_acc: 89.71%, best_acc: 89.71%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.35469894, tr_acc: 87.50%, val_acc: 90.05%, best_acc: 90.05%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.34230046, tr_acc: 84.38%, val_acc: 90.35%, best_acc: 90.35%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.33177495, tr_acc: 84.38%, val_acc: 90.67%, best_acc: 90.67%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
# Hyper Run Time : 10/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.22131043, tr_acc: 75.00%, val_acc: 79.98%, best_acc: 79.98%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 2/10, Loss: 0.58758141, tr_acc: 90.62%, val_acc: 84.80%, best_acc: 84.80%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 3/10, Loss: 0.48355938, tr_acc: 78.12%, val_acc: 87.15%, best_acc: 87.15%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 4/10, Loss: 0.43311122, tr_acc: 90.62%, val_acc: 87.98%, best_acc: 87.98%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 5/10, Loss: 0.40017979, tr_acc: 96.88%, val_acc: 88.77%, best_acc: 88.77%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 6/10, Loss: 0.37662479, tr_acc: 65.62%, val_acc: 89.29%, best_acc: 89.29%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 7/10, Loss: 0.35863970, tr_acc: 84.38%, val_acc: 89.68%, best_acc: 89.68%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 8/10, Loss: 0.34420886, tr_acc: 90.62%, val_acc: 90.25%, best_acc: 90.25%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 9/10, Loss: 0.33203314, tr_acc: 93.75%, val_acc: 90.46%, best_acc: 90.46%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
# Epoch 10/10, Loss: 0.32137724, tr_acc: 90.62%, val_acc: 90.87%, best_acc: 90.87%, goat_acc: 91.00%, v_reset: 0.0, BPTT_on: True
#
#
#
#  0.0 False
#
#
#
#
# Hyper Run Time : 1/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.39139246, tr_acc: 75.00%, val_acc: 75.80%, best_acc: 75.80%, goat_acc: 75.80%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69206003, tr_acc: 84.38%, val_acc: 82.26%, best_acc: 82.26%, goat_acc: 82.26%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.55830370, tr_acc: 75.00%, val_acc: 85.14%, best_acc: 85.14%, goat_acc: 85.14%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49544203, tr_acc: 84.38%, val_acc: 86.45%, best_acc: 86.45%, goat_acc: 86.45%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45652085, tr_acc: 96.88%, val_acc: 87.20%, best_acc: 87.20%, goat_acc: 87.20%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42907298, tr_acc: 87.50%, val_acc: 87.85%, best_acc: 87.85%, goat_acc: 87.85%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40784069, tr_acc: 90.62%, val_acc: 88.49%, best_acc: 88.49%, goat_acc: 88.49%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39166620, tr_acc: 75.00%, val_acc: 89.08%, best_acc: 89.08%, goat_acc: 89.08%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37792389, tr_acc: 93.75%, val_acc: 89.37%, best_acc: 89.37%, goat_acc: 89.37%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36623070, tr_acc: 87.50%, val_acc: 89.69%, best_acc: 89.69%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 2/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.34823131, tr_acc: 93.75%, val_acc: 74.79%, best_acc: 74.79%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70556276, tr_acc: 68.75%, val_acc: 81.67%, best_acc: 81.67%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56840730, tr_acc: 84.38%, val_acc: 84.52%, best_acc: 84.52%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50227696, tr_acc: 90.62%, val_acc: 86.05%, best_acc: 86.05%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46185665, tr_acc: 84.38%, val_acc: 87.01%, best_acc: 87.01%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43349831, tr_acc: 90.62%, val_acc: 87.71%, best_acc: 87.71%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41217037, tr_acc: 84.38%, val_acc: 88.20%, best_acc: 88.20%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39515755, tr_acc: 84.38%, val_acc: 88.62%, best_acc: 88.62%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38091656, tr_acc: 84.38%, val_acc: 89.08%, best_acc: 89.08%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36897326, tr_acc: 93.75%, val_acc: 89.43%, best_acc: 89.43%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 3/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.41643056, tr_acc: 84.38%, val_acc: 74.27%, best_acc: 74.27%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.71995374, tr_acc: 84.38%, val_acc: 81.35%, best_acc: 81.35%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57511663, tr_acc: 84.38%, val_acc: 84.09%, best_acc: 84.09%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50613060, tr_acc: 90.62%, val_acc: 85.64%, best_acc: 85.64%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46346794, tr_acc: 81.25%, val_acc: 86.68%, best_acc: 86.68%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43402901, tr_acc: 93.75%, val_acc: 87.49%, best_acc: 87.49%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41178227, tr_acc: 93.75%, val_acc: 87.88%, best_acc: 87.88%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39415616, tr_acc: 87.50%, val_acc: 88.42%, best_acc: 88.42%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37991806, tr_acc: 90.62%, val_acc: 88.78%, best_acc: 88.78%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36733033, tr_acc: 93.75%, val_acc: 89.24%, best_acc: 89.24%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 4/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.42796262, tr_acc: 71.88%, val_acc: 74.27%, best_acc: 74.27%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70652377, tr_acc: 75.00%, val_acc: 81.47%, best_acc: 81.47%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56633815, tr_acc: 90.62%, val_acc: 84.46%, best_acc: 84.46%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49944246, tr_acc: 84.38%, val_acc: 86.34%, best_acc: 86.34%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45821977, tr_acc: 90.62%, val_acc: 87.36%, best_acc: 87.36%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42922962, tr_acc: 65.62%, val_acc: 88.06%, best_acc: 88.06%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40775836, tr_acc: 93.75%, val_acc: 88.63%, best_acc: 88.63%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39087073, tr_acc: 93.75%, val_acc: 88.94%, best_acc: 88.94%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37709310, tr_acc: 100.00%, val_acc: 89.17%, best_acc: 89.17%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36519512, tr_acc: 78.12%, val_acc: 89.59%, best_acc: 89.59%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 5/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.30083480, tr_acc: 78.12%, val_acc: 76.80%, best_acc: 76.80%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.66999857, tr_acc: 71.88%, val_acc: 82.49%, best_acc: 82.49%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.54704521, tr_acc: 78.12%, val_acc: 85.08%, best_acc: 85.08%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.48719354, tr_acc: 87.50%, val_acc: 86.71%, best_acc: 86.71%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.44945396, tr_acc: 96.88%, val_acc: 87.51%, best_acc: 87.51%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42275680, tr_acc: 84.38%, val_acc: 88.35%, best_acc: 88.35%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40226841, tr_acc: 84.38%, val_acc: 88.74%, best_acc: 88.74%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38595007, tr_acc: 93.75%, val_acc: 89.12%, best_acc: 89.12%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37243871, tr_acc: 81.25%, val_acc: 89.57%, best_acc: 89.57%, goat_acc: 89.69%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36112071, tr_acc: 87.50%, val_acc: 89.84%, best_acc: 89.84%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 6/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.36614577, tr_acc: 78.12%, val_acc: 74.60%, best_acc: 74.60%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70994422, tr_acc: 68.75%, val_acc: 81.48%, best_acc: 81.48%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57349039, tr_acc: 87.50%, val_acc: 84.36%, best_acc: 84.36%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50662328, tr_acc: 93.75%, val_acc: 85.95%, best_acc: 85.95%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46551044, tr_acc: 90.62%, val_acc: 86.95%, best_acc: 86.95%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43667676, tr_acc: 90.62%, val_acc: 87.60%, best_acc: 87.60%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41523323, tr_acc: 81.25%, val_acc: 88.36%, best_acc: 88.36%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39819865, tr_acc: 81.25%, val_acc: 88.78%, best_acc: 88.78%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38446729, tr_acc: 84.38%, val_acc: 89.19%, best_acc: 89.19%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37244735, tr_acc: 87.50%, val_acc: 89.55%, best_acc: 89.55%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 7/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.44048555, tr_acc: 65.62%, val_acc: 74.45%, best_acc: 74.45%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70600232, tr_acc: 75.00%, val_acc: 81.89%, best_acc: 81.89%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56340231, tr_acc: 90.62%, val_acc: 84.89%, best_acc: 84.89%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49670836, tr_acc: 84.38%, val_acc: 86.41%, best_acc: 86.41%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45591798, tr_acc: 81.25%, val_acc: 87.31%, best_acc: 87.31%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42725441, tr_acc: 84.38%, val_acc: 88.16%, best_acc: 88.16%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40571808, tr_acc: 87.50%, val_acc: 88.85%, best_acc: 88.85%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38886108, tr_acc: 87.50%, val_acc: 89.35%, best_acc: 89.35%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37473130, tr_acc: 87.50%, val_acc: 89.64%, best_acc: 89.64%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36241831, tr_acc: 87.50%, val_acc: 89.84%, best_acc: 89.84%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 8/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.39731068, tr_acc: 78.12%, val_acc: 75.45%, best_acc: 75.45%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70209809, tr_acc: 81.25%, val_acc: 82.49%, best_acc: 82.49%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56285501, tr_acc: 78.12%, val_acc: 85.11%, best_acc: 85.11%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49634853, tr_acc: 87.50%, val_acc: 86.72%, best_acc: 86.72%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45575326, tr_acc: 75.00%, val_acc: 87.75%, best_acc: 87.75%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42725871, tr_acc: 87.50%, val_acc: 88.29%, best_acc: 88.29%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40573630, tr_acc: 84.38%, val_acc: 88.95%, best_acc: 88.95%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38852528, tr_acc: 90.62%, val_acc: 89.34%, best_acc: 89.34%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37451714, tr_acc: 90.62%, val_acc: 89.75%, best_acc: 89.75%, goat_acc: 89.84%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36248016, tr_acc: 84.38%, val_acc: 90.07%, best_acc: 90.07%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 9/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.39523775, tr_acc: 75.00%, val_acc: 74.04%, best_acc: 74.04%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69455789, tr_acc: 71.88%, val_acc: 81.76%, best_acc: 81.76%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.55798354, tr_acc: 81.25%, val_acc: 84.34%, best_acc: 84.34%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49361537, tr_acc: 84.38%, val_acc: 86.01%, best_acc: 86.01%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45433336, tr_acc: 87.50%, val_acc: 87.00%, best_acc: 87.00%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42680047, tr_acc: 78.12%, val_acc: 87.82%, best_acc: 87.82%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40624185, tr_acc: 87.50%, val_acc: 88.33%, best_acc: 88.33%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38990812, tr_acc: 81.25%, val_acc: 88.93%, best_acc: 88.93%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37634829, tr_acc: 93.75%, val_acc: 89.27%, best_acc: 89.27%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36456406, tr_acc: 78.12%, val_acc: 89.60%, best_acc: 89.60%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
#
# Hyper Run Time : 10/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.42211894, tr_acc: 75.00%, val_acc: 75.12%, best_acc: 75.12%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69406515, tr_acc: 75.00%, val_acc: 82.13%, best_acc: 82.13%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56176379, tr_acc: 78.12%, val_acc: 84.62%, best_acc: 84.62%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49899103, tr_acc: 84.38%, val_acc: 86.27%, best_acc: 86.27%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46055503, tr_acc: 93.75%, val_acc: 87.19%, best_acc: 87.19%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43411504, tr_acc: 78.12%, val_acc: 87.78%, best_acc: 87.78%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41338769, tr_acc: 78.12%, val_acc: 88.31%, best_acc: 88.31%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39648947, tr_acc: 90.62%, val_acc: 88.83%, best_acc: 88.83%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38282479, tr_acc: 75.00%, val_acc: 89.14%, best_acc: 89.14%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37095526, tr_acc: 96.88%, val_acc: 89.40%, best_acc: 89.40%, goat_acc: 90.07%, v_reset: 0.0, BPTT_on: False
#
#
#
#  10000.0 True
#
#
#
#
# Hyper Run Time : 1/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.25107898, tr_acc: 87.50%, val_acc: 77.83%, best_acc: 77.83%, goat_acc: 77.83%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.63722828, tr_acc: 81.25%, val_acc: 83.60%, best_acc: 83.60%, goat_acc: 83.60%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52681945, tr_acc: 84.38%, val_acc: 85.92%, best_acc: 85.92%, goat_acc: 85.92%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47406774, tr_acc: 90.62%, val_acc: 87.12%, best_acc: 87.12%, goat_acc: 87.12%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.44133712, tr_acc: 87.50%, val_acc: 87.82%, best_acc: 87.82%, goat_acc: 87.82%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41879796, tr_acc: 93.75%, val_acc: 88.50%, best_acc: 88.50%, goat_acc: 88.50%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.40091742, tr_acc: 90.62%, val_acc: 88.84%, best_acc: 88.84%, goat_acc: 88.84%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38674295, tr_acc: 90.62%, val_acc: 89.25%, best_acc: 89.25%, goat_acc: 89.25%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.37439874, tr_acc: 90.62%, val_acc: 89.63%, best_acc: 89.63%, goat_acc: 89.63%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36443026, tr_acc: 87.50%, val_acc: 89.88%, best_acc: 89.88%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 2/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.30607081, tr_acc: 71.88%, val_acc: 77.20%, best_acc: 77.20%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.64673103, tr_acc: 81.25%, val_acc: 83.21%, best_acc: 83.21%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52705222, tr_acc: 90.62%, val_acc: 85.72%, best_acc: 85.72%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47175548, tr_acc: 93.75%, val_acc: 87.12%, best_acc: 87.12%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43696011, tr_acc: 81.25%, val_acc: 87.93%, best_acc: 87.93%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41313534, tr_acc: 78.12%, val_acc: 88.36%, best_acc: 88.36%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39585766, tr_acc: 87.50%, val_acc: 88.99%, best_acc: 88.99%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38141033, tr_acc: 90.62%, val_acc: 89.12%, best_acc: 89.12%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.36971026, tr_acc: 81.25%, val_acc: 89.37%, best_acc: 89.37%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.35958706, tr_acc: 100.00%, val_acc: 89.70%, best_acc: 89.70%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 3/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.24699430, tr_acc: 71.88%, val_acc: 78.39%, best_acc: 78.39%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.62935219, tr_acc: 56.25%, val_acc: 83.62%, best_acc: 83.62%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52280043, tr_acc: 78.12%, val_acc: 85.64%, best_acc: 85.64%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47164216, tr_acc: 87.50%, val_acc: 86.86%, best_acc: 86.86%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43954386, tr_acc: 81.25%, val_acc: 87.54%, best_acc: 87.54%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41702334, tr_acc: 90.62%, val_acc: 88.26%, best_acc: 88.26%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39874221, tr_acc: 93.75%, val_acc: 88.79%, best_acc: 88.79%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38395153, tr_acc: 84.38%, val_acc: 89.02%, best_acc: 89.02%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.37151760, tr_acc: 93.75%, val_acc: 89.39%, best_acc: 89.39%, goat_acc: 89.88%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36149617, tr_acc: 87.50%, val_acc: 89.96%, best_acc: 89.96%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 4/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.29656409, tr_acc: 81.25%, val_acc: 77.30%, best_acc: 77.30%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.64139496, tr_acc: 84.38%, val_acc: 83.49%, best_acc: 83.49%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52487463, tr_acc: 81.25%, val_acc: 85.80%, best_acc: 85.80%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.46962722, tr_acc: 87.50%, val_acc: 86.92%, best_acc: 86.92%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43577423, tr_acc: 84.38%, val_acc: 87.78%, best_acc: 87.78%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41264954, tr_acc: 81.25%, val_acc: 88.72%, best_acc: 88.72%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39483887, tr_acc: 93.75%, val_acc: 89.06%, best_acc: 89.06%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38094567, tr_acc: 87.50%, val_acc: 89.43%, best_acc: 89.43%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.36966080, tr_acc: 87.50%, val_acc: 89.75%, best_acc: 89.75%, goat_acc: 89.96%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.35952971, tr_acc: 96.88%, val_acc: 90.10%, best_acc: 90.10%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 5/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.24426232, tr_acc: 71.88%, val_acc: 77.78%, best_acc: 77.78%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.63025068, tr_acc: 71.88%, val_acc: 83.57%, best_acc: 83.57%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52197718, tr_acc: 93.75%, val_acc: 85.63%, best_acc: 85.63%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47046919, tr_acc: 93.75%, val_acc: 86.98%, best_acc: 86.98%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43746991, tr_acc: 90.62%, val_acc: 87.62%, best_acc: 87.62%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41466028, tr_acc: 87.50%, val_acc: 88.33%, best_acc: 88.33%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39690392, tr_acc: 84.38%, val_acc: 88.84%, best_acc: 88.84%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38225358, tr_acc: 87.50%, val_acc: 89.12%, best_acc: 89.12%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.37033758, tr_acc: 87.50%, val_acc: 89.52%, best_acc: 89.52%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36013243, tr_acc: 87.50%, val_acc: 89.95%, best_acc: 89.95%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 6/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.25933801, tr_acc: 65.62%, val_acc: 77.52%, best_acc: 77.52%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.64770276, tr_acc: 93.75%, val_acc: 83.06%, best_acc: 83.06%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52888084, tr_acc: 90.62%, val_acc: 85.29%, best_acc: 85.29%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47385471, tr_acc: 71.88%, val_acc: 86.94%, best_acc: 86.94%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.44017674, tr_acc: 90.62%, val_acc: 87.89%, best_acc: 87.89%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41588534, tr_acc: 93.75%, val_acc: 88.38%, best_acc: 88.38%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39786580, tr_acc: 93.75%, val_acc: 89.02%, best_acc: 89.02%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38386416, tr_acc: 87.50%, val_acc: 89.30%, best_acc: 89.30%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.37174300, tr_acc: 84.38%, val_acc: 89.57%, best_acc: 89.57%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36195703, tr_acc: 87.50%, val_acc: 89.99%, best_acc: 89.99%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 7/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.27777053, tr_acc: 75.00%, val_acc: 78.03%, best_acc: 78.03%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.63741599, tr_acc: 78.12%, val_acc: 83.91%, best_acc: 83.91%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52393818, tr_acc: 87.50%, val_acc: 86.16%, best_acc: 86.16%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47042605, tr_acc: 84.38%, val_acc: 87.46%, best_acc: 87.46%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43759048, tr_acc: 93.75%, val_acc: 88.30%, best_acc: 88.30%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41459257, tr_acc: 87.50%, val_acc: 88.98%, best_acc: 88.98%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39693732, tr_acc: 75.00%, val_acc: 89.42%, best_acc: 89.42%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38210047, tr_acc: 90.62%, val_acc: 89.71%, best_acc: 89.71%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.36995867, tr_acc: 90.62%, val_acc: 89.96%, best_acc: 89.96%, goat_acc: 90.10%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36022458, tr_acc: 84.38%, val_acc: 90.19%, best_acc: 90.19%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 8/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.26094463, tr_acc: 90.62%, val_acc: 76.49%, best_acc: 76.49%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.66638913, tr_acc: 87.50%, val_acc: 82.86%, best_acc: 82.86%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.54311105, tr_acc: 84.38%, val_acc: 85.65%, best_acc: 85.65%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.48456727, tr_acc: 90.62%, val_acc: 86.92%, best_acc: 86.92%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.44962009, tr_acc: 93.75%, val_acc: 87.71%, best_acc: 87.71%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.42579902, tr_acc: 84.38%, val_acc: 88.33%, best_acc: 88.33%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.40686676, tr_acc: 84.38%, val_acc: 88.66%, best_acc: 88.66%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.39152730, tr_acc: 87.50%, val_acc: 89.00%, best_acc: 89.00%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.37970034, tr_acc: 81.25%, val_acc: 89.24%, best_acc: 89.24%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.36923896, tr_acc: 90.62%, val_acc: 89.56%, best_acc: 89.56%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 9/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.20640371, tr_acc: 65.62%, val_acc: 77.69%, best_acc: 77.69%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.61551860, tr_acc: 90.62%, val_acc: 84.04%, best_acc: 84.04%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.50785002, tr_acc: 84.38%, val_acc: 86.18%, best_acc: 86.18%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.45637870, tr_acc: 84.38%, val_acc: 87.17%, best_acc: 87.17%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.42557299, tr_acc: 100.00%, val_acc: 87.96%, best_acc: 87.96%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.40431859, tr_acc: 84.38%, val_acc: 88.58%, best_acc: 88.58%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.38774732, tr_acc: 87.50%, val_acc: 89.06%, best_acc: 89.06%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.37436060, tr_acc: 90.62%, val_acc: 89.26%, best_acc: 89.26%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.36272197, tr_acc: 75.00%, val_acc: 89.59%, best_acc: 89.59%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.35308273, tr_acc: 96.88%, val_acc: 89.84%, best_acc: 89.84%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
#
# Hyper Run Time : 10/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.27216437, tr_acc: 84.38%, val_acc: 77.64%, best_acc: 77.64%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 2/10, Loss: 0.64969386, tr_acc: 71.88%, val_acc: 83.46%, best_acc: 83.46%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 3/10, Loss: 0.52971082, tr_acc: 87.50%, val_acc: 85.89%, best_acc: 85.89%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 4/10, Loss: 0.47257811, tr_acc: 84.38%, val_acc: 87.41%, best_acc: 87.41%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 5/10, Loss: 0.43755841, tr_acc: 90.62%, val_acc: 88.30%, best_acc: 88.30%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 6/10, Loss: 0.41348980, tr_acc: 75.00%, val_acc: 88.87%, best_acc: 88.87%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 7/10, Loss: 0.39491021, tr_acc: 78.12%, val_acc: 89.04%, best_acc: 89.04%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 8/10, Loss: 0.38040457, tr_acc: 90.62%, val_acc: 89.38%, best_acc: 89.38%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 9/10, Loss: 0.36784630, tr_acc: 100.00%, val_acc: 89.71%, best_acc: 89.71%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
# Epoch 10/10, Loss: 0.35760703, tr_acc: 96.88%, val_acc: 89.84%, best_acc: 89.84%, goat_acc: 90.19%, v_reset: 10000.0, BPTT_on: True
#
#
#
#  10000.0 False
#
#
#
#
# Hyper Run Time : 1/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.40558670, tr_acc: 71.88%, val_acc: 74.29%, best_acc: 74.29%, goat_acc: 74.29%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69821459, tr_acc: 71.88%, val_acc: 81.97%, best_acc: 81.97%, goat_acc: 81.97%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.55781693, tr_acc: 93.75%, val_acc: 85.09%, best_acc: 85.09%, goat_acc: 85.09%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49252395, tr_acc: 87.50%, val_acc: 86.49%, best_acc: 86.49%, goat_acc: 86.49%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45326982, tr_acc: 84.38%, val_acc: 87.45%, best_acc: 87.45%, goat_acc: 87.45%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42598860, tr_acc: 84.38%, val_acc: 88.13%, best_acc: 88.13%, goat_acc: 88.13%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40520908, tr_acc: 93.75%, val_acc: 88.50%, best_acc: 88.50%, goat_acc: 88.50%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38878407, tr_acc: 78.12%, val_acc: 89.02%, best_acc: 89.02%, goat_acc: 89.02%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37600043, tr_acc: 90.62%, val_acc: 89.48%, best_acc: 89.48%, goat_acc: 89.48%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36499876, tr_acc: 81.25%, val_acc: 89.74%, best_acc: 89.74%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 2/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.43822555, tr_acc: 78.12%, val_acc: 74.09%, best_acc: 74.09%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.71907980, tr_acc: 75.00%, val_acc: 81.66%, best_acc: 81.66%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57737591, tr_acc: 68.75%, val_acc: 84.22%, best_acc: 84.22%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.51119761, tr_acc: 90.62%, val_acc: 85.76%, best_acc: 85.76%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.47125179, tr_acc: 93.75%, val_acc: 86.66%, best_acc: 86.66%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.44328274, tr_acc: 87.50%, val_acc: 87.48%, best_acc: 87.48%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.42250132, tr_acc: 84.38%, val_acc: 88.09%, best_acc: 88.09%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.40566066, tr_acc: 81.25%, val_acc: 88.31%, best_acc: 88.31%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.39182702, tr_acc: 78.12%, val_acc: 88.59%, best_acc: 88.59%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.38075502, tr_acc: 90.62%, val_acc: 89.17%, best_acc: 89.17%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 3/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.37232433, tr_acc: 71.88%, val_acc: 74.66%, best_acc: 74.66%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.71315613, tr_acc: 87.50%, val_acc: 81.40%, best_acc: 81.40%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57544967, tr_acc: 90.62%, val_acc: 83.93%, best_acc: 83.93%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50942392, tr_acc: 71.88%, val_acc: 85.80%, best_acc: 85.80%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46844119, tr_acc: 84.38%, val_acc: 86.55%, best_acc: 86.55%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43902130, tr_acc: 84.38%, val_acc: 87.38%, best_acc: 87.38%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41816911, tr_acc: 81.25%, val_acc: 88.13%, best_acc: 88.13%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.40113764, tr_acc: 96.88%, val_acc: 88.51%, best_acc: 88.51%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38727764, tr_acc: 68.75%, val_acc: 89.05%, best_acc: 89.05%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37523391, tr_acc: 84.38%, val_acc: 89.38%, best_acc: 89.38%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 4/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.39110737, tr_acc: 75.00%, val_acc: 74.70%, best_acc: 74.70%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.71662175, tr_acc: 78.12%, val_acc: 82.04%, best_acc: 82.04%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57499451, tr_acc: 75.00%, val_acc: 84.53%, best_acc: 84.53%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50625627, tr_acc: 90.62%, val_acc: 86.25%, best_acc: 86.25%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46444413, tr_acc: 93.75%, val_acc: 87.19%, best_acc: 87.19%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43538235, tr_acc: 90.62%, val_acc: 87.78%, best_acc: 87.78%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41357796, tr_acc: 87.50%, val_acc: 88.56%, best_acc: 88.56%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39594992, tr_acc: 90.62%, val_acc: 88.80%, best_acc: 88.80%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38210690, tr_acc: 84.38%, val_acc: 89.07%, best_acc: 89.07%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36991154, tr_acc: 96.88%, val_acc: 89.59%, best_acc: 89.59%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 5/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.42336950, tr_acc: 68.75%, val_acc: 75.17%, best_acc: 75.17%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.70275138, tr_acc: 84.38%, val_acc: 82.01%, best_acc: 82.01%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56489240, tr_acc: 78.12%, val_acc: 84.70%, best_acc: 84.70%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49856766, tr_acc: 93.75%, val_acc: 86.39%, best_acc: 86.39%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45855345, tr_acc: 84.38%, val_acc: 87.35%, best_acc: 87.35%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43025567, tr_acc: 78.12%, val_acc: 88.05%, best_acc: 88.05%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40855850, tr_acc: 90.62%, val_acc: 88.74%, best_acc: 88.74%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39148998, tr_acc: 87.50%, val_acc: 89.23%, best_acc: 89.23%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37748059, tr_acc: 90.62%, val_acc: 89.61%, best_acc: 89.61%, goat_acc: 89.74%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36546121, tr_acc: 90.62%, val_acc: 89.93%, best_acc: 89.93%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 6/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.32692474, tr_acc: 84.38%, val_acc: 75.17%, best_acc: 75.17%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69349227, tr_acc: 81.25%, val_acc: 81.98%, best_acc: 81.98%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.56324673, tr_acc: 93.75%, val_acc: 84.67%, best_acc: 84.67%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.50077008, tr_acc: 90.62%, val_acc: 86.21%, best_acc: 86.21%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46139019, tr_acc: 93.75%, val_acc: 87.02%, best_acc: 87.02%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.43380587, tr_acc: 93.75%, val_acc: 87.78%, best_acc: 87.78%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41252901, tr_acc: 90.62%, val_acc: 88.22%, best_acc: 88.22%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39590616, tr_acc: 96.88%, val_acc: 88.81%, best_acc: 88.81%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38185486, tr_acc: 93.75%, val_acc: 89.33%, best_acc: 89.33%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36995741, tr_acc: 93.75%, val_acc: 89.44%, best_acc: 89.44%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 7/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.46406511, tr_acc: 81.25%, val_acc: 73.96%, best_acc: 73.96%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.73885857, tr_acc: 84.38%, val_acc: 81.46%, best_acc: 81.46%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.58498597, tr_acc: 78.12%, val_acc: 84.38%, best_acc: 84.38%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.51369424, tr_acc: 84.38%, val_acc: 85.87%, best_acc: 85.87%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.47084271, tr_acc: 75.00%, val_acc: 86.80%, best_acc: 86.80%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.44149287, tr_acc: 81.25%, val_acc: 87.74%, best_acc: 87.74%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41878089, tr_acc: 84.38%, val_acc: 88.19%, best_acc: 88.19%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.40110915, tr_acc: 93.75%, val_acc: 88.68%, best_acc: 88.68%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38698690, tr_acc: 84.38%, val_acc: 89.04%, best_acc: 89.04%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37484855, tr_acc: 84.38%, val_acc: 89.47%, best_acc: 89.47%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 8/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.36296719, tr_acc: 75.00%, val_acc: 75.14%, best_acc: 75.14%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.69140280, tr_acc: 81.25%, val_acc: 82.39%, best_acc: 82.39%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.55523507, tr_acc: 90.62%, val_acc: 85.24%, best_acc: 85.24%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.49111065, tr_acc: 87.50%, val_acc: 86.61%, best_acc: 86.61%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.45228930, tr_acc: 78.12%, val_acc: 87.20%, best_acc: 87.20%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.42548501, tr_acc: 78.12%, val_acc: 87.85%, best_acc: 87.85%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.40515182, tr_acc: 84.38%, val_acc: 88.43%, best_acc: 88.43%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.38919894, tr_acc: 93.75%, val_acc: 88.91%, best_acc: 88.91%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.37597038, tr_acc: 84.38%, val_acc: 89.23%, best_acc: 89.23%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.36473676, tr_acc: 93.75%, val_acc: 89.55%, best_acc: 89.55%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 9/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.50453923, tr_acc: 81.25%, val_acc: 73.22%, best_acc: 73.22%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.72485887, tr_acc: 81.25%, val_acc: 81.49%, best_acc: 81.49%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.57838645, tr_acc: 78.12%, val_acc: 84.31%, best_acc: 84.31%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.51021587, tr_acc: 87.50%, val_acc: 86.15%, best_acc: 86.15%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.46960480, tr_acc: 90.62%, val_acc: 87.06%, best_acc: 87.06%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.44118298, tr_acc: 90.62%, val_acc: 87.63%, best_acc: 87.63%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41987491, tr_acc: 84.38%, val_acc: 88.06%, best_acc: 88.06%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.40275639, tr_acc: 90.62%, val_acc: 88.51%, best_acc: 88.51%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38873190, tr_acc: 96.88%, val_acc: 88.95%, best_acc: 88.95%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37684625, tr_acc: 78.12%, val_acc: 89.37%, best_acc: 89.37%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
#
# Hyper Run Time : 10/10
#
#
# SNN(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (lif1): LIF_layer()
#   (fc2): Linear(in_features=200, out_features=10, bias=True)
# )
# Training Start...
# Epoch 1/10, Loss: 1.42940910, tr_acc: 62.50%, val_acc: 73.60%, best_acc: 73.60%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 2/10, Loss: 0.73957379, tr_acc: 81.25%, val_acc: 81.42%, best_acc: 81.42%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 3/10, Loss: 0.58850827, tr_acc: 93.75%, val_acc: 84.12%, best_acc: 84.12%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 4/10, Loss: 0.51583551, tr_acc: 84.38%, val_acc: 86.01%, best_acc: 86.01%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 5/10, Loss: 0.47160481, tr_acc: 90.62%, val_acc: 86.87%, best_acc: 86.87%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 6/10, Loss: 0.44101471, tr_acc: 87.50%, val_acc: 87.85%, best_acc: 87.85%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 7/10, Loss: 0.41748394, tr_acc: 87.50%, val_acc: 88.34%, best_acc: 88.34%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 8/10, Loss: 0.39927595, tr_acc: 93.75%, val_acc: 88.95%, best_acc: 88.95%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 9/10, Loss: 0.38432231, tr_acc: 87.50%, val_acc: 89.35%, best_acc: 89.35%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
# Epoch 10/10, Loss: 0.37169757, tr_acc: 90.62%, val_acc: 89.54%, best_acc: 89.54%, goat_acc: 89.93%, v_reset: 10000.0, BPTT_on: False
