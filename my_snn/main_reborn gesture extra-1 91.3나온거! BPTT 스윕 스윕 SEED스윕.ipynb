# %%
import sys
import os
import argparse
import torch
import torch.nn as nn 
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import time

from snntorch import spikegen
import matplotlib.pyplot as plt
import snntorch.spikeplot as splt
from IPython.display import HTML

from tqdm import tqdm

from apex.parallel import DistributedDataParallel as DDP

import random
import datetime

import json

from sklearn.utils import shuffle

''' 레퍼런스
https://spikingjelly.readthedocs.io/zh-cn/0.0.0.0.4/spikingjelly.datasets.html#module-spikingjelly.datasets
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/datasets.py
https://github.com/GorkaAbad/Sneaky-Spikes/blob/main/how_to.md
https://github.com/nmi-lab/torchneuromorphic
https://snntorch.readthedocs.io/en/latest/snntorch.spikevision.spikedata.html#shd
'''

import snntorch
from snntorch.spikevision import spikedata

import modules.spikingjelly;
from modules.spikingjelly.datasets.dvs128_gesture import DVS128Gesture
from modules.spikingjelly.datasets.cifar10_dvs import CIFAR10DVS
from modules.spikingjelly.datasets.n_mnist import NMNIST
# from modules.spikingjelly.datasets.es_imagenet import ESImageNet
from modules.spikingjelly.datasets import split_to_train_test_set
from modules.spikingjelly.datasets.n_caltech101 import NCaltech101
from modules.spikingjelly.datasets import pad_sequence_collate, padded_sequence_mask

import modules.torchneuromorphic as torchneuromorphic

import wandb

from torchviz import make_dot
import graphviz
from turtle import shape
# Out:
# /tmp/ipykernel_4000/3748606120.py:46: DeprecationWarning: The module snntorch.spikevision is deprecated. For loading neuromorphic datasets, we recommend using the Tonic project: https://github.com/neuromorphs/tonic
#   from snntorch.spikevision import spikedata

# %%
# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
from matplotlib.ft2font import EXTERNAL_STREAM


def my_snn_system(devices = "0,1,2,3",
                    single_step = False, # True # False
                    unique_name = 'main',
                    my_seed = 42,
                    TIME = 10,
                    BATCH = 256,
                    IMAGE_SIZE = 32,
                    which_data = 'CIFAR10',
                    # CLASS_NUM = 10,
                    data_path = '/data2',
                    rate_coding = True,
    
                    lif_layer_v_init = 0.0,
                    lif_layer_v_decay = 0.6,
                    lif_layer_v_threshold = 1.2,
                    lif_layer_v_reset = 0.0,
                    lif_layer_sg_width = 1,

                    # synapse_conv_in_channels = IMAGE_PIXEL_CHANNEL,
                    synapse_conv_kernel_size = 3,
                    synapse_conv_stride = 1,
                    synapse_conv_padding = 1,

                    synapse_trace_const1 = 1,
                    synapse_trace_const2 = 0.6,

                    # synapse_fc_out_features = CLASS_NUM,

                    pre_trained = False,
                    convTrue_fcFalse = True,

                    cfg = [64, 64],
                    net_print = False, # True # False
                    
                    pre_trained_path = "net_save/save_now_net.pth",
                    learning_rate = 0.0001,
                    epoch_num = 200,
                    tdBN_on = False,
                    BN_on = False,

                    surrogate = 'sigmoid',

                    BPTT_on = False,

                    optimizer_what = 'SGD', # 'SGD' 'Adam', 'RMSprop'
                    scheduler_name = 'no',
                    
                    ddp_on = False, # DECREPATED # fALSE

                    dvs_clipping = 1, 
                    dvs_duration = 25_000,


                    DFA_on = False, # True # False
                    trace_on = False, 
                    OTTT_input_trace_on = False, # True # False
                    
                    exclude_class = True, # True # False # gesture에서 10번째 클래스 제외

                    merge_polarities = False, # True # False # tonic dvs dataset 에서 polarities 합치기
                    denoise_on = True, 

                    extra_train_dataset = 0, # DECREPATED # data_loader에서 train dataset을 몇개 더 쓸건지 

                    num_workers = 2,
                    chaching_on = True,
                    pin_memory = True, # True # False
                    
                    UDA_on = False,  # DECREPATED # uda
                    alpha_uda = 1.0, # DECREPATED # uda

                    bias = True,

                    last_lif = False,
                        
                    temporal_filter = 1, 
                    initial_pooling = 1,

                    temporal_filter_accumulation = False,

                    quantize_bit_list=[],
                    scale_exp=[],
                    lif_layer_sg_width2 = None,
                    lif_layer_v_threshold2 = None,
                    learning_rate2 = None,
                    init_scaling = None,
                    learning_rate3 = None,
                    ):
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print('param', hyperparameters,'\n')
    hyperparameters['current epoch'] = 0
    ######################################################################################

    ## hyperparameter check #############################################################
    if single_step == True:
        assert BPTT_on == False and tdBN_on == False 
    if tdBN_on == True:
        assert BPTT_on == True
    if pre_trained == True:
        print('\n\n')
        print("Caution! pre_trained is True\n\n"*3)    
    if DFA_on == True:
        assert single_step == True and BPTT_on == False 
    # assert single_step == DFA_on, 'DFA랑 single_step공존하게해라'
    if trace_on:
        assert BPTT_on == False and single_step == True
    if OTTT_input_trace_on == True:
        assert BPTT_on == False and single_step == True #and trace_on == True
    if temporal_filter > 1:
        assert convTrue_fcFalse == False
    ######################################################################################


    

    ## wandb 세팅 ###################################################################
    current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    wandb.config.update(hyperparameters)
    wandb.run.name = f'lr_{learning_rate}_{unique_name}_{which_data}_tstep{TIME}'
    wandb.define_metric("summary_val_acc", summary="max")
    # wandb.run.log_code(".", 
    #                     include_fn=lambda path: path.endswith(".py") or path.endswith(".ipynb"),
    #                     exclude_fn=lambda path: 'logs/' in path or 'net_save/' in path or 'result_save/' in path or 'trying/' in path or 'wandb/' in path or 'private/' in path or '.git/' in path or 'tonic' in path or 'torchneuromorphic' in path or 'spikingjelly' in path 
    #                     )
    ###################################################################################



    ## gpu setting ##################################################################################################################
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= devices
    ###################################################################################################################################


    ## seed setting ##################################################################################################################
    seed_assign(my_seed)
    ###################################################################################################################################
    

    ## data_loader 가져오기 ##################################################################################################################
    # data loader, pixel channel, class num
    train_data_split_indices = []
    train_loader, test_loader, synapse_conv_in_channels, CLASS_NUM, train_data_count = data_loader(
            which_data,
            data_path, 
            rate_coding, 
            BATCH, 
            IMAGE_SIZE,
            ddp_on,
            TIME*temporal_filter, 
            dvs_clipping,
            dvs_duration,
            exclude_class,
            merge_polarities,
            denoise_on,
            my_seed,
            extra_train_dataset,
            num_workers,
            chaching_on,
            pin_memory,
            train_data_split_indices,) 
    synapse_fc_out_features = CLASS_NUM

    print('\nlen(train_loader):', len(train_loader), 'BATCH:', BATCH, 'train_data_count:', train_data_count) 
    print('len(test_loader):', len(test_loader), 'BATCH:', BATCH)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"\ndevice ==> {device}\n")
    if device == "cpu":
        print("="*50,"\n[WARNING]\n[WARNING]\n[WARNING]\n: cpu mode\n\n","="*50)

    ### network setting #######################################################################################################################
    if (convTrue_fcFalse == False):
        net = REBORN_MY_SNN_FC(cfg, synapse_conv_in_channels*temporal_filter, IMAGE_SIZE//initial_pooling, synapse_fc_out_features,
                    synapse_trace_const1, synapse_trace_const2, 
                    lif_layer_v_init, lif_layer_v_decay, 
                    lif_layer_v_threshold, lif_layer_v_reset,
                    lif_layer_sg_width,
                    tdBN_on,
                    BN_on, TIME,
                    surrogate,
                    BPTT_on,
                    DFA_on,
                    bias,
                    single_step,
                    last_lif,
                    trace_on,
                    quantize_bit_list,
                    scale_exp,
                    ANPI_MODE=False,
                    lif_layer_sg_width2=lif_layer_sg_width2,
                    lif_layer_v_threshold2=lif_layer_v_threshold2,
                    init_scaling=init_scaling).to(device)
    else:
        net = REBORN_MY_SNN_CONV(cfg, synapse_conv_in_channels, IMAGE_SIZE//initial_pooling,
                    synapse_conv_kernel_size, synapse_conv_stride, 
                    synapse_conv_padding, synapse_trace_const1, 
                    synapse_trace_const2, 
                    lif_layer_v_init, lif_layer_v_decay, 
                    lif_layer_v_threshold, lif_layer_v_reset,
                    lif_layer_sg_width,
                    synapse_fc_out_features, 
                    tdBN_on,
                    BN_on, TIME,
                    surrogate,
                    BPTT_on,
                    DFA_on,
                    bias,
                    single_step,
                    last_lif,
                    trace_on,
                    quantize_bit_list,
                    scale_exp).to(device)

    net = torch.nn.DataParallel(net) 
    
    if pre_trained == True:
        # 1. 전체 state_dict 로드
        checkpoint = torch.load(pre_trained_path)

        # 2. 현재 모델의 state_dict 가져오기
        model_dict = net.state_dict()

        # 3. 'SYNAPSE'가 포함된 key만 필터링 (현재 모델에도 존재하는 key만)
        filtered_dict = {k: v for k, v in checkpoint.items() if ('weight' in k or 'bias' in k) and k in model_dict}

        # 4. 업데이트된 키 출력
        print("🔄 업데이트된 SYNAPSE 관련 레이어들:")
        for k in filtered_dict.keys():
            print(f" - {k}")

        # 5. 모델 dict 업데이트 및 로딩
        model_dict.update(filtered_dict)
        net.load_state_dict(model_dict)
    
    net = net.to(device)
    if (net_print == True):
        print(net)    

    print(f"\n========================================================\nTrainable parameters: {sum(p.numel() for p in net.parameters() if p.requires_grad):,}\n========================================================\n")
    ####################################################################################################################################
    

    ## wandb logging ###########################################
    # wandb.watch(net, log="all", log_freq = 10) #gradient, parameter logging해줌
    ############################################################

    ## criterion ########################################## # loss 구해주는 친구
    def my_cross_entropy_loss(logits, targets):
        # logits: (batch_size, num_classes)
        # targets: (batch_size,) -> 클래스 인덱스
        log_probs = F.log_softmax(logits, dim=1)  # log(p_i)
        loss = F.nll_loss(log_probs, targets)
        # print(loss.shape)
        return loss
    
    class CustomLossFunction(torch.autograd.Function):
        @staticmethod
        def forward(ctx, input, target):
            ctx.save_for_backward(input, target)
            return F.cross_entropy(input, target)

        @staticmethod
        def backward(ctx, grad_output):
            # MAE 스타일의 gradient를 흉내냄
            input, target = ctx.saved_tensors
            input_argmax = input.argmax(dim=1)
            input_one_hot = torch.zeros_like(input).scatter_(1, input_argmax.unsqueeze(1), 1.0)
            target_one_hot = torch.zeros_like(input).scatter_(1, target.unsqueeze(1), 1.0)

            # print('grad_output', grad_output) # 이거 걍 1.0임
            return input_one_hot - target_one_hot, None  # target에는 gradient 없음

    # Wrapper module
    class CustomCriterion(torch.nn.Module):
        def __init__(self):
            super().__init__()

        def forward(self, input, target):
            return CustomLossFunction.apply(input, target)

    # Wrapper module
    class CustomCriterionMSE(nn.Module):
        def __init__(self):
            super().__init__()

        def forward(self, input, target):
            # return CustomCriterion_mseloss.apply(input, target)

            # target을 one-hot 벡터로 변환
            target_one_hot = torch.zeros_like(input)
            target_one_hot.scatter_(1, target.unsqueeze(1), 1.0)

            # MSE 계산
            loss = F.mse_loss(input, target_one_hot, reduction='mean')
            # print(f'input {input}', f'target_one_hot {target_one_hot}', f'loss {loss}')
            return loss

    # criterion = nn.CrossEntropyLoss().to(device)
    # criterion = CustomCriterion().to(device)
    criterion = CustomCriterionMSE().to(device)
    
    # if (OTTT_sWS_on == True):
    #     # criterion = nn.CrossEntropyLoss().to(device)
        # criterion = lambda y_t, target_t: ((1 - 0.05) * F.cross_entropy(y_t, target_t) + 0.05 * F.mse_loss(y_t, F.one_hot(target_t, CLASS_NUM).float())) / TIME 
    #     if which_data == 'DVS_GESTURE':
    #         criterion = lambda y_t, target_t: ((1 - 0.001) * F.cross_entropy(y_t, target_t) + 0.001 * F.mse_loss(y_t, F.one_hot(target_t, CLASS_NUM).float())) / TIME 
    ####################################################

    ## optimizer, scheduler ########################################################################
    class MySGD(torch.optim.Optimizer):
        def __init__(self, params, lr=0.01, momentum=0.0, quantize_bit_list=[], scale_exp=[], net=None):
            if momentum < 0.0 or momentum >= 1.0:
                raise ValueError(f"Invalid momentum value: {momentum}")
            
            defaults = {'lr': lr, 'momentum': momentum}
            super(MySGD, self).__init__(params, defaults)
            self.step_count = 0
            self.quantize_bit_list = quantize_bit_list
            # self.quantize_bit_list = []
            self.scale_exp = scale_exp
            self.param_to_name = {param: name for name, param in net.module.named_parameters()} if net else {}

        @torch.no_grad()
        def step(self):
            """모든 파라미터에 대해 gradient descent 수행"""
            loss = None
            for group in self.param_groups:
                # lr = group['lr']

                momentum = group['momentum']
                for param in group['params']:
                    if param.grad is None:
                        continue
                    name = self.param_to_name.get(param, 'unknown')

                    if 'layers.1.fc.weight' in name:
                        lr = learning_rate
                        assert learning_rate != None
                    elif 'layers.3.fc.weight' in name:
                        lr = learning_rate2
                        assert learning_rate2 != None
                    elif 'layers.5.fc.weight' in name:
                        # lr = 1.0
                        lr = learning_rate3
                        assert learning_rate3 != None

                    # gradient를 이용해 파라미터 업데이트
                    d_p = param.grad

                    if momentum > 0.0:
                        assert False
                        param_state = self.state[param]
                        if 'momentum_buffer' not in param_state:
                            # momentum buffer 초기화
                            buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
                        else:
                            buf = param_state['momentum_buffer']
                            buf.mul_(momentum).add_(d_p)
                            # buf *= momentum 
                            # buf += d_p
                        d_p = buf

                    dw = -lr*d_p
                    param.add_(dw)
            return loss
    
    if(optimizer_what == 'SGD'):
        optimizer = MySGD(net.parameters(), lr=learning_rate, momentum=0.0, quantize_bit_list=quantize_bit_list, scale_exp=scale_exp, net=net)
        # optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.0)
        print(optimizer)
    elif(optimizer_what == 'Adam'):
        optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
        # optimizer = torch.optim.Adam(net.parameters(), lr=0.00001)
        # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate/256 * BATCH, weight_decay=1e-4)
        # optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=0, betas=(0.9, 0.999))
    elif(optimizer_what == 'RMSprop'):
        pass


    if (scheduler_name == 'StepLR'):
        scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    elif (scheduler_name == 'ExponentialLR'):
        scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
    elif (scheduler_name == 'ReduceLROnPlateau'):
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10)
    elif (scheduler_name == 'CosineAnnealingLR'):
        # scheduler = lr_scheduler.CosineAnnealingLR(optimizer, eta_min=0, T_max=50)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=0, T_max=epoch_num)
    elif (scheduler_name == 'OneCycleLR'):
        scheduler = lr_scheduler.OneCycleLR(optimizer, max_lr=0.1, steps_per_epoch=len(train_loader), epochs=epoch_num)
    else:
        pass # 'no' scheduler
    ## optimizer, scheduler ########################################################################


    tr_acc = 0
    tr_correct = 0
    tr_total = 0
    tr_acc_best = 0
    tr_epoch_loss_temp = 0
    tr_epoch_loss = 0
    val_acc_best = 0
    val_acc_now = 0
    val_loss = 0
    iter_of_val = False
    total_backward_count = 0
    real_backward_count = 0
    #======== EPOCH START ==========================================================================================
    for epoch in range(epoch_num):
        epoch_start_time = time.time()
        print('total_backward_count', total_backward_count, 'real_backward_count',real_backward_count, f'{100*real_backward_count/(total_backward_count+0.00000001):7.3f}%')
        if epoch == 1:
            for name, module in net.named_modules():
                if isinstance(module, Feedback_Receiver):
                    print(f"[{name}] weight_fb parameter count: {module.weight_fb.numel():,}")

        max_val_box = []
        max_val_scale_exp_8bit_box = []
        max_val_scale_exp_16bit_box = []
        perc_95_box = []
        perc_95_scale_exp_8bit_box = []
        perc_95_scale_exp_16bit_box = []
        perc_99_box = []
        perc_99_scale_exp_8bit_box = []
        perc_99_scale_exp_16bit_box = []
        perc_999_box = []
        perc_999_scale_exp_8bit_box = []
        perc_999_scale_exp_16bit_box = []
        ##### weight 프린트 ######################################################################
        for name, param in net.module.named_parameters():
            if ('weight' in name or 'bias' in name) and ('1' in name or '3' in name or '5' in name):
                data = param.detach().cpu().numpy().flatten()
                abs_data = np.abs(data)

                # 통계량 계산
                mean = np.mean(data)
                std = np.std(data)
                abs_mean = np.mean(abs_data)
                abs_std = np.std(abs_data)
                eps = 1e-15

                # 절대값 기반 max, percentiles
                max_val = abs_data.max()
                print(name, f'epoch {epoch}: mean={mean:.4f}, std={std:.4f}, |mean|={abs_mean:.4f}, |std|={abs_std:.4f}, max={max_val:.4f}')
                max_val_scale_exp_8bit = math.ceil(math.log2((eps+max_val)/ (2**(8-1) -1)))
                max_val_scale_exp_16bit = math.ceil(math.log2((eps+max_val)/ (2**(16-1) -1)))
                perc_95 = np.percentile(abs_data, 95)
                perc_95_scale_exp_8bit = math.ceil(math.log2((eps+perc_95)/ (2**(8-1) -1)))
                perc_95_scale_exp_16bit = math.ceil(math.log2((eps+perc_95)/ (2**(16-1) -1)))
                perc_99 = np.percentile(abs_data, 99)
                perc_99_scale_exp_8bit = math.ceil(math.log2((eps+perc_99)/ (2**(8-1) -1)))
                perc_99_scale_exp_16bit = math.ceil(math.log2((eps+perc_99)/ (2**(16-1) -1)))
                perc_999 = np.percentile(abs_data, 99.9)
                perc_999_scale_exp_8bit = math.ceil(math.log2((eps+perc_999)/ (2**(8-1) -1)))
                perc_999_scale_exp_16bit = math.ceil(math.log2((eps+perc_999)/ (2**(16-1) -1)))
                
                max_val_box.append(max_val)
                max_val_scale_exp_8bit_box.append(max_val_scale_exp_8bit)
                max_val_scale_exp_16bit_box.append(max_val_scale_exp_16bit)
                perc_95_box.append(perc_95)
                perc_95_scale_exp_8bit_box.append(perc_95_scale_exp_8bit)
                perc_95_scale_exp_16bit_box.append(perc_95_scale_exp_16bit)
                perc_99_box.append(perc_99)
                perc_99_scale_exp_8bit_box.append(perc_99_scale_exp_8bit)
                perc_99_scale_exp_16bit_box.append(perc_99_scale_exp_16bit)
                perc_999_box.append(perc_999)
                perc_999_scale_exp_8bit_box.append(perc_999_scale_exp_8bit)
                perc_999_scale_exp_16bit_box.append(perc_999_scale_exp_16bit)




                # if epoch % 5 == 0 or epoch < 3:
                #     print("=> Plotting weight and bias distributions...")
                #     # 그래프 그리기
                #     plt.figure(figsize=(6, 4))
                #     plt.hist(data, bins=100, alpha=0.7, color='skyblue')
                #     plt.axvline(x=max_val, color='red', linestyle='--', label=f'Max: {max_val:.4f}')
                #     plt.axvline(x=-max_val, color='red', linestyle='--')
                #     plt.axvline(x=perc_95, color='green', linestyle='--', label=f'95%: {perc_95:.4f}')
                #     plt.axvline(x=-perc_95, color='green', linestyle='--')
                #     plt.axvline(x=perc_99, color='orange', linestyle='--', label=f'99%: {perc_99:.4f}')
                #     plt.axvline(x=-perc_99, color='orange', linestyle='--')
                #     plt.axvline(x=perc_999, color='purple', linestyle='--', label=f'99.9%: {perc_999:.4f}')
                #     plt.axvline(x=-perc_999, color='purple', linestyle='--')
                    
                #     # 제목에 통계값 포함
                #     title = (
                #         f"{name}, Epoch {epoch}\n"
                #         f"mean={mean:.4f}, std={std:.4f}, "
                #         f"|mean|={abs_mean:.4f}, |std|={abs_std:.4f}\n"
                #         f"Scale 8bit max = { max_val_scale_exp_8bit}, "
                #         f"Scale 16bit max = {max_val_scale_exp_16bit}\n"
                #         f"Scale 8bit p999 = {perc_999_scale_exp_8bit }, "
                #         f"Scale 16bit p999 = {perc_999_scale_exp_16bit }\n"
                #         f"Scale 8bit p99 = {perc_99_scale_exp_8bit }, "
                #         f"Scale 16bit p99 = { perc_99_scale_exp_16bit}\n"
                #         f"Scale 8bit p95 = { perc_95_scale_exp_8bit}, "
                #         f"Scale 16bit p95 = { perc_95_scale_exp_16bit}"
                #     )
                #     plt.title(title)
                #     plt.xlabel('Value')
                #     plt.ylabel('Frequency')
                #     plt.grid(True)
                #     plt.legend()
                #     plt.tight_layout()
                #     plt.show()
        ##### weight 프린트 ######################################################################

        ####### iterator : input_loading & tqdm을 통한 progress_bar 생성###################
        iterator = enumerate(train_loader, 0)
        # iterator = tqdm(iterator, total=len(train_loader), desc='train', dynamic_ncols=True, position=0, leave=True)
        ##################################################################################   

        ###### ITERATION START ##########################################################################################################
        for i, data in iterator:
            net.train() # train 모드로 바꿔줘야함
            ### data loading & semi-pre-processing ################################################################################
            if len(data) == 2:
                inputs, labels = data
                # 처리 로직 작성
            elif len(data) == 3:
                inputs, labels, x_len = data
            else:
                assert False, 'data length is not 2 or 3'
            #######################################################################################################################
            if extra_train_dataset == -1:
                # print(inputs.shape)
                assert BATCH == 1
                now_T = inputs.shape[1]
                now_time_steps = temporal_filter*TIME
                # start_idx = random.randint(0, now_T - now_time_steps)
                start_idx = random.choice(range(0, now_T - now_time_steps + 1, now_time_steps))
                # start_idx = random.choice([i for i in range(0, now_T - now_time_steps + 1, now_time_steps)])
                inputs = inputs[:, start_idx : start_idx + now_time_steps]
                if dvs_clipping != 0:
                    inputs[inputs<dvs_clipping] = 0.0
                    inputs[inputs>=dvs_clipping] = 1.0
            ## batch 크기 ######################################
            real_batch = labels.size(0)
            ###########################################################

            # 차원 전처리
            ###########################################################################################################################        
            if (which_data == 'DVS_CIFAR10' or which_data == 'DVS_GESTURE' or which_data == 'DVS_GESTURE_TONIC' or which_data == 'DVS_CIFAR10_2' or which_data == 'NMNIST' or which_data == 'NMNIST_TONIC' or which_data == 'N_CALTECH101' or which_data == 'n_tidigits' or which_data == 'heidelberg'):
                inputs = inputs.permute(1, 0, 2, 3, 4)
            elif rate_coding == True :
                inputs = spikegen.rate(inputs, num_steps=TIME)
            else :
                inputs = inputs.repeat(TIME, 1, 1, 1, 1)
            # inputs: [Time, Batch, Channel, Height, Width]  
            ####################################################################################################################### 
                
            # if i % 1000 == 999:
            #     # SYNAPSE_FC에 있는 sparsity_print_and_reset() 실행
            #     for name, module in net.module.named_modules():
            #         if isinstance(module, SYNAPSE_FC):
            #             module.sparsity_print_and_reset()

                            
            ## initial pooling #######################################################################
            if (initial_pooling > 1):
                pool = nn.MaxPool2d(kernel_size=2)
                num_pooling_layers = int(math.log2(initial_pooling))
                # Time, Batch, Channel 차원은 그대로 두고, Height, Width 차원에 대해서만 pooling 적용
                shape_temp = inputs.shape
                inputs = inputs.reshape(shape_temp[0]*shape_temp[1], shape_temp[2], shape_temp[3], shape_temp[4])
                for _ in range(num_pooling_layers):
                    inputs = pool(inputs)
                inputs = inputs.reshape(shape_temp[0], shape_temp[1], shape_temp[2], shape_temp[3]//initial_pooling, shape_temp[4]//initial_pooling)
            ## initial pooling #######################################################################
            ## temporal filtering ####################################################################
            shape_temp = inputs.shape
            if (temporal_filter > 1):
                slice_bucket = []
                for t_temp in range(TIME):
                    start = t_temp * temporal_filter
                    end = start + temporal_filter
                    slice_concat = torch.movedim(inputs[start:end], 0, -2).reshape(shape_temp[1],shape_temp[2],shape_temp[3],-1)
                    
                    if temporal_filter_accumulation == True:
                        if t_temp == 0:
                            slice_bucket.append(slice_concat)
                        else:
                            slice_bucket.append(slice_concat+slice_bucket[t_temp-1])
                    else:
                        slice_bucket.append(slice_concat)

                inputs = torch.stack(slice_bucket, dim=0)
                if temporal_filter_accumulation == True and dvs_clipping > 0:
                    inputs = (inputs != 0.0).float()
            ## temporal filtering ####################################################################
            ####################################################################################################################### 
                

            # # dvs 데이터 시각화 코드 (확인 필요할 시 써라)
            # ##############################################################################################
            # dvs_visualization(inputs, labels, TIME, BATCH, my_seed)
            # #####################################################################################################

            ## to (device) #######################################
            inputs = inputs.to(device)
            labels = labels.to(device)
            ###########################################################

            # ## gradient 초기화 #######################################
            # optimizer.zero_grad()
            # ###########################################################
                            
            if merge_polarities == True:
                inputs = inputs[:,:,0:1,:,:]

            if single_step == False:
                # net에 넣어줄때는 batch가 젤 앞 차원으로 와야함. # dataparallel때매##############################
                # inputs: [Time, Batch, Channel, Height, Width]   
                inputs = inputs.permute(1, 0, 2, 3, 4) # net에 넣어줄때는 batch가 젤 앞 차원으로 와야함. # dataparallel때매
                # inputs: [Batch, Time, Channel, Height, Width] 
                #################################################################################################
            else:
                labels = labels.repeat(TIME, 1)
                ## first input도 ottt trace 적용하기 위한 코드 (validation 시에는 필요X) ##########################
                if trace_on == True and OTTT_input_trace_on == True:
                    spike = inputs
                    trace = torch.full_like(spike, fill_value = 0.0, dtype = torch.float, requires_grad=False)
                    inputs = []
                    for t in range(TIME):
                        trace[t] = trace[t-1]*synapse_trace_const2 + spike[t]*synapse_trace_const1
                        inputs += [[spike[t], trace[t]]]
                ##################################################################################################


            if single_step == False:
                optimizer.zero_grad()
                outputs = net(inputs)
                outputs = outputs.sum(dim=0)
                ##################################################################################
                ## loss, backward ##########################################
                iter_loss = criterion(outputs, labels)
                iter_loss.backward()
                ############################################################
                ## weight 업데이트!! ##################################
                optimizer.step()
                ################################################################
            else:
                outputs_all = []
                iter_loss = 0.0
                for t in range(TIME):
                    optimizer.step() # full step time update
                    optimizer.zero_grad()
                    ### input[t] --> net --> output_one_time #########################################
                    outputs_one_time = net(inputs[t])
                    ##################################################################################
                    one_time_loss = criterion(outputs_one_time, labels[t].contiguous())
                    one_time_loss.backward() # one_time backward
                    iter_loss += one_time_loss.data
                    outputs_all.append(outputs_one_time.detach())

                    total_backward_count = total_backward_count + 1
                    outputs_one_time_argmax = (outputs_one_time.detach()).argmax(dim=1)
                    real_backward_count = real_backward_count + (outputs_one_time_argmax != labels[t]).sum().item()


                outputs_all = torch.stack(outputs_all, dim=1)
                outputs = outputs_all.mean(1) # ottt꺼 쓸때
                labels = labels[0]
                iter_loss /= TIME

            tr_epoch_loss_temp += iter_loss.data/len(train_loader)

            ## net 그림 출력해보기 #################################################################
            # print('시각화')
            # make_dot(outputs, params=dict(list(net.named_parameters()))).render("net_torchviz", format="png")
            # return 0
            ##################################################################################

            #### batch 어긋남 방지 ###############################################
            assert real_batch == outputs.size(0), f'batch size is not same. real_batch: {real_batch}, outputs.size(0): {outputs.size(0)}'
            #######################################################################
            

            ####### training accruacy save for print ###############################
            _, predicted = torch.max(outputs.data, 1)
            total = real_batch
            correct = (predicted == labels).sum().item()
            iter_acc = correct / total
            tr_total += total
            tr_correct += correct
            iter_acc_string = f'epoch-{epoch:<3} iter_acc:{100 * iter_acc:7.2f}%, lr={[f"{lr:9.7f}" for lr in (param_group["lr"] for param_group in optimizer.param_groups)]}'
            iter_acc_string2 = f'epoch-{epoch:<3} lr={[f"{lr:9.7f}" for lr in (param_group["lr"] for param_group in optimizer.param_groups)]}'
            ################################################################
            

            ##### validation ##################################################################################################################################
            if i == len(train_loader)-1 :
                iter_of_val = True

                tr_acc = tr_correct/tr_total
                tr_correct = 0
                tr_total = 0

                val_loss = 0
                correct_val = 0
                total_val = 0

                with torch.no_grad():
                    net.eval() # eval 모드로 바꿔줘야함 
                    for data_val in test_loader:
                        ## data_val loading & semi-pre-processing ##########################################################
                        if len(data_val) == 2:
                            inputs_val, labels_val = data_val
                        elif len(data_val) == 3:
                            inputs_val, labels_val, x_len = data_val
                        else:
                            assert False, 'data_val length is not 2 or 3'

                        if extra_train_dataset == -1:
                            assert BATCH == 1
                            now_T = inputs_val.shape[1]
                            now_time_steps = temporal_filter*TIME
                            start_idx = 0
                            inputs_val = inputs_val[:, start_idx : start_idx + now_time_steps]

                            if dvs_clipping != 0:
                                inputs_val[inputs_val<dvs_clipping] = 0.0
                                inputs_val[inputs_val>=dvs_clipping] = 1.0

                        if (which_data == 'DVS_CIFAR10' or which_data == 'DVS_GESTURE' or which_data == 'DVS_GESTURE_TONIC' or which_data == 'DVS_CIFAR10_2' or which_data == 'NMNIST' or which_data == 'NMNIST_TONIC' or which_data == 'N_CALTECH101' or which_data == 'n_tidigits' or which_data == 'heidelberg'):
                            inputs_val = inputs_val.permute(1, 0, 2, 3, 4)
                        elif rate_coding == True :
                            inputs_val = spikegen.rate(inputs_val, num_steps=TIME)
                        else :
                            inputs_val = inputs_val.repeat(TIME, 1, 1, 1, 1)
                        # inputs_val: [Time, Batch, Channel, Height, Width]  
                        ###################################################################################################

                        
                        ## initial pooling #######################################################################
                        if (initial_pooling > 1):
                            pool = nn.MaxPool2d(kernel_size=2)
                            num_pooling_layers = int(math.log2(initial_pooling))
                            # Time, Batch, Channel 차원은 그대로 두고, Height, Width 차원에 대해서만 pooling 적용
                            shape_temp = inputs_val.shape
                            inputs_val = inputs_val.reshape(shape_temp[0]*shape_temp[1], shape_temp[2], shape_temp[3], shape_temp[4])
                            for _ in range(num_pooling_layers):
                                inputs_val = pool(inputs_val)
                            inputs_val = inputs_val.reshape(shape_temp[0], shape_temp[1], shape_temp[2], shape_temp[3]//initial_pooling, shape_temp[4]//initial_pooling)
                        ## initial pooling #######################################################################

                        ## temporal filtering ####################################################################
                        shape_temp = inputs_val.shape
                        if (temporal_filter > 1):
                            slice_bucket = []
                            for t_temp in range(TIME):
                                start = t_temp * temporal_filter
                                end = start + temporal_filter
                                slice_concat = torch.movedim(inputs_val[start:end], 0, -2).reshape(shape_temp[1],shape_temp[2],shape_temp[3],-1)
                                
                                if temporal_filter_accumulation == True:
                                    if t_temp == 0:
                                        slice_bucket.append(slice_concat)
                                    else:
                                        slice_bucket.append(slice_concat+slice_bucket[t_temp-1])
                                else:
                                    slice_bucket.append(slice_concat)

                            inputs_val = torch.stack(slice_bucket, dim=0)
                            if temporal_filter_accumulation == True and dvs_clipping > 0:
                                inputs = (inputs != 0.0).float()
                        ## temporal filtering ####################################################################
                            
                        inputs_val = inputs_val.to(device)
                        labels_val = labels_val.to(device)
                        real_batch = labels_val.size(0)
                        
                        if merge_polarities == True:
                            inputs_val = inputs_val[:,:,0:1,:,:]

                        ## network 연산 시작 ############################################################################################################
                        if single_step == False:
                            outputs = net(inputs_val.permute(1, 0, 2, 3, 4)) #inputs_val: [Batch, Time, Channel, Height, Width]  
                            outputs = outputs.sum(dim=0)
                            val_loss += criterion(outputs, labels_val)/len(test_loader)
                        else:
                            outputs_all = []
                            for t in range(TIME):
                                outputs = net(inputs_val[t])
                                val_loss_temp = criterion(outputs, labels_val)
                                outputs_all.append(outputs.detach())
                                val_loss += (val_loss_temp.data/TIME)/len(test_loader)
                            outputs_all = torch.stack(outputs_all, dim=1)
                            outputs = outputs_all.mean(1)
                        #################################################################################################################################

                        _, predicted = torch.max(outputs.data, 1)
                        total_val += real_batch
                        assert real_batch == outputs.size(0), f'batch size is not same. real_batch: {real_batch}, outputs.size(0): {outputs.size(0)}'
                        correct_val += (predicted == labels_val).sum().item()

                    val_acc_now = correct_val / total_val

                if val_acc_best < val_acc_now:
                    val_acc_best = val_acc_now
                    # wandb 키면 state_dict아닌거는 저장 안됨
                    # network save
                    torch.save(net.state_dict(), f"net_save/save_now_net_weights_{unique_name}.pth")

                if tr_acc_best < tr_acc:
                    tr_acc_best = tr_acc

                tr_epoch_loss = tr_epoch_loss_temp
                tr_epoch_loss_temp = 0

            ####################################################################################################################################################
            
            ## progress bar update ############################################################################################################
            epoch_end_time = time.time()
            epoch_time = epoch_end_time - epoch_start_time
            if iter_of_val == False:
                # iterator.set_description(f"{iter_acc_string}, iter_loss:{iter_loss:10.6f}") 
                pass 
            else:
                # iterator.set_description(f"{iter_acc_string2}, tr/val_loss:{tr_epoch_loss:10.6f}/{val_loss:10.6f}, tr:{100 * tr_acc:7.2f}%, tr_best:{100 * tr_acc_best:7.2f}%, val:{100 * val_acc_now:7.2f}%, val_best:{100 * val_acc_best:7.2f}%")  
                print(f"{iter_acc_string2}, tr/val_loss:{tr_epoch_loss:10.6f}/{val_loss:10.6f}, val:{100 * val_acc_now:7.2f}%, val_best:{100 * val_acc_best:7.2f}%, tr:{100 * tr_acc:7.2f}%, tr_best:{100 * tr_acc_best:7.2f}%, epoch time: {epoch_time:.2f} seconds, {epoch_time/60:.2f} minutes")
                iter_of_val = False
            ####################################################################################################################################
            
            ## wandb logging ############################################################################################################
            if i == len(train_loader)-1 :
                wandb.log({"iter_acc": iter_acc})
                wandb.log({"tr_acc": tr_acc})
                wandb.log({"val_acc_now": val_acc_now})
                wandb.log({"val_acc_best": val_acc_best})
                wandb.log({"summary_val_acc": val_acc_now})
                wandb.log({"epoch": epoch})
                wandb.log({"val_loss": val_loss}) 
                wandb.log({"tr_epoch_loss": tr_epoch_loss}) 
                # wandb.log({"max_val_scale_exp_8bit_1w": max_val_scale_exp_8bit_box[0]}) 
                # wandb.log({"max_val_scale_exp_8bit_1b": max_val_scale_exp_8bit_box[1]})
                # wandb.log({"max_val_scale_exp_8bit_2w": max_val_scale_exp_8bit_box[2]}) 
                # wandb.log({"max_val_scale_exp_8bit_2b": max_val_scale_exp_8bit_box[3]}) 
                # wandb.log({"max_val_scale_exp_8bit_3w": max_val_scale_exp_8bit_box[4]}) 
                # wandb.log({"max_val_scale_exp_8bit_3b": max_val_scale_exp_8bit_box[5]})

                # wandb.log({"perc_999_scale_exp_8bit_1w": perc_999_scale_exp_8bit_box[0]}) 
                # wandb.log({"perc_999_scale_exp_8bit_1b": perc_999_scale_exp_8bit_box[1]})
                # wandb.log({"perc_999_scale_exp_8bit_2w": perc_999_scale_exp_8bit_box[2]}) 
                # wandb.log({"perc_999_scale_exp_8bit_2b": perc_999_scale_exp_8bit_box[3]}) 
                # wandb.log({"perc_999_scale_exp_8bit_3w": perc_999_scale_exp_8bit_box[4]}) 
                # wandb.log({"perc_999_scale_exp_8bit_3b": perc_999_scale_exp_8bit_box[5]}) 

                for name, module in net.module.named_modules():
                    if isinstance(module, SYNAPSE_FC):
                        module.sparsity_print_and_reset()
                
                if epoch > 10:
                    assert val_acc_best > 0.2
                elif epoch > 50:
                    assert val_acc_best > 0.4
                elif epoch > 60:
                    assert val_acc_best > 0.5
                elif epoch > 100:
                    assert val_acc_best > 0.6
                        
                # if epoch > 100:
                #     assert val_acc_best > 0.6
                    
            ####################################################################################################################################
            
        ###### ITERATION END ##########################################################################################################

        ## scheduler update #############################################################################
        if (scheduler_name != 'no'):
            if (scheduler_name == 'ReduceLROnPlateau'):
                scheduler.step(val_loss)
            else:
                scheduler.step()
        #################################################################################################
        
    #======== EPOCH END ==========================================================================================

# %%
# unique_name = 'main' ## 이거 설정하면 새로운 경로에 모두 save
# wandb.init(project= f'my_snn {unique_name}',save_code=False, dir='/data2/bh_wandb', tags=["common"])
# ## wandb 과거 하이퍼파라미터 가져와서 붙여넣기 (devices unique_name은 니가 할당해라)#################################
# param = {'devices': '3', 'single_step': True, 'unique_name': 'main', 'my_seed': 42, 'TIME': 10, 'BATCH': 16, 'IMAGE_SIZE': 128, 'which_data': 'DVS_GESTURE_TONIC', 'data_path': '/data2', 'rate_coding': False, 'lif_layer_v_init': 0, 'lif_layer_v_decay': 0.25, 'lif_layer_v_threshold': 0.75, 'lif_layer_v_reset': 0, 'lif_layer_sg_width': 4, 'synapse_conv_kernel_size': 3, 'synapse_conv_stride': 1, 'synapse_conv_padding': 1, 'synapse_trace_const1': 1, 'synapse_trace_const2': 0, 'pre_trained': False, 'convTrue_fcFalse': False, 'cfg': [200, 200], 'net_print': True, 'pre_trained_path': 'net_save/save_now_net_weights_{unique_name}.pth', 'learning_rate': 0.001, 'epoch_num': 100, 'tdBN_on': False, 'BN_on': False, 'surrogate': 'hard_sigmoid', 'BPTT_on': False, 'optimizer_what': 'SGD', 'scheduler_name': 'no', 'ddp_on': False, 'dvs_clipping': 2, 'dvs_duration': 25000, 'DFA_on': True, 'trace_on': True, 'OTTT_input_trace_on': False, 'exclude_class': True, 'merge_polarities': False, 'denoise_on': True, 'extra_train_dataset': 0, 'num_workers': 2, 'chaching_on': True, 'pin_memory': True, 'UDA_on': False, 'alpha_uda': 1, 'bias': True, 'last_lif': False, 'temporal_filter': 5, 'initial_pooling': 8}
# my_snn_system(devices = '0',single_step = param['single_step'],unique_name = unique_name,my_seed = param['my_seed'],TIME = param['TIME'],BATCH = param['BATCH'],IMAGE_SIZE = param['IMAGE_SIZE'],which_data = param['which_data'],data_path = param['data_path'],rate_coding = param['rate_coding'],lif_layer_v_init = param['lif_layer_v_init'],lif_layer_v_decay = param['lif_layer_v_decay'],lif_layer_v_threshold = param['lif_layer_v_threshold'],lif_layer_v_reset = param['lif_layer_v_reset'],lif_layer_sg_width = param['lif_layer_sg_width'],synapse_conv_kernel_size = param['synapse_conv_kernel_size'],synapse_conv_stride = param['synapse_conv_stride'],synapse_conv_padding = param['synapse_conv_padding'],synapse_trace_const1 = param['synapse_trace_const1'],synapse_trace_const2 = param['synapse_trace_const2'],pre_trained = param['pre_trained'],convTrue_fcFalse = param['convTrue_fcFalse'],cfg = param['cfg'],net_print = param['net_print'],pre_trained_path = param['pre_trained_path'],learning_rate = param['learning_rate'],epoch_num = param['epoch_num'],tdBN_on = param['tdBN_on'],BN_on = param['BN_on'],surrogate = param['surrogate'],BPTT_on = param['BPTT_on'],optimizer_what = param['optimizer_what'],scheduler_name = param['scheduler_name'],ddp_on = param['ddp_on'],dvs_clipping = param['dvs_clipping'],dvs_duration = param['dvs_duration'],DFA_on = param['DFA_on'],trace_on = param['trace_on'],OTTT_input_trace_on = param['OTTT_input_trace_on'],exclude_class = param['exclude_class'],merge_polarities = param['merge_polarities'],denoise_on = param['denoise_on'],extra_train_dataset = param['extra_train_dataset'],num_workers = param['num_workers'],chaching_on = param['chaching_on'],pin_memory = param['pin_memory'],UDA_on = param['UDA_on'],alpha_uda = param['alpha_uda'],bias = param['bias'],last_lif = param['last_lif'],temporal_filter = param['temporal_filter'],initial_pooling = param['initial_pooling'],temporal_filter_accumulation= param['temporal_filter_accumulation'])
# #############################################################################

# %%
# ### my_snn control board (Gesture) ########################
# decay = 0.5 # 0.0 # 0.875 0.25 0.125 0.75 0.5
# # nda 0.25 # ottt 0.5

# unique_name = 'main'
# run_name = datetime.datetime.now().strftime("%Y%m%d_%H%M%S_") + f"{datetime.datetime.now().microsecond // 1000:03d}"


# wandb.init(project= f'my_snn {unique_name}',save_code=False, dir='/data2/bh_wandb', tags=["common"])

# my_snn_system(  devices = "5",
#                 single_step = False, # True # False # DFA_on이랑 같이 가라
#                 unique_name = run_name,
#                 my_seed = 3,
#                 TIME = 10, # dvscifar 10 # ottt 6 or 10 # nda 10  # 제작하는 dvs에서 TIME넘거나 적으면 자르거나 PADDING함
#                 BATCH = 1, # batch norm 할거면 2이상으로 해야함   # nda 256   #  ottt 128
#                 IMAGE_SIZE = 14, # dvscifar 48 # MNIST 28 # CIFAR10 32 # PMNIST 28 #NMNIST 34 # GESTURE 128
#                 # dvsgesture 128, dvs_cifar2 128, nmnist 34, n_caltech101 180,240, n_tidigits 64, heidelberg 700, 

#                 # DVS_CIFAR10 할거면 time 10으로 해라
#                 which_data = 'DVS_GESTURE_TONIC',
# # 'CIFAR100' 'CIFAR10' 'MNIST' 'FASHION_MNIST' 'DVS_CIFAR10' 'PMNIST'아직
# # 'DVS_GESTURE', 'DVS_GESTURE_TONIC','DVS_CIFAR10_2','NMNIST','NMNIST_TONIC','CIFAR10','N_CALTECH101','n_tidigits','heidelberg'
#                 # CLASS_NUM = 10,
#                 data_path = '/data2', # YOU NEED TO CHANGE THIS
#                 rate_coding = False, # True # False

#                 lif_layer_v_init = 0.0,
#                 lif_layer_v_decay = decay,
#                 lif_layer_v_threshold = 1.0,   #nda 0.5  #ottt 1.0
#                 lif_layer_v_reset = 0.0, # 10000이상은 hardreset (내 LIF쓰기는 함 ㅇㅇ)
#                 lif_layer_sg_width = 4.0, # 2.570969004857107 # sigmoid류에서는 alpha값 4.0, rectangle류에서는 width값 0.5

#                 # synapse_conv_in_channels = IMAGE_PIXEL_CHANNEL,
#                 synapse_conv_kernel_size = 3,
#                 synapse_conv_stride = 1,
#                 synapse_conv_padding = 1,

#                 synapse_trace_const1 = 1, # 현재 trace구할 때 현재 spike에 곱해지는 상수. 걍 1로 두셈.
#                 synapse_trace_const2 = decay, # 현재 trace구할 때 직전 trace에 곱해지는 상수. lif_layer_v_decay와 같게 할 것을 추천

#                 # synapse_fc_out_features = CLASS_NUM,

#                 pre_trained = False, # True # False
#                 convTrue_fcFalse = False, # True # False

#                 # 'P' for average pooling, 'D' for (1,1) aver pooling, 'M' for maxpooling, 'L' for linear classifier, [  ] for residual block
#                 # conv에서 10000 이상은 depth-wise separable (BPTT만 지원), 20000이상은 depth-wise (BPTT만 지원)
#                 # cfg = ['M', 'M', 32, 'P', 32, 'P', 32, 'P'], 
#                 # cfg = ['M', 'M', 64, 'P', 64, 'P', 64, 'P'], 
#                 # cfg = ['M', 'M', 64, 'M', 96, 'M', 128, 'M'], 
#                 cfg = [200, 200], 
#                 # cfg = ['M', 'M', 64, 'M', 96], 
#                 # cfg = ['M', 'M', 64, 'M', 96, 'L', 512, 512], 
#                 # cfg = ['M', 'M', 64], 
#                 # cfg = [64, 124, 64, 124],
#                 # cfg = ['M','M',512], 
#                 # cfg = [512], 
#                 # cfg = ['M', 'M', 64, 128, 'P', 128, 'P'], 
#                 # cfg = ['M','M',512],
#                 # cfg = ['M',200],
#                 # cfg = [200,200],
#                 # cfg = ['M','M',200,200],
#                 # cfg = ([200],[200],[200],[2]), # (feature extractor, classifier, domain adapter, # of domain)
#                 # cfg = (['M','M',200],[200],[200],[2]), # (feature extractor, classifier, domain adapter, # of domain)
#                 # cfg = ['M',200,200],
#                 # cfg = ['M','M',1024,512,256,128,64],
#                 # cfg = [200,200],
#                 # cfg = [12], #fc
#                 # cfg = [12, 'M', 48, 'M', 12], 
#                 # cfg = [64,[64,64],64], # 끝에 linear classifier 하나 자동으로 붙습니다
#                 # cfg = [64, 128, 'P', 256, 256, 'P', 512, 512, 'P', 512, 512, 'D'], #ottt
#                 # cfg = [64, 128, 'P', 256, 256, 'P', 512, 512, 'P', 512, 512], 
#                 # cfg = [64, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512], 
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512, 'D'], # nda
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512], # nda 128pixel
#                 # cfg = [64, 'P', 128, 'P', 256, 256, 'P', 512, 512, 512, 512, 'L', 4096, 4096],
#                 # cfg = [20001,10001], # depthwise, separable
#                 # cfg = [64,20064,10001], # vanilla conv, depthwise, separable
#                 # cfg = [8, 'P', 8, 'P', 8, 'P', 8,'P', 8, 'P'],
#                 # cfg = [],        
                
#                 net_print = True, # True # False # True로 하길 추천
                
#                 pre_trained_path = f"net_save/save_now_net_weights_{unique_name}.pth",
#                 # learning_rate = 0.001, #0.1 bptt, #0.01 ottt, # default 0.001  # ottt 0.1 # nda 0.001 # 0.00936191669529645
#                 learning_rate = 0.01, #0.1 bptt, #0.01 ottt, # default 0.001  # ottt 0.1 # nda 0.001 # 0.00936191669529645
#                 epoch_num = 200,
#                 tdBN_on = False,  # True # False
#                 BN_on = False,  # True # False
                
#                 surrogate = 'sigmoid', # 'sigmoid' 'rectangle' 'rough_rectangle' 'hard_sigmoid'
                
#                 BPTT_on = True,  # True # False # True이면 BPTT, False이면 OTTT  # depthwise, separable은 BPTT만 가능
                
#                 optimizer_what = 'SGD', # 'SGD' 'Adam', 'RMSprop'
#                 scheduler_name = 'no', # 'no' 'StepLR' 'ExponentialLR' 'ReduceLROnPlateau' 'CosineAnnealingLR' 'OneCycleLR'
                
#                 ddp_on = False, # DECREPATED # fALSE

#                 dvs_clipping = 14, #일반적으로 1 또는 2 # 100ms때는 5 # 숫자만큼 크면 spike 아니면 걍 0
#                 # gesture, cifar-dvs2, nmnist, ncaltech101
#                 # gesture: 100_000c1-5, 25_000c5, 10_000c5, 1_000c5, 1_000_000c5

#                 dvs_duration = 25_000, # 0 아니면 time sampling # dvs number sampling OR time sampling # gesture, cifar-dvs2, nmnist, ncaltech101
#                 # 있는 데이터들 #gesture 100_000 25_000 10_000 1_000 1_000_000 #nmnist 10000 #nmnist_tonic 10_000 25_000
#                 # 한 숫자가 1us인듯 (spikingjelly코드에서)
#                 # 한 장에 50 timestep만 생산함. 싫으면 my_snn/trying/spikingjelly_dvsgesture의__init__.py 를 참고해봐
#                 # nmnist 5_000us, gesture는 100_000us, 25_000us

#                 DFA_on = False, # True # False # single_step이랑 같이 켜야 됨.

#                 trace_on = False,   # True # False
#                 OTTT_input_trace_on = False, # True # False # 맨 처음 input에 trace 적용 # trace_on False면 의미없음.

#                 exclude_class = True, # True # False # gesture에서 10번째 클래스 제외

#                 merge_polarities = True, # True # False # tonic dvs dataset 에서 polarities 합치기
#                 denoise_on = False, # True # False # &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&

#                 extra_train_dataset = -1, 

#                 num_workers = 2, # local wsl에서는 2가 맞고, 서버에서는 4가 좋더라.
#                 chaching_on = True, # True # False # only for certain datasets (gesture_tonic, nmnist_tonic)
#                 pin_memory = True, # True # False 

#                 UDA_on = False,  # DECREPATED # uda
#                 alpha_uda = 1.0, # DECREPATED # uda

#                 bias = False, # True # False 

#                 last_lif = False, # True # False 

#                 temporal_filter = 5, 
#                 initial_pooling = 1,

#                 temporal_filter_accumulation = False, # True # False 

#                 quantize_bit_list  =  [],
#                 scale_exp = [[999,999],[999,999],[999,999]],
#                 lif_layer_sg_width2 = 4.0,
#                 lif_layer_v_threshold2 = 1.0,
#                 learning_rate2 = 0.01,
#                 init_scaling = None,
#                 learning_rate3 = 0.01,
#                 ) 

# # num_workers = 4 * num_GPU (or 8, 16, 2 * num_GPU)
# # entry * batch_size * num_worker = num_GPU * GPU_throughtput
# # num_workers = batch_size / num_GPU
# # num_workers = batch_size / num_CPU

# # sigmoid와 BN이 있어야 잘된다.
# # average pooling  
# # 이 낫다. 

# # nda에서는 decay = 0.25, threshold = 0.5, width =1, surrogate = rectangle, batch = 256, tdBN = True
# ## OTTT 에서는 decay = 0.5, threshold = 1.0, surrogate = sigmoid, batch = 128, BN = True

# wandb.finish()

# %%
# sweep 하는 코드, 위 셀 주석처리 해야 됨.

# 이런 워닝 뜨는 거는 걍 너가 main 안에서  wandb.config.update(hyperparameters)할 때 물려서임. 어차피 근데 sweep에서 지정한 걸로 덮어짐 
# wandb: WARNING Config item 'BATCH' was locked by 'sweep' (ignored update).

unique_name_hyper = 'main'
sweep_configuration = {
    'method': 'random', # 'random', 'bayes', 'grid'
    'name': f'my_snn_sweep{datetime.datetime.now().strftime("%Y%m%d_%H%M%S")}',
    'metric': {'goal': 'maximize', 'name': 'val_acc_best'},
    'parameters': 
    {
        # "devices": {"values": ["1"]},
        "single_step": {"values": [False]},
        # "unique_name": {"values": [unique_name_hyper]},
        "my_seed": {"min": 1, "max": 42000},
        # "my_seed": {"values": [1]},
        "TIME": {"values": [10]},
        "BATCH": {"values": [1]},
        "IMAGE_SIZE": {"values": [14]},
        "which_data": {"values": ['DVS_GESTURE_TONIC']},
        "data_path": {"values": ['/data2']},
        "rate_coding": {"values": [False]},
        "lif_layer_v_init": {"values": [0.0]},
        "lif_layer_v_decay": {"values": [0.125]},
        # "lif_layer_v_decay": {"min": 0.1, "max": 0.9},
        "lif_layer_v_threshold": {"values": [0.0005]},
        # "lif_layer_v_threshold": {"min": 0.001, "max": 10.0},
        "lif_layer_v_reset": {"values": [0.0]},
        "lif_layer_sg_width": {"values": [2.0]},
        # "lif_layer_sg_width": {"min": 1.0, "max": 32.0},

        "synapse_conv_kernel_size": {"values": [3]},
        "synapse_conv_stride": {"values": [1]},
        "synapse_conv_padding": {"values": [1]},

        "synapse_trace_const1": {"values": [1]},
        # "synapse_trace_const2": {"values": [0.5]},

        "pre_trained": {"values": [False]},
        "convTrue_fcFalse": {"values": [False]},

        "cfg": {"values": [[200,200]]},

        "net_print": {"values": [True]},

        "pre_trained_path": {"values": [""]},

        "learning_rate": {"values": [5.0]}, 
        # "learning_rate": {"min": 0.00001, "max": 1.0},
        
        "epoch_num": {"values": [200]}, 
        "tdBN_on": {"values": [False]},
        "BN_on": {"values": [False]},

        "surrogate": {"values": ['sigmoid']},

        "BPTT_on": {"values": [True]},

        "optimizer_what": {"values": ['SGD']},
        "scheduler_name": {"values": ['no']},

        "ddp_on": {"values": [False]},

        "dvs_clipping": {"values": [14]}, 

        "dvs_duration": {"values": [25_000]}, 

        "DFA_on": {"values": [False]},

        "trace_on": {"values": [False]},
        "OTTT_input_trace_on": {"values": [False]},

        "exclude_class": {"values": [True]},

        "merge_polarities": {"values": [True]},
        "denoise_on": {"values": [False]},

        "extra_train_dataset": {"values": [-1]},

        "num_workers": {"values": [2]},
        "chaching_on": {"values": [True]},
        "pin_memory": {"values": [True]},

        "UDA_on": {"values": [False]},
        "alpha_uda": {"values": [1.0]},

        "bias": {"values": [False]},

        "last_lif": {"values": [False]},

        "temporal_filter": {"values": [5]},
        "initial_pooling": {"values": [1]},

        "temporal_filter_accumulation": {"values": [False]},
        "lif_layer_sg_width2": {"values": [1.0]},
        # "lif_layer_sg_width2": {"min": 1.0, "max": 32.0},
        "lif_layer_v_threshold2": {"values": [2.0]},
        # "lif_layer_v_threshold2": {"min": 0.001, "max": 10.0},
        "learning_rate2": {"values": [0.5]}, 
        "init_scaling": {"values": [None]},
        "learning_rate3": {"values": [0.001]}, 
     }
}

def hyper_iter():
    ### my_snn control board ########################
    wandb.init(save_code=False, dir='/data2/bh_wandb', tags=["sweep"])

    my_snn_system(  
        devices  =  "4",
        single_step  =  wandb.config.single_step,
        unique_name  =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S_") + f"{datetime.datetime.now().microsecond // 1000:03d}",
        my_seed  =  wandb.config.my_seed,
        TIME  =  wandb.config.TIME,
        BATCH  =  wandb.config.BATCH,
        IMAGE_SIZE  =  wandb.config.IMAGE_SIZE,
        which_data  =  wandb.config.which_data,
        data_path  =  wandb.config.data_path,
        rate_coding  =  wandb.config.rate_coding,
        lif_layer_v_init  =  wandb.config.lif_layer_v_init,
        lif_layer_v_decay  =  wandb.config.lif_layer_v_decay,
        lif_layer_v_threshold  =  wandb.config.lif_layer_v_threshold,
        lif_layer_v_reset  =  wandb.config.lif_layer_v_reset,
        lif_layer_sg_width  =  wandb.config.lif_layer_sg_width,
        synapse_conv_kernel_size  =  wandb.config.synapse_conv_kernel_size,
        synapse_conv_stride  =  wandb.config.synapse_conv_stride,
        synapse_conv_padding  =  wandb.config.synapse_conv_padding,
        synapse_trace_const1  =  wandb.config.synapse_trace_const1,
        synapse_trace_const2  =  wandb.config.lif_layer_v_decay,
        pre_trained  =  wandb.config.pre_trained,
        convTrue_fcFalse  =  wandb.config.convTrue_fcFalse,
        cfg  =  wandb.config.cfg,
        net_print  =  wandb.config.net_print,
        pre_trained_path  =  wandb.config.pre_trained_path,
        learning_rate  =  wandb.config.learning_rate,
        epoch_num  =  wandb.config.epoch_num,
        tdBN_on  =  wandb.config.tdBN_on,
        BN_on  =  wandb.config.BN_on,
        surrogate  =  wandb.config.surrogate,
        BPTT_on  =  wandb.config.BPTT_on,
        optimizer_what  =  wandb.config.optimizer_what,
        scheduler_name  =  wandb.config.scheduler_name,
        ddp_on  =  wandb.config.ddp_on,
        dvs_clipping  =  wandb.config.dvs_clipping,
        dvs_duration  =  wandb.config.dvs_duration,
        DFA_on  =  wandb.config.DFA_on,
        trace_on  =  wandb.config.trace_on,
        OTTT_input_trace_on  =  wandb.config.OTTT_input_trace_on,
        exclude_class  =  wandb.config.exclude_class,
        merge_polarities  =  wandb.config.merge_polarities,
        denoise_on  =  wandb.config.denoise_on,
        extra_train_dataset  =  wandb.config.extra_train_dataset,
        num_workers  =  wandb.config.num_workers,
        chaching_on  =  wandb.config.chaching_on,
        pin_memory  =  wandb.config.pin_memory,
        UDA_on  =  wandb.config.UDA_on,
        alpha_uda  =  wandb.config.alpha_uda,
        bias  =  wandb.config.bias,
        last_lif  =  wandb.config.last_lif,
        temporal_filter  =  wandb.config.temporal_filter,
        initial_pooling  =  wandb.config.initial_pooling,
        temporal_filter_accumulation  =  wandb.config.temporal_filter_accumulation,
        quantize_bit_list  =  [],
        scale_exp = [[999,999],[999,999],[999,999]],
        lif_layer_sg_width2 = wandb.config.lif_layer_sg_width2,
        lif_layer_v_threshold2 = wandb.config.lif_layer_v_threshold2,
        learning_rate2 = wandb.config.learning_rate2,
        init_scaling = wandb.config.init_scaling,
        learning_rate3 = wandb.config.learning_rate3,
                        ) 
    # sigmoid와 BN이 있어야 잘된다.
    # average pooling
    # 이 낫다. 
    
    # nda에서는 decay = 0.25, threshold = 0.5, width =1, surrogate = rectangle, batch = 256, tdBN = True
    ## OTTT 에서는 decay = 0.5, threshold = 1.0, surrogate = sigmoid, batch = 128, BN = True

sweep_id = '3h6c9ywq'
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'my_snn {unique_name_hyper}')
wandb.agent(sweep_id, function=hyper_iter, count=10000, project=f'my_snn {unique_name_hyper}')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: 3h6c9ywq
# Sweep URL: https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/3h6c9ywq
# wandb: Agent Starting Run: 3ubacutj with config:
# wandb: 	BATCH: 1
# wandb: 	BN_on: False
# wandb: 	BPTT_on: True
# wandb: 	DFA_on: False
# wandb: 	IMAGE_SIZE: 14
# wandb: 	OTTT_input_trace_on: False
# wandb: 	TIME: 10
# wandb: 	UDA_on: False
# wandb: 	alpha_uda: 1
# wandb: 	bias: False
# wandb: 	cfg: [200, 200]
# wandb: 	chaching_on: True
# wandb: 	convTrue_fcFalse: False
# wandb: 	data_path: /data2
# wandb: 	ddp_on: False
# wandb: 	denoise_on: False
# wandb: 	dvs_clipping: 14
# wandb: 	dvs_duration: 25000
# wandb: 	epoch_num: 200
# wandb: 	exclude_class: True
# wandb: 	extra_train_dataset: -1
# wandb: 	init_scaling: None
# wandb: 	initial_pooling: 1
# wandb: 	last_lif: False
# wandb: 	learning_rate: 5
# wandb: 	learning_rate2: 0.5
# wandb: 	learning_rate3: 0.001
# wandb: 	lif_layer_sg_width: 2
# wandb: 	lif_layer_sg_width2: 1
# wandb: 	lif_layer_v_decay: 0.125
# wandb: 	lif_layer_v_init: 0
# wandb: 	lif_layer_v_reset: 0
# wandb: 	lif_layer_v_threshold: 0.0005
# wandb: 	lif_layer_v_threshold2: 2
# wandb: 	merge_polarities: True
# wandb: 	my_seed: 3907
# wandb: 	net_print: True
# wandb: 	num_workers: 2
# wandb: 	optimizer_what: SGD
# wandb: 	pin_memory: True
# wandb: 	pre_trained: False
# wandb: 	pre_trained_path:
# wandb: 	rate_coding: False
# wandb: 	scheduler_name: no
# wandb: 	single_step: False
# wandb: 	surrogate: sigmoid
# wandb: 	synapse_conv_kernel_size: 3
# wandb: 	synapse_conv_padding: 1
# wandb: 	synapse_conv_stride: 1
# wandb: 	synapse_trace_const1: 1
# wandb: 	tdBN_on: False
# wandb: 	temporal_filter: 5
# wandb: 	temporal_filter_accumulation: False
# wandb: 	trace_on: False
# wandb: 	which_data: DVS_GESTURE_TONIC
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/data2/bh_wandb/wandb/run-20251212_133822-3ubacutj</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/3ubacutj' target="_blank">ruby-sweep-1</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/3h6c9ywq' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/3h6c9ywq</a>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main</a>
#  View sweep at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/3h6c9ywq' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/sweeps/3h6c9ywq</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/3ubacutj' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/my_snn%20main/runs/3ubacutj</a>
# wandb: WARNING Config item 'single_step' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'my_seed' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'TIME' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BATCH' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'IMAGE_SIZE' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'which_data' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'data_path' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'rate_coding' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_init' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_decay' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_threshold' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_reset' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_sg_width' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_kernel_size' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_stride' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_conv_padding' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'synapse_trace_const1' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pre_trained' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'convTrue_fcFalse' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'cfg' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'net_print' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pre_trained_path' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'epoch_num' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'tdBN_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BN_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'surrogate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'BPTT_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer_what' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'scheduler_name' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'ddp_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dvs_clipping' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'dvs_duration' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'DFA_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'trace_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'OTTT_input_trace_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'exclude_class' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'merge_polarities' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'denoise_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'extra_train_dataset' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'num_workers' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'chaching_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'pin_memory' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'UDA_on' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'alpha_uda' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'bias' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'last_lif' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'temporal_filter' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'initial_pooling' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'temporal_filter_accumulation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_sg_width2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'lif_layer_v_threshold2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'init_scaling' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate2' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate3' was locked by 'sweep' (ignored update).
# param {'devices': '4', 'single_step': False, 'unique_name': '20251212_133831_273', 'my_seed': 3907, 'TIME': 10, 'BATCH': 1, 'IMAGE_SIZE': 14, 'which_data': 'DVS_GESTURE_TONIC', 'data_path': '/data2', 'rate_coding': False, 'lif_layer_v_init': 0, 'lif_layer_v_decay': 0.125, 'lif_layer_v_threshold': 0.0005, 'lif_layer_v_reset': 0, 'lif_layer_sg_width': 2, 'synapse_conv_kernel_size': 3, 'synapse_conv_stride': 1, 'synapse_conv_padding': 1, 'synapse_trace_const1': 1, 'synapse_trace_const2': 0.125, 'pre_trained': False, 'convTrue_fcFalse': False, 'cfg': [200, 200], 'net_print': True, 'pre_trained_path': '', 'epoch_num': 200, 'tdBN_on': False, 'BN_on': False, 'surrogate': 'sigmoid', 'BPTT_on': True, 'optimizer_what': 'SGD', 'scheduler_name': 'no', 'ddp_on': False, 'dvs_clipping': 14, 'dvs_duration': 25000, 'DFA_on': False, 'trace_on': False, 'OTTT_input_trace_on': False, 'exclude_class': True, 'merge_polarities': True, 'denoise_on': False, 'extra_train_dataset': -1, 'num_workers': 2, 'chaching_on': True, 'pin_memory': True, 'UDA_on': False, 'alpha_uda': 1, 'bias': False, 'last_lif': False, 'temporal_filter': 5, 'initial_pooling': 1, 'temporal_filter_accumulation': False, 'quantize_bit_list': [], 'scale_exp': [[999, 999], [999, 999], [999, 999]], 'lif_layer_sg_width2': 1, 'lif_layer_v_threshold2': 2, 'init_scaling': None, 'learning_rate': 5, 'learning_rate2': 0.5, 'learning_rate3': 0.001}
#
# 이 데이터셋의 데이터 개수는 979 입니다. (test set은 안바뀌게 해놨다 알제)
# 이 데이터셋의 데이터 개수는 240 입니다. (test set은 안바뀌게 해놨다 알제)
# dataset_hash = 0e8a8f2d81b4fe037308b5d792c4a037
# cache path exists
#
# len(train_loader): 979 BATCH: 1 train_data_count: 979
# len(test_loader): 240 BATCH: 1
#
# device ==> cuda
#
#
#
#
#  layer_count 1
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
#
#
#
# LIF 1 sg_bit 0 self.sg_width 2, self.v_threshold 0.0005
#
#
# ++++++++++++++++++++++++
#
#  lif layer 1 v_bit: 0, v_exp: None
#
# ++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#  layer_count 2
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
#
#
#
# LIF 2 sg_bit 0 self.sg_width 1, self.v_threshold 2
#
#
# ++++++++++++++++++++++++
#
#  lif layer 2 v_bit: 0, v_exp: None
#
# ++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#  layer_count 3
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
# DataParallel(
#   (module): REBORN_MY_SNN_FC(
#     (layers): REBORN_MY_Sequential(
#       (0): DimChanger_for_FC()
#       (1): SYNAPSE_FC(in_features=980, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=1, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (2): LIF_layer(v_init=0, v_decay=0.125, v_threshold=0.0005, v_reset=0, sg_width=2, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.125, TIME=10, sstep=False, trace_on=False, layer_count=1, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (3): SYNAPSE_FC(in_features=200, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=2, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (4): LIF_layer(v_init=0, v_decay=0.125, v_threshold=2, v_reset=0, sg_width=1, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.125, TIME=10, sstep=False, trace_on=False, layer_count=2, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (5): SYNAPSE_FC(in_features=200, out_features=10, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=3, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#     )
#   )
# )
#
# ========================================================
# Trainable parameters: 238,000
# ========================================================
#
# MySGD (
# Parameter Group 0
#     lr: 5
#     momentum: 0.0
# )
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 0: mean=-0.0000, std=0.0184, |mean|=0.0159, |std|=0.0092, max=0.0319
# layers.3.fc.weight epoch 0: mean=-0.0003, std=0.0407, |mean|=0.0353, |std|=0.0204, max=0.0707
# layers.5.fc.weight epoch 0: mean=-0.0013, std=0.0405, |mean|=0.0352, |std|=0.0200, max=0.0707
# epoch-0   lr=['5.0000000'], tr/val_loss:  0.112812/  0.078283, val:  48.33%, val_best:  48.33%, tr:  38.61%, tr_best:  38.61%, epoch time: 18.77 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0870%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.4085%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.4804%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 1: mean=-0.0164, std=0.0642, |mean|=0.0440, |std|=0.0495, max=0.5296
# layers.3.fc.weight epoch 1: mean=-0.0166, std=0.0542, |mean|=0.0455, |std|=0.0338, max=0.3138
# layers.5.fc.weight epoch 1: mean=-0.0018, std=0.0393, |mean|=0.0341, |std|=0.0196, max=0.0707
# epoch-1   lr=['5.0000000'], tr/val_loss:  0.079670/  0.074893, val:  60.42%, val_best:  60.42%, tr:  58.12%, tr_best:  58.12%, epoch time: 18.10 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0615%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.8012%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.1447%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 2: mean=-0.0185, std=0.0774, |mean|=0.0515, |std|=0.0607, max=0.7672
# layers.3.fc.weight epoch 2: mean=-0.0193, std=0.0593, |mean|=0.0493, |std|=0.0382, max=0.3398
# layers.5.fc.weight epoch 2: mean=-0.0020, std=0.0386, |mean|=0.0333, |std|=0.0195, max=0.0707
# epoch-2   lr=['5.0000000'], tr/val_loss:  0.070591/  0.060791, val:  62.50%, val_best:  62.50%, tr:  60.67%, tr_best:  60.67%, epoch time: 18.08 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0693%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.7131%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.9277%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 3: mean=-0.0196, std=0.0888, |mean|=0.0572, |std|=0.0707, max=1.2231
# layers.3.fc.weight epoch 3: mean=-0.0215, std=0.0626, |mean|=0.0518, |std|=0.0412, max=0.3785
# layers.5.fc.weight epoch 3: mean=-0.0022, std=0.0380, |mean|=0.0327, |std|=0.0195, max=0.0707
# epoch-3   lr=['5.0000000'], tr/val_loss:  0.061152/  0.061323, val:  61.67%, val_best:  62.50%, tr:  66.80%, tr_best:  66.80%, epoch time: 17.79 seconds, 0.30 minutes
# layer   1  Sparsity: 91.1355%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.0238%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.7071%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 4: mean=-0.0194, std=0.0969, |mean|=0.0611, |std|=0.0776, max=1.6746
# layers.3.fc.weight epoch 4: mean=-0.0227, std=0.0655, |mean|=0.0538, |std|=0.0437, max=0.4586
# layers.5.fc.weight epoch 4: mean=-0.0023, std=0.0375, |mean|=0.0321, |std|=0.0196, max=0.0707
# epoch-4   lr=['5.0000000'], tr/val_loss:  0.054672/  0.054463, val:  66.25%, val_best:  66.25%, tr:  70.99%, tr_best:  70.99%, epoch time: 17.91 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0621%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.2693%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5362%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 5: mean=-0.0211, std=0.1032, |mean|=0.0645, |std|=0.0832, max=1.8112
# layers.3.fc.weight epoch 5: mean=-0.0234, std=0.0676, |mean|=0.0553, |std|=0.0454, max=0.4461
# layers.5.fc.weight epoch 5: mean=-0.0024, std=0.0371, |mean|=0.0316, |std|=0.0196, max=0.0707
# epoch-5   lr=['5.0000000'], tr/val_loss:  0.053177/  0.056011, val:  68.75%, val_best:  68.75%, tr:  75.59%, tr_best:  75.59%, epoch time: 18.16 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0601%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.4044%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.4396%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 6: mean=-0.0210, std=0.1089, |mean|=0.0675, |std|=0.0879, max=1.7474
# layers.3.fc.weight epoch 6: mean=-0.0239, std=0.0698, |mean|=0.0569, |std|=0.0470, max=0.4394
# layers.5.fc.weight epoch 6: mean=-0.0026, std=0.0367, |mean|=0.0311, |std|=0.0197, max=0.0707
# epoch-6   lr=['5.0000000'], tr/val_loss:  0.048054/  0.049792, val:  75.00%, val_best:  75.00%, tr:  77.43%, tr_best:  77.43%, epoch time: 18.10 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0717%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.1662%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.3001%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 7: mean=-0.0214, std=0.1138, |mean|=0.0703, |std|=0.0921, max=1.7040
# layers.3.fc.weight epoch 7: mean=-0.0240, std=0.0719, |mean|=0.0583, |std|=0.0485, max=0.4369
# layers.5.fc.weight epoch 7: mean=-0.0027, std=0.0364, |mean|=0.0307, |std|=0.0198, max=0.0707
# epoch-7   lr=['5.0000000'], tr/val_loss:  0.041753/  0.048506, val:  72.08%, val_best:  75.00%, tr:  81.82%, tr_best:  81.82%, epoch time: 17.98 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0358%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.2788%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.1500%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 8: mean=-0.0220, std=0.1184, |mean|=0.0731, |std|=0.0957, max=1.7412
# layers.3.fc.weight epoch 8: mean=-0.0240, std=0.0741, |mean|=0.0598, |std|=0.0500, max=0.4603
# layers.5.fc.weight epoch 8: mean=-0.0027, std=0.0361, |mean|=0.0303, |std|=0.0198, max=0.0707
# epoch-8   lr=['5.0000000'], tr/val_loss:  0.036123/  0.041182, val:  82.50%, val_best:  82.50%, tr:  86.52%, tr_best:  86.52%, epoch time: 18.41 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1048%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.2233%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.0383%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 9: mean=-0.0221, std=0.1224, |mean|=0.0755, |std|=0.0988, max=1.7058
# layers.3.fc.weight epoch 9: mean=-0.0242, std=0.0759, |mean|=0.0610, |std|=0.0513, max=0.4681
# layers.5.fc.weight epoch 9: mean=-0.0028, std=0.0359, |mean|=0.0300, |std|=0.0199, max=0.0707
# epoch-9   lr=['5.0000000'], tr/val_loss:  0.032882/  0.042272, val:  78.33%, val_best:  82.50%, tr:  88.25%, tr_best:  88.25%, epoch time: 18.09 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0850%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.0659%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.9271%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 10: mean=-0.0224, std=0.1264, |mean|=0.0779, |std|=0.1020, max=1.7015
# layers.3.fc.weight epoch 10: mean=-0.0241, std=0.0779, |mean|=0.0622, |std|=0.0527, max=0.4665
# layers.5.fc.weight epoch 10: mean=-0.0028, std=0.0357, |mean|=0.0297, |std|=0.0199, max=0.0707
# epoch-10  lr=['5.0000000'], tr/val_loss:  0.030973/  0.039978, val:  80.42%, val_best:  82.50%, tr:  88.76%, tr_best:  88.76%, epoch time: 18.72 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0660%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.1255%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.8227%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 11: mean=-0.0227, std=0.1303, |mean|=0.0802, |std|=0.1052, max=1.7995
# layers.3.fc.weight epoch 11: mean=-0.0245, std=0.0794, |mean|=0.0633, |std|=0.0538, max=0.4789
# layers.5.fc.weight epoch 11: mean=-0.0029, std=0.0355, |mean|=0.0295, |std|=0.0200, max=0.0707
# epoch-11  lr=['5.0000000'], tr/val_loss:  0.028618/  0.038906, val:  81.25%, val_best:  82.50%, tr:  90.09%, tr_best:  90.09%, epoch time: 17.69 seconds, 0.29 minutes
# layer   1  Sparsity: 91.0880%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.0437%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.7076%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 12: mean=-0.0224, std=0.1342, |mean|=0.0822, |std|=0.1084, max=1.8667
# layers.3.fc.weight epoch 12: mean=-0.0250, std=0.0806, |mean|=0.0642, |std|=0.0548, max=0.4790
# layers.5.fc.weight epoch 12: mean=-0.0029, std=0.0353, |mean|=0.0292, |std|=0.0200, max=0.0707
# epoch-12  lr=['5.0000000'], tr/val_loss:  0.026591/  0.037594, val:  81.25%, val_best:  82.50%, tr:  92.24%, tr_best:  92.24%, epoch time: 18.34 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0643%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.9872%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.6889%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 13: mean=-0.0230, std=0.1372, |mean|=0.0840, |std|=0.1109, max=1.9015
# layers.3.fc.weight epoch 13: mean=-0.0254, std=0.0817, |mean|=0.0650, |std|=0.0557, max=0.4999
# layers.5.fc.weight epoch 13: mean=-0.0029, std=0.0351, |mean|=0.0289, |std|=0.0201, max=0.0707
# epoch-13  lr=['5.0000000'], tr/val_loss:  0.024299/  0.036859, val:  83.33%, val_best:  83.33%, tr:  92.65%, tr_best:  92.65%, epoch time: 18.18 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0995%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.1046%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.5865%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 14: mean=-0.0229, std=0.1400, |mean|=0.0855, |std|=0.1132, max=1.9399
# layers.3.fc.weight epoch 14: mean=-0.0254, std=0.0829, |mean|=0.0657, |std|=0.0566, max=0.4968
# layers.5.fc.weight epoch 14: mean=-0.0030, std=0.0349, |mean|=0.0287, |std|=0.0201, max=0.0707
# epoch-14  lr=['5.0000000'], tr/val_loss:  0.023790/  0.037397, val:  81.67%, val_best:  83.33%, tr:  93.36%, tr_best:  93.36%, epoch time: 18.60 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0385%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.9822%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.5100%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 15: mean=-0.0233, std=0.1424, |mean|=0.0870, |std|=0.1151, max=1.9404
# layers.3.fc.weight epoch 15: mean=-0.0253, std=0.0840, |mean|=0.0664, |std|=0.0573, max=0.4910
# layers.5.fc.weight epoch 15: mean=-0.0030, std=0.0347, |mean|=0.0285, |std|=0.0201, max=0.0707
# epoch-15  lr=['5.0000000'], tr/val_loss:  0.021628/  0.037558, val:  80.83%, val_best:  83.33%, tr:  94.69%, tr_best:  94.69%, epoch time: 18.16 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0757%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.0799%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.4654%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 16: mean=-0.0231, std=0.1446, |mean|=0.0883, |std|=0.1169, max=1.8661
# layers.3.fc.weight epoch 16: mean=-0.0258, std=0.0847, |mean|=0.0670, |std|=0.0579, max=0.4980
# layers.5.fc.weight epoch 16: mean=-0.0030, std=0.0346, |mean|=0.0282, |std|=0.0202, max=0.0707
# epoch-16  lr=['5.0000000'], tr/val_loss:  0.020777/  0.035016, val:  83.33%, val_best:  83.33%, tr:  95.40%, tr_best:  95.40%, epoch time: 18.30 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0930%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.1979%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.4499%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 17: mean=-0.0235, std=0.1466, |mean|=0.0895, |std|=0.1185, max=1.9612
# layers.3.fc.weight epoch 17: mean=-0.0260, std=0.0855, |mean|=0.0675, |std|=0.0585, max=0.5031
# layers.5.fc.weight epoch 17: mean=-0.0031, std=0.0344, |mean|=0.0280, |std|=0.0202, max=0.0707
# epoch-17  lr=['5.0000000'], tr/val_loss:  0.019239/  0.034437, val:  85.00%, val_best:  85.00%, tr:  95.81%, tr_best:  95.81%, epoch time: 18.30 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1040%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.0395%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.4171%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 18: mean=-0.0235, std=0.1485, |mean|=0.0905, |std|=0.1200, max=1.9690
# layers.3.fc.weight epoch 18: mean=-0.0261, std=0.0861, |mean|=0.0680, |std|=0.0590, max=0.5215
# layers.5.fc.weight epoch 18: mean=-0.0031, std=0.0342, |mean|=0.0278, |std|=0.0202, max=0.0707
# epoch-18  lr=['5.0000000'], tr/val_loss:  0.017106/  0.036401, val:  79.58%, val_best:  85.00%, tr:  96.63%, tr_best:  96.63%, epoch time: 18.37 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0757%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.8468%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.3377%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 19: mean=-0.0234, std=0.1499, |mean|=0.0915, |std|=0.1211, max=1.9762
# layers.3.fc.weight epoch 19: mean=-0.0263, std=0.0867, |mean|=0.0684, |std|=0.0594, max=0.5211
# layers.5.fc.weight epoch 19: mean=-0.0031, std=0.0341, |mean|=0.0276, |std|=0.0202, max=0.0707
# epoch-19  lr=['5.0000000'], tr/val_loss:  0.017488/  0.036236, val:  82.08%, val_best:  85.00%, tr:  95.81%, tr_best:  96.63%, epoch time: 17.96 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0894%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7830%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.3152%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 20: mean=-0.0232, std=0.1515, |mean|=0.0924, |std|=0.1223, max=1.9631
# layers.3.fc.weight epoch 20: mean=-0.0264, std=0.0873, |mean|=0.0688, |std|=0.0599, max=0.5289
# layers.5.fc.weight epoch 20: mean=-0.0031, std=0.0339, |mean|=0.0274, |std|=0.0202, max=0.0707
# epoch-20  lr=['5.0000000'], tr/val_loss:  0.016518/  0.033718, val:  82.92%, val_best:  85.00%, tr:  97.34%, tr_best:  97.34%, epoch time: 18.04 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0738%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.8175%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.3037%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 21: mean=-0.0234, std=0.1528, |mean|=0.0932, |std|=0.1234, max=1.9448
# layers.3.fc.weight epoch 21: mean=-0.0265, std=0.0879, |mean|=0.0692, |std|=0.0603, max=0.5299
# layers.5.fc.weight epoch 21: mean=-0.0032, std=0.0338, |mean|=0.0272, |std|=0.0203, max=0.0707
# epoch-21  lr=['5.0000000'], tr/val_loss:  0.015644/  0.032953, val:  83.33%, val_best:  85.00%, tr:  97.34%, tr_best:  97.34%, epoch time: 18.23 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0715%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7692%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.2812%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 22: mean=-0.0234, std=0.1541, |mean|=0.0940, |std|=0.1244, max=1.9581
# layers.3.fc.weight epoch 22: mean=-0.0266, std=0.0885, |mean|=0.0696, |std|=0.0607, max=0.5385
# layers.5.fc.weight epoch 22: mean=-0.0032, std=0.0337, |mean|=0.0270, |std|=0.0203, max=0.0707
# epoch-22  lr=['5.0000000'], tr/val_loss:  0.015326/  0.032171, val:  85.42%, val_best:  85.42%, tr:  97.24%, tr_best:  97.34%, epoch time: 18.59 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0664%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7969%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.2447%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 23: mean=-0.0233, std=0.1554, |mean|=0.0947, |std|=0.1254, max=1.9426
# layers.3.fc.weight epoch 23: mean=-0.0268, std=0.0890, |mean|=0.0700, |std|=0.0611, max=0.5308
# layers.5.fc.weight epoch 23: mean=-0.0032, std=0.0335, |mean|=0.0269, |std|=0.0203, max=0.0707
# epoch-23  lr=['5.0000000'], tr/val_loss:  0.013874/  0.031032, val:  85.00%, val_best:  85.42%, tr:  98.06%, tr_best:  98.06%, epoch time: 18.24 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0696%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.8190%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.1634%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 24: mean=-0.0237, std=0.1564, |mean|=0.0953, |std|=0.1262, max=1.9797
# layers.3.fc.weight epoch 24: mean=-0.0267, std=0.0895, |mean|=0.0703, |std|=0.0614, max=0.5324
# layers.5.fc.weight epoch 24: mean=-0.0032, std=0.0334, |mean|=0.0267, |std|=0.0203, max=0.0707
# epoch-24  lr=['5.0000000'], tr/val_loss:  0.013347/  0.032506, val:  84.17%, val_best:  85.42%, tr:  97.75%, tr_best:  98.06%, epoch time: 18.14 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0648%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7660%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.1296%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 25: mean=-0.0236, std=0.1574, |mean|=0.0959, |std|=0.1270, max=1.9803
# layers.3.fc.weight epoch 25: mean=-0.0268, std=0.0898, |mean|=0.0706, |std|=0.0617, max=0.5438
# layers.5.fc.weight epoch 25: mean=-0.0032, std=0.0333, |mean|=0.0266, |std|=0.0203, max=0.0707
# epoch-25  lr=['5.0000000'], tr/val_loss:  0.012762/  0.031641, val:  85.83%, val_best:  85.83%, tr:  97.85%, tr_best:  98.06%, epoch time: 17.97 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0866%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7729%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.1096%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 26: mean=-0.0235, std=0.1584, |mean|=0.0966, |std|=0.1278, max=2.0048
# layers.3.fc.weight epoch 26: mean=-0.0269, std=0.0903, |mean|=0.0709, |std|=0.0621, max=0.5487
# layers.5.fc.weight epoch 26: mean=-0.0032, std=0.0332, |mean|=0.0264, |std|=0.0203, max=0.0707
# epoch-26  lr=['5.0000000'], tr/val_loss:  0.012011/  0.031917, val:  85.00%, val_best:  85.83%, tr:  98.47%, tr_best:  98.47%, epoch time: 18.27 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0998%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6975%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.1114%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 27: mean=-0.0235, std=0.1594, |mean|=0.0972, |std|=0.1285, max=1.9723
# layers.3.fc.weight epoch 27: mean=-0.0268, std=0.0908, |mean|=0.0712, |std|=0.0624, max=0.5655
# layers.5.fc.weight epoch 27: mean=-0.0032, std=0.0331, |mean|=0.0263, |std|=0.0204, max=0.0707
# epoch-27  lr=['5.0000000'], tr/val_loss:  0.012535/  0.029987, val:  86.67%, val_best:  86.67%, tr:  98.47%, tr_best:  98.47%, epoch time: 18.39 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0822%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6554%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.1074%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 28: mean=-0.0237, std=0.1603, |mean|=0.0978, |std|=0.1293, max=1.9980
# layers.3.fc.weight epoch 28: mean=-0.0269, std=0.0912, |mean|=0.0715, |std|=0.0627, max=0.5703
# layers.5.fc.weight epoch 28: mean=-0.0033, std=0.0330, |mean|=0.0261, |std|=0.0204, max=0.0707
# epoch-28  lr=['5.0000000'], tr/val_loss:  0.012402/  0.029620, val:  87.92%, val_best:  87.92%, tr:  98.26%, tr_best:  98.47%, epoch time: 18.09 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0599%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7851%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0955%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 29: mean=-0.0235, std=0.1613, |mean|=0.0983, |std|=0.1300, max=1.9569
# layers.3.fc.weight epoch 29: mean=-0.0270, std=0.0916, |mean|=0.0718, |std|=0.0630, max=0.5847
# layers.5.fc.weight epoch 29: mean=-0.0033, std=0.0329, |mean|=0.0260, |std|=0.0204, max=0.0707
# epoch-29  lr=['5.0000000'], tr/val_loss:  0.011207/  0.031042, val:  86.67%, val_best:  87.92%, tr:  99.18%, tr_best:  99.18%, epoch time: 18.29 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0610%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5959%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0528%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 30: mean=-0.0237, std=0.1621, |mean|=0.0988, |std|=0.1306, max=1.9925
# layers.3.fc.weight epoch 30: mean=-0.0268, std=0.0921, |mean|=0.0721, |std|=0.0633, max=0.6023
# layers.5.fc.weight epoch 30: mean=-0.0033, std=0.0328, |mean|=0.0258, |std|=0.0204, max=0.0707
# epoch-30  lr=['5.0000000'], tr/val_loss:  0.012212/  0.030976, val:  87.50%, val_best:  87.92%, tr:  98.77%, tr_best:  99.18%, epoch time: 18.25 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0918%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6898%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0372%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 31: mean=-0.0238, std=0.1630, |mean|=0.0994, |std|=0.1313, max=2.0083
# layers.3.fc.weight epoch 31: mean=-0.0269, std=0.0925, |mean|=0.0723, |std|=0.0636, max=0.6077
# layers.5.fc.weight epoch 31: mean=-0.0033, std=0.0326, |mean|=0.0257, |std|=0.0204, max=0.0707
# epoch-31  lr=['5.0000000'], tr/val_loss:  0.012035/  0.030982, val:  86.25%, val_best:  87.92%, tr:  98.57%, tr_best:  99.18%, epoch time: 18.47 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0199%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.7456%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0589%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 32: mean=-0.0237, std=0.1638, |mean|=0.0999, |std|=0.1320, max=1.9939
# layers.3.fc.weight epoch 32: mean=-0.0271, std=0.0927, |mean|=0.0725, |std|=0.0638, max=0.6054
# layers.5.fc.weight epoch 32: mean=-0.0034, std=0.0325, |mean|=0.0255, |std|=0.0204, max=0.0707
# epoch-32  lr=['5.0000000'], tr/val_loss:  0.011090/  0.030837, val:  84.58%, val_best:  87.92%, tr:  98.57%, tr_best:  99.18%, epoch time: 18.39 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0971%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6403%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0517%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 33: mean=-0.0237, std=0.1646, |mean|=0.1004, |std|=0.1325, max=1.9534
# layers.3.fc.weight epoch 33: mean=-0.0271, std=0.0931, |mean|=0.0727, |std|=0.0640, max=0.6189
# layers.5.fc.weight epoch 33: mean=-0.0034, std=0.0324, |mean|=0.0254, |std|=0.0204, max=0.0707
# epoch-33  lr=['5.0000000'], tr/val_loss:  0.010843/  0.030416, val:  86.67%, val_best:  87.92%, tr:  98.57%, tr_best:  99.18%, epoch time: 17.97 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0921%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6018%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0398%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 34: mean=-0.0238, std=0.1653, |mean|=0.1009, |std|=0.1331, max=1.9795
# layers.3.fc.weight epoch 34: mean=-0.0270, std=0.0935, |mean|=0.0730, |std|=0.0644, max=0.6205
# layers.5.fc.weight epoch 34: mean=-0.0034, std=0.0323, |mean|=0.0252, |std|=0.0204, max=0.0707
# epoch-34  lr=['5.0000000'], tr/val_loss:  0.009578/  0.032578, val:  84.17%, val_best:  87.92%, tr:  98.98%, tr_best:  99.18%, epoch time: 18.44 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0577%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5993%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.0102%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 35: mean=-0.0238, std=0.1660, |mean|=0.1013, |std|=0.1336, max=1.9836
# layers.3.fc.weight epoch 35: mean=-0.0271, std=0.0938, |mean|=0.0732, |std|=0.0645, max=0.6333
# layers.5.fc.weight epoch 35: mean=-0.0034, std=0.0322, |mean|=0.0251, |std|=0.0205, max=0.0707
# epoch-35  lr=['5.0000000'], tr/val_loss:  0.009517/  0.030255, val:  84.58%, val_best:  87.92%, tr:  99.28%, tr_best:  99.28%, epoch time: 18.62 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1061%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5705%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9964%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 36: mean=-0.0239, std=0.1666, |mean|=0.1017, |std|=0.1341, max=1.9611
# layers.3.fc.weight epoch 36: mean=-0.0270, std=0.0942, |mean|=0.0735, |std|=0.0648, max=0.6289
# layers.5.fc.weight epoch 36: mean=-0.0035, std=0.0321, |mean|=0.0250, |std|=0.0205, max=0.0707
# epoch-36  lr=['5.0000000'], tr/val_loss:  0.009276/  0.029225, val:  85.83%, val_best:  87.92%, tr:  98.88%, tr_best:  99.28%, epoch time: 17.99 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0831%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6358%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9711%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 37: mean=-0.0239, std=0.1672, |mean|=0.1021, |std|=0.1346, max=1.9133
# layers.3.fc.weight epoch 37: mean=-0.0270, std=0.0945, |mean|=0.0737, |std|=0.0650, max=0.6377
# layers.5.fc.weight epoch 37: mean=-0.0035, std=0.0321, |mean|=0.0249, |std|=0.0205, max=0.0707
# epoch-37  lr=['5.0000000'], tr/val_loss:  0.009410/  0.031123, val:  82.92%, val_best:  87.92%, tr:  98.98%, tr_best:  99.28%, epoch time: 17.96 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0683%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6054%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9509%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 38: mean=-0.0239, std=0.1679, |mean|=0.1026, |std|=0.1350, max=1.9676
# layers.3.fc.weight epoch 38: mean=-0.0270, std=0.0948, |mean|=0.0739, |std|=0.0652, max=0.6362
# layers.5.fc.weight epoch 38: mean=-0.0035, std=0.0320, |mean|=0.0248, |std|=0.0205, max=0.0707
# epoch-38  lr=['5.0000000'], tr/val_loss:  0.008238/  0.030479, val:  87.08%, val_best:  87.92%, tr:  99.49%, tr_best:  99.49%, epoch time: 18.10 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0647%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5492%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9239%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 39: mean=-0.0241, std=0.1684, |mean|=0.1029, |std|=0.1354, max=1.9703
# layers.3.fc.weight epoch 39: mean=-0.0269, std=0.0951, |mean|=0.0741, |std|=0.0654, max=0.6430
# layers.5.fc.weight epoch 39: mean=-0.0035, std=0.0319, |mean|=0.0247, |std|=0.0205, max=0.0707
# epoch-39  lr=['5.0000000'], tr/val_loss:  0.008354/  0.030247, val:  87.50%, val_best:  87.92%, tr:  99.28%, tr_best:  99.49%, epoch time: 19.00 seconds, 0.32 minutes
# layer   1  Sparsity: 91.0565%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6056%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9477%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 40: mean=-0.0243, std=0.1689, |mean|=0.1033, |std|=0.1358, max=2.0039
# layers.3.fc.weight epoch 40: mean=-0.0271, std=0.0953, |mean|=0.0743, |std|=0.0656, max=0.6476
# layers.5.fc.weight epoch 40: mean=-0.0035, std=0.0318, |mean|=0.0245, |std|=0.0205, max=0.0707
# epoch-40  lr=['5.0000000'], tr/val_loss:  0.008217/  0.030589, val:  84.58%, val_best:  87.92%, tr:  99.28%, tr_best:  99.49%, epoch time: 18.51 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0994%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6119%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.9122%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 41: mean=-0.0242, std=0.1694, |mean|=0.1036, |std|=0.1362, max=1.9904
# layers.3.fc.weight epoch 41: mean=-0.0271, std=0.0956, |mean|=0.0745, |std|=0.0658, max=0.6515
# layers.5.fc.weight epoch 41: mean=-0.0035, std=0.0317, |mean|=0.0245, |std|=0.0205, max=0.0707
# epoch-41  lr=['5.0000000'], tr/val_loss:  0.007681/  0.029680, val:  87.08%, val_best:  87.92%, tr:  99.18%, tr_best:  99.49%, epoch time: 18.50 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0498%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6125%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8936%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 42: mean=-0.0242, std=0.1699, |mean|=0.1039, |std|=0.1366, max=2.0052
# layers.3.fc.weight epoch 42: mean=-0.0272, std=0.0959, |mean|=0.0746, |std|=0.0660, max=0.6544
# layers.5.fc.weight epoch 42: mean=-0.0035, std=0.0317, |mean|=0.0243, |std|=0.0206, max=0.0707
# epoch-42  lr=['5.0000000'], tr/val_loss:  0.007758/  0.029667, val:  85.42%, val_best:  87.92%, tr:  99.18%, tr_best:  99.49%, epoch time: 18.17 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0906%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6553%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8813%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 43: mean=-0.0243, std=0.1704, |mean|=0.1043, |std|=0.1370, max=2.0266
# layers.3.fc.weight epoch 43: mean=-0.0272, std=0.0961, |mean|=0.0748, |std|=0.0662, max=0.6514
# layers.5.fc.weight epoch 43: mean=-0.0035, std=0.0316, |mean|=0.0242, |std|=0.0206, max=0.0707
# epoch-43  lr=['5.0000000'], tr/val_loss:  0.007550/  0.029816, val:  85.00%, val_best:  87.92%, tr:  99.28%, tr_best:  99.49%, epoch time: 18.46 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0760%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5336%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8425%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 44: mean=-0.0241, std=0.1709, |mean|=0.1046, |std|=0.1373, max=2.0225
# layers.3.fc.weight epoch 44: mean=-0.0272, std=0.0964, |mean|=0.0750, |std|=0.0663, max=0.6620
# layers.5.fc.weight epoch 44: mean=-0.0035, std=0.0315, |mean|=0.0242, |std|=0.0206, max=0.0707
# epoch-44  lr=['5.0000000'], tr/val_loss:  0.007455/  0.028058, val:  86.67%, val_best:  87.92%, tr:  99.39%, tr_best:  99.49%, epoch time: 18.85 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1194%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5539%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8553%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 45: mean=-0.0243, std=0.1714, |mean|=0.1049, |std|=0.1377, max=2.0279
# layers.3.fc.weight epoch 45: mean=-0.0272, std=0.0967, |mean|=0.0752, |std|=0.0666, max=0.6619
# layers.5.fc.weight epoch 45: mean=-0.0036, std=0.0315, |mean|=0.0241, |std|=0.0206, max=0.0707
# epoch-45  lr=['5.0000000'], tr/val_loss:  0.007315/  0.027251, val:  88.33%, val_best:  88.33%, tr:  99.59%, tr_best:  99.59%, epoch time: 18.16 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0369%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5902%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8416%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 46: mean=-0.0242, std=0.1718, |mean|=0.1052, |std|=0.1380, max=2.0325
# layers.3.fc.weight epoch 46: mean=-0.0273, std=0.0968, |mean|=0.0753, |std|=0.0667, max=0.6784
# layers.5.fc.weight epoch 46: mean=-0.0036, std=0.0314, |mean|=0.0240, |std|=0.0206, max=0.0707
# epoch-46  lr=['5.0000000'], tr/val_loss:  0.007039/  0.027518, val:  87.08%, val_best:  88.33%, tr:  99.59%, tr_best:  99.59%, epoch time: 18.25 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0879%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.6000%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8573%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 47: mean=-0.0245, std=0.1722, |mean|=0.1055, |std|=0.1383, max=2.0329
# layers.3.fc.weight epoch 47: mean=-0.0272, std=0.0972, |mean|=0.0755, |std|=0.0669, max=0.6698
# layers.5.fc.weight epoch 47: mean=-0.0036, std=0.0313, |mean|=0.0239, |std|=0.0206, max=0.0707
# epoch-47  lr=['5.0000000'], tr/val_loss:  0.006940/  0.028504, val:  85.83%, val_best:  88.33%, tr:  99.39%, tr_best:  99.59%, epoch time: 18.27 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0775%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5062%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8349%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 48: mean=-0.0242, std=0.1727, |mean|=0.1058, |std|=0.1386, max=2.0597
# layers.3.fc.weight epoch 48: mean=-0.0272, std=0.0974, |mean|=0.0756, |std|=0.0671, max=0.6767
# layers.5.fc.weight epoch 48: mean=-0.0036, std=0.0312, |mean|=0.0238, |std|=0.0206, max=0.0707
# epoch-48  lr=['5.0000000'], tr/val_loss:  0.006849/  0.029582, val:  85.83%, val_best:  88.33%, tr:  99.69%, tr_best:  99.69%, epoch time: 18.13 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0438%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 84.5623%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 96.8169%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 49: mean=-0.0245, std=0.1730, |mean|=0.1061, |std|=0.1389, max=2.0509
# layers.3.fc.weight epoch 49: mean=-0.0271, std=0.0976, |mean|=0.0758, |std|=0.0673, max=0.6837
# layers.5.fc.weight epoch 49: mean=-0.0036, std=0.0312, |mean|=0.0237, |std|=0.0206, max=0.0707
# ...
#
#
# ++++++++++++++++++++++++
#
#  lif layer 2 v_bit: 0, v_exp: None
#
# ++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
#  layer_count 3
# weight bias bit 0
# weight exp, bias exp None None
# bit_for_output 0 exp_for_output None
#
#
#
# DataParallel(
#   (module): REBORN_MY_SNN_FC(
#     (layers): REBORN_MY_Sequential(
#       (0): DimChanger_for_FC()
#       (1): SYNAPSE_FC(in_features=980, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=1, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (2): LIF_layer(v_init=0, v_decay=0.125, v_threshold=0.0005, v_reset=0, sg_width=2, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.125, TIME=10, sstep=False, trace_on=False, layer_count=1, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (3): SYNAPSE_FC(in_features=200, out_features=200, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=2, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#       (4): LIF_layer(v_init=0, v_decay=0.125, v_threshold=2, v_reset=0, sg_width=1, surrogate=sigmoid, BPTT_on=True, trace_const1=1, trace_const2=0.125, TIME=10, sstep=False, trace_on=False, layer_count=2, scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False)
#       (5): SYNAPSE_FC(in_features=200, out_features=10, TIME=10, bias=False, sstep=False, time_different_weight=False, layer_count=3, quantize_bit_list=[], scale_exp=[[999, 999], [999, 999], [999, 999]], ANPI_MODE=False, init_scaling=None)
#     )
#   )
# )
#
# ========================================================
# Trainable parameters: 238,000
# ========================================================
#
# MySGD (
# Parameter Group 0
#     lr: 5
#     momentum: 0.0
# )
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 0: mean=-0.0000, std=0.0184, |mean|=0.0160, |std|=0.0092, max=0.0319
# layers.3.fc.weight epoch 0: mean=0.0000, std=0.0407, |mean|=0.0352, |std|=0.0204, max=0.0707
# layers.5.fc.weight epoch 0: mean=-0.0006, std=0.0406, |mean|=0.0351, |std|=0.0204, max=0.0707
# epoch-0   lr=['5.0000000'], tr/val_loss:  0.111374/  0.097947, val:  39.17%, val_best:  39.17%, tr:  39.53%, tr_best:  39.53%, epoch time: 18.98 seconds, 0.32 minutes
# layer   1  Sparsity: 91.0954%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 85.5043%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.5180%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 1: mean=-0.0172, std=0.0656, |mean|=0.0447, |std|=0.0510, max=0.5705
# layers.3.fc.weight epoch 1: mean=-0.0149, std=0.0553, |mean|=0.0457, |std|=0.0345, max=0.3087
# layers.5.fc.weight epoch 1: mean=-0.0011, std=0.0394, |mean|=0.0340, |std|=0.0199, max=0.0705
# epoch-1   lr=['5.0000000'], tr/val_loss:  0.080830/  0.072014, val:  58.75%, val_best:  58.75%, tr:  57.92%, tr_best:  57.92%, epoch time: 18.48 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0718%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.2689%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.2724%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 2: mean=-0.0194, std=0.0803, |mean|=0.0522, |std|=0.0641, max=0.8288
# layers.3.fc.weight epoch 2: mean=-0.0186, std=0.0598, |mean|=0.0492, |std|=0.0387, max=0.3534
# layers.5.fc.weight epoch 2: mean=-0.0014, std=0.0387, |mean|=0.0332, |std|=0.0198, max=0.0705
# epoch-2   lr=['5.0000000'], tr/val_loss:  0.068473/  0.068392, val:  59.58%, val_best:  59.58%, tr:  63.33%, tr_best:  63.33%, epoch time: 18.57 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0983%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.3831%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 99.0281%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 3: mean=-0.0222, std=0.0885, |mean|=0.0568, |std|=0.0714, max=0.9705
# layers.3.fc.weight epoch 3: mean=-0.0201, std=0.0630, |mean|=0.0514, |std|=0.0415, max=0.3796
# layers.5.fc.weight epoch 3: mean=-0.0016, std=0.0381, |mean|=0.0326, |std|=0.0197, max=0.0705
# epoch-3   lr=['5.0000000'], tr/val_loss:  0.060261/  0.068153, val:  62.50%, val_best:  62.50%, tr:  66.70%, tr_best:  66.70%, epoch time: 18.72 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0334%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4984%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.8263%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 4: mean=-0.0230, std=0.0952, |mean|=0.0604, |std|=0.0771, max=1.0414
# layers.3.fc.weight epoch 4: mean=-0.0215, std=0.0654, |mean|=0.0533, |std|=0.0436, max=0.3960
# layers.5.fc.weight epoch 4: mean=-0.0018, std=0.0376, |mean|=0.0320, |std|=0.0198, max=0.0705
# epoch-4   lr=['5.0000000'], tr/val_loss:  0.055371/  0.066151, val:  67.92%, val_best:  67.92%, tr:  71.81%, tr_best:  71.81%, epoch time: 18.59 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0648%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4694%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.6677%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 5: mean=-0.0228, std=0.1012, |mean|=0.0637, |std|=0.0818, max=1.1631
# layers.3.fc.weight epoch 5: mean=-0.0219, std=0.0679, |mean|=0.0550, |std|=0.0455, max=0.4264
# layers.5.fc.weight epoch 5: mean=-0.0019, std=0.0372, |mean|=0.0316, |std|=0.0198, max=0.0705
# epoch-5   lr=['5.0000000'], tr/val_loss:  0.048454/  0.050277, val:  72.92%, val_best:  72.92%, tr:  76.20%, tr_best:  76.20%, epoch time: 18.53 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0796%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.2970%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.5018%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 6: mean=-0.0237, std=0.1067, |mean|=0.0669, |std|=0.0864, max=1.1657
# layers.3.fc.weight epoch 6: mean=-0.0223, std=0.0703, |mean|=0.0567, |std|=0.0472, max=0.4341
# layers.5.fc.weight epoch 6: mean=-0.0020, std=0.0370, |mean|=0.0312, |std|=0.0199, max=0.0705
# epoch-6   lr=['5.0000000'], tr/val_loss:  0.043652/  0.052279, val:  72.92%, val_best:  72.92%, tr:  78.45%, tr_best:  78.45%, epoch time: 18.35 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0868%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.1376%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.3459%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 7: mean=-0.0236, std=0.1127, |mean|=0.0702, |std|=0.0912, max=1.4517
# layers.3.fc.weight epoch 7: mean=-0.0223, std=0.0726, |mean|=0.0582, |std|=0.0488, max=0.4625
# layers.5.fc.weight epoch 7: mean=-0.0021, std=0.0367, |mean|=0.0308, |std|=0.0200, max=0.0706
# epoch-7   lr=['5.0000000'], tr/val_loss:  0.040724/  0.049823, val:  72.50%, val_best:  72.92%, tr:  79.67%, tr_best:  79.67%, epoch time: 18.06 seconds, 0.30 minutes
# layer   1  Sparsity: 91.1167%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.1285%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.2620%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 8: mean=-0.0242, std=0.1186, |mean|=0.0737, |std|=0.0960, max=1.4174
# layers.3.fc.weight epoch 8: mean=-0.0225, std=0.0749, |mean|=0.0598, |std|=0.0504, max=0.4955
# layers.5.fc.weight epoch 8: mean=-0.0022, std=0.0365, |mean|=0.0305, |std|=0.0201, max=0.0705
# epoch-8   lr=['5.0000000'], tr/val_loss:  0.036803/  0.049964, val:  72.92%, val_best:  72.92%, tr:  82.74%, tr_best:  82.74%, epoch time: 18.26 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0600%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.2032%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.1561%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 9: mean=-0.0248, std=0.1245, |mean|=0.0769, |std|=0.1010, max=1.6908
# layers.3.fc.weight epoch 9: mean=-0.0221, std=0.0776, |mean|=0.0615, |std|=0.0523, max=0.5182
# layers.5.fc.weight epoch 9: mean=-0.0022, std=0.0363, |mean|=0.0303, |std|=0.0202, max=0.0705
# epoch-9   lr=['5.0000000'], tr/val_loss:  0.034522/  0.044000, val:  76.25%, val_best:  76.25%, tr:  86.62%, tr_best:  86.62%, epoch time: 18.49 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1075%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.2866%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.1097%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 10: mean=-0.0257, std=0.1300, |mean|=0.0800, |std|=0.1057, max=1.5974
# layers.3.fc.weight epoch 10: mean=-0.0227, std=0.0794, |mean|=0.0627, |std|=0.0537, max=0.5326
# layers.5.fc.weight epoch 10: mean=-0.0023, std=0.0361, |mean|=0.0300, |std|=0.0202, max=0.0705
# epoch-10  lr=['5.0000000'], tr/val_loss:  0.031245/  0.040191, val:  83.33%, val_best:  83.33%, tr:  87.95%, tr_best:  87.95%, epoch time: 18.77 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1017%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4730%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.0886%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 11: mean=-0.0262, std=0.1351, |mean|=0.0828, |std|=0.1100, max=1.7198
# layers.3.fc.weight epoch 11: mean=-0.0232, std=0.0812, |mean|=0.0639, |std|=0.0551, max=0.5543
# layers.5.fc.weight epoch 11: mean=-0.0024, std=0.0359, |mean|=0.0298, |std|=0.0202, max=0.0705
# epoch-11  lr=['5.0000000'], tr/val_loss:  0.028593/  0.042333, val:  79.58%, val_best:  83.33%, tr:  90.91%, tr_best:  90.91%, epoch time: 18.26 seconds, 0.30 minutes
# layer   1  Sparsity: 91.0841%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.6595%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.0351%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 12: mean=-0.0273, std=0.1394, |mean|=0.0853, |std|=0.1136, max=1.7236
# layers.3.fc.weight epoch 12: mean=-0.0233, std=0.0827, |mean|=0.0649, |std|=0.0562, max=0.5956
# layers.5.fc.weight epoch 12: mean=-0.0024, std=0.0357, |mean|=0.0295, |std|=0.0202, max=0.0705
# epoch-12  lr=['5.0000000'], tr/val_loss:  0.027792/  0.039443, val:  81.25%, val_best:  83.33%, tr:  89.58%, tr_best:  90.91%, epoch time: 18.55 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0864%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.7118%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 98.0336%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 13: mean=-0.0271, std=0.1433, |mean|=0.0874, |std|=0.1168, max=1.7399
# layers.3.fc.weight epoch 13: mean=-0.0240, std=0.0837, |mean|=0.0657, |std|=0.0571, max=0.5974
# layers.5.fc.weight epoch 13: mean=-0.0025, std=0.0355, |mean|=0.0293, |std|=0.0202, max=0.0705
# epoch-13  lr=['5.0000000'], tr/val_loss:  0.026215/  0.041023, val:  80.00%, val_best:  83.33%, tr:  91.83%, tr_best:  91.83%, epoch time: 18.57 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0749%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.5598%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.9874%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 14: mean=-0.0269, std=0.1467, |mean|=0.0892, |std|=0.1195, max=1.7072
# layers.3.fc.weight epoch 14: mean=-0.0244, std=0.0846, |mean|=0.0664, |std|=0.0578, max=0.5840
# layers.5.fc.weight epoch 14: mean=-0.0026, std=0.0353, |mean|=0.0290, |std|=0.0202, max=0.0705
# epoch-14  lr=['5.0000000'], tr/val_loss:  0.025466/  0.037193, val:  83.33%, val_best:  83.33%, tr:  91.83%, tr_best:  91.83%, epoch time: 18.44 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0365%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4767%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.9563%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 15: mean=-0.0270, std=0.1498, |mean|=0.0910, |std|=0.1220, max=1.6826
# layers.3.fc.weight epoch 15: mean=-0.0244, std=0.0858, |mean|=0.0672, |std|=0.0587, max=0.6001
# layers.5.fc.weight epoch 15: mean=-0.0027, std=0.0351, |mean|=0.0288, |std|=0.0202, max=0.0705
# epoch-15  lr=['5.0000000'], tr/val_loss:  0.023548/  0.036449, val:  84.58%, val_best:  84.58%, tr:  93.87%, tr_best:  93.87%, epoch time: 18.40 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1123%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.3409%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.9244%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 16: mean=-0.0275, std=0.1524, |mean|=0.0926, |std|=0.1241, max=1.7246
# layers.3.fc.weight epoch 16: mean=-0.0246, std=0.0866, |mean|=0.0677, |std|=0.0593, max=0.6171
# layers.5.fc.weight epoch 16: mean=-0.0027, std=0.0348, |mean|=0.0285, |std|=0.0202, max=0.0705
# epoch-16  lr=['5.0000000'], tr/val_loss:  0.023181/  0.035789, val:  84.58%, val_best:  84.58%, tr:  94.69%, tr_best:  94.69%, epoch time: 18.44 seconds, 0.31 minutes
# layer   1  Sparsity: 91.1069%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4039%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.9021%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 17: mean=-0.0277, std=0.1546, |mean|=0.0939, |std|=0.1259, max=1.7516
# layers.3.fc.weight epoch 17: mean=-0.0250, std=0.0874, |mean|=0.0683, |std|=0.0599, max=0.6171
# layers.5.fc.weight epoch 17: mean=-0.0028, std=0.0346, |mean|=0.0282, |std|=0.0202, max=0.0705
# epoch-17  lr=['5.0000000'], tr/val_loss:  0.020632/  0.033700, val:  82.92%, val_best:  84.58%, tr:  94.28%, tr_best:  94.69%, epoch time: 18.34 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0800%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.5466%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.8272%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 18: mean=-0.0281, std=0.1566, |mean|=0.0950, |std|=0.1275, max=1.7860
# layers.3.fc.weight epoch 18: mean=-0.0251, std=0.0881, |mean|=0.0688, |std|=0.0605, max=0.6162
# layers.5.fc.weight epoch 18: mean=-0.0029, std=0.0344, |mean|=0.0280, |std|=0.0202, max=0.0705
# epoch-18  lr=['5.0000000'], tr/val_loss:  0.019688/  0.034135, val:  84.58%, val_best:  84.58%, tr:  94.48%, tr_best:  94.69%, epoch time: 18.36 seconds, 0.31 minutes
# layer   1  Sparsity: 91.0491%
# layer   1  average_sram_cycle_util: 0.0000%
# layer   2  Sparsity: 86.4290%
# layer   2  average_sram_cycle_util: 0.0000%
# layer   3  Sparsity: 97.8091%
# layer   3  average_sram_cycle_util: 0.0000%
# total_backward_count 0 real_backward_count 0   0.000%
# layers.1.fc.weight epoch 19: mean=-0.0281, std=0.1585, |mean|=0.0962, |std|=0.1291, max=1.8736
# layers.3.fc.weight epoch 19: mean=-0.0252, std=0.0889, |mean|=0.0693, |std|=0.0611, max=0.6125
# layers.5.fc.weight epoch 19: mean=-0.0029, std=0.0342, |mean|=0.0278, |std|=0.0202, max=0.0705
