# %% [markdown]
# # ssp.train.py

# %%
import torch   
import torch.nn as nn 
import torch.nn.functional as F   
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle
import json
import time

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    coarse_com_mode = True,
    coarse_com_config = (2.0, -2.0), # (max, min)

    sae_l2_norm_bridge = True,
    sae_lif_bridge = False,

    accuracy_check_epoch_term = 5,
    
    lif_add_at_last = False,

    two_channel_input = False,
    ):
    if coarse_com_mode == True:
        assert coarse_com_config[0] > coarse_com_config[1], 'coarse_com_config[0] > coarse_com_config[1]이어야 함'
        assert SAE_net == True, 'coarse_com_mode는 SAE_net이 True일 때만 가능'

    if two_channel_input == True:
        assert Conv_net and coarse_com_mode, 'two_channel_input는 Conv_net이 True일 때만 가능'

    seed_assign(my_seed)
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    # JSON으로 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'w') as f:
        json.dump(hyperparameters, f, indent=4)
    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset2", summary="max")


    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])


    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'


    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    if coarse_com_mode == True:
        level_num = TIME
        TIME = spike_length
        spike_length = level_num
        level_interval = (coarse_com_config[0] - coarse_com_config[1]) / (level_num-1)  # max - min
        levels = [coarse_com_config[1] + level_interval * i for i in range(level_num)]
        levels = torch.tensor(levels).to(torch.float).to(device)
        levels = levels.repeat(TIME,1) 
        # print('levels', levels, levels.shape) # TIME, level_num

    n_sample = spike_length

    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            input_channels = 2 if two_channel_input else 1
            net = Autoencoder_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, 4], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            input_channels = 2 if two_channel_input else 1
            net = SAE_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)
        else:
            net = SAE_fc_only(encoder_ch=[96, 64, 32, 4], 
                                decoder_ch=[32,64,96,n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마
    net.module.load_state_dict(torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250108_201216_960.pth'))




    wandb.watch(net, log="all", log_freq = 10)





    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__



    net = net.to(device)
    print(f"Total number of parameters: {sum(p.numel() for p in net.module.encoder.parameters())}")
    print(net)
    print('Device:',device)

    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0

    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__
    
    for epoch in range(max_epoch):

        ae_train_start_time = time.time()
        running_loss = 0.0
        iter = 0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike_backup = data
            spike = data
            spike = spike.to(device) # batch, feature
            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                spike = (spike > levels).to(torch.float) 
                # spike: batch, time, level_num
                # levels: time, level_num
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    if two_channel_input == True:
                        spike_backup = spike_backup.to(device)
                        spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_backup = (spike_backup <= levels).to(torch.float) 
                        spike_backup = spike_backup.unsqueeze(-2)
                        spike = torch.cat((spike, spike_backup), dim=-2)
                assert spike.shape[0] == batch_size and spike.shape[1] == TIME
            elif 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
            else:
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) #batch in_channel,feature

            spike_class = net(spike) # batch, time, feature

            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                # loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                # loss1 = nn.MSELoss()(spike_class[..., 5:25, :], spike[..., 5:25, :])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5, :], spike[..., 0:5, :])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length, :], spike[..., 25:spike_length, :])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                loss = nn.MSELoss()(spike_class, spike)
            elif 'SAE' in net.module.__class__.__name__:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            else:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            # print(f'\nepoch-{epoch}, running_loss : {running_loss:.5f}, iter percent {iter/len(train_loader)*100:.2f}%')
            iter += 1
        avg_loss = running_loss / len(train_loader)
        assert not np.isnan(avg_loss), f"Error: avg_loss is NaN! Running loss: {running_loss}, Length of train_loader: {len(train_loader)}"
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')
        print(f"ae train 실행 시간: {time.time()-ae_train_start_time:.3f}초")





        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    

        if(epoch % accuracy_check_epoch_term == 0 or epoch == 1 or epoch == max_epoch-1): 
            accuracy_check_start_time = time.time()
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = 4*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else 4

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    spike_torch = torch.from_numpy(spike_template).float()
                    spike_backup = spike_torch
                    spike_torch = spike_torch.to(device)
                    if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_torch = (spike_torch > levels).to(torch.float) 
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                            if two_channel_input == True:
                                spike_backup = spike_backup.to(device)
                                spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                spike_backup = (spike_backup <= levels).to(torch.float) 
                                spike_backup = spike_backup.unsqueeze(-2) # batch, time, in_channel, feature
                                spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                    elif 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    else:
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                    inner_inf = net.module.encoder(spike_torch)

                    # if 'SAE' in net.module.__class__.__name__:
                    #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                    #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                    #     print(all_equal, inner_inf)

                    if 'SAE' in net.module.__class__.__name__:
                        if SAE_hidden_nomean == True:
                            inner_inf = inner_inf.reshape(spike_template.shape[0],-1)# time*feature 펼치기
                        else:
                            inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균

                    Cluster = inner_inf.cpu().detach().numpy()

                encoder_batch = 128
                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    now_index = 0
                    while (1):
                        now_end_index = now_index+encoder_batch if now_index+encoder_batch < len(spike) else len(spike)
                        spike_batch = spike[now_index:now_end_index] 
                        spike_torch = torch.from_numpy(spike_batch)
                        spike_torch = spike_torch.float()
                        spike_backup = spike_torch
                        spike_torch = spike_torch.to(device)
                        if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                            spike_torch = (spike_torch > levels).to(torch.float) 
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                                if two_channel_input == True:
                                    spike_backup = spike_backup.to(device)
                                    spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                    spike_backup = (spike_backup <= levels).to(torch.float) 
                                    spike_backup = spike_backup.unsqueeze(-2)
                                    spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                        elif 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                        else:
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                                
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.reshape(spike_batch.shape[0],-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[now_index:now_end_index] = inner_inf.cpu().detach().numpy()
                        now_index += encoder_batch
                        if (now_index >= len(spike)):
                            break
                    
                spike_id = np.zeros(len(spike))
                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                            tau[q] = tau[q] / denominator

                    # for i in range(num_cluster): # l2 distance
                    #     distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))
                    distance_sm = np.sum(np.power(np.abs(Cluster - spike_hidden[spike_index, :]), 2), axis=1)

                    m = np.argmin(distance_sm)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16
                
                # print('Cluster',Cluster)
                # print('spike_id', spike_id)

                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                perm_start_time = time.time()
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1
                # print(f"perm 실행 시간: {time.time()-perm_start_time:.3f}초")
                
                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                torch.save(net.module.state_dict(), f"net_save/save_now_net_{current_time}.pth")
                print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
            print(f"accuracy_check 실행 시간: {time.time()-accuracy_check_start_time:.3f}초")

        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset2": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


        # 저장
        with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
            pickle.dump({
                "loss_history": loss_history,
                "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
            }, f)

# %%
gpu = 5
Conv_net = True
SAE_net = False

# hyperparameter
dataset_num = 16
spike_length = 50 # coarse_com_mode일 때는 time step이 됨.
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 2400 #1400 2400 # 그 초기 몇개까지만 cluster update할지


batch_size = 32
max_epoch = 7000
learning_rate = 0.001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 50 # SAE일 때만 유효. coarse_com_mode일 때는 level_num이 됨. 즉 feature 개수.
v_decay = 0.5 # -cor
v_threshold = 0.5 # -cor
v_reset = 0.0 # -cor # 10000이상 일 시 hard reset
BPTT_on = True # +cor

SAE_hidden_nomean = True # True False

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'SGD' #'Adam', 'SGD' # 둘다 준수함. loss 줄이는 거는 adam이 좋긴한데, cluster accuracy는 비슷함.

coarse_com_mode = False
coarse_com_config = (2.0, -2.0) # (max, min) (2.0, -2.0) (3.0 -3.0)

sae_l2_norm_bridge = False # True False
sae_lif_bridge = True # False True

accuracy_check_epoch_term = 1
    
lif_add_at_last = False # True False

two_channel_input = False # True False

wandb.init(project= f'spike_sorting just run',save_code=False)


cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    
    current_time = current_time,

    optimizer = optimizer, #'Adam', 'SGD'

    coarse_com_mode = coarse_com_mode,
    coarse_com_config = coarse_com_config, # (max, min)

    
    sae_l2_norm_bridge = sae_l2_norm_bridge,
    sae_lif_bridge = sae_lif_bridge,

    accuracy_check_epoch_term = accuracy_check_epoch_term,
    
    lif_add_at_last = lif_add_at_last,

    two_channel_input = two_channel_input,
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250108_210643-tb23o84l</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/tb23o84l' target="_blank">vocal-dream-341</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/tb23o84l' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/tb23o84l</a>
# {'gpu': 5, 'Conv_net': True, 'SAE_net': False, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 2400, 'batch_size': 32, 'max_epoch': 7000, 'learning_rate': 0.001, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 50, 'v_decay': 0.5, 'v_threshold': 0.5, 'v_reset': 0.0, 'BPTT_on': True, 'SAE_hidden_nomean': True, 'current_time': '20250108_210641_941', 'optimizer': 'SGD', 'coarse_com_mode': False, 'sae_l2_norm_bridge': False, 'sae_lif_bridge': True, 'accuracy_check_epoch_term': 1, 'lif_add_at_last': False, 'two_channel_input': False, 'coarse_com_config': (2.0, -2.0)}
# Total number of parameters: 26592
# DataParallel(
#   (module): Autoencoder_conv1(
#     (encoder): Sequential(
#       (0): Conv1d(1, 32, kernel_size=(3,), stride=(2,), bias=False)
#       (1): ReLU()
#       (2): Conv1d(32, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (3): ReLU()
#       (4): Conv1d(64, 96, kernel_size=(3,), stride=(2,), bias=False)
#       (5): ReLU()
#       (6): SSBH_DimChanger_for_fc()
#       (7): Linear(in_features=480, out_features=4, bias=False)
#       (8): SSBH_L2NormLayer()
#     )
#     (decoder): Sequential(
#       (0): Linear(in_features=4, out_features=480, bias=False)
#       (1): ReLU()
#       (2): SSBH_DimChanger_for_conv1()
#       (3): ConvTranspose1d(96, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (4): ReLU()
#       (5): ConvTranspose1d(64, 32, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (6): ReLU()
#       (7): ConvTranspose1d(32, 1, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250108_210641_941
#
# epoch-0 loss : 0.01847
# ae train 실행 시간: 9.494초
#
# epoch-0 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91119005 0.9664293  0.97614504 0.92817164 0.90532544
#  0.96784232 0.97175141 0.89711538 0.81518756]
# mean_cluster_accuracy_during_training_cycle : 94.16%, post_traincycle_acc : 94.48%, total_acc : 94.25%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.48%
# accuracy_check 실행 시간: 7.921초
#
# epoch-1 loss : 0.01849
# ae train 실행 시간: 8.849초
#
# epoch-1 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91296625 0.9664293  0.97423664 0.92723881 0.90433925
#  0.96784232 0.97175141 0.89423077 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.17%, post_traincycle_acc : 94.53%, total_acc : 94.28%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.53%
# accuracy_check 실행 시간: 7.613초
#
# epoch-2 loss : 0.01847
# ae train 실행 시간: 9.151초
#
# epoch-2 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91474245 0.9664293  0.97519084 0.92723881 0.90138067
#  0.96784232 0.97175141 0.90384615 0.84354986]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.67%, total_acc : 94.39%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.200초
#
# epoch-3 loss : 0.01846
# ae train 실행 시간: 9.389초
#
# epoch-3 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95252226 0.90941385 0.9664293  0.97423664 0.92817164 0.90433925
#  0.96887967 0.97175141 0.89423077 0.82708143]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.50%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.215초
#
# epoch-4 loss : 0.01849
# ae train 실행 시간: 9.311초
#
# epoch-4 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91119005 0.9664293  0.97519084 0.92537313 0.90335306
#  0.96784232 0.97080979 0.89807692 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.58%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.176초
#
# epoch-5 loss : 0.01851
# ae train 실행 시간: 9.588초
#
# epoch-5 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91474245 0.9664293  0.97423664 0.92350746 0.90335306
#  0.96887967 0.97175141 0.89903846 0.81335773]
# mean_cluster_accuracy_during_training_cycle : 94.12%, post_traincycle_acc : 94.44%, total_acc : 94.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.313초
#
# epoch-6 loss : 0.01845
# ae train 실행 시간: 9.883초
#
# epoch-6 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91385435 0.9664293  0.97614504 0.92910448 0.90433925
#  0.96784232 0.97269303 0.90192308 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.33%, post_traincycle_acc : 94.64%, total_acc : 94.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.180초
#
# epoch-7 loss : 0.01850
# ae train 실행 시간: 9.138초
#
# epoch-7 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91207815 0.9664293  0.97328244 0.92537313 0.90433925
#  0.96887967 0.97175141 0.90384615 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.64%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 5.963초
#
# epoch-8 loss : 0.01847
# ae train 실행 시간: 9.123초
#
# epoch-8 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97524752 0.95714286
#  0.95351137 0.91385435 0.9664293  0.97519084 0.92537313 0.90532544
#  0.96784232 0.97175141 0.89711538 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.58%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 7.404초
#
# epoch-9 loss : 0.01852
# ae train 실행 시간: 9.724초
#
# epoch-9 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91207815 0.9664293  0.97423664 0.9244403  0.90039448
#  0.96887967 0.97269303 0.90288462 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.57%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.209초
#
# epoch-10 loss : 0.01847
# ae train 실행 시간: 9.583초
#
# epoch-10 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91207815 0.9664293  0.97519084 0.92817164 0.90729783
#  0.96887967 0.97175141 0.9        0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.63%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.248초
#
# epoch-11 loss : 0.01846
# ae train 실행 시간: 9.328초
#
# epoch-11 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95647873 0.91296625 0.9664293  0.97423664 0.92350746 0.90433925
#  0.96887967 0.97175141 0.89423077 0.81335773]
# mean_cluster_accuracy_during_training_cycle : 94.18%, post_traincycle_acc : 94.43%, total_acc : 94.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.031초
#
# epoch-12 loss : 0.01846
# ae train 실행 시간: 8.928초
#
# epoch-12 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.90852575 0.9664293  0.97423664 0.92817164 0.90335306
#  0.96887967 0.97175141 0.89615385 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.20%, post_traincycle_acc : 94.54%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 5.953초
#
# epoch-13 loss : 0.01847
# ae train 실행 시간: 9.247초
#
# epoch-13 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91296625 0.9664293  0.97519084 0.93003731 0.90927022
#  0.96887967 0.97175141 0.89711538 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.65%, total_acc : 94.40%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 7.265초
#
# epoch-14 loss : 0.01847
# ae train 실행 시간: 9.477초
#
# epoch-14 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91119005 0.9664293  0.97423664 0.92630597 0.90433925
#  0.96887967 0.97175141 0.9        0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.57%, total_acc : 94.31%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 5.965초
#
# epoch-15 loss : 0.01847
# ae train 실행 시간: 9.141초
#
# epoch-15 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95714286
#  0.95351137 0.91207815 0.9664293  0.97519084 0.92350746 0.90433925
#  0.96887967 0.97080979 0.89423077 0.81427264]
# mean_cluster_accuracy_during_training_cycle : 94.13%, post_traincycle_acc : 94.39%, total_acc : 94.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 5.979초
#
# epoch-16 loss : 0.01850
# ae train 실행 시간: 9.421초
#
# epoch-16 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91651865 0.965412   0.97423664 0.92164179 0.90433925
#  0.96887967 0.97080979 0.89711538 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.55%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.162초
#
# epoch-17 loss : 0.01849
# ae train 실행 시간: 9.471초
#
# epoch-17 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91474245 0.9664293  0.97519084 0.9244403  0.90236686
#  0.96887967 0.97175141 0.90288462 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.61%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.237초
#
# epoch-18 loss : 0.01849
# ae train 실행 시간: 9.490초
#
# epoch-18 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91119005 0.965412   0.97423664 0.93003731 0.90532544
#  0.96887967 0.97269303 0.9        0.84172004]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.67%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.230초
#
# epoch-19 loss : 0.01845
# ae train 실행 시간: 9.735초
#
# epoch-19 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95714286
#  0.95153314 0.90852575 0.9664293  0.97423664 0.9244403  0.90138067
#  0.96887967 0.97175141 0.89615385 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.14%, post_traincycle_acc : 94.47%, total_acc : 94.24%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.132초
#
# epoch-20 loss : 0.01848
# ae train 실행 시간: 9.040초
#
# epoch-20 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95252226 0.91385435 0.9664293  0.97519084 0.92630597 0.90433925
#  0.96887967 0.97175141 0.89711538 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.58%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.209초
#
# epoch-21 loss : 0.01848
# ae train 실행 시간: 9.100초
#
# epoch-21 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91296625 0.9664293  0.97423664 0.92164179 0.90335306
#  0.96887967 0.97269303 0.90384615 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.18%, post_traincycle_acc : 94.54%, total_acc : 94.29%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.625초
#
# epoch-22 loss : 0.01848
# ae train 실행 시간: 8.971초
#
# epoch-22 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95450049 0.90941385 0.9664293  0.97519084 0.92257463 0.90335306
#  0.96784232 0.97175141 0.89423077 0.82891125]
# mean_cluster_accuracy_during_training_cycle : 94.19%, post_traincycle_acc : 94.48%, total_acc : 94.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.437초
#
# epoch-23 loss : 0.01844
# ae train 실행 시간: 8.975초
#
# epoch-23 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91296625 0.9664293  0.97614504 0.91977612 0.90039448
#  0.96784232 0.97175141 0.89519231 0.82250686]
# mean_cluster_accuracy_during_training_cycle : 94.19%, post_traincycle_acc : 94.43%, total_acc : 94.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 7.026초
#
# epoch-24 loss : 0.01847
# ae train 실행 시간: 8.921초
#
# epoch-24 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91474245 0.9664293  0.97519084 0.92537313 0.90532544
#  0.96887967 0.97175141 0.90192308 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.59%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.506초
#
# epoch-25 loss : 0.01846
# ae train 실행 시간: 8.890초
#
# epoch-25 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95647873 0.91207815 0.9664293  0.97423664 0.92537313 0.90532544
#  0.96887967 0.97269303 0.90673077 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.67%, total_acc : 94.41%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.252초
#
# epoch-26 loss : 0.01848
# ae train 실행 시간: 8.946초
#
# epoch-26 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91119005 0.9664293  0.97614504 0.9244403  0.90729783
#  0.96887967 0.97269303 0.90192308 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.62%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.099초
#
# epoch-27 loss : 0.01847
# ae train 실행 시간: 9.302초
#
# epoch-27 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91030195 0.9664293  0.97614504 0.92630597 0.90631164
#  0.96784232 0.97175141 0.90288462 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.60%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.102초
#
# epoch-28 loss : 0.01846
# ae train 실행 시간: 9.308초
#
# epoch-28 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92723881 0.90335306
#  0.96887967 0.97080979 0.89615385 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.54%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.139초
#
# epoch-29 loss : 0.01847
# ae train 실행 시간: 9.705초
#
# epoch-29 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91030195 0.9664293  0.97519084 0.92257463 0.90532544
#  0.96887967 0.97080979 0.89519231 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.11%, post_traincycle_acc : 94.49%, total_acc : 94.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.051초
#
# epoch-30 loss : 0.01846
# ae train 실행 시간: 9.539초
#
# epoch-30 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91207815 0.9664293  0.97423664 0.92723881 0.90631164
#  0.96887967 0.97269303 0.90192308 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.65%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 6.130초
#
# epoch-31 loss : 0.01844
# ae train 실행 시간: 9.721초
#
# epoch-31 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95845697 0.91119005 0.9664293  0.97423664 0.92817164 0.90433925
#  0.96887967 0.97269303 0.89615385 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.61%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.67%
# accuracy_check 실행 시간: 5.851초
#
# epoch-32 loss : 0.01844
# ae train 실행 시간: 9.639초
#
# epoch-32 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91385435 0.9664293  0.97519084 0.92630597 0.90828402
#  0.96887967 0.97269303 0.90480769 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 94.36%, post_traincycle_acc : 94.70%, total_acc : 94.46%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.963초
#
# epoch-33 loss : 0.01845
# ae train 실행 시간: 9.604초
#
# epoch-33 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91474245 0.9664293  0.97614504 0.92910448 0.90631164
#  0.96784232 0.97175141 0.89423077 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.63%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.977초
#
# epoch-34 loss : 0.01843
# ae train 실행 시간: 9.592초
#
# epoch-34 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91385435 0.9664293  0.97423664 0.92723881 0.90138067
#  0.96887967 0.97175141 0.89807692 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.61%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.029초
#
# epoch-35 loss : 0.01846
# ae train 실행 시간: 9.356초
#
# epoch-35 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.90852575 0.9664293  0.97519084 0.92630597 0.90631164
#  0.96887967 0.97269303 0.89807692 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.016초
#
# epoch-36 loss : 0.01843
# ae train 실행 시간: 8.818초
#
# epoch-36 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91030195 0.9664293  0.97519084 0.92537313 0.90532544
#  0.96887967 0.97080979 0.9        0.82342177]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.50%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.168초
#
# epoch-37 loss : 0.01845
# ae train 실행 시간: 9.220초
#
# epoch-37 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95714286
#  0.95548961 0.91563055 0.9664293  0.97423664 0.92630597 0.90138067
#  0.96887967 0.97080979 0.90480769 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.58%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.890초
#
# epoch-38 loss : 0.01848
# ae train 실행 시간: 9.508초
#
# epoch-38 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91651865 0.9664293  0.97423664 0.9244403  0.90631164
#  0.96887967 0.97175141 0.89903846 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.58%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 7.405초
#
# epoch-39 loss : 0.01845
# ae train 실행 시간: 9.574초
#
# epoch-39 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91207815 0.9664293  0.97423664 0.92537313 0.90433925
#  0.96887967 0.97175141 0.9        0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.20%, post_traincycle_acc : 94.53%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.041초
#
# epoch-40 loss : 0.01845
# ae train 실행 시간: 9.509초
#
# epoch-40 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95714286
#  0.95351137 0.91385435 0.9664293  0.97423664 0.92723881 0.90828402
#  0.96784232 0.97080979 0.90480769 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.31%, post_traincycle_acc : 94.61%, total_acc : 94.40%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.005초
#
# epoch-41 loss : 0.01842
# ae train 실행 시간: 9.573초
#
# epoch-41 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91207815 0.9664293  0.97423664 0.92630597 0.90433925
#  0.96887967 0.97269303 0.90384615 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.62%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.105초
#
# epoch-42 loss : 0.01844
# ae train 실행 시간: 9.522초
#
# epoch-42 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95746785 0.91385435 0.9664293  0.97614504 0.92537313 0.90729783
#  0.96887967 0.97080979 0.89615385 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.60%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.945초
#
# epoch-43 loss : 0.01842
# ae train 실행 시간: 9.465초
#
# epoch-43 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95845697 0.91296625 0.9664293  0.97519084 0.92630597 0.90433925
#  0.96887967 0.97269303 0.90096154 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.62%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.873초
#
# epoch-44 loss : 0.01844
# ae train 실행 시간: 9.511초
#
# epoch-44 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91207815 0.9664293  0.97423664 0.92070896 0.90335306
#  0.96887967 0.97175141 0.89519231 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.15%, post_traincycle_acc : 94.49%, total_acc : 94.25%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.873초
#
# epoch-45 loss : 0.01842
# ae train 실행 시간: 9.644초
#
# epoch-45 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91119005 0.9664293  0.97519084 0.9244403  0.90236686
#  0.96887967 0.97175141 0.89230769 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.51%, total_acc : 94.31%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.986초
#
# epoch-46 loss : 0.01846
# ae train 실행 시간: 9.745초
#
# epoch-46 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91207815 0.9664293  0.97519084 0.92537313 0.90433925
#  0.96887967 0.97080979 0.90192308 0.82250686]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.53%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.105초
#
# epoch-47 loss : 0.01847
# ae train 실행 시간: 8.723초
#
# epoch-47 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92723881 0.90335306
#  0.96887967 0.97269303 0.90673077 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.63%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.882초
#
# epoch-48 loss : 0.01842
# ae train 실행 시간: 9.000초
#
# epoch-48 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92350746 0.90335306
#  0.96887967 0.97175141 0.89903846 0.84263495]
# mean_cluster_accuracy_during_training_cycle : 94.20%, post_traincycle_acc : 94.62%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.012초
#
# epoch-49 loss : 0.01845
# ae train 실행 시간: 9.539초
#
# epoch-49 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.90941385 0.9664293  0.97328244 0.92164179 0.90236686
#  0.96887967 0.97269303 0.90576923 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.58%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.893초
#
# epoch-50 loss : 0.01840
# ae train 실행 시간: 9.448초
#
# epoch-50 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95647873 0.91474245 0.9664293  0.97519084 0.92537313 0.90433925
#  0.96887967 0.97175141 0.90384615 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.34%, post_traincycle_acc : 94.63%, total_acc : 94.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 7.088초
#
# epoch-51 loss : 0.01841
# ae train 실행 시간: 9.398초
#
# epoch-51 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91474245 0.965412   0.97423664 0.9244403  0.90729783
#  0.96887967 0.97175141 0.90480769 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.63%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.965초
#
# epoch-52 loss : 0.01841
# ae train 실행 시간: 9.501초
#
# epoch-52 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91651865 0.9664293  0.97519084 0.92537313 0.90532544
#  0.96887967 0.97175141 0.89615385 0.82708143]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.045초
#
# epoch-53 loss : 0.01843
# ae train 실행 시간: 9.466초
#
# epoch-53 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91030195 0.965412   0.97423664 0.92723881 0.90433925
#  0.96887967 0.97363465 0.9        0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.58%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.001초
#
# epoch-54 loss : 0.01843
# ae train 실행 시간: 9.567초
#
# epoch-54 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95647873 0.91385435 0.9664293  0.97423664 0.92350746 0.90433925
#  0.96887967 0.97175141 0.89519231 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.55%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.168초
#
# epoch-55 loss : 0.01845
# ae train 실행 시간: 9.535초
#
# epoch-55 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95746785 0.91474245 0.9664293  0.97423664 0.9244403  0.90335306
#  0.96887967 0.97269303 0.90769231 0.84080512]
# mean_cluster_accuracy_during_training_cycle : 94.33%, post_traincycle_acc : 94.70%, total_acc : 94.44%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.887초
#
# epoch-56 loss : 0.01843
# ae train 실행 시간: 9.422초
#
# epoch-56 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91651865 0.965412   0.97519084 0.93097015 0.90335306
#  0.96887967 0.97175141 0.89423077 0.82616651]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.56%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.989초
#
# epoch-57 loss : 0.01843
# ae train 실행 시간: 9.516초
#
# epoch-57 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91385435 0.9664293  0.97423664 0.92910448 0.90236686
#  0.96887967 0.97269303 0.90480769 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.67%, total_acc : 94.41%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.919초
#
# epoch-58 loss : 0.01842
# ae train 실행 시간: 8.750초
#
# epoch-58 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95647873 0.91474245 0.9664293  0.97519084 0.92723881 0.90335306
#  0.96887967 0.97080979 0.89711538 0.82708143]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.56%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.932초
#
# epoch-59 loss : 0.01841
# ae train 실행 시간: 9.448초
#
# epoch-59 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91474245 0.9664293  0.97423664 0.92910448 0.90532544
#  0.96887967 0.97175141 0.89326923 0.82708143]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.55%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.048초
#
# epoch-60 loss : 0.01842
# ae train 실행 시간: 9.440초
#
# epoch-60 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91829485 0.965412   0.97519084 0.92537313 0.90039448
#  0.96887967 0.97175141 0.89903846 0.82891125]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.56%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 7.783초
#
# epoch-61 loss : 0.01842
# ae train 실행 시간: 9.460초
#
# epoch-61 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91296625 0.9664293  0.97614504 0.92630597 0.90532544
#  0.96887967 0.97363465 0.90192308 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.64%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.841초
#
# epoch-62 loss : 0.01841
# ae train 실행 시간: 9.351초
#
# epoch-62 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91030195 0.9664293  0.97423664 0.92817164 0.90433925
#  0.96887967 0.97269303 0.89615385 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.194초
#
# epoch-63 loss : 0.01841
# ae train 실행 시간: 9.352초
#
# epoch-63 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91119005 0.9664293  0.97423664 0.92723881 0.90532544
#  0.96887967 0.97269303 0.90480769 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.33%, post_traincycle_acc : 94.64%, total_acc : 94.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.341초
#
# epoch-64 loss : 0.01843
# ae train 실행 시간: 9.445초
#
# epoch-64 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91296625 0.9664293  0.97519084 0.92817164 0.90335306
#  0.96887967 0.97175141 0.90192308 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.63%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 7.711초
#
# epoch-65 loss : 0.01840
# ae train 실행 시간: 9.452초
#
# epoch-65 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96843083 0.96554935 0.97425743 0.95714286
#  0.95153314 0.91119005 0.9664293  0.97423664 0.92070896 0.89940828
#  0.96887967 0.97080979 0.89615385 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.13%, post_traincycle_acc : 94.45%, total_acc : 94.23%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.117초
#
# epoch-66 loss : 0.01842
# ae train 실행 시간: 9.439초
#
# epoch-66 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91296625 0.9664293  0.97519084 0.92537313 0.90631164
#  0.96887967 0.97175141 0.89519231 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.59%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.286초
#
# epoch-67 loss : 0.01842
# ae train 실행 시간: 9.203초
#
# epoch-67 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.90941385 0.9664293  0.97614504 0.92630597 0.90631164
#  0.96887967 0.97363465 0.90673077 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.30%, post_traincycle_acc : 94.66%, total_acc : 94.41%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.083초
#
# epoch-68 loss : 0.01842
# ae train 실행 시간: 9.705초
#
# epoch-68 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95153314 0.91385435 0.9664293  0.97423664 0.92537313 0.90335306
#  0.96887967 0.97363465 0.90288462 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.61%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.153초
#
# epoch-69 loss : 0.01843
# ae train 실행 시간: 9.636초
#
# epoch-69 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95548961 0.91207815 0.9664293  0.97519084 0.92723881 0.90039448
#  0.96887967 0.97175141 0.89807692 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.55%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.469초
#
# epoch-70 loss : 0.01839
# ae train 실행 시간: 9.757초
#
# epoch-70 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95647873 0.91474245 0.9664293  0.97423664 0.92723881 0.90631164
#  0.96887967 0.97269303 0.90576923 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.31%, post_traincycle_acc : 94.69%, total_acc : 94.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.279초
#
# epoch-71 loss : 0.01839
# ae train 실행 시간: 9.527초
#
# epoch-71 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91207815 0.9664293  0.97423664 0.92630597 0.90335306
#  0.96887967 0.97175141 0.90673077 0.84720952]
# mean_cluster_accuracy_during_training_cycle : 94.38%, post_traincycle_acc : 94.72%, total_acc : 94.48%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.72%
# accuracy_check 실행 시간: 6.224초
#
# epoch-72 loss : 0.01840
# ae train 실행 시간: 9.322초
#
# epoch-72 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91119005 0.9664293  0.97423664 0.92630597 0.90138067
#  0.96887967 0.97269303 0.90480769 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.59%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.72%
# accuracy_check 실행 시간: 6.288초
#
# epoch-73 loss : 0.01839
# ae train 실행 시간: 9.127초
#
# epoch-73 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91563055 0.9664293  0.97519084 0.92723881 0.90532544
#  0.96887967 0.97363465 0.90769231 0.84172004]
# mean_cluster_accuracy_during_training_cycle : 94.35%, post_traincycle_acc : 94.73%, total_acc : 94.47%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.026초
#
# epoch-74 loss : 0.01840
# ae train 실행 시간: 9.135초
#
# epoch-74 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91119005 0.9664293  0.97423664 0.92537313 0.90335306
#  0.96887967 0.97269303 0.90480769 0.83989021]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.64%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.122초
#
# epoch-75 loss : 0.01840
# ae train 실행 시간: 9.718초
#
# epoch-75 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91474245 0.9664293  0.97423664 0.92723881 0.90236686
#  0.96887967 0.97269303 0.89615385 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.59%, total_acc : 94.34%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.339초
#
# epoch-76 loss : 0.01841
# ae train 실행 시간: 9.790초
#
# epoch-76 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91563055 0.9664293  0.97423664 0.92630597 0.90433925
#  0.96887967 0.97175141 0.90096154 0.82616651]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.654초
#
# epoch-77 loss : 0.01838
# ae train 실행 시간: 9.501초
#
# epoch-77 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91563055 0.9664293  0.97423664 0.92910448 0.90828402
#  0.96887967 0.97363465 0.90288462 0.82708143]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.63%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.703초
#
# epoch-78 loss : 0.01841
# ae train 실행 시간: 9.121초
#
# epoch-78 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91385435 0.9664293  0.97519084 0.92630597 0.90335306
#  0.96887967 0.97269303 0.90961538 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 94.37%, post_traincycle_acc : 94.71%, total_acc : 94.47%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.544초
#
# epoch-79 loss : 0.01837
# ae train 실행 시간: 9.448초
#
# epoch-79 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91474245 0.9664293  0.97519084 0.92910448 0.90236686
#  0.96887967 0.97269303 0.90384615 0.83989021]
# mean_cluster_accuracy_during_training_cycle : 94.34%, post_traincycle_acc : 94.70%, total_acc : 94.45%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.303초
#
# epoch-80 loss : 0.01837
# ae train 실행 시간: 9.530초
#
# epoch-80 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97524752 0.95803571
#  0.95647873 0.91474245 0.9664293  0.97519084 0.92910448 0.90532544
#  0.96887967 0.97269303 0.90384615 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.33%, post_traincycle_acc : 94.65%, total_acc : 94.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.635초
#
# epoch-81 loss : 0.01838
# ae train 실행 시간: 9.838초
#
# epoch-81 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95746785 0.91119005 0.9664293  0.97519084 0.92630597 0.9112426
#  0.96887967 0.97175141 0.90192308 0.82342177]
# mean_cluster_accuracy_during_training_cycle : 94.30%, post_traincycle_acc : 94.60%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.487초
#
# epoch-82 loss : 0.01839
# ae train 실행 시간: 9.678초
#
# epoch-82 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91119005 0.9664293  0.97519084 0.92630597 0.90828402
#  0.96887967 0.96986817 0.89711538 0.81518756]
# mean_cluster_accuracy_during_training_cycle : 94.12%, post_traincycle_acc : 94.46%, total_acc : 94.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.364초
#
# epoch-83 loss : 0.01841
# ae train 실행 시간: 9.921초
#
# epoch-83 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95647873 0.91296625 0.9664293  0.97614504 0.92537313 0.90532544
#  0.96887967 0.97175141 0.90288462 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.36%, post_traincycle_acc : 94.66%, total_acc : 94.45%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 7.336초
#
# epoch-84 loss : 0.01840
# ae train 실행 시간: 9.006초
#
# epoch-84 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91296625 0.965412   0.97614504 0.92723881 0.90532544
#  0.96887967 0.97269303 0.90673077 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.66%, total_acc : 94.40%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.400초
#
# epoch-85 loss : 0.01839
# ae train 실행 시간: 9.045초
#
# epoch-85 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91119005 0.9664293  0.97423664 0.9244403  0.90039448
#  0.96887967 0.97269303 0.89615385 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.52%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.195초
#
# epoch-86 loss : 0.01837
# ae train 실행 시간: 8.900초
#
# epoch-86 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92164179 0.90335306
#  0.96887967 0.97269303 0.89807692 0.82891125]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.53%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.475초
#
# epoch-87 loss : 0.01840
# ae train 실행 시간: 9.407초
#
# epoch-87 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95746785 0.91474245 0.9664293  0.97423664 0.92630597 0.90631164
#  0.96887967 0.97175141 0.90288462 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.67%, total_acc : 94.41%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 6.575초
#
# epoch-88 loss : 0.01840
# ae train 실행 시간: 9.187초
#
# epoch-88 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91119005 0.9664293  0.97423664 0.92630597 0.90138067
#  0.96887967 0.97080979 0.89711538 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.55%, total_acc : 94.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.73%
# accuracy_check 실행 시간: 7.025초
#
# epoch-89 loss : 0.01840
# ae train 실행 시간: 8.967초
#
# epoch-89 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91474245 0.9664293  0.97519084 0.92537313 0.90532544
# ...
#  0.95548961 0.91740675 0.965412   0.97900763 0.94776119 0.91814596
#  0.96680498 0.97175141 0.90288462 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.59%, post_traincycle_acc : 94.89%, total_acc : 94.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.513초
#
# epoch-3341 loss : 0.01647
# ae train 실행 시간: 9.262초
#
# epoch-3341 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.96935933 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92273535 0.965412   0.97805344 0.94123134 0.92209073
#  0.96576763 0.97269303 0.90961538 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.01%, post_traincycle_acc : 94.95%, total_acc : 94.29%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.387초
#
# epoch-3342 loss : 0.01648
# ae train 실행 시간: 9.763초
#
# epoch-3342 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92007105 0.965412   0.97900763 0.94402985 0.92110454
#  0.96680498 0.97269303 0.91346154 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.96%, total_acc : 94.69%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 8.379초
#
# epoch-3343 loss : 0.01645
# ae train 실행 시간: 9.376초
#
# epoch-3343 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95647873 0.92095915 0.965412   0.97900763 0.94123134 0.92504931
#  0.96576763 0.97175141 0.91057692 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.48%, post_traincycle_acc : 94.97%, total_acc : 94.63%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.381초
#
# epoch-3344 loss : 0.01645
# ae train 실행 시간: 9.839초
#
# epoch-3344 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92007105 0.965412   0.97805344 0.94216418 0.92011834
#  0.96576763 0.97080979 0.90673077 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.02%, post_traincycle_acc : 94.91%, total_acc : 94.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.526초
#
# epoch-3345 loss : 0.01647
# ae train 실행 시간: 9.871초
#
# epoch-3345 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95845697 0.92539964 0.965412   0.97805344 0.94029851 0.92307692
#  0.96576763 0.97175141 0.90769231 0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 93.89%, post_traincycle_acc : 94.91%, total_acc : 94.20%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.532초
#
# epoch-3346 loss : 0.01645
# ae train 실행 시간: 9.634초
#
# epoch-3346 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92184725 0.965412   0.97900763 0.94776119 0.92209073
#  0.96576763 0.97175141 0.90769231 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.65%, post_traincycle_acc : 94.95%, total_acc : 94.74%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.421초
#
# epoch-3347 loss : 0.01645
# ae train 실행 시간: 9.855초
#
# epoch-3347 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96368715 0.97524752 0.95803571
#  0.95746785 0.92184725 0.965412   0.97900763 0.94309701 0.91814596
#  0.96576763 0.97175141 0.91153846 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.15%, post_traincycle_acc : 94.96%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.530초
#
# epoch-3348 loss : 0.01648
# ae train 실행 시간: 9.735초
#
# epoch-3348 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95746785 0.91563055 0.965412   0.97805344 0.93843284 0.91715976
#  0.96576763 0.97175141 0.91442308 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.86%, total_acc : 94.66%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.566초
#
# epoch-3349 loss : 0.01645
# ae train 실행 시간: 9.423초
#
# epoch-3349 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.96935933 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92007105 0.965412   0.97805344 0.94123134 0.92209073
#  0.96576763 0.97175141 0.90673077 0.82891125]
# mean_cluster_accuracy_during_training_cycle : 94.34%, post_traincycle_acc : 94.86%, total_acc : 94.50%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.316초
#
# epoch-3350 loss : 0.01644
# ae train 실행 시간: 9.537초
#
# epoch-3350 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92273535 0.965412   0.97805344 0.94029851 0.9122288
#  0.96576763 0.97175141 0.90865385 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.86%, total_acc : 94.67%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.368초
#
# epoch-3351 loss : 0.01653
# ae train 실행 시간: 9.677초
#
# epoch-3351 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96554935 0.97524752 0.95803571
#  0.95548961 0.92539964 0.965412   0.97805344 0.9375     0.92110454
#  0.96576763 0.97175141 0.90961538 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.64%, post_traincycle_acc : 94.95%, total_acc : 94.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.568초
#
# epoch-3352 loss : 0.01647
# ae train 실행 시간: 10.241초
#
# epoch-3352 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92451155 0.965412   0.97805344 0.93843284 0.90927022
#  0.96576763 0.97363465 0.91538462 0.84080512]
# mean_cluster_accuracy_during_training_cycle : 94.64%, post_traincycle_acc : 94.94%, total_acc : 94.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.973초
#
# epoch-3353 loss : 0.01645
# ae train 실행 시간: 9.335초
#
# epoch-3353 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95548961 0.91829485 0.965412   0.97900763 0.94029851 0.91518738
#  0.96680498 0.97269303 0.90769231 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.66%, post_traincycle_acc : 94.90%, total_acc : 94.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.258초
#
# epoch-3354 loss : 0.01644
# ae train 실행 시간: 9.201초
#
# epoch-3354 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.91829485 0.965412   0.97805344 0.94309701 0.91715976
#  0.96576763 0.97269303 0.90865385 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.61%, post_traincycle_acc : 94.88%, total_acc : 94.69%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 8.259초
#
# epoch-3355 loss : 0.01646
# ae train 실행 시간: 9.962초
#
# epoch-3355 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95746785 0.92273535 0.965412   0.97805344 0.94029851 0.9122288
#  0.96680498 0.97269303 0.90865385 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 94.55%, post_traincycle_acc : 94.85%, total_acc : 94.64%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.305초
#
# epoch-3356 loss : 0.01646
# ae train 실행 시간: 9.291초
#
# epoch-3356 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95845697 0.91740675 0.965412   0.97805344 0.94216418 0.92110454
#  0.96576763 0.97175141 0.90961538 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.62%, post_traincycle_acc : 94.93%, total_acc : 94.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.323초
#
# epoch-3357 loss : 0.01646
# ae train 실행 시간: 10.186초
#
# epoch-3357 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95450049 0.91651865 0.965412   0.97805344 0.94402985 0.92011834
#  0.96784232 0.97269303 0.91057692 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.63%, post_traincycle_acc : 94.95%, total_acc : 94.72%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.511초
#
# epoch-3358 loss : 0.01643
# ae train 실행 시간: 9.784초
#
# epoch-3358 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92007105 0.965412   0.97805344 0.94123134 0.92011834
#  0.96576763 0.97175141 0.90673077 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.92%, total_acc : 94.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.541초
#
# epoch-3359 loss : 0.01642
# ae train 실행 시간: 8.997초
#
# epoch-3359 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95746785 0.92273535 0.965412   0.97805344 0.94123134 0.92011834
#  0.96576763 0.97175141 0.90769231 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.12%, post_traincycle_acc : 94.94%, total_acc : 94.37%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.392초
#
# epoch-3360 loss : 0.01645
# ae train 실행 시간: 10.203초
#
# epoch-3360 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92273535 0.965412   0.97900763 0.94402985 0.92110454
#  0.96680498 0.97175141 0.90480769 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.60%, post_traincycle_acc : 94.91%, total_acc : 94.69%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.459초
#
# epoch-3361 loss : 0.01646
# ae train 실행 시간: 9.821초
#
# epoch-3361 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95548961 0.92095915 0.965412   0.97805344 0.94216418 0.92110454
#  0.96680498 0.97175141 0.91153846 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.60%, post_traincycle_acc : 94.95%, total_acc : 94.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.330초
#
# epoch-3362 loss : 0.01650
# ae train 실행 시간: 9.950초
#
# epoch-3362 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95845697 0.91918295 0.965412   0.97805344 0.94776119 0.92011834
#  0.96784232 0.97269303 0.90673077 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 94.66%, post_traincycle_acc : 94.99%, total_acc : 94.75%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.465초
#
# epoch-3363 loss : 0.01649
# ae train 실행 시간: 9.550초
#
# epoch-3363 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95450049 0.92273535 0.965412   0.97805344 0.94123134 0.90828402
#  0.96576763 0.97269303 0.91153846 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.50%, post_traincycle_acc : 94.87%, total_acc : 94.61%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.494초
#
# epoch-3364 loss : 0.01647
# ae train 실행 시간: 8.892초
#
# epoch-3364 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95647873 0.92007105 0.965412   0.97805344 0.94029851 0.91913215
#  0.96680498 0.97269303 0.90576923 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.87%, total_acc : 94.67%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.339초
#
# epoch-3365 loss : 0.01646
# ae train 실행 시간: 9.122초
#
# epoch-3365 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95647873 0.92451155 0.965412   0.97900763 0.93656716 0.91814596
#  0.96576763 0.97269303 0.90673077 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.57%, post_traincycle_acc : 94.87%, total_acc : 94.66%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.214초
#
# epoch-3366 loss : 0.01644
# ae train 실행 시간: 9.245초
#
# epoch-3366 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96554935 0.97524752 0.95803571
#  0.95647873 0.92007105 0.965412   0.97805344 0.94029851 0.92110454
#  0.96576763 0.97080979 0.90961538 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.05%, post_traincycle_acc : 94.92%, total_acc : 94.31%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.710초
#
# epoch-3367 loss : 0.01648
# ae train 실행 시간: 9.485초
#
# epoch-3367 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95450049 0.92095915 0.965412   0.97805344 0.94123134 0.92110454
#  0.96576763 0.97269303 0.90865385 0.82891125]
# mean_cluster_accuracy_during_training_cycle : 93.86%, post_traincycle_acc : 94.89%, total_acc : 94.16%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.470초
#
# epoch-3368 loss : 0.01647
# ae train 실행 시간: 10.005초
#
# epoch-3368 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95647873 0.91829485 0.965412   0.97805344 0.94029851 0.92307692
#  0.96576763 0.97175141 0.90769231 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.58%, post_traincycle_acc : 94.91%, total_acc : 94.68%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 7.347초
#
# epoch-3369 loss : 0.01643
# ae train 실행 시간: 9.748초
#
# epoch-3369 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97028784 0.96461825 0.97524752 0.95803571
#  0.95647873 0.92273535 0.965412   0.97805344 0.93936567 0.9260355
#  0.96576763 0.97175141 0.91153846 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.02%, post_traincycle_acc : 94.97%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.529초
#
# epoch-3370 loss : 0.01651
# ae train 실행 시간: 9.112초
#
# epoch-3370 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97121634 0.96461825 0.97524752 0.95803571
#  0.95548961 0.91740675 0.965412   0.97805344 0.94123134 0.91814596
#  0.96576763 0.97175141 0.91057692 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.61%, post_traincycle_acc : 94.91%, total_acc : 94.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.356초
#
# epoch-3371 loss : 0.01645
# ae train 실행 시간: 9.713초
#
# epoch-3371 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.97214485 0.96461825 0.97524752 0.95803571
#  0.95548961 0.91918295 0.965412   0.97805344 0.94309701 0.92307692
#  0.96680498 0.97175141 0.90769231 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.60%, post_traincycle_acc : 94.96%, total_acc : 94.71%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 95.15%
# accuracy_check 실행 시간: 6.535초

# %%
# # Sweep code


# from unittest import TextTestRunner


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [True]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400, 2400]}, # [1400, 2400]

#         "batch_size": {"values": [16,32,48]}, 
#         "max_epoch": {"values": [1]}, 
#         "learning_rate": {"values": [0.001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [False]}, 

#         "lif_add_at_first": {"values": [False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [50,40,30,20]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75,0.875]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75,1.0]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True, False]}, # [True, False]

#         # "current_time": {"values": [current_time]} #밑에서 직접설정됨.

#         "optimizer": {"values": ['Adam', 'SGD']}, # ['Adam', 'SGD']

#         "coarse_com_mode": {"values": [True]}, # ['Adam', 'SGD']
#         "coarse_com_config": {"values": [(2.0, -2.0), (3.0, -3.0)]}, # ['Adam', 'SGD']

#         "sae_l2_norm_bridge": {"values": [False]}, # [True, False]
#         "sae_lif_bridge": {"values": [True]}, # [False, True]
        
#         "accuracy_check_epoch_term": {"values": [5]}, 

#         "lif_add_at_last": {"values": [True, False]},# [True, False]

#         "two_channel_input": {"values": [True, False]},# [True, False]
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  3
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer

#     coarse_com_mode = wandb.config.coarse_com_mode
#     coarse_com_config = wandb.config.coarse_com_config # (max, min)

#     sae_l2_norm_bridge = wandb.config.sae_l2_norm_bridge
#     sae_lif_bridge = wandb.config.sae_lif_bridge

#     accuracy_check_epoch_term = wandb.config.accuracy_check_epoch_term

#     lif_add_at_last = wandb.config.lif_add_at_last

#     two_channel_input = wandb.config.two_channel_input

#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'

#         coarse_com_mode = coarse_com_mode,
#         coarse_com_config = coarse_com_config, # (max, min)
        
#         sae_l2_norm_bridge = sae_l2_norm_bridge,
#         sae_lif_bridge = sae_lif_bridge,

#         accuracy_check_epoch_term = accuracy_check_epoch_term,

#         lif_add_at_last = lif_add_at_last,
        
#         two_channel_input = two_channel_input,
#         )
    
# # sweep_id = 'ygoj9jt4'
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
wandb.finish()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle
import json

# current_time = '20250102_225243_972'

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)


# JSON으로 저장
with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'r') as f:
    loaded_hyperparameters = json.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']
print(data)
max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {loaded_hyperparameters['dataset_num']}, Conv {loaded_hyperparameters['Conv_net']}, SAE {loaded_hyperparameters['SAE_net']}, Current time {loaded_hyperparameters['current_time']}, Spike Length: {loaded_hyperparameters['spike_length']}, Num Cluster: {loaded_hyperparameters['num_cluster']}, "
    f"Training Cycle: {loaded_hyperparameters['training_cycle']}, Batch Size: {loaded_hyperparameters['batch_size']}, Max Epoch: {loaded_hyperparameters['max_epoch']}, \n"
    f"Learning Rate: {loaded_hyperparameters['learning_rate']}, Input Normalize: {loaded_hyperparameters['normalize_on']}, Need Bias: {loaded_hyperparameters['need_bias']}, "
    f"LIF Add at First: {loaded_hyperparameters['lif_add_at_first']}, TIME: {loaded_hyperparameters['TIME']}, Seed: {loaded_hyperparameters['my_seed']}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
# Out:
# {'loss_history': [(0, 0.21351501323593158), (1, 0.023199494164437055), (2, 0.017738570736255496), (3, 0.014975587793936332)], 'mean_cluster_accuracy_during_training_cycle_all_dataset_history': [(0, 71.80803571428571), (1, 62.65625)], 'mean_cluster_accuracy_post_training_cycle_all_dataset_history': [(0, 72.43745413885463), (1, 63.40956149573771)], 'mean_cluster_accuracy_total_all_dataset_history': [(0, 72.18033163752375), (1, 63.10359442680347)]}
