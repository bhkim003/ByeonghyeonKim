# %% [markdown]
# # ssp.train.py

# %%
import torch   
import torch.nn as nn 
import torch.nn.functional as F   
import numpy as np
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
from scipy import io
import itertools
import math
import datetime
import wandb
import pickle
import json
import time

# my module import
from modules import *

# modules 폴더에 새모듈.py 만들면
# modules/__init__py 파일에 form .새모듈 import * 하셈
# 그리고 새모듈.py에서 from modules.새모듈 import * 하셈

# %%
def cluster_train_system( 
    gpu = 3,
    Conv_net = True,
    SAE_net = True,

    # hyperparameter
    dataset_num = 16,
    spike_length = 50,
    num_cluster = 4,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = 2400, # 그 초기 몇개까지만 cluster update할지


    batch_size = 32,
    max_epoch = 7000,
    learning_rate = 0.001,
    normalize_on = False, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = False,
    # first_layer_no_train = False
    lif_add_at_first = False,
    my_seed = 42,

    TIME = 10, # SAE일 때만 유효
    v_decay = 0.5,
    v_threshold = 0.5,
    v_reset = 10000.0, # 10000이상 일 시 hard reset
    BPTT_on = True,

    SAE_hidden_nomean = True,
    current_time = '20250101_210938_786',

    optimizer = 'Adam',
    coarse_com_mode = True,
    coarse_com_config = (2.0, -2.0), # (max, min)

    sae_l2_norm_bridge = True,
    sae_lif_bridge = False,

    accuracy_check_epoch_term = 5,
    
    lif_add_at_last = False,

    two_channel_input = False,
    ):
    if coarse_com_mode == True:
        assert coarse_com_config[0] > coarse_com_config[1], 'coarse_com_config[0] > coarse_com_config[1]이어야 함'
        assert SAE_net == True, 'coarse_com_mode는 SAE_net이 True일 때만 가능'

    if two_channel_input == True:
        assert Conv_net and coarse_com_mode, 'two_channel_input는 Conv_net이 True일 때만 가능'

    seed_assign(my_seed)
    ## 함수 내 모든 로컬 변수 저장 ########################################################
    hyperparameters = locals()
    print(hyperparameters)
    # JSON으로 저장
    with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'w') as f:
        json.dump(hyperparameters, f, indent=4)
    ######################################################################################

    
    wandb.config.update(hyperparameters)
    wandb.run.name = f'{current_time}_SAE_net_{SAE_net}_v_threshold_{v_threshold}'
    wandb.define_metric("best_mean_cluster_accuracy_post_training_cycle_all_dataset2", summary="max")


    my_path_ground_BH = '/data2/spike_sorting/quiroga/BH/'


    filename = ["C_Easy1_noise005.mat", "C_Easy1_noise01.mat", "C_Easy1_noise015.mat", "C_Easy1_noise02.mat",
                "C_Easy2_noise005.mat", "C_Easy2_noise01.mat", "C_Easy2_noise015.mat", "C_Easy2_noise02.mat",
                "C_Difficult1_noise005.mat", "C_Difficult1_noise01.mat", "C_Difficult1_noise015.mat", "C_Difficult1_noise02.mat",
                "C_Difficult2_noise005.mat", "C_Difficult2_noise01.mat", "C_Difficult2_noise015.mat", "C_Difficult2_noise02.mat"]


    spike_tot = ["BH_Spike_e1n005.npy", "BH_Spike_e1n010.npy", "BH_Spike_e1n015.npy", "BH_Spike_e1n020.npy",
                "BH_Spike_e2n005.npy", "BH_Spike_e2n010.npy", "BH_Spike_e2n015.npy", "BH_Spike_e2n020.npy",
                "BH_Spike_d1n005.npy", "BH_Spike_d1n010.npy", "BH_Spike_d1n015.npy", "BH_Spike_d1n020.npy",
                "BH_Spike_d2n005.npy", "BH_Spike_d2n010.npy", "BH_Spike_d2n015.npy", "BH_Spike_d2n020.npy"]

    label_tot = ["BH_Label_e1n005.npy", "BH_Label_e1n010.npy", "BH_Label_e1n015.npy", "BH_Label_e1n020.npy",
                "BH_Label_e2n005.npy", "BH_Label_e2n010.npy", "BH_Label_e2n015.npy", "BH_Label_e2n020.npy",
                "BH_Label_d1n005.npy", "BH_Label_d1n010.npy", "BH_Label_d1n015.npy", "BH_Label_d1n020.npy",
                "BH_Label_d2n005.npy", "BH_Label_d2n010.npy", "BH_Label_d2n015.npy", "BH_Label_d2n020.npy"]

    template =  ["BH_Spike_TEMPLATE_e1n005.npy", "BH_Spike_TEMPLATE_e1n010.npy", "BH_Spike_TEMPLATE_e1n015.npy", "BH_Spike_TEMPLATE_e1n020.npy",
                "BH_Spike_TEMPLATE_e2n005.npy", "BH_Spike_TEMPLATE_e2n010.npy", "BH_Spike_TEMPLATE_e2n015.npy", "BH_Spike_TEMPLATE_e2n020.npy",
                "BH_Spike_TEMPLATE_d1n005.npy", "BH_Spike_TEMPLATE_d1n010.npy", "BH_Spike_TEMPLATE_d1n015.npy", "BH_Spike_TEMPLATE_d1n020.npy",
                "BH_Spike_TEMPLATE_d2n005.npy", "BH_Spike_TEMPLATE_d2n010.npy", "BH_Spike_TEMPLATE_d2n015.npy", "BH_Spike_TEMPLATE_d2n020.npy"]

    AE_train_path_gt_detect = 'BH_quiroga_training_dataset_gt_detect.pt' 
    AE_test_path_gt_detect = 'BH_quiroga_test_dataset_gt_detect.pt'

    AE_train_path_real_detect = 'BH_quiroga_training_dataset_real_detect.pt'
    AE_test_path_real_detect = 'BH_quiroga_test_dataset_real_detect.pt'

    AE_train_data = AE_train_path_real_detect #AE_train_path_gt_detect #AE_train_path_real_detect
    AE_test_data = AE_test_path_real_detect #AE_test_path_gt_detect  #AE_test_path_real_detect

    # thr_tot = np.array([0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7, 0.5, 0.5, 0.55, 0.7])
    cos_thr = np.array([0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.85, 0.95, 0.9, 0.8, 0.95, 0.95, 0.95, 0.95, 0.8])


    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
    os.environ["CUDA_VISIBLE_DEVICES"]= f'{gpu}'


    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


    if coarse_com_mode == True:
        level_num = TIME
        TIME = spike_length
        spike_length = level_num
        level_interval = (coarse_com_config[0] - coarse_com_config[1]) / (level_num-1)  # max - min
        levels = [coarse_com_config[1] + level_interval * i for i in range(level_num)]
        levels = torch.tensor(levels).to(torch.float).to(device)
        levels = levels.repeat(TIME,1) 
        # print('levels', levels, levels.shape) # TIME, level_num

    n_sample = spike_length

    class spikedataset(Dataset):
        def __init__(self, path, transform = None):    
            self.transform = transform
            self.spike = torch.load(path)
            
        def __getitem__(self, index):
            spike = self.spike[index]            
            if self.transform is not None:
                spike = self.transform(spike)
            return spike
        
        def __len__(self):
            return len(self.spike)

    train_dataset = spikedataset(my_path_ground_BH + AE_train_data)
    train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)

    test_dataset = spikedataset(my_path_ground_BH + AE_test_data)
    test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)



    # 모델 초기화
    if SAE_net == False:
        if Conv_net == True:
            input_channels = 2 if two_channel_input else 1
            net = Autoencoder_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
        else:
            net = Autoencoder_only_FC(encoder_ch=[96, 64, 32, 4], decoder_ch=[32,64,96,n_sample], n_sample=n_sample, need_bias=need_bias)
            net = torch.nn.DataParallel(net)
    else:
        if Conv_net == True: 
            input_channels = 2 if two_channel_input else 1
            net = SAE_conv1(input_channels=input_channels, input_length=n_sample, encoder_ch = [32, 64, 96], fc_dim = 4, padding = 0, stride = 2, kernel_size = 3, 
                                synapse_fc_trace_const1=1, 
                                synapse_fc_trace_const2=v_decay, #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)
        else:
            net = SAE_fc_only(encoder_ch=[96, 64, 32, 4], 
                                decoder_ch=[32,64,96,n_sample], 
                                in_channels=n_sample, # in_channel 이 여기선 걍 lenght.
                                synapse_fc_trace_const1=1,
                                synapse_fc_trace_const2=v_decay,  #안씀 
                                TIME=TIME, v_init=0.0, v_decay=v_decay, v_threshold=v_threshold, v_reset=v_reset, 
                                sg_width=4.0, surrogate='sigmoid', BPTT_on=BPTT_on, need_bias=need_bias, lif_add_at_first=lif_add_at_first,
                                sae_l2_norm_bridge = sae_l2_norm_bridge, sae_lif_bridge = sae_lif_bridge, lif_add_at_last=lif_add_at_last)
            net = torch.nn.DataParallel(net)

    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_AE_re_e7000.pth')
    # net = torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250101_210938_786.pth')
    # load했으면 torch.nn.DataParallel 하지마
    # net.module.load_state_dict(torch.load('/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/net_save/save_now_net_20250108_125822_284.pth'))




    wandb.watch(net, log="all", log_freq = 10)





    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__



    net = net.to(device)
    print(net)
    print('Device:',device)

    
    if optimizer == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9)
    else:
        assert False, 'optimizer를 잘못 입력했습니다.'
        
    loss_history = []
    mean_cluster_accuracy_during_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_post_training_cycle_all_dataset_history = []
    mean_cluster_accuracy_total_all_dataset_history = []

    tau = np.zeros(num_cluster)

    print(f"\nStart Training, current_time = {current_time}")
    mean_cluster_accuracy_post_training_cycle_all_dataset = 0
    best_mean_cluster_accuracy_post_training_cycle_all_dataset = 0

    if SAE_net == True:
        assert 'SAE' in net.module.__class__.__name__
    
    for epoch in range(max_epoch):

        ae_train_start_time = time.time()
        running_loss = 0.0
        iter = 0
        net.train()
        for data in train_loader:
            optimizer.zero_grad()
            spike_backup = data
            spike = data
            spike = spike.to(device) # batch, feature
            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                spike = (spike > levels).to(torch.float) 
                # spike: batch, time, level_num
                # levels: time, level_num
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    if two_channel_input == True:
                        spike_backup = spike_backup.to(device)
                        spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_backup = (spike_backup <= levels).to(torch.float) 
                        spike_backup = spike_backup.unsqueeze(-2)
                        spike = torch.cat((spike, spike_backup), dim=-2)
                assert spike.shape[0] == batch_size and spike.shape[1] == TIME
            elif 'SAE' in net.module.__class__.__name__:
                spike = spike.unsqueeze(-1).repeat(1, 1, TIME).permute(0,2,1) # (batch, time, feature)로 변환
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
            else:
                if Conv_net == True:
                    spike = spike.unsqueeze(-2) #batch in_channel,feature

            spike_class = net(spike) # batch, time, feature

            if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                # loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                # loss1 = nn.MSELoss()(spike_class[..., 5:25, :], spike[..., 5:25, :])
                # loss2 = nn.MSELoss()(spike_class[..., 0:5, :], spike[..., 0:5, :])
                # loss3 = nn.MSELoss()(spike_class[..., 25:spike_length, :], spike[..., 25:spike_length, :])
                # loss = loss1 * 2.125 + (loss2 + loss3)/4

                loss = nn.MSELoss()(spike_class, spike)
            elif 'SAE' in net.module.__class__.__name__:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            else:
                loss1 = nn.MSELoss()(spike_class[..., 5:25], spike[..., 5:25])
                loss2 = nn.MSELoss()(spike_class[..., 0:5], spike[..., 0:5])
                loss3 = nn.MSELoss()(spike_class[..., 25:spike_length], spike[..., 25:spike_length])
                loss = loss1 * 2.125 + (loss2 + loss3)/4
                assert spike_length > 25, 'spike_length가 25보다 작음'
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            # print(f'\nepoch-{epoch}, running_loss : {running_loss:.5f}, iter percent {iter/len(train_loader)*100:.2f}%')
            iter += 1
        avg_loss = running_loss / len(train_loader)
        assert not np.isnan(avg_loss), f"Error: avg_loss is NaN! Running loss: {running_loss}, Length of train_loader: {len(train_loader)}"
        loss_history.append((epoch, avg_loss))
        print(f'\nepoch-{epoch} loss : {avg_loss:.5f}')
        print(f"ae train 실행 시간: {time.time()-ae_train_start_time:.3f}초")





        cluster_accuracy_during_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_post_training_cycle_all_dataset = np.zeros(dataset_num)
        cluster_accuracy_total_all_dataset = np.zeros(dataset_num)    

        if(epoch % accuracy_check_epoch_term == 0 or epoch == 1 or epoch == max_epoch-1): 
            accuracy_check_start_time = time.time()
            print(f'\nepoch-{epoch} accuracy check')
            for ds in range(dataset_num):
                # print('\n', spike_tot[ds])

                spike_template = np.load(my_path_ground_BH + template[ds])
                spike = np.load(my_path_ground_BH + spike_tot[ds])
                label = np.load(my_path_ground_BH + label_tot[ds])
                
                hidden_size = 4*TIME if 'SAE' in net.module.__class__.__name__ and SAE_hidden_nomean == True else 4

                Cluster = np.zeros((num_cluster, hidden_size))
                assert Cluster.shape[-1] == hidden_size, '이거 hidden dim 4 아니게 할 거면 잘 바꿔라'
                
                net.eval()
                with torch.no_grad():
                    spike_torch = torch.from_numpy(spike_template).float()
                    spike_backup = spike_torch
                    spike_torch = spike_torch.to(device)
                    if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                        spike_torch = (spike_torch > levels).to(torch.float) 
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                            if two_channel_input == True:
                                spike_backup = spike_backup.to(device)
                                spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                spike_backup = (spike_backup <= levels).to(torch.float) 
                                spike_backup = spike_backup.unsqueeze(-2) # batch, time, in_channel, feature
                                spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                    elif 'SAE' in net.module.__class__.__name__:
                        spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                    else:
                        if Conv_net == True:
                            spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                    inner_inf = net.module.encoder(spike_torch)

                    # if 'SAE' in net.module.__class__.__name__:
                    #     tensors = [inner_inf[0][i] for i in range(TIME)] 
                    #     all_equal = all(torch.equal(tensors[0], t) for t in tensors)
                    #     print(all_equal, inner_inf)

                    if 'SAE' in net.module.__class__.__name__:
                        if SAE_hidden_nomean == True:
                            inner_inf = inner_inf.reshape(spike_template.shape[0],-1)# time*feature 펼치기
                        else:
                            inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균

                    Cluster = inner_inf.cpu().detach().numpy()

                encoder_batch = 128
                spike_hidden = np.zeros((len(spike), hidden_size))
                net.eval()
                with torch.no_grad():
                    now_index = 0
                    while (1):
                        now_end_index = now_index+encoder_batch if now_index+encoder_batch < len(spike) else len(spike)
                        spike_batch = spike[now_index:now_end_index] 
                        spike_torch = torch.from_numpy(spike_batch)
                        spike_torch = spike_torch.float()
                        spike_backup = spike_torch
                        spike_torch = spike_torch.to(device)
                        if coarse_com_mode == True and 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                            spike_torch = (spike_torch > levels).to(torch.float) 
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                                if two_channel_input == True:
                                    spike_backup = spike_backup.to(device)
                                    spike_backup = spike_backup.unsqueeze(2).repeat(1, 1, level_num) # spike_length == level_num # (batch, time, feature)로 변환 
                                    spike_backup = (spike_backup <= levels).to(torch.float) 
                                    spike_backup = spike_backup.unsqueeze(-2)
                                    spike_torch = torch.cat((spike_torch, spike_backup), dim=-2)
                        elif 'SAE' in net.module.__class__.__name__:
                            spike_torch = spike_torch.unsqueeze(1).repeat(1, TIME, 1) # (batch, time, feature)로 변환
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) # batch, time, in_channel, feature or batch in_channel,feature
                        else:
                            if Conv_net == True:
                                spike_torch = spike_torch.unsqueeze(-2) #batch in_channel,feature
                                
                        inner_inf = net.module.encoder(spike_torch)
                        if 'SAE' in net.module.__class__.__name__:
                            if SAE_hidden_nomean == True:
                                inner_inf = inner_inf.reshape(spike_batch.shape[0],-1)# 펼치기
                            else:
                                inner_inf = inner_inf.mean(dim=1)# Time 방향으로 평균
                        spike_hidden[now_index:now_end_index] = inner_inf.cpu().detach().numpy()
                        now_index += encoder_batch
                        if (now_index >= len(spike)):
                            break
                    
                spike_id = np.zeros(len(spike))
                distance_sm = np.zeros(num_cluster)
                tau = np.zeros(num_cluster)
                
                for spike_index in range(len(spike)): 
                    for q in range(num_cluster):
                        tau[q] = np.dot(spike_hidden[spike_index, :], Cluster[q, :]) # 이거 l2norm 거쳐서 나온 거니까 분모 1임.
                        if 'SAE' in net.module.__class__.__name__: # AE 때는 l2norm거쳐서 나와서 괜찮음
                            denominator =  np.linalg.norm(spike_hidden[spike_index, :])*np.linalg.norm(Cluster[q, :]) + 1e-12
                            tau[q] = tau[q] / denominator

                    # for i in range(num_cluster): # l2 distance
                    #     distance_sm[i] = np.sum(np.power(np.abs(Cluster[i] - spike_hidden[spike_index, :]), 2))
                    distance_sm = np.sum(np.power(np.abs(Cluster - spike_hidden[spike_index, :]), 2), axis=1)

                    m = np.argmin(distance_sm)
                    spike_id[spike_index] = m + 1
                    # print(spike_tot[ds], spike_index,np.max(tau))
                    if(np.max(tau) >= cos_thr[ds] and spike_index < training_cycle): # 원래 1400 아니냐?
                        Cluster[m] = (Cluster[m] * 15 + spike_hidden[spike_index, :])/16
                
                # print('Cluster',Cluster)
                # print('spike_id', spike_id)

                # spike id 분포 확인하기
                # unique_elements, counts = np.unique(spike_id, return_counts=True)
                # print("Unique elements:", unique_elements)
                # print("Counts:", counts)

                cluster_accuracy_during_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_post_training_cycle = np.zeros(math.factorial(num_cluster))
                cluster_accuracy_total = np.zeros(math.factorial(num_cluster))
                
                label_converter_ground = list(range(1, num_cluster + 1)) # [1, 2, 3, 4] 생성
                label_converter_permutations = list(itertools.permutations(label_converter_ground)) # 모든 순열 구하기
                perm_i = 0
                perm_start_time = time.time()
                for perm in label_converter_permutations:
                    label_converter = list(perm)
                    # print(label_converter)
                    correct_during_training_cycle = 0
                    correct_post_training_cycle = 0

                    assert len(spike_id) == len(label), 'spike_id랑 label 길이 같아야 됨.'
                    for i in range(len(spike_id)):
                        if(label_converter[int(spike_id[i]-1)] == label[i]):
                            if i < training_cycle:
                                correct_during_training_cycle += 1
                            else:
                                correct_post_training_cycle += 1

                    cluster_accuracy_during_training_cycle[perm_i] = correct_during_training_cycle/training_cycle
                    cluster_accuracy_post_training_cycle[perm_i] = correct_post_training_cycle/(len(spike_id)-training_cycle)
                    cluster_accuracy_total[perm_i] = (correct_during_training_cycle+correct_post_training_cycle)/(len(spike_id))
                    perm_i += 1
                # print(f"perm 실행 시간: {time.time()-perm_start_time:.3f}초")
                
                cluster_accuracy_during_training_cycle_all_dataset[ds] = np.max(cluster_accuracy_during_training_cycle)
                cluster_accuracy_post_training_cycle_all_dataset[ds] = cluster_accuracy_post_training_cycle[np.argmax(cluster_accuracy_during_training_cycle)]
                cluster_accuracy_total_all_dataset[ds] = cluster_accuracy_total[np.argmax(cluster_accuracy_during_training_cycle)]

            print('cluster_accuracy_post_training_cycle_all_dataset', cluster_accuracy_post_training_cycle_all_dataset)

            mean_cluster_accuracy_during_training_cycle_all_dataset = np.mean(cluster_accuracy_during_training_cycle_all_dataset)
            mean_cluster_accuracy_post_training_cycle_all_dataset = np.mean(cluster_accuracy_post_training_cycle_all_dataset)
            mean_cluster_accuracy_total_all_dataset = np.mean(cluster_accuracy_total_all_dataset)
            
            mean_cluster_accuracy_during_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_during_training_cycle_all_dataset*100))
            mean_cluster_accuracy_post_training_cycle_all_dataset_history.append((epoch, mean_cluster_accuracy_post_training_cycle_all_dataset*100))
            mean_cluster_accuracy_total_all_dataset_history.append((epoch, mean_cluster_accuracy_total_all_dataset*100))
            print(f"mean_cluster_accuracy_during_training_cycle : {mean_cluster_accuracy_during_training_cycle_all_dataset*100:.2f}%, post_traincycle_acc : {mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%, total_acc : {mean_cluster_accuracy_total_all_dataset*100:.2f}%")

            if mean_cluster_accuracy_post_training_cycle_all_dataset > best_mean_cluster_accuracy_post_training_cycle_all_dataset:
                # torch.save(net, f"net_save/save_now_net_{current_time}.pth")
                torch.save(net.module.state_dict(), f"net_save/save_now_net_{current_time}.pth")
                print('save model')
                best_mean_cluster_accuracy_post_training_cycle_all_dataset = mean_cluster_accuracy_post_training_cycle_all_dataset
            print(f"best_mean_cluster_accuracy_post_training_cycle_all_dataset : {best_mean_cluster_accuracy_post_training_cycle_all_dataset*100:.2f}%")
            print(f"accuracy_check 실행 시간: {time.time()-accuracy_check_start_time:.3f}초")

        wandb.log({"avg_loss": avg_loss})
        wandb.log({"mean_cluster_accuracy_post_training_cycle_all_dataset": mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset": best_mean_cluster_accuracy_post_training_cycle_all_dataset})
        wandb.log({"best_mean_cluster_accuracy_post_training_cycle_all_dataset2": best_mean_cluster_accuracy_post_training_cycle_all_dataset})


        # 저장
        with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "wb") as f:
            pickle.dump({
                "loss_history": loss_history,
                "mean_cluster_accuracy_during_training_cycle_all_dataset_history": mean_cluster_accuracy_during_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_post_training_cycle_all_dataset_history": mean_cluster_accuracy_post_training_cycle_all_dataset_history,
                "mean_cluster_accuracy_total_all_dataset_history": mean_cluster_accuracy_total_all_dataset_history,
            }, f)

# %%
gpu = 5
Conv_net = True
SAE_net = False

# hyperparameter
dataset_num = 16
spike_length = 50 # coarse_com_mode일 때는 time step이 됨.
num_cluster = 4  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
training_cycle = 2400 #1400 2400 # 그 초기 몇개까지만 cluster update할지


batch_size = 32
max_epoch = 7000
learning_rate = 0.001
normalize_on = False # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
need_bias = False
# first_layer_no_train = False
lif_add_at_first = False
my_seed = 42

TIME = 50 # SAE일 때만 유효. coarse_com_mode일 때는 level_num이 됨. 즉 feature 개수.
v_decay = 0.5 # -cor
v_threshold = 0.5 # -cor
v_reset = 0.0 # -cor # 10000이상 일 시 hard reset
BPTT_on = True # +cor

SAE_hidden_nomean = True # True False

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

optimizer = 'SGD' #'Adam', 'SGD' # 둘다 준수함. loss 줄이는 거는 adam이 좋긴한데, cluster accuracy는 비슷함.

coarse_com_mode = False
coarse_com_config = (2.0, -2.0) # (max, min) (2.0, -2.0) (3.0 -3.0)

sae_l2_norm_bridge = False # True False
sae_lif_bridge = True # False True

accuracy_check_epoch_term = 1
    
lif_add_at_last = False # True False

two_channel_input = False # True False

wandb.init(project= f'spike_sorting just run',save_code=False)


cluster_train_system( 
    gpu = gpu,
    Conv_net = Conv_net,
    SAE_net = SAE_net,

    # hyperparameter
    dataset_num = dataset_num,
    spike_length = spike_length,
    num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
    training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


    batch_size = batch_size,
    max_epoch = max_epoch,
    learning_rate = learning_rate,
    normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
    need_bias = need_bias,
    # first_layer_no_train = False
    lif_add_at_first = lif_add_at_first,
    my_seed = my_seed,

    TIME = TIME, # SAE일 때만 유효
    v_decay = v_decay,
    v_threshold = v_threshold,
    v_reset = v_reset, # 10000이상 일 시 hard reset
    BPTT_on = BPTT_on,

    SAE_hidden_nomean = SAE_hidden_nomean,
    
    current_time = current_time,

    optimizer = optimizer, #'Adam', 'SGD'

    coarse_com_mode = coarse_com_mode,
    coarse_com_config = coarse_com_config, # (max, min)

    
    sae_l2_norm_bridge = sae_l2_norm_bridge,
    sae_lif_bridge = sae_lif_bridge,

    accuracy_check_epoch_term = accuracy_check_epoch_term,
    
    lif_add_at_last = lif_add_at_last,

    two_channel_input = two_channel_input,
    )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bhkim003 (bhkim003-seoul-national-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/nfs/home/bhkim003/github_folder/ByeonghyeonKim/my_snn/wandb/run-20250108_131101-vp3ohrcu</code>
# Syncing run <strong><a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/vp3ohrcu' target="_blank">summer-totem-228</a></strong> to <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run</a>
#  View run at <a href='https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/vp3ohrcu' target="_blank">https://wandb.ai/bhkim003-seoul-national-university/spike_sorting%20just%20run/runs/vp3ohrcu</a>
# {'gpu': 5, 'Conv_net': True, 'SAE_net': False, 'dataset_num': 16, 'spike_length': 50, 'num_cluster': 4, 'training_cycle': 2400, 'batch_size': 32, 'max_epoch': 7000, 'learning_rate': 0.001, 'normalize_on': False, 'need_bias': False, 'lif_add_at_first': False, 'my_seed': 42, 'TIME': 50, 'v_decay': 0.5, 'v_threshold': 0.5, 'v_reset': 0.0, 'BPTT_on': True, 'SAE_hidden_nomean': True, 'current_time': '20250108_131059_668', 'optimizer': 'SGD', 'coarse_com_mode': False, 'sae_l2_norm_bridge': False, 'sae_lif_bridge': True, 'accuracy_check_epoch_term': 1, 'lif_add_at_last': False, 'two_channel_input': False, 'coarse_com_config': (2.0, -2.0)}
# DataParallel(
#   (module): Autoencoder_conv1(
#     (encoder): Sequential(
#       (0): Conv1d(1, 32, kernel_size=(3,), stride=(2,), bias=False)
#       (1): ReLU()
#       (2): Conv1d(32, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (3): ReLU()
#       (4): Conv1d(64, 96, kernel_size=(3,), stride=(2,), bias=False)
#       (5): ReLU()
#       (6): SSBH_DimChanger_for_fc()
#       (7): Linear(in_features=480, out_features=4, bias=False)
#       (8): SSBH_L2NormLayer()
#     )
#     (decoder): Sequential(
#       (0): Linear(in_features=4, out_features=480, bias=False)
#       (1): ReLU()
#       (2): SSBH_DimChanger_for_conv1()
#       (3): ConvTranspose1d(96, 64, kernel_size=(3,), stride=(2,), bias=False)
#       (4): ReLU()
#       (5): ConvTranspose1d(64, 32, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#       (6): ReLU()
#       (7): ConvTranspose1d(32, 1, kernel_size=(3,), stride=(2,), output_padding=(1,), bias=False)
#     )
#   )
# )
# Device: cuda
#
# Start Training, current_time = 20250108_131059_668
#
# epoch-0 loss : 0.12814
# ae train 실행 시간: 10.421초
#
# epoch-0 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.97058824 0.97028784 0.95344507 0.97425743 0.92232143
#  0.89614243 0.76465364 0.95116989 0.91125954 0.8125     0.70414201
#  0.95228216 0.94067797 0.86346154 0.7621226 ]
# mean_cluster_accuracy_during_training_cycle : 89.16%, post_traincycle_acc : 89.54%, total_acc : 89.27%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.54%
# accuracy_check 실행 시간: 6.195초
#
# epoch-1 loss : 0.04091
# ae train 실행 시간: 10.119초
#
# epoch-1 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97576302 0.9741533  0.96843083 0.95623836 0.97425743 0.92410714
#  0.89812067 0.75843694 0.95727365 0.90935115 0.84701493 0.47830375
#  0.94917012 0.94161959 0.85865385 0.77584629]
# mean_cluster_accuracy_during_training_cycle : 87.96%, post_traincycle_acc : 88.42%, total_acc : 88.10%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.54%
# accuracy_check 실행 시간: 6.430초
#
# epoch-2 loss : 0.03688
# ae train 실행 시간: 10.044초
#
# epoch-2 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97576302 0.9741533  0.96843083 0.95623836 0.97425743 0.93125
#  0.90306627 0.77531083 0.95523906 0.91412214 0.83395522 0.46745562
#  0.95020747 0.94161959 0.86442308 0.77310156]
# mean_cluster_accuracy_during_training_cycle : 88.08%, post_traincycle_acc : 88.49%, total_acc : 88.21%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.54%
# accuracy_check 실행 시간: 5.972초
#
# epoch-3 loss : 0.03514
# ae train 실행 시간: 10.100초
#
# epoch-3 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.97504456 0.96935933 0.95530726 0.97425743 0.93392857
#  0.90405539 0.77886323 0.95320448 0.91603053 0.83395522 0.49211045
#  0.95124481 0.93973635 0.85961538 0.77035682]
# mean_cluster_accuracy_during_training_cycle : 87.51%, post_traincycle_acc : 88.65%, total_acc : 87.86%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 89.54%
# accuracy_check 실행 시간: 5.977초
#
# epoch-4 loss : 0.03404
# ae train 실행 시간: 10.191초
#
# epoch-4 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97666068 0.97504456 0.96935933 0.95716946 0.97326733 0.93392857
#  0.90108803 0.78330373 0.95320448 0.91030534 0.83022388 0.79191321
#  0.95228216 0.94161959 0.85576923 0.76852699]
# mean_cluster_accuracy_during_training_cycle : 88.56%, post_traincycle_acc : 90.46%, total_acc : 89.13%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.46%
# accuracy_check 실행 시간: 5.919초
#
# epoch-5 loss : 0.03326
# ae train 실행 시간: 9.823초
#
# epoch-5 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97486535 0.9741533  0.96935933 0.95623836 0.97326733 0.93928571
#  0.90801187 0.78596803 0.95523906 0.89503817 0.82742537 0.51282051
#  0.95124481 0.94161959 0.84519231 0.77218664]
# mean_cluster_accuracy_during_training_cycle : 87.38%, post_traincycle_acc : 88.64%, total_acc : 87.76%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.46%
# accuracy_check 실행 시간: 5.927초
#
# epoch-6 loss : 0.03267
# ae train 실행 시간: 9.956초
#
# epoch-6 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97666068 0.97504456 0.96935933 0.95623836 0.97326733 0.9375
#  0.90702275 0.78774423 0.95422177 0.91603053 0.82835821 0.7800789
#  0.95228216 0.94538606 0.85288462 0.76303751]
# mean_cluster_accuracy_during_training_cycle : 88.86%, post_traincycle_acc : 90.47%, total_acc : 89.34%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.47%
# accuracy_check 실행 시간: 5.647초
#
# epoch-7 loss : 0.03222
# ae train 실행 시간: 10.457초
#
# epoch-7 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97576302 0.9741533  0.96935933 0.95810056 0.97326733 0.93928571
#  0.90702275 0.79484902 0.95320448 0.90076336 0.83022388 0.79191321
#  0.95228216 0.94444444 0.85576923 0.75388838]
# mean_cluster_accuracy_during_training_cycle : 88.85%, post_traincycle_acc : 90.46%, total_acc : 89.34%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.47%
# accuracy_check 실행 시간: 5.888초
#
# epoch-8 loss : 0.03178
# ae train 실행 시간: 9.626초
#
# epoch-8 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97504456 0.96935933 0.95623836 0.97326733 0.94017857
#  0.90999011 0.79307282 0.95116989 0.90553435 0.81436567 0.79487179
#  0.95435685 0.94256121 0.84038462 0.74931382]
# mean_cluster_accuracy_during_training_cycle : 89.05%, post_traincycle_acc : 90.30%, total_acc : 89.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.47%
# accuracy_check 실행 시간: 5.813초
#
# epoch-9 loss : 0.03143
# ae train 실행 시간: 9.826초
#
# epoch-9 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.9741533  0.96935933 0.95903166 0.97227723 0.94196429
#  0.90900099 0.79662522 0.95523906 0.90839695 0.79664179 0.81262327
#  0.9533195  0.94538606 0.85769231 0.75022873]
# mean_cluster_accuracy_during_training_cycle : 89.11%, post_traincycle_acc : 90.50%, total_acc : 89.52%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.50%
# accuracy_check 실행 시간: 6.032초
#
# epoch-10 loss : 0.03112
# ae train 실행 시간: 9.794초
#
# epoch-10 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.9741533  0.96935933 0.95716946 0.97227723 0.94196429
#  0.90999011 0.80284192 0.95320448 0.89599237 0.79570896 0.81065089
#  0.9533195  0.94067797 0.84807692 0.75114364]
# mean_cluster_accuracy_during_training_cycle : 88.71%, post_traincycle_acc : 90.34%, total_acc : 89.20%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.50%
# accuracy_check 실행 시간: 7.263초
#
# epoch-11 loss : 0.03082
# ae train 실행 시간: 9.910초
#
# epoch-11 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.97028784 0.95996276 0.97227723 0.94285714
#  0.91097923 0.80639432 0.95523906 0.90171756 0.79011194 0.78402367
#  0.95539419 0.9472693  0.85865385 0.74473925]
# mean_cluster_accuracy_during_training_cycle : 89.26%, post_traincycle_acc : 90.34%, total_acc : 89.58%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.50%
# accuracy_check 실행 시간: 5.994초
#
# epoch-12 loss : 0.03056
# ae train 실행 시간: 9.443초
#
# epoch-12 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.9741533  0.96935933 0.95996276 0.97128713 0.94285714
#  0.91196835 0.80284192 0.95218718 0.89217557 0.81436567 0.81952663
#  0.95435685 0.94915254 0.85096154 0.76578225]
# mean_cluster_accuracy_during_training_cycle : 89.42%, post_traincycle_acc : 90.68%, total_acc : 89.79%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.68%
# accuracy_check 실행 시간: 5.609초
#
# epoch-13 loss : 0.03035
# ae train 실행 시간: 9.507초
#
# epoch-13 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.97028784 0.96089385 0.97227723 0.94107143
#  0.91295747 0.80017762 0.95116989 0.89217557 0.79011194 0.8086785
#  0.95435685 0.94915254 0.86153846 0.76761208]
# mean_cluster_accuracy_during_training_cycle : 89.27%, post_traincycle_acc : 90.54%, total_acc : 89.65%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.68%
# accuracy_check 실행 시간: 7.423초
#
# epoch-14 loss : 0.03014
# ae train 실행 시간: 10.278초
#
# epoch-14 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96935933 0.95996276 0.97128713 0.94196429
#  0.91493571 0.80817052 0.95218718 0.89503817 0.78171642 0.81065089
#  0.9533195  0.95009416 0.84615385 0.77493138]
# mean_cluster_accuracy_during_training_cycle : 89.40%, post_traincycle_acc : 90.53%, total_acc : 89.73%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.68%
# accuracy_check 실행 시간: 7.551초
#
# epoch-15 loss : 0.02991
# ae train 실행 시간: 9.858초
#
# epoch-15 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.97028784 0.96089385 0.97128713 0.94196429
#  0.91493571 0.80461812 0.95218718 0.89694656 0.80037313 0.82248521
#  0.95435685 0.95009416 0.86346154 0.77218664]
# mean_cluster_accuracy_during_training_cycle : 89.54%, post_traincycle_acc : 90.82%, total_acc : 89.92%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.82%
# accuracy_check 실행 시간: 6.023초
#
# epoch-16 loss : 0.02974
# ae train 실행 시간: 10.257초
#
# epoch-16 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97755835 0.97504456 0.97028784 0.95996276 0.97128713 0.94285714
#  0.91691395 0.80461812 0.95930824 0.89408397 0.78451493 0.82149901
#  0.95435685 0.94915254 0.86346154 0.78682525]
# mean_cluster_accuracy_during_training_cycle : 89.47%, post_traincycle_acc : 90.82%, total_acc : 89.87%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.82%
# accuracy_check 실행 시간: 5.892초
#
# epoch-17 loss : 0.02956
# ae train 실행 시간: 9.575초
#
# epoch-17 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96935933 0.95996276 0.97128713 0.94285714
#  0.91493571 0.79928952 0.95116989 0.89312977 0.7994403  0.81952663
#  0.95435685 0.94915254 0.86057692 0.76852699]
# mean_cluster_accuracy_during_training_cycle : 89.39%, post_traincycle_acc : 90.67%, total_acc : 89.77%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.82%
# accuracy_check 실행 시간: 5.946초
#
# epoch-18 loss : 0.02940
# ae train 실행 시간: 10.119초
#
# epoch-18 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.95996276 0.97128713 0.94107143
#  0.91790307 0.80284192 0.95015259 0.88931298 0.79197761 0.81854043
#  0.95643154 0.95009416 0.85865385 0.78682525]
# mean_cluster_accuracy_during_training_cycle : 89.47%, post_traincycle_acc : 90.74%, total_acc : 89.85%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.82%
# accuracy_check 실행 시간: 6.020초
#
# epoch-19 loss : 0.02923
# ae train 실행 시간: 9.720초
#
# epoch-19 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96182495 0.97128713 0.94107143
#  0.91889219 0.80195382 0.95116989 0.88454198 0.77705224 0.81952663
#  0.95643154 0.95480226 0.86538462 0.79414456]
# mean_cluster_accuracy_during_training_cycle : 89.26%, post_traincycle_acc : 90.76%, total_acc : 89.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.82%
# accuracy_check 실행 시간: 6.375초
#
# epoch-20 loss : 0.02912
# ae train 실행 시간: 10.567초
#
# epoch-20 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96182495 0.97128713 0.94196429
#  0.91790307 0.80639432 0.95015259 0.89408397 0.7994403  0.82149901
#  0.95643154 0.95009416 0.86346154 0.78499543]
# mean_cluster_accuracy_during_training_cycle : 89.72%, post_traincycle_acc : 90.89%, total_acc : 90.07%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.89%
# accuracy_check 실행 시간: 6.234초
#
# epoch-21 loss : 0.02897
# ae train 실행 시간: 10.655초
#
# epoch-21 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96089385 0.97128713 0.94196429
#  0.91988131 0.80817052 0.94608342 0.88931298 0.79477612 0.82544379
#  0.95643154 0.95103578 0.87307692 0.78865508]
# mean_cluster_accuracy_during_training_cycle : 89.49%, post_traincycle_acc : 90.94%, total_acc : 89.92%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.94%
# accuracy_check 실행 시간: 6.558초
#
# epoch-22 loss : 0.02888
# ae train 실행 시간: 9.856초
#
# epoch-22 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96089385 0.97128713 0.94107143
#  0.91889219 0.80461812 0.93387589 0.88835878 0.78451493 0.81952663
#  0.95746888 0.95386064 0.86730769 0.78956999]
# mean_cluster_accuracy_during_training_cycle : 89.73%, post_traincycle_acc : 90.71%, total_acc : 90.02%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 90.94%
# accuracy_check 실행 시간: 6.511초
#
# epoch-23 loss : 0.02874
# ae train 실행 시간: 9.598초
#
# epoch-23 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96275605 0.97128713 0.94285714
#  0.92087043 0.80994671 0.95116989 0.89217557 0.81156716 0.82642998
#  0.95643154 0.9566855  0.86923077 0.79871912]
# mean_cluster_accuracy_during_training_cycle : 89.94%, post_traincycle_acc : 91.21%, total_acc : 90.32%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.21%
# accuracy_check 실행 시간: 6.562초
#
# epoch-24 loss : 0.02862
# ae train 실행 시간: 9.509초
#
# epoch-24 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96275605 0.97227723 0.94107143
#  0.91493571 0.80195382 0.92268566 0.89312977 0.79850746 0.82051282
#  0.95643154 0.95103578 0.86442308 0.78591034]
# mean_cluster_accuracy_during_training_cycle : 89.82%, post_traincycle_acc : 90.68%, total_acc : 90.07%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.21%
# accuracy_check 실행 시간: 6.476초
#
# epoch-25 loss : 0.02851
# ae train 실행 시간: 9.819초
#
# epoch-25 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96089385 0.97227723 0.94196429
#  0.91592483 0.80639432 0.95116989 0.89217557 0.81343284 0.8234714
#  0.95850622 0.9566855  0.87211538 0.78774016]
# mean_cluster_accuracy_during_training_cycle : 89.86%, post_traincycle_acc : 91.10%, total_acc : 90.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.21%
# accuracy_check 실행 시간: 7.490초
#
# epoch-26 loss : 0.02843
# ae train 실행 시간: 10.476초
#
# epoch-26 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96182495 0.97227723 0.94375
#  0.91790307 0.80639432 0.95015259 0.89694656 0.81436567 0.82642998
#  0.95539419 0.9566855  0.875      0.80329369]
# mean_cluster_accuracy_during_training_cycle : 89.97%, post_traincycle_acc : 91.27%, total_acc : 90.36%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.27%
# accuracy_check 실행 시간: 5.879초
#
# epoch-27 loss : 0.02828
# ae train 실행 시간: 10.267초
#
# epoch-27 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96275605 0.97227723 0.94107143
#  0.91790307 0.80817052 0.93489318 0.89312977 0.7891791  0.82445759
#  0.95539419 0.95574388 0.87403846 0.80237877]
# mean_cluster_accuracy_during_training_cycle : 89.85%, post_traincycle_acc : 90.96%, total_acc : 90.18%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.27%
# accuracy_check 실행 시간: 5.868초
#
# epoch-28 loss : 0.02819
# ae train 실행 시간: 10.393초
#
# epoch-28 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96089385 0.97227723 0.94375
#  0.91988131 0.81083481 0.93082401 0.89408397 0.81343284 0.81952663
#  0.95746888 0.95762712 0.875      0.81061299]
# mean_cluster_accuracy_during_training_cycle : 90.05%, post_traincycle_acc : 91.17%, total_acc : 90.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.27%
# accuracy_check 실행 시간: 5.847초
#
# epoch-29 loss : 0.02811
# ae train 실행 시간: 10.204초
#
# epoch-29 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96275605 0.97227723 0.94375
#  0.92087043 0.81438721 0.95116989 0.89599237 0.79011194 0.82741617
#  0.95746888 0.95574388 0.88365385 0.81061299]
# mean_cluster_accuracy_during_training_cycle : 89.99%, post_traincycle_acc : 91.30%, total_acc : 90.38%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.30%
# accuracy_check 실행 시간: 6.051초
#
# epoch-30 loss : 0.02800
# ae train 실행 시간: 10.138초
#
# epoch-30 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94375
#  0.92185955 0.81083481 0.92777213 0.89790076 0.8125     0.8234714
#  0.95850622 0.95574388 0.88076923 0.81061299]
# mean_cluster_accuracy_during_training_cycle : 90.20%, post_traincycle_acc : 91.25%, total_acc : 90.51%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.30%
# accuracy_check 실행 시간: 5.863초
#
# epoch-31 loss : 0.02794
# ae train 실행 시간: 10.056초
#
# epoch-31 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96275605 0.97227723 0.94285714
#  0.91988131 0.80994671 0.94811801 0.89885496 0.81623134 0.82938856
#  0.96058091 0.9566855  0.88076923 0.81427264]
# mean_cluster_accuracy_during_training_cycle : 90.07%, post_traincycle_acc : 91.46%, total_acc : 90.48%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 5.995초
#
# epoch-32 loss : 0.02781
# ae train 실행 시간: 10.175초
#
# epoch-32 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94196429
#  0.91790307 0.80373002 0.94404883 0.88454198 0.79011194 0.82642998
#  0.95850622 0.95574388 0.88269231 0.81518756]
# mean_cluster_accuracy_during_training_cycle : 89.78%, post_traincycle_acc : 91.11%, total_acc : 90.18%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 5.931초
#
# epoch-33 loss : 0.02775
# ae train 실행 시간: 9.844초
#
# epoch-33 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96275605 0.97227723 0.94642857
#  0.92087043 0.81172291 0.92675483 0.89408397 0.82649254 0.82445759
#  0.95954357 0.95762712 0.87980769 0.81976212]
# mean_cluster_accuracy_during_training_cycle : 90.29%, post_traincycle_acc : 91.40%, total_acc : 90.62%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 7.368초
#
# epoch-34 loss : 0.02763
# ae train 실행 시간: 9.951초
#
# epoch-34 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97504456 0.96843083 0.96182495 0.97227723 0.94375
#  0.91691395 0.81349911 0.92675483 0.89694656 0.81156716 0.82051282
#  0.95643154 0.95574388 0.87596154 0.81061299]
# mean_cluster_accuracy_during_training_cycle : 90.22%, post_traincycle_acc : 91.16%, total_acc : 90.50%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 5.945초
#
# epoch-35 loss : 0.02758
# ae train 실행 시간: 10.153초
#
# epoch-35 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94553571
#  0.91988131 0.81083481 0.92777213 0.89408397 0.81529851 0.82149901
#  0.95746888 0.95762712 0.88173077 0.81335773]
# mean_cluster_accuracy_during_training_cycle : 90.28%, post_traincycle_acc : 91.26%, total_acc : 90.57%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 6.248초
#
# epoch-36 loss : 0.02753
# ae train 실행 시간: 10.130초
#
# epoch-36 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96368715 0.97227723 0.94464286
#  0.91889219 0.81971581 0.93387589 0.89408397 0.81623134 0.82051282
#  0.96161826 0.95856874 0.88461538 0.82250686]
# mean_cluster_accuracy_during_training_cycle : 90.39%, post_traincycle_acc : 91.45%, total_acc : 90.70%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.46%
# accuracy_check 실행 시간: 5.898초
#
# epoch-37 loss : 0.02743
# ae train 실행 시간: 10.162초
#
# epoch-37 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96089385 0.97227723 0.94375
#  0.91988131 0.81705151 0.95015259 0.89599237 0.81436567 0.82248521
#  0.96058091 0.9613936  0.88461538 0.82250686]
# mean_cluster_accuracy_during_training_cycle : 90.38%, post_traincycle_acc : 91.55%, total_acc : 90.73%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.55%
# accuracy_check 실행 시간: 6.441초
#
# epoch-38 loss : 0.02737
# ae train 실행 시간: 9.247초
#
# epoch-38 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.94553571
#  0.92185955 0.82415631 0.93489318 0.89790076 0.81623134 0.81952663
#  0.96161826 0.95951036 0.88653846 0.82342177]
# mean_cluster_accuracy_during_training_cycle : 90.48%, post_traincycle_acc : 91.55%, total_acc : 90.80%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.55%
# accuracy_check 실행 시간: 6.475초
#
# epoch-39 loss : 0.02729
# ae train 실행 시간: 9.953초
#
# epoch-39 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.94553571
#  0.92087043 0.81527531 0.94608342 0.89599237 0.80317164 0.82149901
#  0.96161826 0.96233522 0.8875     0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 90.52%, post_traincycle_acc : 91.51%, total_acc : 90.82%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.55%
# accuracy_check 실행 시간: 6.358초
#
# epoch-40 loss : 0.02720
# ae train 실행 시간: 10.005초
#
# epoch-40 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96089385 0.97227723 0.94464286
#  0.92087043 0.81793961 0.95218718 0.91793893 0.83022388 0.8234714
#  0.9626556  0.96045198 0.88557692 0.82616651]
# mean_cluster_accuracy_during_training_cycle : 90.65%, post_traincycle_acc : 91.86%, total_acc : 91.01%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 5.964초
#
# epoch-41 loss : 0.02716
# ae train 실행 시간: 9.806초
#
# epoch-41 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94553571
#  0.91889219 0.82149201 0.95015259 0.89885496 0.80410448 0.81459566
#  0.9626556  0.96233522 0.88557692 0.82433669]
# mean_cluster_accuracy_during_training_cycle : 90.63%, post_traincycle_acc : 91.53%, total_acc : 90.90%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.304초
#
# epoch-42 loss : 0.02710
# ae train 실행 시간: 9.736초
#
# epoch-42 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96182495 0.97227723 0.94732143
#  0.91988131 0.81438721 0.95015259 0.89980916 0.80503731 0.82445759
#  0.96058091 0.9613936  0.89038462 0.8179323 ]
# mean_cluster_accuracy_during_training_cycle : 90.60%, post_traincycle_acc : 91.55%, total_acc : 90.88%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 5.995초
#
# epoch-43 loss : 0.02706
# ae train 실행 시간: 9.881초
#
# epoch-43 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96368715 0.97227723 0.94553571
#  0.91889219 0.81083481 0.95015259 0.90171756 0.80597015 0.8234714
#  0.9626556  0.96045198 0.88365385 0.82250686]
# mean_cluster_accuracy_during_training_cycle : 90.59%, post_traincycle_acc : 91.53%, total_acc : 90.87%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.708초
#
# epoch-44 loss : 0.02696
# ae train 실행 시간: 10.346초
#
# epoch-44 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97227723 0.94464286
#  0.91988131 0.81527531 0.94506612 0.89503817 0.80037313 0.81952663
#  0.9626556  0.96045198 0.8875     0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 90.48%, post_traincycle_acc : 91.46%, total_acc : 90.77%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.389초
#
# epoch-45 loss : 0.02692
# ae train 실행 시간: 9.320초
#
# epoch-45 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94375
#  0.91889219 0.81705151 0.95320448 0.89885496 0.80503731 0.82741617
#  0.9626556  0.9613936  0.88461538 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 90.51%, post_traincycle_acc : 91.61%, total_acc : 90.84%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.407초
#
# epoch-46 loss : 0.02686
# ae train 실행 시간: 9.966초
#
# epoch-46 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94464286
#  0.91394659 0.82238011 0.95218718 0.90076336 0.80503731 0.8234714
#  0.96161826 0.96045198 0.88557692 0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 90.47%, post_traincycle_acc : 91.57%, total_acc : 90.79%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.388초
#
# epoch-47 loss : 0.02684
# ae train 실행 시간: 10.218초
#
# epoch-47 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97227723 0.94553571
#  0.91790307 0.8259325  0.95116989 0.90076336 0.80597015 0.82051282
#  0.9626556  0.95951036 0.88653846 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 90.52%, post_traincycle_acc : 91.66%, total_acc : 90.86%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.597초
#
# epoch-48 loss : 0.02675
# ae train 실행 시간: 9.889초
#
# epoch-48 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94375
#  0.91988131 0.8259325  0.9491353  0.89980916 0.80597015 0.81755424
#  0.9626556  0.96233522 0.88557692 0.82799634]
# mean_cluster_accuracy_during_training_cycle : 90.67%, post_traincycle_acc : 91.60%, total_acc : 90.95%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 5.761초
#
# epoch-49 loss : 0.02666
# ae train 실행 시간: 9.649초
#
# epoch-49 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96089385 0.97227723 0.94553571
#  0.92185955 0.8259325  0.95218718 0.90267176 0.80970149 0.82149901
#  0.9626556  0.9613936  0.88653846 0.82342177]
# mean_cluster_accuracy_during_training_cycle : 90.50%, post_traincycle_acc : 91.68%, total_acc : 90.85%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 5.890초
#
# epoch-50 loss : 0.02663
# ae train 실행 시간: 10.451초
#
# epoch-50 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94464286
#  0.92087043 0.82326821 0.95015259 0.90171756 0.80690299 0.82051282
#  0.96161826 0.96233522 0.88653846 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 90.72%, post_traincycle_acc : 91.66%, total_acc : 91.00%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 7.543초
#
# epoch-51 loss : 0.02660
# ae train 실행 시간: 9.906초
#
# epoch-51 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96089385 0.97227723 0.94642857
#  0.92383778 0.8277087  0.95218718 0.90839695 0.80876866 0.81755424
#  0.96161826 0.96233522 0.88557692 0.82616651]
# mean_cluster_accuracy_during_training_cycle : 90.74%, post_traincycle_acc : 91.72%, total_acc : 91.03%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.224초
#
# epoch-52 loss : 0.02654
# ae train 실행 시간: 9.746초
#
# epoch-52 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.94553571
#  0.91691395 0.82238011 0.95218718 0.90935115 0.81436567 0.82741617
#  0.96369295 0.96233522 0.8875     0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 90.59%, post_traincycle_acc : 91.77%, total_acc : 90.94%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 6.625초
#
# epoch-53 loss : 0.02649
# ae train 실행 시간: 9.918초
#
# epoch-53 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97227723 0.94642857
#  0.92284866 0.8268206  0.95116989 0.90935115 0.81063433 0.82544379
#  0.96161826 0.9613936  0.88461538 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 90.74%, post_traincycle_acc : 91.81%, total_acc : 91.06%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.86%
# accuracy_check 실행 시간: 7.958초
#
# epoch-54 loss : 0.02646
# ae train 실행 시간: 9.876초
#
# epoch-54 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.94821429
#  0.92284866 0.8339254  0.95320448 0.90744275 0.81529851 0.8234714
#  0.9626556  0.96233522 0.88942308 0.82616651]
# mean_cluster_accuracy_during_training_cycle : 90.96%, post_traincycle_acc : 91.89%, total_acc : 91.24%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.89%
# accuracy_check 실행 시간: 7.652초
#
# epoch-55 loss : 0.02642
# ae train 실행 시간: 9.962초
#
# epoch-55 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94732143
#  0.9248269  0.8294849  0.95320448 0.90171756 0.81436567 0.82445759
#  0.9626556  0.96516008 0.88942308 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 90.95%, post_traincycle_acc : 91.88%, total_acc : 91.22%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.89%
# accuracy_check 실행 시간: 6.508초
#
# epoch-56 loss : 0.02639
# ae train 실행 시간: 8.796초
#
# epoch-56 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.94642857
#  0.92284866 0.8294849  0.95422177 0.91698473 0.82742537 0.81854043
#  0.96369295 0.9613936  0.88269231 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 90.96%, post_traincycle_acc : 91.96%, total_acc : 91.26%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.96%
# accuracy_check 실행 시간: 6.297초
#
# epoch-57 loss : 0.02631
# ae train 실행 시간: 9.243초
#
# epoch-57 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94821429
#  0.92383778 0.8348135  0.95320448 0.90553435 0.81529851 0.82938856
#  0.96369295 0.96233522 0.88269231 0.82433669]
# mean_cluster_accuracy_during_training_cycle : 91.00%, post_traincycle_acc : 91.87%, total_acc : 91.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 91.96%
# accuracy_check 실행 시간: 6.197초
#
# epoch-58 loss : 0.02625
# ae train 실행 시간: 8.912초
#
# epoch-58 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96182495 0.97227723 0.94732143
#  0.9248269  0.8374778  0.95422177 0.91889313 0.8386194  0.82840237
#  0.96161826 0.96327684 0.88653846 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 90.82%, post_traincycle_acc : 92.19%, total_acc : 91.23%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.19%
# accuracy_check 실행 시간: 6.389초
#
# epoch-59 loss : 0.02623
# ae train 실행 시간: 9.274초
#
# epoch-59 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.94642857
#  0.9248269  0.8268206  0.95116989 0.91030534 0.81529851 0.82544379
#  0.96473029 0.96327684 0.8875     0.83623056]
# mean_cluster_accuracy_during_training_cycle : 90.89%, post_traincycle_acc : 91.93%, total_acc : 91.20%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.19%
# accuracy_check 실행 시간: 7.812초
#
# epoch-60 loss : 0.02619
# ae train 실행 시간: 9.335초
#
# epoch-60 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96368715 0.97128713 0.94821429
#  0.92185955 0.8321492  0.95218718 0.91889313 0.81716418 0.81656805
#  0.96369295 0.96421846 0.8875     0.83623056]
# mean_cluster_accuracy_during_training_cycle : 90.97%, post_traincycle_acc : 91.98%, total_acc : 91.27%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.19%
# accuracy_check 실행 시간: 5.791초
#
# epoch-61 loss : 0.02613
# ae train 실행 시간: 9.182초
#
# epoch-61 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.94821429
#  0.9248269  0.8365897  0.95523906 0.91984733 0.82649254 0.82149901
#  0.96369295 0.96327684 0.88461538 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 90.90%, post_traincycle_acc : 92.09%, total_acc : 91.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.19%
# accuracy_check 실행 시간: 5.842초
#
# epoch-62 loss : 0.02609
# ae train 실행 시간: 9.478초
#
# epoch-62 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.94821429
#  0.92284866 0.8374778  0.95523906 0.91984733 0.8386194  0.83136095
#  0.96161826 0.96421846 0.88846154 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 91.10%, post_traincycle_acc : 92.27%, total_acc : 91.45%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.27%
# accuracy_check 실행 시간: 7.574초
#
# epoch-63 loss : 0.02608
# ae train 실행 시간: 8.902초
#
# epoch-63 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96368715 0.97227723 0.95
#  0.92087043 0.8339254  0.95320448 0.91889313 0.81809701 0.82248521
#  0.96473029 0.96610169 0.88557692 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 91.00%, post_traincycle_acc : 92.06%, total_acc : 91.32%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.27%
# accuracy_check 실행 시간: 5.970초
#
# epoch-64 loss : 0.02602
# ae train 실행 시간: 9.356초
#
# epoch-64 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.9741533  0.96843083 0.96368715 0.97128713 0.94821429
#  0.91988131 0.8365897  0.95523906 0.92843511 0.84328358 0.83136095
#  0.96369295 0.96421846 0.88846154 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 90.96%, post_traincycle_acc : 92.31%, total_acc : 91.37%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.31%
# accuracy_check 실행 시간: 5.919초
#
# epoch-65 loss : 0.02596
# ae train 실행 시간: 9.160초
#
# epoch-65 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96275605 0.97227723 0.94732143
#  0.92878338 0.8321492  0.95727365 0.92175573 0.81716418 0.82642998
#  0.96473029 0.96516008 0.88365385 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 91.29%, post_traincycle_acc : 92.11%, total_acc : 91.53%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.31%
# accuracy_check 실행 시간: 5.952초
#
# epoch-66 loss : 0.02595
# ae train 실행 시간: 9.314초
#
# epoch-66 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.95089286
#  0.92680514 0.8410302  0.95523906 0.91889313 0.8125     0.82840237
#  0.96369295 0.96610169 0.88461538 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 91.22%, post_traincycle_acc : 92.14%, total_acc : 91.49%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.31%
# accuracy_check 실행 시간: 5.737초
#
# epoch-67 loss : 0.02591
# ae train 실행 시간: 9.234초
#
# epoch-67 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96275605 0.97227723 0.95089286
#  0.9248269  0.8401421  0.95930824 0.92461832 0.81809701 0.83037475
#  0.96473029 0.96327684 0.8875     0.83714547]
# mean_cluster_accuracy_during_training_cycle : 91.30%, post_traincycle_acc : 92.24%, total_acc : 91.58%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.31%
# accuracy_check 실행 시간: 5.974초
#
# epoch-68 loss : 0.02587
# ae train 실행 시간: 9.462초
#
# epoch-68 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96275605 0.97128713 0.95
#  0.92383778 0.839254   0.95523906 0.92175573 0.84328358 0.83431953
#  0.96369295 0.96421846 0.88365385 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 91.04%, post_traincycle_acc : 92.33%, total_acc : 91.42%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.33%
# accuracy_check 실행 시간: 5.914초
#
# epoch-69 loss : 0.02583
# ae train 실행 시간: 8.819초
#
# epoch-69 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97128713 0.95089286
#  0.92878338 0.84280639 0.95727365 0.92366412 0.84421642 0.83234714
#  0.96369295 0.96421846 0.88365385 0.83623056]
# mean_cluster_accuracy_during_training_cycle : 91.33%, post_traincycle_acc : 92.40%, total_acc : 91.65%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.40%
# accuracy_check 실행 시간: 5.965초
#
# epoch-70 loss : 0.02580
# ae train 실행 시간: 9.129초
#
# epoch-70 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96275605 0.97128713 0.95178571
#  0.92581602 0.8410302  0.95930824 0.92270992 0.84235075 0.83234714
#  0.96369295 0.96233522 0.88365385 0.83714547]
# mean_cluster_accuracy_during_training_cycle : 91.15%, post_traincycle_acc : 92.36%, total_acc : 91.51%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.40%
# accuracy_check 실행 시간: 6.394초
#
# epoch-71 loss : 0.02577
# ae train 실행 시간: 9.646초
#
# epoch-71 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96275605 0.97128713 0.95089286
#  0.92680514 0.8383659  0.95625636 0.92366412 0.81902985 0.82248521
#  0.96576763 0.96421846 0.88942308 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 90.89%, post_traincycle_acc : 92.19%, total_acc : 91.27%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.40%
# accuracy_check 실행 시간: 6.326초
#
# epoch-72 loss : 0.02574
# ae train 실행 시간: 9.718초
#
# epoch-72 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97227723 0.95267857
#  0.93372898 0.84724689 0.95930824 0.92461832 0.81809701 0.72189349
#  0.96369295 0.96327684 0.8875     0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 90.07%, post_traincycle_acc : 91.68%, total_acc : 90.55%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.40%
# accuracy_check 실행 시간: 6.014초
#
# epoch-73 loss : 0.02569
# ae train 실행 시간: 8.889초
#
# epoch-73 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96275605 0.97128713 0.95089286
#  0.9248269  0.839254   0.95625636 0.92652672 0.84328358 0.83431953
#  0.96576763 0.96327684 0.8875     0.83989021]
# mean_cluster_accuracy_during_training_cycle : 91.21%, post_traincycle_acc : 92.42%, total_acc : 91.57%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.42%
# accuracy_check 실행 시간: 6.017초
#
# epoch-74 loss : 0.02566
# ae train 실행 시간: 9.076초
#
# epoch-74 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97227723 0.95178571
#  0.93273986 0.84724689 0.95829095 0.92652672 0.84421642 0.83431953
#  0.96473029 0.96421846 0.88846154 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 91.27%, post_traincycle_acc : 92.55%, total_acc : 91.65%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 6.027초
#
# epoch-75 loss : 0.02562
# ae train 실행 시간: 9.242초
#
# epoch-75 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96275605 0.97227723 0.95178571
#  0.93076162 0.84280639 0.95625636 0.92366412 0.81529851 0.82642998
#  0.96473029 0.96327684 0.8875     0.83806038]
# mean_cluster_accuracy_during_training_cycle : 91.08%, post_traincycle_acc : 92.23%, total_acc : 91.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 6.120초
#
# epoch-76 loss : 0.02560
# ae train 실행 시간: 9.307초
#
# epoch-76 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97128713 0.95089286
#  0.92284866 0.8410302  0.95727365 0.92366412 0.84514925 0.83136095
#  0.96369295 0.96610169 0.88846154 0.83989021]
# mean_cluster_accuracy_during_training_cycle : 91.25%, post_traincycle_acc : 92.41%, total_acc : 91.60%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 6.202초
#
# epoch-77 loss : 0.02555
# ae train 실행 시간: 9.685초
#
# epoch-77 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.95089286
#  0.92779426 0.84191829 0.95727365 0.92366412 0.81529851 0.83431953
#  0.96576763 0.96516008 0.8875     0.83806038]
# mean_cluster_accuracy_during_training_cycle : 91.52%, post_traincycle_acc : 92.28%, total_acc : 91.75%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 6.188초
#
# epoch-78 loss : 0.02553
# ae train 실행 시간: 9.130초
#
# epoch-78 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96657382 0.96368715 0.97227723 0.95267857
#  0.92680514 0.84635879 0.95829095 0.92557252 0.81716418 0.82544379
#  0.96473029 0.96516008 0.8875     0.83531565]
# mean_cluster_accuracy_during_training_cycle : 91.41%, post_traincycle_acc : 92.26%, total_acc : 91.66%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 5.973초
#
# epoch-79 loss : 0.02550
# ae train 실행 시간: 8.939초
#
# epoch-79 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96368715 0.97128713 0.95267857
#  0.9297725  0.84902309 0.95727365 0.92557252 0.83395522 0.82840237
#  0.96576763 0.96421846 0.8875     0.84080512]
# mean_cluster_accuracy_during_training_cycle : 91.43%, post_traincycle_acc : 92.46%, total_acc : 91.74%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.55%
# accuracy_check 실행 시간: 7.673초
#
# epoch-80 loss : 0.02549
# ae train 실행 시간: 9.149초
#
# epoch-80 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96368715 0.97128713 0.95178571
#  0.93076162 0.84813499 0.95930824 0.92557252 0.84794776 0.82544379
#  0.96576763 0.96610169 0.89134615 0.83989021]
# mean_cluster_accuracy_during_training_cycle : 91.53%, post_traincycle_acc : 92.56%, total_acc : 91.84%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.56%
# accuracy_check 실행 시간: 6.056초
#
# epoch-81 loss : 0.02544
# ae train 실행 시간: 9.299초
#
# epoch-81 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97128713 0.95178571
#  0.92581602 0.84280639 0.95930824 0.92557252 0.8488806  0.83037475
#  0.96680498 0.96421846 0.89038462 0.84263495]
# mean_cluster_accuracy_during_training_cycle : 91.61%, post_traincycle_acc : 92.53%, total_acc : 91.89%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.56%
# accuracy_check 실행 시간: 6.033초
#
# epoch-82 loss : 0.02542
# ae train 실행 시간: 9.164초
#
# epoch-82 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96461825 0.97227723 0.95357143
#  0.9297725  0.84902309 0.95727365 0.92557252 0.81623134 0.82840237
#  0.96576763 0.96610169 0.88846154 0.84354986]
# mean_cluster_accuracy_during_training_cycle : 91.67%, post_traincycle_acc : 92.39%, total_acc : 91.88%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.56%
# accuracy_check 실행 시간: 6.207초
#
# epoch-83 loss : 0.02540
# ae train 실행 시간: 9.048초
#
# epoch-83 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96843083 0.96554935 0.97227723 0.95357143
#  0.93273986 0.84902309 0.95829095 0.92843511 0.83208955 0.83037475
#  0.96576763 0.96704331 0.89134615 0.8462946 ]
# mean_cluster_accuracy_during_training_cycle : 91.64%, post_traincycle_acc : 92.59%, total_acc : 91.92%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.59%
# accuracy_check 실행 시간: 5.969초
#
# epoch-84 loss : 0.02538
# ae train 실행 시간: 9.029초
#
# epoch-84 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97128713 0.95267857
#  0.93076162 0.85257549 0.95930824 0.92748092 0.84048507 0.83037475
#  0.96680498 0.96610169 0.89134615 0.85178408]
# mean_cluster_accuracy_during_training_cycle : 91.72%, post_traincycle_acc : 92.66%, total_acc : 92.00%
# save model
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.66%
# accuracy_check 실행 시간: 5.706초
#
# epoch-85 loss : 0.02533
# ae train 실행 시간: 9.393초
#
# epoch-85 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97227723 0.95267857
#  0.93175074 0.85168739 0.95930824 0.92843511 0.85074627 0.83037475
#  0.96576763 0.96421846 0.8875     0.84263495]
# mean_cluster_accuracy_during_training_cycle : 91.63%, post_traincycle_acc : 92.64%, total_acc : 91.93%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.66%
# accuracy_check 실행 시간: 5.964초
#
# epoch-86 loss : 0.02527
# ae train 실행 시간: 8.849초
#
# epoch-86 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96461825 0.97227723 0.95267857
#  0.9347181  0.85257549 0.96032553 0.92748092 0.83022388 0.83037475
#  0.96680498 0.96798493 0.89134615 0.84446478]
# mean_cluster_accuracy_during_training_cycle : 91.78%, post_traincycle_acc : 92.61%, total_acc : 92.03%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.66%
# accuracy_check 실행 시간: 5.914초
#
# epoch-87 loss : 0.02525
# ae train 실행 시간: 9.103초
#
# epoch-87 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96750232 0.96368715 0.97128713 0.95267857
#  0.92779426 0.84635879 0.95930824 0.92843511 0.82835821 0.82938856
#  0.96680498 0.96516008 0.88846154 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 91.60%, post_traincycle_acc : 92.42%, total_acc : 91.84%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.66%
# accuracy_check 실행 시간: 5.894초
#
# epoch-88 loss : 0.02524
# ae train 실행 시간: 9.030초
#
# epoch-88 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.9741533  0.96935933 0.96461825 0.97128713 0.95357143
#  0.93175074 0.84902309 0.96032553 0.92557252 0.83208955 0.82642998
#  0.96680498 0.96327684 0.89134615 0.84263495]
# mean_cluster_accuracy_during_training_cycle : 91.60%, post_traincycle_acc : 92.51%, total_acc : 91.87%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 92.66%
# accuracy_check 실행 시간: 6.065초
#
# epoch-89 loss : 0.02522
# ae train 실행 시간: 9.393초
#
# epoch-89 accuracy check
# ...
#  0.95153314 0.91296625 0.9664293  0.97519084 0.92630597 0.90532544
#  0.96887967 0.97269303 0.89519231 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.361초
#
# epoch-1577 loss : 0.01852
# ae train 실행 시간: 9.361초
#
# epoch-1577 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95252226 0.91296625 0.9664293  0.97423664 0.92537313 0.90335306
#  0.96784232 0.97269303 0.90192308 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.58%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.325초
#
# epoch-1578 loss : 0.01851
# ae train 실행 시간: 9.409초
#
# epoch-1578 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91474245 0.9664293  0.97423664 0.9244403  0.90335306
#  0.96887967 0.97269303 0.90673077 0.84446478]
# mean_cluster_accuracy_during_training_cycle : 94.29%, post_traincycle_acc : 94.69%, total_acc : 94.41%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.949초
#
# epoch-1579 loss : 0.01849
# ae train 실행 시간: 9.310초
#
# epoch-1579 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91296625 0.9664293  0.97328244 0.92350746 0.90335306
#  0.96784232 0.97175141 0.90288462 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.18%, post_traincycle_acc : 94.56%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.229초
#
# epoch-1580 loss : 0.01850
# ae train 실행 시간: 9.185초
#
# epoch-1580 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.90852575 0.9664293  0.97328244 0.9244403  0.90138067
#  0.96784232 0.97175141 0.89711538 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.19%, post_traincycle_acc : 94.49%, total_acc : 94.28%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.393초
#
# epoch-1581 loss : 0.01852
# ae train 실행 시간: 9.293초
#
# epoch-1581 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91119005 0.9664293  0.97328244 0.92350746 0.90335306
#  0.96887967 0.97269303 0.89807692 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.57%, total_acc : 94.34%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.258초
#
# epoch-1582 loss : 0.01852
# ae train 실행 시간: 9.282초
#
# epoch-1582 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91385435 0.9664293  0.97423664 0.92817164 0.90039448
#  0.96887967 0.97363465 0.90865385 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.32%, post_traincycle_acc : 94.64%, total_acc : 94.42%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.257초
#
# epoch-1583 loss : 0.01851
# ae train 실행 시간: 9.139초
#
# epoch-1583 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.90763766 0.9664293  0.97519084 0.92537313 0.90631164
#  0.96887967 0.97363465 0.89903846 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.59%, total_acc : 94.34%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.367초
#
# epoch-1584 loss : 0.01848
# ae train 실행 시간: 8.933초
#
# epoch-1584 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91385435 0.9664293  0.97423664 0.92630597 0.90335306
#  0.96887967 0.97269303 0.90480769 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.61%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.178초
#
# epoch-1585 loss : 0.01852
# ae train 실행 시간: 8.655초
#
# epoch-1585 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95548961 0.91385435 0.9664293  0.97423664 0.92630597 0.90335306
#  0.96887967 0.97269303 0.9        0.83714547]
# mean_cluster_accuracy_during_training_cycle : 94.30%, post_traincycle_acc : 94.62%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.311초
#
# epoch-1586 loss : 0.01852
# ae train 실행 시간: 8.995초
#
# epoch-1586 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91207815 0.9664293  0.97423664 0.92537313 0.90335306
#  0.96887967 0.97175141 0.89711538 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.56%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.341초
#
# epoch-1587 loss : 0.01853
# ae train 실행 시간: 9.335초
#
# epoch-1587 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95153314 0.91030195 0.9664293  0.97423664 0.9244403  0.90729783
#  0.96887967 0.97269303 0.89903846 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.55%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.554초
#
# epoch-1588 loss : 0.01849
# ae train 실행 시간: 9.240초
#
# epoch-1588 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91474245 0.9664293  0.97423664 0.92537313 0.90236686
#  0.96887967 0.97269303 0.90769231 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 94.35%, post_traincycle_acc : 94.67%, total_acc : 94.44%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.248초
#
# epoch-1589 loss : 0.01852
# ae train 실행 시간: 8.932초
#
# epoch-1589 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91474245 0.9664293  0.97423664 0.92723881 0.90532544
#  0.96887967 0.97269303 0.90673077 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.36%, post_traincycle_acc : 94.67%, total_acc : 94.45%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.350초
#
# epoch-1590 loss : 0.01848
# ae train 실행 시간: 9.146초
#
# epoch-1590 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91207815 0.9664293  0.97614504 0.92537313 0.90631164
#  0.96887967 0.97175141 0.90384615 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.64%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.909초
#
# epoch-1591 loss : 0.01850
# ae train 실행 시간: 9.515초
#
# epoch-1591 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.91474245 0.9664293  0.97328244 0.92350746 0.90236686
#  0.96887967 0.97175141 0.9        0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.265초
#
# epoch-1592 loss : 0.01850
# ae train 실행 시간: 8.762초
#
# epoch-1592 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95252226 0.91296625 0.9664293  0.97328244 0.9244403  0.90335306
#  0.96887967 0.97269303 0.90673077 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.61%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.346초
#
# epoch-1593 loss : 0.01847
# ae train 실행 시간: 9.220초
#
# epoch-1593 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91296625 0.9664293  0.97423664 0.9244403  0.90138067
#  0.96887967 0.97269303 0.90096154 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.23%, post_traincycle_acc : 94.59%, total_acc : 94.34%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.329초
#
# epoch-1594 loss : 0.01849
# ae train 실행 시간: 9.222초
#
# epoch-1594 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91385435 0.9664293  0.97423664 0.92350746 0.90631164
#  0.96887967 0.97080979 0.89711538 0.83165599]
# mean_cluster_accuracy_during_training_cycle : 94.19%, post_traincycle_acc : 94.54%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.338초
#
# epoch-1595 loss : 0.01849
# ae train 실행 시간: 8.727초
#
# epoch-1595 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97593583 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91207815 0.9664293  0.97328244 0.92537313 0.90433925
#  0.96887967 0.97175141 0.89615385 0.83074108]
# mean_cluster_accuracy_during_training_cycle : 94.20%, post_traincycle_acc : 94.54%, total_acc : 94.30%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.390초
#
# epoch-1596 loss : 0.01848
# ae train 실행 시간: 8.898초
#
# epoch-1596 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95548961 0.90941385 0.9664293  0.97423664 0.92537313 0.90631164
#  0.96887967 0.97269303 0.89807692 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.22%, post_traincycle_acc : 94.57%, total_acc : 94.33%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 5.958초
#
# epoch-1597 loss : 0.01851
# ae train 실행 시간: 9.163초
#
# epoch-1597 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95351137 0.91207815 0.9664293  0.97328244 0.92630597 0.90236686
#  0.96887967 0.97269303 0.90480769 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.24%, post_traincycle_acc : 94.62%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.269초
#
# epoch-1598 loss : 0.01851
# ae train 실행 시간: 9.028초
#
# epoch-1598 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91207815 0.9664293  0.97328244 0.92350746 0.90236686
#  0.96887967 0.97175141 0.90576923 0.83348582]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.58%, total_acc : 94.35%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.343초
#
# epoch-1599 loss : 0.01848
# ae train 실행 시간: 9.245초
#
# epoch-1599 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91207815 0.9664293  0.97423664 0.92723881 0.90335306
#  0.96887967 0.97175141 0.90480769 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.26%, post_traincycle_acc : 94.65%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.216초
#
# epoch-1600 loss : 0.01851
# ae train 실행 시간: 9.311초
#
# epoch-1600 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96461825 0.97425743 0.95803571
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92257463 0.90335306
#  0.96784232 0.97269303 0.90673077 0.8389753 ]
# mean_cluster_accuracy_during_training_cycle : 94.28%, post_traincycle_acc : 94.63%, total_acc : 94.38%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.195초
#
# epoch-1601 loss : 0.01851
# ae train 실행 시간: 9.181초
#
# epoch-1601 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96843083 0.96554935 0.97425743 0.95803571
#  0.95252226 0.91385435 0.9664293  0.97423664 0.92723881 0.90532544
#  0.96887967 0.97175141 0.90480769 0.83806038]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.65%, total_acc : 94.39%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.357초
#
# epoch-1602 loss : 0.01849
# ae train 실행 시간: 8.764초
#
# epoch-1602 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97935368 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95548961 0.91563055 0.9664293  0.97423664 0.9244403  0.90236686
#  0.96887967 0.97175141 0.89711538 0.83257091]
# mean_cluster_accuracy_during_training_cycle : 94.19%, post_traincycle_acc : 94.58%, total_acc : 94.31%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.103초
#
# epoch-1603 loss : 0.01847
# ae train 실행 시간: 9.092초
#
# epoch-1603 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95450049 0.91296625 0.9664293  0.97423664 0.92537313 0.90729783
#  0.96887967 0.97175141 0.89711538 0.82982617]
# mean_cluster_accuracy_during_training_cycle : 94.14%, post_traincycle_acc : 94.56%, total_acc : 94.26%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.247초
#
# epoch-1604 loss : 0.01846
# ae train 실행 시간: 8.852초
#
# epoch-1604 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95450049 0.91030195 0.9664293  0.97423664 0.92630597 0.90631164
#  0.96784232 0.97269303 0.89903846 0.83531565]
# mean_cluster_accuracy_during_training_cycle : 94.27%, post_traincycle_acc : 94.60%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.429초
#
# epoch-1605 loss : 0.01848
# ae train 실행 시간: 9.380초
#
# epoch-1605 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95803571
#  0.95351137 0.91207815 0.9664293  0.97423664 0.92630597 0.90335306
#  0.96887967 0.97363465 0.90480769 0.83440073]
# mean_cluster_accuracy_during_training_cycle : 94.25%, post_traincycle_acc : 94.63%, total_acc : 94.36%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.302초
#
# epoch-1606 loss : 0.01848
# ae train 실행 시간: 8.645초
#
# epoch-1606 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96461825 0.97425743 0.95803571
#  0.95746785 0.91385435 0.9664293  0.97614504 0.92350746 0.90433925
#  0.96887967 0.97269303 0.90480769 0.83989021]
# mean_cluster_accuracy_during_training_cycle : 94.32%, post_traincycle_acc : 94.68%, total_acc : 94.43%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.446초
#
# epoch-1607 loss : 0.01848
# ae train 실행 시간: 8.932초
#
# epoch-1607 accuracy check
# cluster_accuracy_post_training_cycle_all_dataset [0.97845601 0.97682709 0.96935933 0.96554935 0.97425743 0.95714286
#  0.95351137 0.91296625 0.9664293  0.97328244 0.9244403  0.90039448
#  0.96784232 0.97175141 0.90096154 0.8252516 ]
# mean_cluster_accuracy_during_training_cycle : 94.21%, post_traincycle_acc : 94.49%, total_acc : 94.29%
# best_mean_cluster_accuracy_post_training_cycle_all_dataset : 94.70%
# accuracy_check 실행 시간: 6.399초

# %%
# # Sweep code


# from unittest import TextTestRunner


# unique_name_hyper = 'cluster_train_system'
# # run_name = 'spike_sorting'
# sweep_start_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"
# sweep_configuration = {
#     'method': 'bayes', # 'random', 'bayes'
#     'name': f'spike_sorting_{sweep_start_time}',
#     'metric': {'goal': 'maximize', 'name': 'best_mean_cluster_accuracy_post_training_cycle_all_dataset'},
#     'parameters': 
#     {
#         # "gpu": {"values": [1]},  # 이건 sweep parameter아님. hyper_iter에서 직접 설정
#         "Conv_net": {"values": [True]}, 
#         "SAE_net": {"values": [True]}, 

#         "dataset_num": {"values": [16]}, 
#         "spike_length": {"values": [50]},  
#         "num_cluster": {"values": [4]}, 
#         "training_cycle": {"values": [1400, 2400]}, # [1400, 2400]

#         "batch_size": {"values": [16,32,48]}, 
#         "max_epoch": {"values": [1]}, 
#         "learning_rate": {"values": [0.001]},
#         "normalize_on": {"values": [False]},
#         "need_bias": {"values": [False]}, 

#         "lif_add_at_first": {"values": [False]}, # [True, False]
#         "my_seed": {"values": [42]}, 

#         "TIME": {"values": [50,40,30,20]}, #  [4,6,8,10]
#         "v_decay": {"values": [0.25,0.50,0.75,0.875]}, # [0.25,0.50,0.75]
#         "v_threshold": {"values": [0.25,0.50,0.75,1.0]}, # [0.25,0.50,0.75]
#         "v_reset": {"values": [0.0, 10000.0]},  # [0.0, 10000.0]
#         "BPTT_on": {"values": [True, False]},  # [True, False]

#         "SAE_hidden_nomean": {"values": [True, False]}, # [True, False]

#         # "current_time": {"values": [current_time]} #밑에서 직접설정됨.

#         "optimizer": {"values": ['Adam', 'SGD']}, # ['Adam', 'SGD']

#         "coarse_com_mode": {"values": [True]}, # ['Adam', 'SGD']
#         "coarse_com_config": {"values": [(2.0, -2.0), (3.0, -3.0)]}, # ['Adam', 'SGD']

#         "sae_l2_norm_bridge": {"values": [False]}, # [True, False]
#         "sae_lif_bridge": {"values": [True]}, # [False, True]
        
#         "accuracy_check_epoch_term": {"values": [5]}, 

#         "lif_add_at_last": {"values": [True, False]},# [True, False]

#         "two_channel_input": {"values": [True, False]},# [True, False]
#      }
# }


# def hyper_iter():
#     ### my_snn control board ########################
#     wandb.init(save_code = False)
#     gpu  =  3
#     Conv_net  =  wandb.config.Conv_net
#     SAE_net  =  wandb.config.SAE_net

#     dataset_num  =  wandb.config.dataset_num
#     spike_length  =  wandb.config.spike_length
#     num_cluster  =  wandb.config.num_cluster
#     training_cycle  =  wandb.config.training_cycle

#     batch_size  =  wandb.config.batch_size
#     max_epoch  =  wandb.config.max_epoch
#     learning_rate  =  wandb.config.learning_rate
#     normalize_on  =  wandb.config.normalize_on
#     need_bias  =  wandb.config.need_bias

#     lif_add_at_first  =  wandb.config.lif_add_at_first
#     my_seed  =  wandb.config.my_seed


#     TIME  =  wandb.config.TIME
#     v_decay  =  wandb.config.v_decay
#     v_threshold  =  wandb.config.v_threshold
#     v_reset  =  wandb.config.v_reset
#     BPTT_on  =  wandb.config.BPTT_on

#     SAE_hidden_nomean  =  wandb.config.SAE_hidden_nomean
    
#     current_time =  datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + f"_{str(int(datetime.datetime.now().microsecond / 1000)).zfill(3)}"

#     optimizer  =  wandb.config.optimizer

#     coarse_com_mode = wandb.config.coarse_com_mode
#     coarse_com_config = wandb.config.coarse_com_config # (max, min)

#     sae_l2_norm_bridge = wandb.config.sae_l2_norm_bridge
#     sae_lif_bridge = wandb.config.sae_lif_bridge

#     accuracy_check_epoch_term = wandb.config.accuracy_check_epoch_term

#     lif_add_at_last = wandb.config.lif_add_at_last

#     two_channel_input = wandb.config.two_channel_input

#     cluster_train_system( 
#         gpu = gpu,
#         Conv_net = Conv_net,
#         SAE_net = SAE_net,

#         # hyperparameter
#         dataset_num = dataset_num,
#         spike_length = spike_length,
#         num_cluster = num_cluster,  # 클러스터 수 설정 # 논문엔 4개라는데 여기서는 3개로 했네
#         training_cycle = training_cycle, # 그 초기 몇개까지만 cluster update할지


#         batch_size = batch_size,
#         max_epoch = max_epoch,
#         learning_rate = learning_rate,
#         normalize_on = normalize_on, # True or False #이거 안 씀 # 이거 별로 안 좋은 normalize같음 # 쓸 거면 다른 거 써라.
#         need_bias = need_bias,
#         # first_layer_no_train = False
#         lif_add_at_first = lif_add_at_first,
#         my_seed = my_seed,

#         TIME = TIME, # SAE일 때만 유효
#         v_decay = v_decay,
#         v_threshold = v_threshold,
#         v_reset = v_reset, # 10000이상 일 시 hard reset
#         BPTT_on = BPTT_on,

#         SAE_hidden_nomean = SAE_hidden_nomean,

#         current_time = current_time,

#         optimizer = optimizer, #'Adam', 'SGD'

#         coarse_com_mode = coarse_com_mode,
#         coarse_com_config = coarse_com_config, # (max, min)
        
#         sae_l2_norm_bridge = sae_l2_norm_bridge,
#         sae_lif_bridge = sae_lif_bridge,

#         accuracy_check_epoch_term = accuracy_check_epoch_term,

#         lif_add_at_last = lif_add_at_last,
        
#         two_channel_input = two_channel_input,
#         )
    
# # sweep_id = 'ygoj9jt4'
# sweep_id = wandb.sweep(sweep=sweep_configuration, project=f'spike_sorting {unique_name_hyper}')
# wandb.agent(sweep_id, function=hyper_iter, count=100000, project=f'spike_sorting {unique_name_hyper}')

# %%
wandb.finish()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pickle
import json

# current_time = '20250102_225243_972'

with open(f"result_save/cluster_accuracy_history_{current_time}.pkl", "rb") as f:
    data = pickle.load(f)


# JSON으로 저장
with open(f"result_save/cluster_accuracy_history_{current_time}.json", 'r') as f:
    loaded_hyperparameters = json.load(f)

loss_history = data['loss_history']
mean_cluster_accuracy_during_training_cycle_all_dataset_history = data['mean_cluster_accuracy_during_training_cycle_all_dataset_history']
mean_cluster_accuracy_post_training_cycle_all_dataset_history = data['mean_cluster_accuracy_post_training_cycle_all_dataset_history']
mean_cluster_accuracy_total_all_dataset_history = data['mean_cluster_accuracy_total_all_dataset_history']
print(data)
max_acc = 0
for i in mean_cluster_accuracy_post_training_cycle_all_dataset_history:
    if i[1] > max_acc:
        max_acc = i[1]

# 설정 정보 제목 작성
title = (
    f"Dataset Num: {loaded_hyperparameters['dataset_num']}, Conv {loaded_hyperparameters['Conv_net']}, SAE {loaded_hyperparameters['SAE_net']}, Current time {loaded_hyperparameters['current_time']}, Spike Length: {loaded_hyperparameters['spike_length']}, Num Cluster: {loaded_hyperparameters['num_cluster']}, "
    f"Training Cycle: {loaded_hyperparameters['training_cycle']}, Batch Size: {loaded_hyperparameters['batch_size']}, Max Epoch: {loaded_hyperparameters['max_epoch']}, \n"
    f"Learning Rate: {loaded_hyperparameters['learning_rate']}, Input Normalize: {loaded_hyperparameters['normalize_on']}, Need Bias: {loaded_hyperparameters['need_bias']}, "
    f"LIF Add at First: {loaded_hyperparameters['lif_add_at_first']}, TIME: {loaded_hyperparameters['TIME']}, Seed: {loaded_hyperparameters['my_seed']}, Best ACC: {max_acc:.2f}%"
)

# 데이터 리스트와 라벨 설정 (Loss 제외)
data_list = [
    ("Mean Cluster Accuracy (During Training Cycle)", mean_cluster_accuracy_during_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Post Training Cycle)", mean_cluster_accuracy_post_training_cycle_all_dataset_history),
    ("Mean Cluster Accuracy (Total)", mean_cluster_accuracy_total_all_dataset_history),
]

# 플롯 생성
fig, ax1 = plt.subplots(figsize=(12, 8))

# 첫 번째 y축: Accuracy 관련 데이터
for label, data in data_list:
    epochs, values = zip(*data)  # epoch, value 분리
    ax1.plot(epochs, values, label=label)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Clurstering Accuracy [%]", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.legend(loc="center right")
ax1.grid(True)

# x축을 정수만 표시하도록 설정
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# 두 번째 y축: Loss History
ax2 = ax1.twinx()
epochs, values = zip(*loss_history)
ax2.plot(epochs, values, label="AE Loss History", color="red", linestyle="--")
ax2.set_ylabel("Loss", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.legend(loc="center left")

# 제목 추가
plt.title(title, fontsize=10)
plt.tight_layout()
plt.savefig(f'net_save/{current_time}', dpi=300, bbox_inches="tight")  # dpi=300은 고해상도로 저장, bbox_inches="tight"는 여백 최소화
plt.show()
# Out:
# {'loss_history': [(0, 0.21351501323593158), (1, 0.023199494164437055), (2, 0.017738570736255496), (3, 0.014975587793936332)], 'mean_cluster_accuracy_during_training_cycle_all_dataset_history': [(0, 71.80803571428571), (1, 62.65625)], 'mean_cluster_accuracy_post_training_cycle_all_dataset_history': [(0, 72.43745413885463), (1, 63.40956149573771)], 'mean_cluster_accuracy_total_all_dataset_history': [(0, 72.18033163752375), (1, 63.10359442680347)]}
